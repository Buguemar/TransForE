# %%
from tools_stance import * 
from transformer_class_SMOTE import *
from models import *
import torch 
from scipy.stats import ortho_group  # Requires version 0.18 of scipy
import gc
from imblearn.over_sampling import SMOTE
import pandas as pd
import gc
import seaborn 


keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")


keys=["commenting", "support", "denying", "questioning"]


dict_cl=dict()
dict_cl[0]="support"
dict_cl[1]="denying"
dict_cl[2]="questioning"
dict_cl[3]="commenting"

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

path="../../Datasets/CSV_Stance/"
train =pd.read_csv(path + "train_semeval_raw.csv")
val=pd.read_csv(path + "dev_semeval_raw.csv")
test=pd.read_csv(path + "test_semeval_raw.csv")

stoplist = stopwords.words("english")
puntos='!?."()[´]“<>¡¿-/;:=_”@#.'
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
def cm_norma(matrix):
    return matrix/matrix.sum(axis=-1, keepdims=True)
    
    
def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    """print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)"""
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    """print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################"""
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

def cleaner(post): 
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=token_2_idx[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in token_2_idx.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in token_2_idx.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
import os 
embeddings_index = {}
token_2_idx={}
idx_2_token={}
f = open(os.path.join("../../Datasets/glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
i=0
for line in f:
    values = line.split()
    if len(values)>200:
        word = values[0]
    else:
        #print ("Problema con line ", line)
        continue
    token_2_idx[word]=i
    idx_2_token[i]=word
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
    i+=1
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# Se encontraron 1193513 terminos con sus vectores de embedding.

# %%
MAX_LEN = 34
emb=200
EMB_matrix=np.zeros((len(token_2_idx.keys()), emb))
for i in range(len(token_2_idx.keys())):
    EMB_matrix[i]=embeddings_index[idx_2_token[i]]
    
transformer = Normalizer().fit(EMB_matrix) 
EMB_matrix=transformer.transform(EMB_matrix)
EMB_matrix.shape
# Out:
# (1193513, 200)

# %%
ids_train=train['Tw_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights= [1.0, 1.0, 1.0, 1.0]
#class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)

ids_val=val['Tw_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

ids_test=test['Tw_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]
# Out:
# Pesos de clases: [1.0, 1.0, 1.0, 1.0]

# %%
sentences = tws_train
n_labels = np.asarray(labels_train)
y_train=to_categorical(n_labels,num_classes=4)

sentences_val = tws_val
n_labels_val = np.array(labels_val)
y_val=to_categorical(n_labels_val,num_classes=4)

sentences_test = tws_test
n_labels_test = np.array(labels_test)
y_test=to_categorical(n_labels_test,num_classes=4)

# %%
input_ids=[]
for sent in sentences:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids.append(encoded_sent) 
    
input_ids_val=[]
for sent in sentences_val:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_val.append(encoded_sent) 

input_ids_test=[]
for sent in sentences_test:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_test.append(encoded_sent)

# %%
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
shape_val=np.asarray(input_ids_val).shape
shape_test=np.asarray(input_ids_test).shape

# %%
x_train=np.zeros((shape[0], emb))
i=0
for in_id in input_ids:
    vector=np.zeros(emb)
    n = np.sum(in_id != 0)
    if n==0:
        x_train[i]=vector
        i+=1
        continue
        
    else:
        for idv in in_id:
            if idv!=0:
                vector+=EMB_matrix[idv]
        x_train[i]=(vector/n)
        i+=1   
    
x_val=np.zeros((shape_val[0], emb))
i=0
for in_id in input_ids_val:
    vector=np.zeros(emb)
    n = np.sum(in_id != 0)
    for idv in in_id:
        if idv!=0:
            vector+=EMB_matrix[idv]
    x_val[i]=(vector/n)
    i+=1  
    
x_test=np.zeros((shape_test[0], emb))
i=0
for in_id in input_ids_test:
    vector=np.zeros(emb)
    n = np.sum(in_id != 0)
    for idv in in_id:
        if idv!=0:
            vector+=EMB_matrix[idv]
    x_test[i]=(vector/n)
    i+=1

# %%
x_train.shape
# Out:
# (4238, 200)

# %%
x_test.shape
# Out:
# (1021, 200)

# %%
def predecir_modelos(bs,predichos_all):  #best fit
    temp=predichos_all.copy()
    final=[np.argmax(pred) for pred in temp]  
    confianzas=[temp[i][final[i]] for i in range(len(final))]
    predichos_new=[]
    for i in range(len(temp)):
        indice=final[i]%4
        predichos_new.append(int(indice))
    return predichos_new,final,confianzas    

def predecir_modelos_norm(bs,predichos_all):  #normalizado
    temp=predichos_all.copy()
    final=[]
    confianzas=[]
    for pred in temp:   
        aux=np.ones(4)
        for i in range(1,6): #for machine pred
            sub=pred[(4*(i-1)):(4*i)]
            aux=aux*np.asarray(sub)
            
        aux=aux/np.sum(aux)
        final.append(np.argmax(aux))
        confianzas.append(aux[np.argmax(aux)])  
           
    predichos_new=[]
    for i in range(len(temp)):
        predichos_new.append(final[i])
    return predichos_new,final,confianzas
    
def predecir_modelos_average(bs,predichos_all): #average
    temp=predichos_all.copy()
    final=[]
    confianzas=[]
    for pred in temp:
        aux=np.zeros(4)
        for i in range(1,6):
            sub=pred[(4*(i-1)):(4*i)]
            aux=aux+np.asarray(sub)
            
        aux=aux/5.0 #dividido en el total de machines
        final.append(np.argmax(aux))
        confianzas.append(aux[np.argmax(aux)])  
           
    predichos_new=[]
    for i in range(len(temp)):
        predichos_new.append(final[i])
    return predichos_new,final,confianzas

# %%
etiq=np.asarray(labels_train)
etiq_v=np.asarray(labels_val)
etiq_t=np.asarray(labels_test)

# %%
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def data_gen(batch_size,mode, x_train, lab_str_embeddings, index_embeddings):
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=x_train.shape[0]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=x_val.shape[0] 
        x_list=np.arange(max_objs)
        x_list=[x+x_train.shape[0] for x in x_list]   
        objs=val['Tw_id']    #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels)  
    if mode=='Test':
        max_objs=x_test.shape[0] 
        x_list=np.arange(max_objs)
        x_list=[x+x_train.shape[0]+x_val.shape[0] for x in x_list]
        total=x_train.shape[0]+x_val.shape[0]
        objs=test['Tw_id']
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
            
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        temp=[]
        for pos in batch:
            temp2=[index_embeddings[pos+5]]  
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for conjunto in range(len(new_x_data)):
            batch=new_x_data[conjunto]
            temp_y=[]
            for linea in range(len(batch)):
                indice=x_data[conjunto][linea]  #pos
                lab=d_lab[lab_str_embeddings[indice+5]]+1 #labels_train
                temp_y.append([lab])       
            y_data.append(temp_y)
            
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    #print ("primer batch X.Y", new_x_data[0], y_data[0])
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)

def make_model_concat(target, K_list_new, N=2, d_model=768, d_ff=1024, h=4, dropout=0.3, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                #print ("batch.src_mask en run epoch", batch.src_mask)
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).numpy())
                #la loss del batch es sobre todos los ejemplos o es promedio en batch?
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            #print ("BATCH\n", i, '\n', batch.src)
            out = model.forward(batch.src, batch.src_mask)
            #print ("OUT DE RUN EPOCH", out)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last


def draw(data, ax, label, color="Blues"):
    seaborn.heatmap(data, 
                    xticklabels=label[0], square=True, yticklabels=label[0], vmin=0.0, vmax=1.0, 
                    cbar=False,  cmap=color, ax=ax)

# %%
etiq_v= n_labels_val
etiq_t= n_labels_test

# %%
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):
        y_new=(y.float()-torch.ones((y.shape))).int() 
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()    
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
        # loss.data[0] * norm

# %%
from bert_serving.client import BertClient
import seaborn 

def draw(data, ax, label, color="Blues"):
    seaborn.heatmap(data, 
                    xticklabels=label[0], square=True, yticklabels=label[0], vmin=0.0, vmax=1.0, 
                    cbar=False,  cmap=color, ax=ax)

#sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
#                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
#    plt.show()
    
bc = BertClient()

# %%
def train_5models_smote(e1, e2, x_val, y_val, xfrom, xto, task, num_epochs, c_gama):
       
    global_accs=[]
    global_fnones=[]
    global_fmacros=[]
    global_cms=[]
    
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    best_macro={'F_ma':0.1 , 'Run':0}
    
    if task== 'Stance':
        path='../../Datasets/Models_Stance/SMOTE'
    elif task== 'Harassment':
        path= '../../Datasets/Models_Harassment/SMOTE'
        
    bs=32
    n_machines=5
    
    keys=["commenting", "support", "denying", "questioning"]

    
    for x in range(xfrom,xto + 1):    
        sm = SMOTE(random_state=27, n_jobs=-1, sampling_strategy='not majority')
        x_train_smote, y_train_smote = sm.fit_sample(np.asarray(x_train, dtype='float32'), np.asarray(n_labels, dtype='float32'))


        x_new_train=np.expand_dims(x_train_smote, axis=-1)
        x_new_val=np.expand_dims(x_val, axis=-1)
        x_new_test=np.expand_dims(x_test, axis=-1)

        y_train=to_categorical(y_train_smote,num_classes=4)

        class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train_smote), y_train_smote)
        print ("class_weights Training set", class_weights)
            
        
        print ("\n\n -------------------- Entrenando SMOTE exec", x," ------------------- \n\n")
        
        ################# TRANSFORMER    
        print ("\n--------------------------------------------------------")
        print ("Trabajando en predicciones Transformer")
        print ("--------------------------------------------------------\n")
        

        print ("Entrenando Run #", x)
        espacio=[np.ones(emb)]
        Ks= ortho_group.rvs(dim=emb)
        random=np.random.randint(Ks.shape[0], size=4)
        K_list=Ks[random]
        K_list_ext=espacio+list(K_list)
        index_embeddings=[0,1,2,3,4]
        lab_str_embeddings=['','','','','']
        
        
        for i in range(len(x_new_train)):
            clase=dict_cl[y_train_smote[i]]   
            final_bert= x_train_smote[i]

            index_embeddings.append(i+5)
            lab_str_embeddings.append(clase)
            K_list_ext.append(final_bert)
            

        objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
        objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
        lab_val=val['Label']
        lab_test=test['Label']
        tw_val=val['Tweet']
        tw_test=test['Tweet']
        llaves=np.concatenate([objs_val,objs_test])
        clases=np.concatenate([lab_val,lab_test])
        sent_all=np.concatenate([tw_val,tw_test])   
        
        for num in range(len(llaves)):
            clase=clases[num]
            tw_tr=sent_all[num]
            tokens_valid = cleaner(tw_tr)[1]  #cleaner: raw, no cleaner:augmented version
            
            trans=[]
            for wd in tokens_valid:
                try:
                    trans.append(token_2_idx[wd])
                except:
                    continue
            encoded_tok=trans

            q_glove=len(encoded_tok)
            glove_tok_f=[EMB_matrix[ide] for ide in encoded_tok]
            final=np.sum(glove_tok_f, axis=0)
            final_bert=final/q_glove

            index_embeddings.append(num+5+train.shape[0])
            lab_str_embeddings.append(clase)
            K_list_ext.append(final_bert)
        

        K_list_new= np.asarray(K_list_ext, dtype='float32')
    
        V = 4
        pesos = torch.from_numpy(class_weights).float()
        criterion = FocalLoss(weights=pesos)
        model = make_model_concat(4, K_list_new, N=2,d_model=emb, d_ff=128, h=4, dropout=0.35)
        model_opt = NoamOpt(model.src_embed[0].d_model,  1, 6000, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))


        for epoch in range(num_epochs):
            model.train()
            DATA=data_gen(bs, 'Train', x_train, lab_str_embeddings, index_embeddings)  
            loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')

            model.eval()
            DATA_VAL=data_gen(bs, 'Val', x_train, lab_str_embeddings, index_embeddings)
            loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(DATA_VAL, model, SimpleLossComputeFL(criterion, None),'Val')
            if epoch%10==0:
                print ("Epoch",epoch, "\tacc_val: %.3f" % acc_val.numpy(), "\tF-macro_val: %.3f" % fma_val.numpy())

        model.eval()
        print ("Testing run #",x)
        DATA_TEST=data_gen(bs, 'Test', x_train, lab_str_embeddings, index_embeddings)
        predicciones = run_epoch(DATA_TEST, model, SimpleLossComputeFL(criterion, None),'Test')
        predicciones=np.concatenate(predicciones, axis=-1)

        glo_acc=accuracy_score(etiq_t, predicciones[:-3])
        glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
        glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

        glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

        plot_cm(cm_norma(glo_cm),["S", "D", "Q", "C"],"TEXT SMOTE Transformer ", cmap=c_gama)
        global_accs.append(glo_acc)
        global_fnones.append(glo_fno)
        global_fmacros.append(glo_fma)
        global_cms.append(glo_cm)
        print("Test_ acc:",glo_acc) 
        print("Test_ f1 none:",glo_fno) 
        print("Test_ f1 macro:",glo_fma) 

        if glo_fma>best_macro['F_ma']:
            best_macro['F_ma']=glo_fma
            best_macro['Run']=x                
            print ("\n\nNuevo best encontrado:\n")
            print ("Acc: %.3f" % glo_acc, "\tF1-ma: %.3f" % glo_fma)
            np.set_printoptions(precision=3)
            print ("\tF1-none: ", glo_fno)
                    
    return best_macro, global_accs, global_fnones, global_fmacros, global_cms  
#best_ma, glo_accs, glo_fno, glo_fma, glo_cms

# %%
import matplotlib.pyplot as plt 

def plot_cm(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):
    
    import itertools
    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(6, 5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
        
    thresh = cm.max() / 2.# if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{:0.3f}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")



    plt.tight_layout()
    plt.ylabel('True label')
    plt.show()

# %% [markdown]
# ## SMOTE - Balanced data

# %%
best_ma, glo_accs, glo_fno, glo_fma, glo_cms= train_5models_smote(8, 4, x_val, y_val, 1, 3, "Stance", 30, "Oranges")
# Out:
# class_weights Training set [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando SMOTE exec 1  -------------------
#
#
#
# --------------------------------------------------------
# Trabajando en predicciones Transformer
# --------------------------------------------------------
#
# Entrenando Run # 1
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: 0.337 	F-macro_val: 0.125
# Epoch 10 	acc_val: 0.038 	F-macro_val: 0.018
# Epoch 20 	acc_val: 0.000 	F-macro_val: 0.000
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.761998041136141
# Test_ f1 none: [0.    0.    0.    0.865]
# Test_ f1 macro: 0.2162312395775431
#
#
# Nuevo best encontrado:
#
# Acc: 0.762 	F1-ma: 0.216
# 	F1-none:  [0.    0.    0.    0.865]
# class_weights Training set [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando SMOTE exec 2  -------------------
#
#
#
# --------------------------------------------------------
# Trabajando en predicciones Transformer
# --------------------------------------------------------
#
# Entrenando Run # 2
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: 0.198 	F-macro_val: 0.082
# Epoch 10 	acc_val: 0.003 	F-macro_val: 0.002
# Epoch 20 	acc_val: 0.000 	F-macro_val: 0.000
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.761998041136141
# Test_ f1 none: [0.    0.    0.    0.865]
# Test_ f1 macro: 0.2162312395775431
# class_weights Training set [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando SMOTE exec 3  -------------------
#
#
#
# --------------------------------------------------------
# Trabajando en predicciones Transformer
# --------------------------------------------------------
#
# Entrenando Run # 3
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: 0.122 	F-macro_val: 0.054
# Epoch 10 	acc_val: 0.017 	F-macro_val: 0.008
# Epoch 20 	acc_val: 0.000 	F-macro_val: 0.000
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.761998041136141
# Test_ f1 none: [0.    0.    0.    0.865]
# Test_ f1 macro: 0.2162312395775431

# %%
print ("best_text", best_ma)
print ("all_accs_text", glo_accs)
print ("all_fno_text", glo_fno)
print ("all_ma_text", glo_fma)
# best_ma, glo_accs, glo_fno, glo_fma, glo_cms
# Out:
# best_text {'F_ma': 0.2162312395775431, 'Run': 1}
# all_accs_text [0.761998041136141, 0.761998041136141, 0.761998041136141]
# all_fno_text [array([0.   , 0.   , 0.   , 0.865]), array([0.   , 0.   , 0.   , 0.865]), array([0.   , 0.   , 0.   , 0.865])]
# all_ma_text [0.2162312395775431, 0.2162312395775431, 0.2162312395775431]

# %%
#best_15, all_accs, all_fno, all_ma, all_cm
print ("Acc: %.3f" % np.mean(np.asarray(glo_accs)), "-- deviation: %.3f" % np.std(np.asarray(glo_accs)))
print ("F-score: %.3f" % np.mean(np.asarray(glo_fma)), "-- deviation: %.3f" % np.std(np.asarray(glo_fma)))
np.set_printoptions(precision=3)
sup=np.mean(np.asarray(glo_fno)[:,0])
den=np.mean(np.asarray(glo_fno)[:,1])
que=np.mean(np.asarray(glo_fno)[:,2])
com=np.mean(np.asarray(glo_fno)[:,3])

print ("(0.5) SDQC:", sup,den,que,com)

print ("\n\nConfusion counts")
m_temp=np.zeros((4,4))
for m in glo_cms:
    m_temp+=np.asarray(m)
    
print (m_temp)

plot_cm(cm_norma(m_temp),["S", "D", "Q", "C"], "", cmap='Oranges')
# Out:
# Acc: 0.762 -- deviation: 0.000
# F-score: 0.216 -- deviation: 0.000
# (0.5) SDQC: 0.0 0.0 0.0 0.8649249583101724
#
#
# Confusion counts
# [[   0.    0.    0.  204.]
#  [   0.    0.    0.  207.]
#  [   0.    0.    0.  318.]
#  [   0.    0.    0. 2334.]]

# %% [markdown]
# ## 15% De 1 - 10

# %%
fs_macro, fs_none, accs, confusions= train_5models_balanced(0.15, 10, 8, 4)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.895
# F1-score macro cnn1 : 0.895
# F1-score None cnn1 : [0.828 0.954 0.973 0.824]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.535
# F1-score None cnn1 : [0.548 0.222 0.596 0.774]
#
# ------ Testing ------
# Accuracy cnn1 : 0.689
# F1-score macro cnn1 : 0.399
# F1-score None cnn1 : [0.019 0.203 0.564 0.809]
#
# ------ Training ------
# Accuracy cnn2 : 0.877
# F1-score macro cnn2 : 0.877
# F1-score None cnn2 : [0.823 0.951 0.946 0.789]
#
# ------ Validation ------
# Accuracy cnn2 : 0.705
# F1-score macro cnn2 : 0.593
# F1-score None cnn2 : [0.605 0.381 0.597 0.788]
#
# ------ Testing ------
# Accuracy cnn2 : 0.701
# F1-score macro cnn2 : 0.408
# F1-score None cnn2 : [0.096 0.154 0.569 0.813]
#
# ------ Training ------
# Accuracy rnn1 : 0.631
# F1-score macro rnn1 : 0.617
# F1-score None rnn1 : [0.674 0.506 0.775 0.515]
#
# ------ Validation ------
# Accuracy rnn1 : 0.573
# F1-score macro rnn1 : 0.489
# F1-score None rnn1 : [0.553 0.222 0.556 0.625]
#
# ------ Testing ------
# Accuracy rnn1 : 0.526
# F1-score macro rnn1 : 0.379
# F1-score None rnn1 : [0.238 0.179 0.446 0.654]
#
# ------ Training ------
# Accuracy rnn2 : 0.822
# F1-score macro rnn2 : 0.826
# F1-score None rnn2 : [0.784 0.881 0.925 0.712]
#
# ------ Validation ------
# Accuracy rnn2 : 0.655
# F1-score macro rnn2 : 0.573
# F1-score None rnn2 : [0.589 0.303 0.677 0.724]
#
# ------ Testing ------
# Accuracy rnn2 : 0.631
# F1-score macro rnn2 : 0.432
# F1-score None rnn2 : [0.203 0.199 0.564 0.762]
#
# ------ Training ------
# Accuracy rnn3 : 0.617
# F1-score macro rnn3 : 0.612
# F1-score None rnn3 : [0.632 0.617 0.753 0.447]
#
# ------ Validation ------
# Accuracy rnn3 : 0.509
# F1-score macro rnn3 : 0.487
# F1-score None rnn3 : [0.509 0.27  0.667 0.502]
#
# ------ Testing ------
# Accuracy rnn3 : 0.408
# F1-score macro rnn3 : 0.367
# F1-score None rnn3 : [0.186 0.218 0.567 0.498]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.896
# F1-score macro cnn1 : 0.896
# F1-score None cnn1 : [0.862 0.941 0.97  0.809]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.598
# F1-score None cnn1 : [0.624 0.375 0.621 0.773]
#
# ------ Testing ------
# Accuracy cnn1 : 0.648
# F1-score macro cnn1 : 0.410
# F1-score None cnn1 : [0.153 0.185 0.525 0.779]
#
# ------ Training ------
# Accuracy cnn2 : 0.893
# F1-score macro cnn2 : 0.894
# F1-score None cnn2 : [0.875 0.94  0.95  0.809]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.587
# F1-score None cnn2 : [0.593 0.316 0.667 0.771]
#
# ------ Testing ------
# Accuracy cnn2 : 0.713
# F1-score macro cnn2 : 0.438
# F1-score None cnn2 : [0.172 0.165 0.591 0.823]
#
# ------ Training ------
# Accuracy rnn1 : 0.575
# F1-score macro rnn1 : 0.556
# F1-score None rnn1 : [0.675 0.456 0.646 0.447]
#
# ------ Validation ------
# Accuracy rnn1 : 0.480
# F1-score macro rnn1 : 0.403
# F1-score None rnn1 : [0.57  0.125 0.409 0.508]
#
# ------ Testing ------
# Accuracy rnn1 : 0.392
# F1-score macro rnn1 : 0.314
# F1-score None rnn1 : [0.245 0.201 0.319 0.489]
#
# ------ Training ------
# Accuracy rnn2 : 0.818
# F1-score macro rnn2 : 0.822
# F1-score None rnn2 : [0.789 0.871 0.926 0.702]
#
# ------ Validation ------
# Accuracy rnn2 : 0.648
# F1-score macro rnn2 : 0.499
# F1-score None rnn2 : [0.609 0.083 0.581 0.724]
#
# ------ Testing ------
# Accuracy rnn2 : 0.629
# F1-score macro rnn2 : 0.415
# F1-score None rnn2 : [0.221 0.236 0.434 0.769]
#
# ------ Training ------
# Accuracy rnn3 : 0.637
# F1-score macro rnn3 : 0.615
# F1-score None rnn3 : [0.671 0.656 0.785 0.349]
#
# ------ Validation ------
# Accuracy rnn3 : 0.399
# F1-score macro rnn3 : 0.385
# F1-score None rnn3 : [0.462 0.154 0.605 0.319]
#
# ------ Testing ------
# Accuracy rnn3 : 0.326
# F1-score macro rnn3 : 0.321
# F1-score None rnn3 : [0.171 0.213 0.524 0.377]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.916
# F1-score macro cnn1 : 0.915
# F1-score None cnn1 : [0.878 0.964 0.977 0.842]
#
# ------ Validation ------
# Accuracy cnn1 : 0.630
# F1-score macro cnn1 : 0.520
# F1-score None cnn1 : [0.592 0.216 0.566 0.706]
#
# ------ Testing ------
# Accuracy cnn1 : 0.649
# F1-score macro cnn1 : 0.421
# F1-score None cnn1 : [0.141 0.221 0.543 0.778]
#
# ------ Training ------
# Accuracy cnn2 : 0.874
# F1-score macro cnn2 : 0.873
# F1-score None cnn2 : [0.797 0.956 0.96  0.78 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.566
# F1-score None cnn2 : [0.571 0.308 0.638 0.749]
#
# ------ Testing ------
# Accuracy cnn2 : 0.689
# F1-score macro cnn2 : 0.423
# F1-score None cnn2 : [0.113 0.204 0.568 0.806]
#
# ------ Training ------
# Accuracy rnn1 : 0.656
# F1-score macro rnn1 : 0.650
# F1-score None rnn1 : [0.677 0.603 0.783 0.539]
#
# ------ Validation ------
# Accuracy rnn1 : 0.559
# F1-score macro rnn1 : 0.478
# F1-score None rnn1 : [0.539 0.2   0.568 0.606]
#
# ------ Testing ------
# Accuracy rnn1 : 0.500
# F1-score macro rnn1 : 0.387
# F1-score None rnn1 : [0.215 0.225 0.492 0.615]
#
# ------ Training ------
# Accuracy rnn2 : 0.798
# F1-score macro rnn2 : 0.797
# F1-score None rnn2 : [0.755 0.869 0.89  0.673]
#
# ------ Validation ------
# Accuracy rnn2 : 0.573
# F1-score macro rnn2 : 0.460
# F1-score None rnn2 : [0.522 0.089 0.552 0.676]
#
# ------ Testing ------
# Accuracy rnn2 : 0.608
# F1-score macro rnn2 : 0.429
# F1-score None rnn2 : [0.211 0.225 0.542 0.739]
#
# ------ Training ------
# Accuracy rnn3 : 0.685
# F1-score macro rnn3 : 0.681
# F1-score None rnn3 : [0.663 0.676 0.805 0.578]
#
# ------ Validation ------
# Accuracy rnn3 : 0.544
# F1-score macro rnn3 : 0.452
# F1-score None rnn3 : [0.561 0.14  0.495 0.613]
#
# ------ Testing ------
# Accuracy rnn3 : 0.500
# F1-score macro rnn3 : 0.379
# F1-score None rnn3 : [0.214 0.224 0.457 0.62 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.900
# F1-score macro cnn1 : 0.901
# F1-score None cnn1 : [0.847 0.959 0.97  0.828]
#
# ------ Validation ------
# Accuracy cnn1 : 0.715
# F1-score macro cnn1 : 0.541
# F1-score None cnn1 : [0.595 0.143 0.627 0.8  ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.739
# F1-score macro cnn1 : 0.452
# F1-score None cnn1 : [0.142 0.257 0.567 0.842]
#
# ------ Training ------
# Accuracy cnn2 : 0.880
# F1-score macro cnn2 : 0.881
# F1-score None cnn2 : [0.805 0.949 0.969 0.799]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.547
# F1-score None cnn2 : [0.517 0.267 0.615 0.787]
#
# ------ Testing ------
# Accuracy cnn2 : 0.756
# F1-score macro cnn2 : 0.412
# F1-score None cnn2 : [0.06  0.116 0.614 0.856]
#
# ------ Training ------
# Accuracy rnn1 : 0.620
# F1-score macro rnn1 : 0.597
# F1-score None rnn1 : [0.652 0.644 0.708 0.384]
#
# ------ Validation ------
# Accuracy rnn1 : 0.423
# F1-score macro rnn1 : 0.393
# F1-score None rnn1 : [0.558 0.235 0.4   0.381]
#
# ------ Testing ------
# Accuracy rnn1 : 0.312
# F1-score macro rnn1 : 0.276
# F1-score None rnn1 : [0.185 0.216 0.353 0.352]
#
# ------ Training ------
# Accuracy rnn2 : 0.827
# F1-score macro rnn2 : 0.825
# F1-score None rnn2 : [0.807 0.886 0.91  0.697]
#
# ------ Validation ------
# Accuracy rnn2 : 0.644
# F1-score macro rnn2 : 0.503
# F1-score None rnn2 : [0.576 0.143 0.55  0.743]
#
# ------ Testing ------
# Accuracy rnn2 : 0.558
# F1-score macro rnn2 : 0.391
# F1-score None rnn2 : [0.131 0.252 0.485 0.696]
#
# ------ Training ------
# Accuracy rnn3 : 0.529
# F1-score macro rnn3 : 0.520
# F1-score None rnn3 : [0.522 0.534 0.658 0.366]
#
# ------ Validation ------
# Accuracy rnn3 : 0.377
# F1-score macro rnn3 : 0.405
# F1-score None rnn3 : [0.482 0.097 0.609 0.432]
#
# ------ Testing ------
# Accuracy rnn3 : 0.279
# F1-score macro rnn3 : 0.269
# F1-score None rnn3 : [0.117 0.157 0.443 0.359]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.909
# F1-score macro cnn1 : 0.910
# F1-score None cnn1 : [0.853 0.966 0.977 0.843]
#
# ------ Validation ------
# Accuracy cnn1 : 0.737
# F1-score macro cnn1 : 0.610
# F1-score None cnn1 : [0.607 0.316 0.704 0.814]
#
# ------ Testing ------
# Accuracy cnn1 : 0.732
# F1-score macro cnn1 : 0.434
# F1-score None cnn1 : [0.117 0.202 0.583 0.834]
# ------ Training ------
# Accuracy cnn2 : 0.866
# F1-score macro cnn2 : 0.864
# F1-score None cnn2 : [0.768 0.957 0.956 0.775]
#
# ------ Validation ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.571
# F1-score None cnn2 : [0.589 0.348 0.583 0.763]
#
# ------ Testing ------
# Accuracy cnn2 : 0.700
# F1-score macro cnn2 : 0.449
# F1-score None cnn2 : [0.093 0.25  0.639 0.811]
#
# ------ Training ------
# Accuracy rnn1 : 0.613
# F1-score macro rnn1 : 0.588
# F1-score None rnn1 : [0.65  0.647 0.752 0.302]
#
# ------ Validation ------
# Accuracy rnn1 : 0.420
# F1-score macro rnn1 : 0.406
# F1-score None rnn1 : [0.519 0.121 0.636 0.349]
#
# ------ Testing ------
# Accuracy rnn1 : 0.303
# F1-score macro rnn1 : 0.327
# F1-score None rnn1 : [0.164 0.206 0.612 0.327]
#
# ------ Training ------
# Accuracy rnn2 : 0.789
# F1-score macro rnn2 : 0.793
# F1-score None rnn2 : [0.763 0.852 0.887 0.67 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.584
# F1-score macro rnn2 : 0.511
# F1-score None rnn2 : [0.504 0.185 0.667 0.689]
#
# ------ Testing ------
# Accuracy rnn2 : 0.612
# F1-score macro rnn2 : 0.430
# F1-score None rnn2 : [0.249 0.153 0.57  0.747]
#
# ------ Training ------
# Accuracy rnn3 : 0.550
# F1-score macro rnn3 : 0.542
# F1-score None rnn3 : [0.502 0.571 0.648 0.447]
#
# ------ Validation ------
# Accuracy rnn3 : 0.402
# F1-score macro rnn3 : 0.400
# F1-score None rnn3 : [0.396 0.109 0.603 0.494]
#
# ------ Testing ------
# Accuracy rnn3 : 0.378
# F1-score macro rnn3 : 0.317
# F1-score None rnn3 : [0.042 0.183 0.55  0.493]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.902
# F1-score macro cnn1 : 0.902
# F1-score None cnn1 : [0.859 0.958 0.97  0.823]
#
# ------ Validation ------
# Accuracy cnn1 : 0.705
# F1-score macro cnn1 : 0.539
# F1-score None cnn1 : [0.622 0.154 0.6   0.78 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.709
# F1-score macro cnn1 : 0.399
# F1-score None cnn1 : [0.078 0.141 0.554 0.822]
#
# ------ Training ------
# Accuracy cnn2 : 0.896
# F1-score macro cnn2 : 0.895
# F1-score None cnn2 : [0.855 0.951 0.966 0.81 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.580
# F1-score None cnn2 : [0.595 0.267 0.677 0.78 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.690
# F1-score macro cnn2 : 0.425
# F1-score None cnn2 : [0.111 0.184 0.594 0.809]
#
# ------ Training ------
# Accuracy rnn1 : 0.619
# F1-score macro rnn1 : 0.604
# F1-score None rnn1 : [0.604 0.706 0.664 0.443]
#
# ------ Validation ------
# Accuracy rnn1 : 0.459
# F1-score macro rnn1 : 0.399
# F1-score None rnn1 : [0.533 0.157 0.369 0.536]
#
# ------ Testing ------
# Accuracy rnn1 : 0.377
# F1-score macro rnn1 : 0.308
# F1-score None rnn1 : [0.22  0.218 0.322 0.47 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.821
# F1-score macro rnn2 : 0.820
# F1-score None rnn2 : [0.775 0.873 0.924 0.708]
#
# ------ Validation ------
# Accuracy rnn2 : 0.573
# F1-score macro rnn2 : 0.503
# F1-score None rnn2 : [0.567 0.145 0.633 0.664]
#
# ------ Testing ------
# Accuracy rnn2 : 0.604
# F1-score macro rnn2 : 0.437
# F1-score None rnn2 : [0.192 0.224 0.594 0.738]
#
# ------ Training ------
# Accuracy rnn3 : 0.583
# F1-score macro rnn3 : 0.567
# F1-score None rnn3 : [0.594 0.582 0.736 0.358]
#
# ------ Validation ------
# Accuracy rnn3 : 0.345
# F1-score macro rnn3 : 0.370
# F1-score None rnn3 : [0.384 0.101 0.568 0.426]
#
# ------ Testing ------
# Accuracy rnn3 : 0.294
# F1-score macro rnn3 : 0.275
# F1-score None rnn3 : [0.098 0.18  0.476 0.346]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.900
# F1-score macro cnn1 : 0.900
# F1-score None cnn1 : [0.837 0.97  0.968 0.827]
#
# ------ Validation ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.531
# F1-score None cnn1 : [0.462 0.273 0.618 0.772]
#
# ------ Testing ------
# Accuracy cnn1 : 0.741
# F1-score macro cnn1 : 0.452
# F1-score None cnn1 : [0.108 0.252 0.609 0.84 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.890
# F1-score macro cnn2 : 0.889
# F1-score None cnn2 : [0.842 0.955 0.966 0.793]
#
# ------ Validation ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.571
# F1-score None cnn2 : [0.591 0.32  0.625 0.747]
#
# ------ Testing ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.459
# F1-score None cnn2 : [0.258 0.217 0.582 0.778]
#
# ------ Training ------
# Accuracy rnn1 : 0.659
# F1-score macro rnn1 : 0.655
# F1-score None rnn1 : [0.672 0.655 0.788 0.507]
#
# ------ Validation ------
# Accuracy rnn1 : 0.566
# F1-score macro rnn1 : 0.487
# F1-score None rnn1 : [0.56  0.162 0.611 0.613]
#
# ------ Testing ------
# Accuracy rnn1 : 0.472
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.201 0.218 0.517 0.593]
#
# ------ Training ------
# Accuracy rnn2 : 0.820
# F1-score macro rnn2 : 0.814
# F1-score None rnn2 : [0.772 0.887 0.924 0.676]
#
# ------ Validation ------
# Accuracy rnn2 : 0.587
# F1-score macro rnn2 : 0.487
# F1-score None rnn2 : [0.603 0.174 0.5   0.671]
#
# ------ Testing ------
# Accuracy rnn2 : 0.524
# F1-score macro rnn2 : 0.378
# F1-score None rnn2 : [0.116 0.226 0.512 0.657]
#
# ------ Training ------
# Accuracy rnn3 : 0.561
# F1-score macro rnn3 : 0.549
# F1-score None rnn3 : [0.583 0.513 0.622 0.476]
#
# ------ Validation ------
# Accuracy rnn3 : 0.466
# F1-score macro rnn3 : 0.396
# F1-score None rnn3 : [0.44  0.216 0.366 0.562]
#
# ------ Testing ------
# Accuracy rnn3 : 0.433
# F1-score macro rnn3 : 0.330
# F1-score None rnn3 : [0.197 0.239 0.337 0.547]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.878
# F1-score macro cnn1 : 0.882
# F1-score None cnn1 : [0.871 0.9   0.962 0.794]
#
# ------ Validation ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.484
# F1-score None cnn1 : [0.573 0.    0.596 0.767]
#
# ------ Testing ------
# Accuracy cnn1 : 0.723
# F1-score macro cnn1 : 0.387
# F1-score None cnn1 : [0.109 0.082 0.521 0.834]
#
# ------ Training ------
# Accuracy cnn2 : 0.865
# F1-score macro cnn2 : 0.866
# F1-score None cnn2 : [0.831 0.916 0.94  0.78 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.722
# F1-score macro cnn2 : 0.586
# F1-score None cnn2 : [0.603 0.286 0.656 0.799]
#
# ------ Testing ------
# Accuracy cnn2 : 0.709
# F1-score macro cnn2 : 0.391
# F1-score None cnn2 : [0.102 0.094 0.546 0.82 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.604
# F1-score macro rnn1 : 0.594
# F1-score None rnn1 : [0.662 0.605 0.709 0.402]
#
# ------ Validation ------
# Accuracy rnn1 : 0.452
# F1-score macro rnn1 : 0.452
# F1-score None rnn1 : [0.536 0.161 0.677 0.435]
#
# ------ Testing ------
# Accuracy rnn1 : 0.339
# F1-score macro rnn1 : 0.341
# F1-score None rnn1 : [0.149 0.194 0.617 0.405]
#
# ------ Training ------
# Accuracy rnn2 : 0.792
# F1-score macro rnn2 : 0.796
# F1-score None rnn2 : [0.77  0.801 0.936 0.677]
#
# ------ Validation ------
# Accuracy rnn2 : 0.655
# F1-score macro rnn2 : 0.503
# F1-score None rnn2 : [0.57  0.083 0.618 0.741]
#
# ------ Testing ------
# Accuracy rnn2 : 0.632
# F1-score macro rnn2 : 0.414
# F1-score None rnn2 : [0.23  0.167 0.493 0.766]
#
# ------ Training ------
# Accuracy rnn3 : 0.679
# F1-score macro rnn3 : 0.674
# F1-score None rnn3 : [0.664 0.664 0.794 0.576]
#
# ------ Validation ------
# Accuracy rnn3 : 0.559
# F1-score macro rnn3 : 0.473
# F1-score None rnn3 : [0.59  0.185 0.471 0.648]
#
# ------ Testing ------
# Accuracy rnn3 : 0.536
# F1-score macro rnn3 : 0.379
# F1-score None rnn3 : [0.214 0.207 0.433 0.664]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.908
# F1-score macro cnn1 : 0.907
# F1-score None cnn1 : [0.884 0.963 0.96  0.823]
#
# ------ Validation ------
# Accuracy cnn1 : 0.673
# F1-score macro cnn1 : 0.585
# F1-score None cnn1 : [0.59  0.333 0.677 0.738]
#
# ------ Testing ------
# Accuracy cnn1 : 0.635
# F1-score macro cnn1 : 0.419
# F1-score None cnn1 : [0.095 0.262 0.561 0.757]
#
# ------ Training ------
# Accuracy cnn2 : 0.886
# F1-score macro cnn2 : 0.887
# F1-score None cnn2 : [0.843 0.937 0.973 0.793]
#
# ------ Validation ------
# Accuracy cnn2 : 0.705
# F1-score macro cnn2 : 0.561
# F1-score None cnn2 : [0.635 0.231 0.588 0.789]
#
# ------ Testing ------
# Accuracy cnn2 : 0.662
# F1-score macro cnn2 : 0.433
# F1-score None cnn2 : [0.142 0.209 0.592 0.79 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.636
# F1-score macro rnn1 : 0.625
# F1-score None rnn1 : [0.649 0.619 0.742 0.489]
#
# ------ Validation ------
# Accuracy rnn1 : 0.534
# F1-score macro rnn1 : 0.437
# F1-score None rnn1 : [0.534 0.118 0.495 0.6  ]
# ------ Testing ------
# Accuracy rnn1 : 0.439
# F1-score macro rnn1 : 0.353
# F1-score None rnn1 : [0.239 0.215 0.414 0.545]
#
# ------ Training ------
# Accuracy rnn2 : 0.832
# F1-score macro rnn2 : 0.832
# F1-score None rnn2 : [0.761 0.899 0.938 0.73 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.665
# F1-score macro rnn2 : 0.509
# F1-score None rnn2 : [0.623 0.069 0.592 0.753]
#
# ------ Testing ------
# Accuracy rnn2 : 0.667
# F1-score macro rnn2 : 0.459
# F1-score None rnn2 : [0.243 0.25  0.557 0.785]
#
# ------ Training ------
# Accuracy rnn3 : 0.662
# F1-score macro rnn3 : 0.657
# F1-score None rnn3 : [0.68  0.646 0.784 0.518]
#
# ------ Validation ------
# Accuracy rnn3 : 0.541
# F1-score macro rnn3 : 0.475
# F1-score None rnn3 : [0.565 0.118 0.639 0.58 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.454
# F1-score macro rnn3 : 0.373
# F1-score None rnn3 : [0.224 0.185 0.509 0.573]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.910
# F1-score macro cnn1 : 0.910
# F1-score None cnn1 : [0.882 0.964 0.959 0.835]
#
# ------ Validation ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.532
# F1-score None cnn1 : [0.534 0.16  0.638 0.795]
#
# ------ Testing ------
# Accuracy cnn1 : 0.699
# F1-score macro cnn1 : 0.430
# F1-score None cnn1 : [0.128 0.186 0.592 0.815]
#
# ------ Training ------
# Accuracy cnn2 : 0.866
# F1-score macro cnn2 : 0.864
# F1-score None cnn2 : [0.754 0.958 0.963 0.782]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.523
# F1-score None cnn2 : [0.539 0.194 0.596 0.763]
#
# ------ Testing ------
# Accuracy cnn2 : 0.729
# F1-score macro cnn2 : 0.428
# F1-score None cnn2 : [0.042 0.24  0.595 0.834]
#
# ------ Training ------
# Accuracy rnn1 : 0.638
# F1-score macro rnn1 : 0.613
# F1-score None rnn1 : [0.663 0.627 0.806 0.356]
#
# ------ Validation ------
# Accuracy rnn1 : 0.395
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.571 0.124 0.473 0.358]
#
# ------ Testing ------
# Accuracy rnn1 : 0.297
# F1-score macro rnn1 : 0.291
# F1-score None rnn1 : [0.188 0.206 0.446 0.324]
#
# ------ Training ------
# Accuracy rnn2 : 0.813
# F1-score macro rnn2 : 0.811
# F1-score None rnn2 : [0.789 0.871 0.913 0.669]
#
# ------ Validation ------
# Accuracy rnn2 : 0.544
# F1-score macro rnn2 : 0.478
# F1-score None rnn2 : [0.563 0.119 0.604 0.625]
#
# ------ Testing ------
# Accuracy rnn2 : 0.497
# F1-score macro rnn2 : 0.386
# F1-score None rnn2 : [0.217 0.208 0.484 0.636]
#
# ------ Training ------
# Accuracy rnn3 : 0.596
# F1-score macro rnn3 : 0.583
# F1-score None rnn3 : [0.655 0.478 0.715 0.483]
#
# ------ Validation ------
# Accuracy rnn3 : 0.562
# F1-score macro rnn3 : 0.486
# F1-score None rnn3 : [0.558 0.235 0.536 0.614]
#
# ------ Testing ------
# Accuracy rnn3 : 0.436
# F1-score macro rnn3 : 0.334
# F1-score None rnn3 : [0.198 0.179 0.41  0.549]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.15 - F1-score promedio para cnn1 : [0.109 0.199 0.562 0.811]
# 0.15 - F1-score promedio para cnn2 : [0.119 0.183 0.589 0.814]
# 0.15 - F1-score promedio para rnn1 : [0.204 0.208 0.454 0.477]
# 0.15 - F1-score promedio para rnn2 : [0.201 0.214 0.524 0.729]
# 0.15 - F1-score promedio para rnn3 : [0.166 0.198 0.471 0.503]
#
# 0.15 - F1-score macro promedio para cnn1 : 0.42022685747066096 desvest:  0.021157965677602975
# 0.15 - F1-score macro promedio para cnn2 : 0.42635661433130123 desvest:  0.018852906974126248
# 0.15 - F1-score macro promedio para rnn1 : 0.33587069785278867 desvest:  0.03727255441697077
# 0.15 - F1-score macro promedio para rnn2 : 0.4170264703843832 desvest:  0.02419203743091565
# 0.15 - F1-score macro promedio para rnn3 : 0.3343655917705837 desvest:  0.03858020753727795
#
# 0.15 - Accuracy promedio para cnn1 : 0.6964740450538688 desvest:  0.03792425692123494
# 0.15 - Accuracy promedio para cnn2 : 0.7006856023506366 desvest:  0.027658158816411833
# 0.15 - Accuracy promedio para rnn1 : 0.395690499510284 desvest:  0.08037908497686318
# 0.15 - Accuracy promedio para rnn2 : 0.5961802154750245 desvest:  0.05056952266780494
# 0.15 - Accuracy promedio para rnn3 : 0.40450538687561216 desvest:  0.08095821049291292

# %%
0.15 - F1-score promedio para cnn1 : [0.084 0.189 0.578 0.827]
0.15 - F1-score promedio para cnn2 : [0.08  0.235 0.565 0.813]
0.15 - F1-score promedio para rnn1 : [0.188 0.193 0.453 0.645]
0.15 - F1-score promedio para rnn2 : [0.139 0.21  0.486 0.707]
0.15 - F1-score promedio para rnn3 : [0.185 0.216 0.485 0.658]

0.15 - F1-score macro promedio para cnn1 : 0.4192007021997456 desvest:  0.01616017471988819
0.15 - F1-score macro promedio para cnn2 : 0.4232225379963527 desvest:  0.01450721987058891
0.15 - F1-score macro promedio para rnn1 : 0.3697950165577151 desvest:  0.0313093338876847
0.15 - F1-score macro promedio para rnn2 : 0.3853513899529677 desvest:  0.01929819286734307
0.15 - F1-score macro promedio para rnn3 : 0.386019968619015 desvest:  0.023981828736258683

0.15 - Accuracy promedio para cnn1 : 0.7169441723800196 desvest:  0.021887619333784303
0.15 - Accuracy promedio para cnn2 : 0.6967678746327131 desvest:  0.02639092010774747
0.15 - Accuracy promedio para rnn1 : 0.5181194906953966 desvest:  0.10244689436292287
0.15 - Accuracy promedio para rnn2 : 0.5705190989226249 desvest:  0.06242947060398407
0.15 - Accuracy promedio para rnn3 : 0.5312438785504406 desvest:  0.07443708438534685

# %%
import numpy as np 

a=np.asarray([0.166 ,0.198 ,0.471, 0.503])
b=np.asarray([0.185 ,0.216 ,0.485, 0.658])
( 0.021887619333784303 + 0.03792425692123494 )/2
# Out:
# 0.02990593812750962

# %% [markdown]
# ## 15% De 11 - 20

# %%
class_weights
# Out:
# [1.0, 1.0, 1.0, 1.0]

# %%
fs_macro, fs_none, accs, confusions= train_5models_balanced(0.15, 10, 8, 4)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 11  --------------------
#
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# ------ Training ------
# Accuracy cnn1 : 0.957
# F1-score macro cnn1 : 0.957
# F1-score None cnn1 : [0.925 0.992 0.99  0.92 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.726
# F1-score macro cnn1 : 0.535
# F1-score None cnn1 : [0.632 0.133 0.566 0.809]
#
# ------ Testing ------
# Accuracy cnn1 : 0.747
# F1-score macro cnn1 : 0.415
# F1-score None cnn1 : [0.055 0.189 0.566 0.849]
#
# ------ Training ------
# Accuracy cnn2 : 0.949
# F1-score macro cnn2 : 0.949
# F1-score None cnn2 : [0.922 0.98  0.984 0.911]
#
# ------ Validation ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.534
# F1-score None cnn2 : [0.557 0.222 0.593 0.762]
#
# ------ Testing ------
# Accuracy cnn2 : 0.686
# F1-score macro cnn2 : 0.422
# F1-score None cnn2 : [0.068 0.257 0.558 0.804]
#
# ------ Training ------
# Accuracy rnn1 : 0.770
# F1-score macro rnn1 : 0.757
# F1-score None rnn1 : [0.763 0.801 0.919 0.546]
#
# ------ Validation ------
# Accuracy rnn1 : 0.395
# F1-score macro rnn1 : 0.370
# F1-score None rnn1 : [0.426 0.091 0.471 0.494]
#
# ------ Testing ------
# Accuracy rnn1 : 0.409
# F1-score macro rnn1 : 0.361
# F1-score None rnn1 : [0.191 0.203 0.534 0.516]
#
# ------ Training ------
# Accuracy rnn2 : 0.938
# F1-score macro rnn2 : 0.938
# F1-score None rnn2 : [0.911 0.978 0.973 0.889]
#
# ------ Validation ------
# Accuracy rnn2 : 0.598
# F1-score macro rnn2 : 0.463
# F1-score None rnn2 : [0.427 0.194 0.519 0.712]
#
# ------ Testing ------
# Accuracy rnn2 : 0.674
# F1-score macro rnn2 : 0.400
# F1-score None rnn2 : [0.126 0.218 0.453 0.802]
#
# ------ Training ------
# Accuracy rnn3 : 0.791
# F1-score macro rnn3 : 0.784
# F1-score None rnn3 : [0.764 0.854 0.888 0.632]
#
# ------ Validation ------
# Accuracy rnn3 : 0.577
# F1-score macro rnn3 : 0.475
# F1-score None rnn3 : [0.612 0.128 0.506 0.655]
#
# ------ Testing ------
# Accuracy rnn3 : 0.500
# F1-score macro rnn3 : 0.373
# F1-score None rnn3 : [0.176 0.234 0.454 0.627]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 12  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.956
# F1-score macro cnn1 : 0.956
# F1-score None cnn1 : [0.941 0.985 0.977 0.919]
#
# ------ Validation ------
# Accuracy cnn1 : 0.701
# F1-score macro cnn1 : 0.530
# F1-score None cnn1 : [0.591 0.154 0.588 0.785]
#
# ------ Testing ------
# Accuracy cnn1 : 0.740
# F1-score macro cnn1 : 0.415
# F1-score None cnn1 : [0.071 0.161 0.586 0.843]
#
# ------ Training ------
# Accuracy cnn2 : 0.949
# F1-score macro cnn2 : 0.948
# F1-score None cnn2 : [0.925 0.985 0.981 0.903]
#
# ------ Validation ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.545
# F1-score None cnn2 : [0.566 0.286 0.548 0.778]
#
# ------ Testing ------
# Accuracy cnn2 : 0.697
# F1-score macro cnn2 : 0.451
# F1-score None cnn2 : [0.167 0.239 0.587 0.812]
#
# ------ Training ------
# Accuracy rnn1 : 0.723
# F1-score macro rnn1 : 0.716
# F1-score None rnn1 : [0.713 0.805 0.781 0.565]
#
# ------ Validation ------
# Accuracy rnn1 : 0.541
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.569 0.2   0.407 0.621]
#
# ------ Testing ------
# Accuracy rnn1 : 0.486
# F1-score macro rnn1 : 0.354
# F1-score None rnn1 : [0.213 0.211 0.376 0.614]
#
# ------ Training ------
# Accuracy rnn2 : 0.918
# F1-score macro rnn2 : 0.918
# F1-score None rnn2 : [0.888 0.954 0.971 0.86 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.626
# F1-score macro rnn2 : 0.496
# F1-score None rnn2 : [0.612 0.16  0.49  0.723]
#
# ------ Testing ------
# Accuracy rnn2 : 0.645
# F1-score macro rnn2 : 0.397
# F1-score None rnn2 : [0.108 0.229 0.472 0.782]
#
# ------ Training ------
# Accuracy rnn3 : 0.803
# F1-score macro rnn3 : 0.796
# F1-score None rnn3 : [0.773 0.863 0.922 0.629]
#
# ------ Validation ------
# Accuracy rnn3 : 0.537
# F1-score macro rnn3 : 0.479
# F1-score None rnn3 : [0.541 0.182 0.622 0.57 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.466
# F1-score macro rnn3 : 0.370
# F1-score None rnn3 : [0.184 0.188 0.526 0.582]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 13  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.957
# F1-score macro cnn1 : 0.957
# F1-score None cnn1 : [0.934 0.979 0.986 0.927]
#
# ------ Validation ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.537
# F1-score None cnn1 : [0.586 0.261 0.556 0.748]
#
# ------ Testing ------
# Accuracy cnn1 : 0.699
# F1-score macro cnn1 : 0.424
# F1-score None cnn1 : [0.133 0.194 0.557 0.812]
#
# ------ Training ------
# Accuracy cnn2 : 0.934
# F1-score macro cnn2 : 0.934
# F1-score None cnn2 : [0.894 0.973 0.987 0.882]
#
# ------ Validation ------
# Accuracy cnn2 : 0.676
# F1-score macro cnn2 : 0.559
# F1-score None cnn2 : [0.651 0.233 0.6   0.753]
#
# ------ Testing ------
# Accuracy cnn2 : 0.655
# F1-score macro cnn2 : 0.422
# F1-score None cnn2 : [0.075 0.248 0.584 0.782]
#
# ------ Training ------
# Accuracy rnn1 : 0.672
# F1-score macro rnn1 : 0.677
# F1-score None rnn1 : [0.712 0.717 0.676 0.603]
#
# ------ Validation ------
# Accuracy rnn1 : 0.580
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.496 0.113 0.488 0.699]
#
# ------ Testing ------
# Accuracy rnn1 : 0.588
# F1-score macro rnn1 : 0.397
# F1-score None rnn1 : [0.237 0.2   0.418 0.733]
#
# ------ Training ------
# Accuracy rnn2 : 0.915
# F1-score macro rnn2 : 0.912
# F1-score None rnn2 : [0.907 0.931 0.979 0.833]
#
# ------ Validation ------
# Accuracy rnn2 : 0.459
# F1-score macro rnn2 : 0.394
# F1-score None rnn2 : [0.41  0.073 0.552 0.542]
#
# ------ Testing ------
# Accuracy rnn2 : 0.489
# F1-score macro rnn2 : 0.366
# F1-score None rnn2 : [0.174 0.203 0.457 0.63 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.794
# F1-score macro rnn3 : 0.793
# F1-score None rnn3 : [0.764 0.85  0.917 0.642]
#
# ------ Validation ------
# Accuracy rnn3 : 0.502
# F1-score macro rnn3 : 0.416
# F1-score None rnn3 : [0.425 0.078 0.554 0.608]
#
# ------ Testing ------
# Accuracy rnn3 : 0.576
# F1-score macro rnn3 : 0.421
# F1-score None rnn3 : [0.202 0.225 0.552 0.704]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#  -------------------- Entrenando exec 14  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.940
# F1-score macro cnn1 : 0.940
# F1-score None cnn1 : [0.897 0.982 0.983 0.897]
#
# ------ Validation ------
# Accuracy cnn1 : 0.733
# F1-score macro cnn1 : 0.617
# F1-score None cnn1 : [0.65  0.385 0.625 0.808]
#
# ------ Testing ------
# Accuracy cnn1 : 0.704
# F1-score macro cnn1 : 0.428
# F1-score None cnn1 : [0.061 0.258 0.578 0.817]
#
# ------ Training ------
# Accuracy cnn2 : 0.955
# F1-score macro cnn2 : 0.955
# F1-score None cnn2 : [0.937 0.982 0.983 0.92 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.687
# F1-score macro cnn2 : 0.554
# F1-score None cnn2 : [0.6   0.273 0.576 0.768]
#
# ------ Testing ------
# Accuracy cnn2 : 0.700
# F1-score macro cnn2 : 0.445
# F1-score None cnn2 : [0.119 0.255 0.595 0.813]
#
# ------ Training ------
# Accuracy rnn1 : 0.682
# F1-score macro rnn1 : 0.677
# F1-score None rnn1 : [0.696 0.696 0.792 0.524]
#
# ------ Validation ------
# Accuracy rnn1 : 0.423
# F1-score macro rnn1 : 0.401
# F1-score None rnn1 : [0.449 0.093 0.538 0.525]
#
# ------ Testing ------
# Accuracy rnn1 : 0.361
# F1-score macro rnn1 : 0.305
# F1-score None rnn1 : [0.157 0.203 0.379 0.479]
#
# ------ Training ------
# Accuracy rnn2 : 0.949
# F1-score macro rnn2 : 0.949
# F1-score None rnn2 : [0.929 0.974 0.984 0.91 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.612
# F1-score macro rnn2 : 0.506
# F1-score None rnn2 : [0.587 0.178 0.566 0.694]
#
# ------ Testing ------
# Accuracy rnn2 : 0.598
# F1-score macro rnn2 : 0.395
# F1-score None rnn2 : [0.154 0.173 0.518 0.737]
#
# ------ Training ------
# Accuracy rnn3 : 0.756
# F1-score macro rnn3 : 0.765
# F1-score None rnn3 : [0.749 0.836 0.822 0.654]
#
# ------ Validation ------
# Accuracy rnn3 : 0.641
# F1-score macro rnn3 : 0.523
# F1-score None rnn3 : [0.504 0.2   0.627 0.76 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.673
# F1-score macro rnn3 : 0.408
# F1-score None rnn3 : [0.122 0.226 0.48  0.805]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 15  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.951
# F1-score macro cnn1 : 0.952
# F1-score None cnn1 : [0.919 0.986 0.988 0.914]
#
# ------ Validation ------
# Accuracy cnn1 : 0.712
# F1-score macro cnn1 : 0.587
# F1-score None cnn1 : [0.532 0.353 0.667 0.797]
#
# ------ Testing ------
# Accuracy cnn1 : 0.738
# F1-score macro cnn1 : 0.419
# F1-score None cnn1 : [0.093 0.153 0.585 0.844]
#
# ------ Training ------
# Accuracy cnn2 : 0.926
# F1-score macro cnn2 : 0.925
# F1-score None cnn2 : [0.853 0.989 0.988 0.871]
#
# ------ Validation ------
# Accuracy cnn2 : 0.722
# F1-score macro cnn2 : 0.561
# F1-score None cnn2 : [0.574 0.235 0.63  0.803]
#
# ------ Testing ------
# Accuracy cnn2 : 0.748
# F1-score macro cnn2 : 0.430
# F1-score None cnn2 : [0.023 0.286 0.565 0.847]
#
# ------ Training ------
# Accuracy rnn1 : 0.805
# F1-score macro rnn1 : 0.804
# F1-score None rnn1 : [0.754 0.864 0.92  0.679]
#
# ------ Validation ------
# Accuracy rnn1 : 0.655
# F1-score macro rnn1 : 0.552
# F1-score None rnn1 : [0.608 0.278 0.588 0.735]
#
# ------ Testing ------
# Accuracy rnn1 : 0.600
# F1-score macro rnn1 : 0.412
# F1-score None rnn1 : [0.201 0.19  0.524 0.734]
#
# ------ Training ------
# Accuracy rnn2 : 0.935
# F1-score macro rnn2 : 0.935
# F1-score None rnn2 : [0.92  0.961 0.981 0.878]
#
# ------ Validation ------
# Accuracy rnn2 : 0.548
# F1-score macro rnn2 : 0.441
# F1-score None rnn2 : [0.488 0.133 0.49  0.651]
#
# ------ Testing ------
# Accuracy rnn2 : 0.532
# F1-score macro rnn2 : 0.378
# F1-score None rnn2 : [0.177 0.224 0.436 0.674]
#
# ------ Training ------
# Accuracy rnn3 : 0.792
# F1-score macro rnn3 : 0.789
# F1-score None rnn3 : [0.762 0.838 0.906 0.651]
#
# ------ Validation ------
# Accuracy rnn3 : 0.552
# F1-score macro rnn3 : 0.440
# F1-score None rnn3 : [0.511 0.083 0.506 0.66 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.561
# F1-score macro rnn3 : 0.386
# F1-score None rnn3 : [0.198 0.173 0.468 0.707]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 16  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.960
# F1-score macro cnn1 : 0.960
# F1-score None cnn1 : [0.94  0.988 0.986 0.927]
#
# ------ Validation ------
# Accuracy cnn1 : 0.701
# F1-score macro cnn1 : 0.537
# F1-score None cnn1 : [0.56  0.222 0.571 0.793]
#
# ------ Testing ------
# Accuracy cnn1 : 0.729
# F1-score macro cnn1 : 0.405
# F1-score None cnn1 : [0.038 0.182 0.565 0.834]
#
# ------ Training ------
# Accuracy cnn2 : 0.957
# F1-score macro cnn2 : 0.957
# F1-score None cnn2 : [0.934 0.986 0.987 0.923]
#
# ------ Validation ------
# Accuracy cnn2 : 0.708
# F1-score macro cnn2 : 0.568
# F1-score None cnn2 : [0.644 0.273 0.571 0.784]
#
# ------ Testing ------
# Accuracy cnn2 : 0.672
# F1-score macro cnn2 : 0.422
# F1-score None cnn2 : [0.1   0.225 0.569 0.793]
#
# ------ Training ------
# Accuracy rnn1 : 0.694
# F1-score macro rnn1 : 0.688
# F1-score None rnn1 : [0.726 0.672 0.767 0.587]
#
# ------ Validation ------
# Accuracy rnn1 : 0.580
# F1-score macro rnn1 : 0.492
# F1-score None rnn1 : [0.563 0.3   0.449 0.655]
#
# ------ Testing ------
# Accuracy rnn1 : 0.531
# F1-score macro rnn1 : 0.352
# F1-score None rnn1 : [0.224 0.145 0.373 0.668]
#
# ------ Training ------
# Accuracy rnn2 : 0.936
# F1-score macro rnn2 : 0.935
# F1-score None rnn2 : [0.931 0.956 0.967 0.887]
#
# ------ Validation ------
# Accuracy rnn2 : 0.537
# F1-score macro rnn2 : 0.449
# F1-score None rnn2 : [0.475 0.151 0.537 0.634]
#
# ------ Testing ------
# Accuracy rnn2 : 0.517
# F1-score macro rnn2 : 0.349
# F1-score None rnn2 : [0.085 0.166 0.482 0.664]
#
# ------ Training ------
# Accuracy rnn3 : 0.741
# F1-score macro rnn3 : 0.724
# F1-score None rnn3 : [0.716 0.819 0.91  0.453]
#
# ------ Validation ------
# Accuracy rnn3 : 0.431
# F1-score macro rnn3 : 0.397
# F1-score None rnn3 : [0.472 0.194 0.537 0.386]
#
# ------ Testing ------
# Accuracy rnn3 : 0.392
# F1-score macro rnn3 : 0.350
# F1-score None rnn3 : [0.167 0.253 0.495 0.484]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 17  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.956
# F1-score macro cnn1 : 0.956
# F1-score None cnn1 : [0.938 0.981 0.986 0.92 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.687
# F1-score macro cnn1 : 0.576
# F1-score None cnn1 : [0.601 0.286 0.654 0.761]
#
# ------ Testing ------
# Accuracy cnn1 : 0.690
# F1-score macro cnn1 : 0.426
# F1-score None cnn1 : [0.074 0.229 0.595 0.808]
#
# ------ Training ------
# Accuracy cnn2 : 0.944
# F1-score macro cnn2 : 0.944
# F1-score None cnn2 : [0.91  0.984 0.984 0.898]
#
# ------ Validation ------
# Accuracy cnn2 : 0.726
# F1-score macro cnn2 : 0.570
# F1-score None cnn2 : [0.621 0.2   0.655 0.806]
#
# ------ Testing ------
# Accuracy cnn2 : 0.707
# F1-score macro cnn2 : 0.413
# F1-score None cnn2 : [0.085 0.195 0.549 0.821]
#
# ------ Training ------
# Accuracy rnn1 : 0.750
# F1-score macro rnn1 : 0.739
# F1-score None rnn1 : [0.753 0.801 0.847 0.556]
#
# ------ Validation ------
# Accuracy rnn1 : 0.537
# F1-score macro rnn1 : 0.440
# F1-score None rnn1 : [0.578 0.154 0.449 0.581]
#
# ------ Testing ------
# Accuracy rnn1 : 0.462
# F1-score macro rnn1 : 0.351
# F1-score None rnn1 : [0.192 0.175 0.447 0.59 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.946
# F1-score macro rnn2 : 0.945
# F1-score None rnn2 : [0.933 0.967 0.981 0.9  ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.591
# F1-score macro rnn2 : 0.485
# F1-score None rnn2 : [0.573 0.146 0.554 0.667]
#
# ------ Testing ------
# Accuracy rnn2 : 0.606
# F1-score macro rnn2 : 0.400
# F1-score None rnn2 : [0.112 0.242 0.507 0.739]
#
# ------ Training ------
# Accuracy rnn3 : 0.790
# F1-score macro rnn3 : 0.781
# F1-score None rnn3 : [0.761 0.84  0.896 0.625]
#
# ------ Validation ------
# Accuracy rnn3 : 0.530
# F1-score macro rnn3 : 0.464
# F1-score None rnn3 : [0.587 0.145 0.524 0.602]
#
# ------ Testing ------
# Accuracy rnn3 : 0.471
# F1-score macro rnn3 : 0.354
# F1-score None rnn3 : [0.15  0.221 0.442 0.602]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 18  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.958
# F1-score macro cnn1 : 0.958
# F1-score None cnn1 : [0.934 0.982 0.987 0.928]
#
# ------ Validation ------
# Accuracy cnn1 : 0.630
# F1-score macro cnn1 : 0.506
# F1-score None cnn1 : [0.414 0.276 0.604 0.731]
#
# ------ Testing ------
# Accuracy cnn1 : 0.678
# F1-score macro cnn1 : 0.426
# F1-score None cnn1 : [0.127 0.197 0.584 0.798]
# ------ Training ------
# Accuracy cnn2 : 0.954
# F1-score macro cnn2 : 0.954
# F1-score None cnn2 : [0.929 0.987 0.984 0.917]
#
# ------ Validation ------
# Accuracy cnn2 : 0.705
# F1-score macro cnn2 : 0.567
# F1-score None cnn2 : [0.58  0.273 0.623 0.793]
#
# ------ Testing ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.404
# F1-score None cnn2 : [0.033 0.222 0.549 0.812]
#
# ------ Training ------
# Accuracy rnn1 : 0.649
# F1-score macro rnn1 : 0.641
# F1-score None rnn1 : [0.605 0.474 0.904 0.581]
#
# ------ Validation ------
# Accuracy rnn1 : 0.690
# F1-score macro rnn1 : 0.473
# F1-score None rnn1 : [0.495 0.    0.609 0.789]
#
# ------ Testing ------
# Accuracy rnn1 : 0.744
# F1-score macro rnn1 : 0.411
# F1-score None rnn1 : [0.085 0.151 0.561 0.846]
#
# ------ Training ------
# Accuracy rnn2 : 0.935
# F1-score macro rnn2 : 0.934
# F1-score None rnn2 : [0.92  0.959 0.977 0.881]
#
# ------ Validation ------
# Accuracy rnn2 : 0.580
# F1-score macro rnn2 : 0.469
# F1-score None rnn2 : [0.459 0.154 0.597 0.667]
#
# ------ Testing ------
# Accuracy rnn2 : 0.618
# F1-score macro rnn2 : 0.409
# F1-score None rnn2 : [0.159 0.173 0.558 0.746]
#
# ------ Training ------
# Accuracy rnn3 : 0.791
# F1-score macro rnn3 : 0.788
# F1-score None rnn3 : [0.761 0.848 0.898 0.645]
#
# ------ Validation ------
# Accuracy rnn3 : 0.605
# F1-score macro rnn3 : 0.506
# F1-score None rnn3 : [0.607 0.19  0.548 0.68 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.530
# F1-score macro rnn3 : 0.385
# F1-score None rnn3 : [0.191 0.202 0.489 0.658]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 19  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.962
# F1-score macro cnn1 : 0.962
# F1-score None cnn1 : [0.943 0.992 0.986 0.928]
#
# ------ Validation ------
# Accuracy cnn1 : 0.648
# F1-score macro cnn1 : 0.530
# F1-score None cnn1 : [0.533 0.3   0.557 0.728]
#
# ------ Testing ------
# Accuracy cnn1 : 0.722
# F1-score macro cnn1 : 0.449
# F1-score None cnn1 : [0.15  0.19  0.627 0.83 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.955
# F1-score macro cnn2 : 0.955
# F1-score None cnn2 : [0.934 0.982 0.988 0.916]
#
# ------ Validation ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.551
# F1-score None cnn2 : [0.585 0.296 0.593 0.731]
#
# ------ Testing ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.407
# F1-score None cnn2 : [0.069 0.205 0.556 0.8  ]
#
# ------ Training ------
# Accuracy rnn1 : 0.788
# F1-score macro rnn1 : 0.781
# F1-score None rnn1 : [0.76  0.837 0.916 0.611]
#
# ------ Validation ------
# Accuracy rnn1 : 0.562
# F1-score macro rnn1 : 0.483
# F1-score None rnn1 : [0.617 0.149 0.522 0.643]
#
# ------ Testing ------
# Accuracy rnn1 : 0.480
# F1-score macro rnn1 : 0.387
# F1-score None rnn1 : [0.208 0.225 0.514 0.604]
#
# ------ Training ------
# Accuracy rnn2 : 0.889
# F1-score macro rnn2 : 0.888
# F1-score None rnn2 : [0.875 0.868 0.983 0.826]
#
# ------ Validation ------
# Accuracy rnn2 : 0.456
# F1-score macro rnn2 : 0.402
# F1-score None rnn2 : [0.397 0.084 0.531 0.596]
#
# ------ Testing ------
# Accuracy rnn2 : 0.495
# F1-score macro rnn2 : 0.361
# F1-score None rnn2 : [0.141 0.195 0.471 0.638]
#
# ------ Training ------
# Accuracy rnn3 : 0.769
# F1-score macro rnn3 : 0.764
# F1-score None rnn3 : [0.755 0.844 0.849 0.605]
#
# ------ Validation ------
# Accuracy rnn3 : 0.541
# F1-score macro rnn3 : 0.447
# F1-score None rnn3 : [0.534 0.143 0.485 0.625]
#
# ------ Testing ------
# Accuracy rnn3 : 0.549
# F1-score macro rnn3 : 0.392
# F1-score None rnn3 : [0.243 0.216 0.426 0.685]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 20  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.963
# F1-score macro cnn1 : 0.963
# F1-score None cnn1 : [0.939 0.989 0.991 0.934]
#
# ------ Validation ------
# Accuracy cnn1 : 0.712
# F1-score macro cnn1 : 0.584
# F1-score None cnn1 : [0.571 0.364 0.609 0.793]
#
# ------ Testing ------
# Accuracy cnn1 : 0.722
# F1-score macro cnn1 : 0.384
# F1-score None cnn1 : [0.036 0.133 0.533 0.833]
#
# ------ Training ------
# Accuracy cnn2 : 0.947
# F1-score macro cnn2 : 0.947
# F1-score None cnn2 : [0.906 0.99  0.986 0.904]
#
# ------ Validation ------
# Accuracy cnn2 : 0.680
# F1-score macro cnn2 : 0.531
# F1-score None cnn2 : [0.525 0.19  0.644 0.767]
#
# ------ Testing ------
# Accuracy cnn2 : 0.731
# F1-score macro cnn2 : 0.416
# F1-score None cnn2 : [0.059 0.22  0.541 0.842]
#
# ------ Training ------
# Accuracy rnn1 : 0.761
# F1-score macro rnn1 : 0.766
# F1-score None rnn1 : [0.755 0.833 0.868 0.609]
#
# ------ Validation ------
# Accuracy rnn1 : 0.601
# F1-score macro rnn1 : 0.497
# F1-score None rnn1 : [0.576 0.15  0.583 0.678]
#
# ------ Testing ------
# Accuracy rnn1 : 0.519
# F1-score macro rnn1 : 0.368
# F1-score None rnn1 : [0.177 0.225 0.405 0.664]
#
# ------ Training ------
# Accuracy rnn2 : 0.922
# F1-score macro rnn2 : 0.921
# F1-score None rnn2 : [0.915 0.973 0.945 0.849]
#
# ------ Validation ------
# Accuracy rnn2 : 0.555
# F1-score macro rnn2 : 0.456
# F1-score None rnn2 : [0.512 0.171 0.5   0.639]
#
# ------ Testing ------
# Accuracy rnn2 : 0.531
# F1-score macro rnn2 : 0.398
# F1-score None rnn2 : [0.154 0.273 0.509 0.658]
#
# ------ Training ------
# Accuracy rnn3 : 0.737
# F1-score macro rnn3 : 0.742
# F1-score None rnn3 : [0.747 0.765 0.848 0.607]
#
# ------ Validation ------
# Accuracy rnn3 : 0.612
# F1-score macro rnn3 : 0.500
# F1-score None rnn3 : [0.522 0.2   0.567 0.71 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.594
# F1-score macro rnn3 : 0.421
# F1-score None rnn3 : [0.216 0.223 0.514 0.731]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.15 - F1-score promedio para cnn1 : [0.084 0.189 0.578 0.827]
# 0.15 - F1-score promedio para cnn2 : [0.08  0.235 0.565 0.813]
# 0.15 - F1-score promedio para rnn1 : [0.188 0.193 0.453 0.645]
# 0.15 - F1-score promedio para rnn2 : [0.139 0.21  0.486 0.707]
# 0.15 - F1-score promedio para rnn3 : [0.185 0.216 0.485 0.658]
#
# 0.15 - F1-score macro promedio para cnn1 : 0.4192007021997456 desvest:  0.01616017471988819
# 0.15 - F1-score macro promedio para cnn2 : 0.4232225379963527 desvest:  0.01450721987058891
# 0.15 - F1-score macro promedio para rnn1 : 0.3697950165577151 desvest:  0.0313093338876847
# 0.15 - F1-score macro promedio para rnn2 : 0.3853513899529677 desvest:  0.01929819286734307
# 0.15 - F1-score macro promedio para rnn3 : 0.386019968619015 desvest:  0.023981828736258683
#
# 0.15 - Accuracy promedio para cnn1 : 0.7169441723800196 desvest:  0.021887619333784303
# 0.15 - Accuracy promedio para cnn2 : 0.6967678746327131 desvest:  0.02639092010774747
# 0.15 - Accuracy promedio para rnn1 : 0.5181194906953966 desvest:  0.10244689436292287
# 0.15 - Accuracy promedio para rnn2 : 0.5705190989226249 desvest:  0.06242947060398407
# 0.15 - Accuracy promedio para rnn3 : 0.5312438785504406 desvest:  0.07443708438534685

# %% [markdown]
# ## 50% De 1 - 10

# %%
fs_macro, fs_none, accs, confusions= train_5models_balanced(0.5, 10, 8, 4)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.891
# F1-score macro cnn1 : 0.891
# F1-score None cnn1 : [0.821 0.949 0.972 0.823]
#
# ------ Validation ------
# Accuracy cnn1 : 0.708
# F1-score macro cnn1 : 0.580
# F1-score None cnn1 : [0.61  0.316 0.607 0.786]
#
# ------ Testing ------
# Accuracy cnn1 : 0.708
# F1-score macro cnn1 : 0.434
# F1-score None cnn1 : [0.14  0.206 0.57  0.819]
#
# ------ Training ------
# Accuracy cnn2 : 0.884
# F1-score macro cnn2 : 0.884
# F1-score None cnn2 : [0.819 0.948 0.965 0.804]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.553
# F1-score None cnn2 : [0.597 0.25  0.623 0.743]
#
# ------ Testing ------
# Accuracy cnn2 : 0.657
# F1-score macro cnn2 : 0.421
# F1-score None cnn2 : [0.145 0.218 0.541 0.781]
#
# ------ Training ------
# Accuracy rnn1 : 0.558
# F1-score macro rnn1 : 0.540
# F1-score None rnn1 : [0.628 0.44  0.739 0.354]
#
# ------ Validation ------
# Accuracy rnn1 : 0.466
# F1-score macro rnn1 : 0.436
# F1-score None rnn1 : [0.477 0.207 0.622 0.439]
#
# ------ Testing ------
# Accuracy rnn1 : 0.373
# F1-score macro rnn1 : 0.333
# F1-score None rnn1 : [0.16  0.19  0.521 0.463]
#
# ------ Training ------
# Accuracy rnn2 : 0.823
# F1-score macro rnn2 : 0.821
# F1-score None rnn2 : [0.789 0.866 0.92  0.708]
#
# ------ Validation ------
# Accuracy rnn2 : 0.566
# F1-score macro rnn2 : 0.484
# F1-score None rnn2 : [0.554 0.113 0.632 0.639]
#
# ------ Testing ------
# Accuracy rnn2 : 0.539
# F1-score macro rnn2 : 0.406
# F1-score None rnn2 : [0.209 0.22  0.528 0.666]
#
# ------ Training ------
# Accuracy rnn3 : 0.663
# F1-score macro rnn3 : 0.659
# F1-score None rnn3 : [0.612 0.646 0.783 0.594]
#
# ------ Validation ------
# Accuracy rnn3 : 0.580
# F1-score macro rnn3 : 0.476
# F1-score None rnn3 : [0.492 0.19  0.541 0.682]
#
# ------ Testing ------
# Accuracy rnn3 : 0.583
# F1-score macro rnn3 : 0.382
# F1-score None rnn3 : [0.089 0.211 0.514 0.714]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.869
# F1-score macro cnn1 : 0.871
# F1-score None cnn1 : [0.781 0.942 0.969 0.791]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.520
# F1-score None cnn1 : [0.483 0.2   0.625 0.772]
#
# ------ Testing ------
# Accuracy cnn1 : 0.761
# F1-score macro cnn1 : 0.406
# F1-score None cnn1 : [0.022 0.162 0.582 0.859]
#
# ------ Training ------
# Accuracy cnn2 : 0.870
# F1-score macro cnn2 : 0.869
# F1-score None cnn2 : [0.779 0.949 0.963 0.785]
#
# ------ Validation ------
# Accuracy cnn2 : 0.690
# F1-score macro cnn2 : 0.561
# F1-score None cnn2 : [0.55  0.25  0.667 0.779]
#
# ------ Testing ------
# Accuracy cnn2 : 0.662
# F1-score macro cnn2 : 0.408
# F1-score None cnn2 : [0.035 0.244 0.569 0.783]
#
# ------ Training ------
# Accuracy rnn1 : 0.523
# F1-score macro rnn1 : 0.503
# F1-score None rnn1 : [0.615 0.524 0.617 0.255]
#
# ------ Validation ------
# Accuracy rnn1 : 0.402
# F1-score macro rnn1 : 0.409
# F1-score None rnn1 : [0.467 0.19  0.667 0.311]
#
# ------ Testing ------
# Accuracy rnn1 : 0.290
# F1-score macro rnn1 : 0.309
# F1-score None rnn1 : [0.167 0.169 0.549 0.35 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.805
# F1-score macro rnn2 : 0.810
# F1-score None rnn2 : [0.796 0.874 0.879 0.69 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.648
# F1-score macro rnn2 : 0.501
# F1-score None rnn2 : [0.61  0.067 0.6   0.726]
#
# ------ Testing ------
# Accuracy rnn2 : 0.612
# F1-score macro rnn2 : 0.394
# F1-score None rnn2 : [0.126 0.249 0.446 0.755]
#
# ------ Training ------
# Accuracy rnn3 : 0.637
# F1-score macro rnn3 : 0.621
# F1-score None rnn3 : [0.678 0.505 0.748 0.553]
#
# ------ Validation ------
# Accuracy rnn3 : 0.577
# F1-score macro rnn3 : 0.495
# F1-score None rnn3 : [0.571 0.273 0.505 0.63 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.461
# F1-score macro rnn3 : 0.340
# F1-score None rnn3 : [0.181 0.188 0.411 0.58 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.896
# F1-score macro cnn1 : 0.894
# F1-score None cnn1 : [0.854 0.942 0.97  0.811]
#
# ------ Validation ------
# Accuracy cnn1 : 0.616
# F1-score macro cnn1 : 0.533
# F1-score None cnn1 : [0.568 0.217 0.656 0.691]
#
# ------ Testing ------
# Accuracy cnn1 : 0.614
# F1-score macro cnn1 : 0.413
# F1-score None cnn1 : [0.122 0.208 0.58  0.744]
#
# ------ Training ------
# Accuracy cnn2 : 0.873
# F1-score macro cnn2 : 0.873
# F1-score None cnn2 : [0.8   0.943 0.961 0.788]
#
# ------ Validation ------
# Accuracy cnn2 : 0.676
# F1-score macro cnn2 : 0.554
# F1-score None cnn2 : [0.537 0.273 0.645 0.762]
#
# ------ Testing ------
# Accuracy cnn2 : 0.712
# F1-score macro cnn2 : 0.421
# F1-score None cnn2 : [0.079 0.19  0.592 0.825]
#
# ------ Training ------
# Accuracy rnn1 : 0.624
# F1-score macro rnn1 : 0.621
# F1-score None rnn1 : [0.655 0.608 0.746 0.473]
#
# ------ Validation ------
# Accuracy rnn1 : 0.541
# F1-score macro rnn1 : 0.472
# F1-score None rnn1 : [0.564 0.179 0.541 0.603]
#
# ------ Testing ------
# Accuracy rnn1 : 0.404
# F1-score macro rnn1 : 0.346
# F1-score None rnn1 : [0.224 0.201 0.459 0.501]
#
# ------ Training ------
# Accuracy rnn2 : 0.797
# F1-score macro rnn2 : 0.797
# F1-score None rnn2 : [0.751 0.828 0.907 0.701]
#
# ------ Validation ------
# Accuracy rnn2 : 0.598
# F1-score macro rnn2 : 0.472
# F1-score None rnn2 : [0.563 0.089 0.533 0.704]
#
# ------ Testing ------
# Accuracy rnn2 : 0.591
# F1-score macro rnn2 : 0.384
# F1-score None rnn2 : [0.091 0.247 0.477 0.723]
#
# ------ Training ------
# Accuracy rnn3 : 0.494
# F1-score macro rnn3 : 0.457
# F1-score None rnn3 : [0.581 0.45  0.57  0.228]
#
# ------ Validation ------
# Accuracy rnn3 : 0.292
# F1-score macro rnn3 : 0.271
# F1-score None rnn3 : [0.459 0.073 0.29  0.263]
#
# ------ Testing ------
# Accuracy rnn3 : 0.210
# F1-score macro rnn3 : 0.206
# F1-score None rnn3 : [0.19  0.202 0.262 0.169]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.907
# F1-score macro cnn1 : 0.907
# F1-score None cnn1 : [0.86  0.962 0.974 0.832]
#
# ------ Validation ------
# Accuracy cnn1 : 0.633
# F1-score macro cnn1 : 0.535
# F1-score None cnn1 : [0.566 0.24  0.633 0.701]
#
# ------ Testing ------
# Accuracy cnn1 : 0.640
# F1-score macro cnn1 : 0.433
# F1-score None cnn1 : [0.128 0.271 0.562 0.768]
#
# ------ Training ------
# Accuracy cnn2 : 0.861
# F1-score macro cnn2 : 0.860
# F1-score None cnn2 : [0.781 0.95  0.938 0.772]
#
# ------ Validation ------
# Accuracy cnn2 : 0.655
# F1-score macro cnn2 : 0.512
# F1-score None cnn2 : [0.562 0.211 0.532 0.744]
#
# ------ Testing ------
# Accuracy cnn2 : 0.678
# F1-score macro cnn2 : 0.416
# F1-score None cnn2 : [0.092 0.248 0.528 0.794]
#
# ------ Training ------
# Accuracy rnn1 : 0.651
# F1-score macro rnn1 : 0.651
# F1-score None rnn1 : [0.626 0.671 0.808 0.5  ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.552
# F1-score macro rnn1 : 0.478
# F1-score None rnn1 : [0.543 0.205 0.56  0.604]
#
# ------ Testing ------
# Accuracy rnn1 : 0.441
# F1-score macro rnn1 : 0.350
# F1-score None rnn1 : [0.164 0.196 0.482 0.557]
#
# ------ Training ------
# Accuracy rnn2 : 0.724
# F1-score macro rnn2 : 0.666
# F1-score None rnn2 : [0.729 0.813 0.873 0.251]
#
# ------ Validation ------
# Accuracy rnn2 : 0.349
# F1-score macro rnn2 : 0.337
# F1-score None rnn2 : [0.49  0.185 0.495 0.177]
#
# ------ Testing ------
# Accuracy rnn2 : 0.223
# F1-score macro rnn2 : 0.235
# F1-score None rnn2 : [0.13  0.196 0.427 0.189]
#
# ------ Training ------
# Accuracy rnn3 : 0.621
# F1-score macro rnn3 : 0.608
# F1-score None rnn3 : [0.662 0.497 0.776 0.5  ]
#
# ------ Validation ------
# Accuracy rnn3 : 0.584
# F1-score macro rnn3 : 0.495
# F1-score None rnn3 : [0.561 0.25  0.527 0.643]
#
# ------ Testing ------
# Accuracy rnn3 : 0.477
# F1-score macro rnn3 : 0.367
# F1-score None rnn3 : [0.182 0.2   0.487 0.596]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.895
# F1-score macro cnn1 : 0.895
# F1-score None cnn1 : [0.84  0.956 0.97  0.816]
#
# ------ Validation ------
# Accuracy cnn1 : 0.687
# F1-score macro cnn1 : 0.572
# F1-score None cnn1 : [0.587 0.333 0.6   0.766]
#
# ------ Testing ------
# Accuracy cnn1 : 0.682
# F1-score macro cnn1 : 0.417
# F1-score None cnn1 : [0.198 0.102 0.568 0.802]
# ------ Training ------
# Accuracy cnn2 : 0.868
# F1-score macro cnn2 : 0.866
# F1-score None cnn2 : [0.788 0.944 0.953 0.778]
#
# ------ Validation ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.532
# F1-score None cnn2 : [0.561 0.238 0.615 0.715]
#
# ------ Testing ------
# Accuracy cnn2 : 0.635
# F1-score macro cnn2 : 0.404
# F1-score None cnn2 : [0.047 0.237 0.577 0.756]
#
# ------ Training ------
# Accuracy rnn1 : 0.594
# F1-score macro rnn1 : 0.588
# F1-score None rnn1 : [0.644 0.505 0.753 0.451]
#
# ------ Validation ------
# Accuracy rnn1 : 0.552
# F1-score macro rnn1 : 0.506
# F1-score None rnn1 : [0.497 0.296 0.638 0.593]
#
# ------ Testing ------
# Accuracy rnn1 : 0.493
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.169 0.234 0.513 0.612]
#
# ------ Training ------
# Accuracy rnn2 : 0.767
# F1-score macro rnn2 : 0.755
# F1-score None rnn2 : [0.733 0.811 0.868 0.608]
#
# ------ Validation ------
# Accuracy rnn2 : 0.477
# F1-score macro rnn2 : 0.440
# F1-score None rnn2 : [0.543 0.205 0.494 0.517]
#
# ------ Testing ------
# Accuracy rnn2 : 0.445
# F1-score macro rnn2 : 0.334
# F1-score None rnn2 : [0.163 0.178 0.423 0.574]
#
# ------ Training ------
# Accuracy rnn3 : 0.665
# F1-score macro rnn3 : 0.666
# F1-score None rnn3 : [0.622 0.66  0.779 0.601]
#
# ------ Validation ------
# Accuracy rnn3 : 0.623
# F1-score macro rnn3 : 0.533
# F1-score None rnn3 : [0.595 0.161 0.657 0.718]
#
# ------ Testing ------
# Accuracy rnn3 : 0.530
# F1-score macro rnn3 : 0.383
# F1-score None rnn3 : [0.115 0.214 0.543 0.661]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.858
# F1-score macro cnn1 : 0.863
# F1-score None cnn1 : [0.813 0.899 0.965 0.773]
#
# ------ Validation ------
# Accuracy cnn1 : 0.722
# F1-score macro cnn1 : 0.510
# F1-score None cnn1 : [0.597 0.    0.636 0.808]
#
# ------ Testing ------
# Accuracy cnn1 : 0.728
# F1-score macro cnn1 : 0.400
# F1-score None cnn1 : [0.119 0.146 0.497 0.838]
#
# ------ Training ------
# Accuracy cnn2 : 0.860
# F1-score macro cnn2 : 0.857
# F1-score None cnn2 : [0.829 0.922 0.915 0.763]
#
# ------ Validation ------
# Accuracy cnn2 : 0.598
# F1-score macro cnn2 : 0.489
# F1-score None cnn2 : [0.575 0.162 0.537 0.68 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.591
# F1-score macro cnn2 : 0.398
# F1-score None cnn2 : [0.156 0.21  0.513 0.714]
#
# ------ Training ------
# Accuracy rnn1 : 0.554
# F1-score macro rnn1 : 0.554
# F1-score None rnn1 : [0.642 0.408 0.715 0.449]
#
# ------ Validation ------
# Accuracy rnn1 : 0.541
# F1-score macro rnn1 : 0.494
# F1-score None rnn1 : [0.524 0.182 0.677 0.591]
#
# ------ Testing ------
# Accuracy rnn1 : 0.454
# F1-score macro rnn1 : 0.372
# F1-score None rnn1 : [0.193 0.127 0.597 0.572]
#
# ------ Training ------
# Accuracy rnn2 : 0.822
# F1-score macro rnn2 : 0.817
# F1-score None rnn2 : [0.796 0.869 0.908 0.696]
#
# ------ Validation ------
# Accuracy rnn2 : 0.537
# F1-score macro rnn2 : 0.479
# F1-score None rnn2 : [0.571 0.213 0.568 0.564]
#
# ------ Testing ------
# Accuracy rnn2 : 0.535
# F1-score macro rnn2 : 0.402
# F1-score None rnn2 : [0.203 0.211 0.533 0.661]
#
# ------ Training ------
# Accuracy rnn3 : 0.614
# F1-score macro rnn3 : 0.616
# F1-score None rnn3 : [0.631 0.596 0.759 0.478]
#
# ------ Validation ------
# Accuracy rnn3 : 0.463
# F1-score macro rnn3 : 0.434
# F1-score None rnn3 : [0.473 0.133 0.597 0.533]
#
# ------ Testing ------
# Accuracy rnn3 : 0.433
# F1-score macro rnn3 : 0.346
# F1-score None rnn3 : [0.095 0.169 0.562 0.558]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.878
# F1-score macro cnn1 : 0.875
# F1-score None cnn1 : [0.773 0.954 0.975 0.797]
#
# ------ Validation ------
# Accuracy cnn1 : 0.630
# F1-score macro cnn1 : 0.498
# F1-score None cnn1 : [0.404 0.25  0.6   0.737]
#
# ------ Testing ------
# Accuracy cnn1 : 0.676
# F1-score macro cnn1 : 0.423
# F1-score None cnn1 : [0.042 0.251 0.611 0.79 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.873
# F1-score macro cnn2 : 0.874
# F1-score None cnn2 : [0.812 0.937 0.953 0.792]
#
# ------ Validation ------
# Accuracy cnn2 : 0.665
# F1-score macro cnn2 : 0.532
# F1-score None cnn2 : [0.573 0.19  0.618 0.745]
#
# ------ Testing ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.415
# F1-score None cnn2 : [0.103 0.207 0.551 0.799]
#
# ------ Training ------
# Accuracy rnn1 : 0.557
# F1-score macro rnn1 : 0.528
# F1-score None rnn1 : [0.616 0.443 0.745 0.309]
#
# ------ Validation ------
# Accuracy rnn1 : 0.420
# F1-score macro rnn1 : 0.389
# F1-score None rnn1 : [0.477 0.19  0.565 0.326]
#
# ------ Testing ------
# Accuracy rnn1 : 0.355
# F1-score macro rnn1 : 0.312
# F1-score None rnn1 : [0.155 0.221 0.44  0.43 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.798
# F1-score macro rnn2 : 0.789
# F1-score None rnn2 : [0.774 0.826 0.921 0.635]
#
# ------ Validation ------
# Accuracy rnn2 : 0.534
# F1-score macro rnn2 : 0.486
# F1-score None rnn2 : [0.641 0.167 0.575 0.559]
#
# ------ Testing ------
# Accuracy rnn2 : 0.464
# F1-score macro rnn2 : 0.381
# F1-score None rnn2 : [0.215 0.211 0.514 0.584]
#
# ------ Training ------
# Accuracy rnn3 : 0.656
# F1-score macro rnn3 : 0.651
# F1-score None rnn3 : [0.666 0.622 0.773 0.545]
#
# ------ Validation ------
# Accuracy rnn3 : 0.612
# F1-score macro rnn3 : 0.530
# F1-score None rnn3 : [0.554 0.286 0.611 0.671]
#
# ------ Testing ------
# Accuracy rnn3 : 0.477
# F1-score macro rnn3 : 0.365
# F1-score None rnn3 : [0.208 0.198 0.459 0.595]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.880
# F1-score macro cnn1 : 0.879
# F1-score None cnn1 : [0.811 0.968 0.943 0.795]
#
# ------ Validation ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.575
# F1-score None cnn1 : [0.615 0.364 0.541 0.78 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.675
# F1-score macro cnn1 : 0.418
# F1-score None cnn1 : [0.132 0.197 0.545 0.796]
#
# ------ Training ------
# Accuracy cnn2 : 0.872
# F1-score macro cnn2 : 0.871
# F1-score None cnn2 : [0.789 0.941 0.971 0.785]
#
# ------ Validation ------
# Accuracy cnn2 : 0.680
# F1-score macro cnn2 : 0.547
# F1-score None cnn2 : [0.59  0.2   0.63  0.767]
#
# ------ Testing ------
# Accuracy cnn2 : 0.668
# F1-score macro cnn2 : 0.424
# F1-score None cnn2 : [0.092 0.233 0.578 0.792]
#
# ------ Training ------
# Accuracy rnn1 : 0.584
# F1-score macro rnn1 : 0.567
# F1-score None rnn1 : [0.593 0.584 0.721 0.368]
#
# ------ Validation ------
# Accuracy rnn1 : 0.399
# F1-score macro rnn1 : 0.384
# F1-score None rnn1 : [0.459 0.143 0.505 0.427]
#
# ------ Testing ------
# Accuracy rnn1 : 0.296
# F1-score macro rnn1 : 0.270
# F1-score None rnn1 : [0.136 0.178 0.437 0.329]
#
# ------ Training ------
# Accuracy rnn2 : 0.799
# F1-score macro rnn2 : 0.798
# F1-score None rnn2 : [0.777 0.84  0.891 0.682]
#
# ------ Validation ------
# Accuracy rnn2 : 0.584
# F1-score macro rnn2 : 0.509
# F1-score None rnn2 : [0.561 0.179 0.633 0.664]
#
# ------ Testing ------
# Accuracy rnn2 : 0.519
# F1-score macro rnn2 : 0.410
# F1-score None rnn2 : [0.207 0.235 0.549 0.65 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.649
# F1-score macro rnn3 : 0.640
# F1-score None rnn3 : [0.65  0.642 0.738 0.532]
#
# ------ Validation ------
# Accuracy rnn3 : 0.502
# F1-score macro rnn3 : 0.439
# F1-score None rnn3 : [0.531 0.196 0.467 0.559]
#
# ------ Testing ------
# Accuracy rnn3 : 0.409
# F1-score macro rnn3 : 0.324
# F1-score None rnn3 : [0.168 0.205 0.419 0.505]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.875
# F1-score macro cnn1 : 0.873
# F1-score None cnn1 : [0.793 0.961 0.948 0.792]
#
# ------ Validation ------
# Accuracy cnn1 : 0.662
# F1-score macro cnn1 : 0.547
# F1-score None cnn1 : [0.576 0.348 0.521 0.745]
#
# ------ Testing ------
# Accuracy cnn1 : 0.652
# F1-score macro cnn1 : 0.407
# F1-score None cnn1 : [0.067 0.277 0.507 0.775]
#
# ------ Training ------
# Accuracy cnn2 : 0.881
# F1-score macro cnn2 : 0.881
# F1-score None cnn2 : [0.815 0.951 0.966 0.793]
#
# ------ Validation ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.556
# F1-score None cnn2 : [0.582 0.267 0.596 0.778]
#
# ------ Testing ------
# Accuracy cnn2 : 0.674
# F1-score macro cnn2 : 0.434
# F1-score None cnn2 : [0.113 0.22  0.609 0.793]
#
# ------ Training ------
# Accuracy rnn1 : 0.606
# F1-score macro rnn1 : 0.586
# F1-score None rnn1 : [0.604 0.612 0.746 0.382]
#
# ------ Validation ------
# Accuracy rnn1 : 0.448
# F1-score macro rnn1 : 0.427
# F1-score None rnn1 : [0.561 0.174 0.511 0.464]
# ------ Testing ------
# Accuracy rnn1 : 0.305
# F1-score macro rnn1 : 0.299
# F1-score None rnn1 : [0.23  0.176 0.452 0.337]
#
# ------ Training ------
# Accuracy rnn2 : 0.809
# F1-score macro rnn2 : 0.811
# F1-score None rnn2 : [0.778 0.86  0.919 0.685]
#
# ------ Validation ------
# Accuracy rnn2 : 0.609
# F1-score macro rnn2 : 0.496
# F1-score None rnn2 : [0.586 0.125 0.594 0.678]
#
# ------ Testing ------
# Accuracy rnn2 : 0.586
# F1-score macro rnn2 : 0.427
# F1-score None rnn2 : [0.23  0.205 0.554 0.719]
#
# ------ Training ------
# Accuracy rnn3 : 0.518
# F1-score macro rnn3 : 0.480
# F1-score None rnn3 : [0.583 0.603 0.598 0.136]
#
# ------ Validation ------
# Accuracy rnn3 : 0.299
# F1-score macro rnn3 : 0.307
# F1-score None rnn3 : [0.436 0.107 0.542 0.143]
#
# ------ Testing ------
# Accuracy rnn3 : 0.188
# F1-score macro rnn3 : 0.240
# F1-score None rnn3 : [0.166 0.194 0.448 0.151]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.853
# F1-score macro cnn1 : 0.850
# F1-score None cnn1 : [0.729 0.95  0.946 0.776]
#
# ------ Validation ------
# Accuracy cnn1 : 0.658
# F1-score macro cnn1 : 0.482
# F1-score None cnn1 : [0.491 0.091 0.592 0.755]
#
# ------ Testing ------
# Accuracy cnn1 : 0.696
# F1-score macro cnn1 : 0.402
# F1-score None cnn1 : [0.041 0.194 0.563 0.81 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.852
# F1-score macro cnn2 : 0.850
# F1-score None cnn2 : [0.753 0.927 0.952 0.769]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.538
# F1-score None cnn2 : [0.54  0.207 0.646 0.76 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.705
# F1-score macro cnn2 : 0.432
# F1-score None cnn2 : [0.058 0.252 0.604 0.814]
#
# ------ Training ------
# Accuracy rnn1 : 0.533
# F1-score macro rnn1 : 0.512
# F1-score None rnn1 : [0.649 0.558 0.578 0.261]
#
# ------ Validation ------
# Accuracy rnn1 : 0.363
# F1-score macro rnn1 : 0.407
# F1-score None rnn1 : [0.551 0.104 0.667 0.306]
#
# ------ Testing ------
# Accuracy rnn1 : 0.211
# F1-score macro rnn1 : 0.275
# F1-score None rnn1 : [0.234 0.152 0.517 0.195]
#
# ------ Training ------
# Accuracy rnn2 : 0.792
# F1-score macro rnn2 : 0.794
# F1-score None rnn2 : [0.746 0.867 0.871 0.691]
#
# ------ Validation ------
# Accuracy rnn2 : 0.495
# F1-score macro rnn2 : 0.413
# F1-score None rnn2 : [0.413 0.118 0.54  0.58 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.488
# F1-score macro rnn2 : 0.352
# F1-score None rnn2 : [0.111 0.202 0.45  0.644]
#
# ------ Training ------
# Accuracy rnn3 : 0.654
# F1-score macro rnn3 : 0.647
# F1-score None rnn3 : [0.645 0.657 0.747 0.538]
#
# ------ Validation ------
# Accuracy rnn3 : 0.555
# F1-score macro rnn3 : 0.458
# F1-score None rnn3 : [0.562 0.15  0.485 0.635]
#
# ------ Testing ------
# Accuracy rnn3 : 0.426
# F1-score macro rnn3 : 0.318
# F1-score None rnn3 : [0.132 0.199 0.4   0.542]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.5 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.5 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.5 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.5 - F1-score promedio para cnn1 : [0.101 0.201 0.558 0.8  ]
# 0.5 - F1-score promedio para cnn2 : [0.092 0.226 0.566 0.785]
# 0.5 - F1-score promedio para rnn1 : [0.183 0.184 0.497 0.435]
# 0.5 - F1-score promedio para rnn2 : [0.168 0.215 0.49  0.616]
# 0.5 - F1-score promedio para rnn3 : [0.153 0.198 0.451 0.507]
#
# 0.5 - F1-score macro promedio para cnn1 : 0.4152549318099966 desvest:  0.011300300603882615
# 0.5 - F1-score macro promedio para cnn2 : 0.4173040518938874 desvest:  0.010908337866118932
# 0.5 - F1-score macro promedio para rnn1 : 0.3246983531398174 desvest:  0.03653894519291251
# 0.5 - F1-score macro promedio para rnn2 : 0.37257142751720956 desvest:  0.05264149657722306
# 0.5 - F1-score macro promedio para rnn3 : 0.3271544604572575 desvest:  0.056708407043371545
#
# 0.5 - Accuracy promedio para cnn1 : 0.6831537708129284 desvest:  0.04073365432103272
# 0.5 - Accuracy promedio para cnn2 : 0.666405484818805 desvest:  0.03300903569618706
# 0.5 - Accuracy promedio para rnn1 : 0.36199804113614104 desvest:  0.08338319973360787
# 0.5 - Accuracy promedio para rnn2 : 0.500097943192948 desvest:  0.10594646969519482
# 0.5 - Accuracy promedio para rnn3 : 0.41939275220372185 desvest:  0.12047633819779714

# %%
0.5 - Accuracy promedio para cnn1 : 0.6646425073457395 desvest:  0.04503938786999346
0.5 - Accuracy promedio para cnn2 : 0.6630754162585701 desvest:  0.04212696017160933
0.5 - Accuracy promedio para rnn1 : 0.3626836434867777 desvest:  0.16261168856408664
0.5 - Accuracy promedio para rnn2 : 0.48041136141038204 desvest:  0.1408321285409304
0.5 - Accuracy promedio para rnn3 : 0.36895200783545545 desvest:  0.11384525946216509

# %%
a=np.asarray([0.153 ,0.198 ,0.451 ,0.507])
b=np.asarray([0.152 ,0.165 ,0.456 ,0.444])

#( 0.03858020753727795 + 0.023981828736258683 )/2
(a + b)/2
# Out:
# array([0.1525, 0.1815, 0.4535, 0.4755])

# %% [markdown]
# ## 50% De 11 - 20

# %%
fs_macro, fs_none, accs, confusions= train_5models(0.5, 8, 4, x_val, y_val, 11, 20, 'Stance', balanced=True)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 11  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.420
# F1-score None cnn1 : [0.153 0.144 0.585 0.797]
#
# ------ Testing ------
# Accuracy cnn2 : 0.633
# F1-score macro cnn2 : 0.427
# F1-score None cnn2 : [0.146 0.226 0.576 0.759]
#
# ------ Testing ------
# Accuracy rnn1 : 0.502
# F1-score macro rnn1 : 0.359
# F1-score None rnn1 : [0.203 0.178 0.425 0.633]
#
# ------ Testing ------
# Accuracy rnn2 : 0.663
# F1-score macro rnn2 : 0.365
# F1-score None rnn2 : [0.094 0.196 0.373 0.796]
#
# ------ Testing ------
# Accuracy rnn3 : 0.585
# F1-score macro rnn3 : 0.310
# F1-score None rnn3 : [0.049 0.107 0.356 0.727]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 12  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.665
# F1-score macro cnn1 : 0.423
# F1-score None cnn1 : [0.085 0.205 0.617 0.785]
#
# ------ Testing ------
# Accuracy cnn2 : 0.613
# F1-score macro cnn2 : 0.421
# F1-score None cnn2 : [0.079 0.225 0.639 0.742]
#
# ------ Testing ------
# Accuracy rnn1 : 0.363
# F1-score macro rnn1 : 0.314
# F1-score None rnn1 : [0.091 0.176 0.505 0.484]
#
# ------ Testing ------
# Accuracy rnn2 : 0.667
# F1-score macro rnn2 : 0.379
# F1-score None rnn2 : [0.124 0.108 0.494 0.792]
#
# ------ Testing ------
# Accuracy rnn3 : 0.351
# F1-score macro rnn3 : 0.265
# F1-score None rnn3 : [0.165 0.132 0.32  0.443]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 13  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.655
# F1-score macro cnn1 : 0.424
# F1-score None cnn1 : [0.126 0.247 0.545 0.779]
#
# ------ Testing ------
# Accuracy cnn2 : 0.642
# F1-score macro cnn2 : 0.438
# F1-score None cnn2 : [0.169 0.256 0.563 0.764]
#
# ------ Testing ------
# Accuracy rnn1 : 0.654
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.203 0.241 0.579 0.773]
#
# ------ Testing ------
# Accuracy rnn2 : 0.460
# F1-score macro rnn2 : 0.348
# F1-score None rnn2 : [0.142 0.199 0.465 0.587]
#
# ------ Testing ------
# Accuracy rnn3 : 0.303
# F1-score macro rnn3 : 0.303
# F1-score None rnn3 : [0.152 0.122 0.575 0.364]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 14  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.715
# F1-score macro cnn1 : 0.396
# F1-score None cnn1 : [0.059 0.16  0.533 0.834]
#
# ------ Testing ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.418
# F1-score None cnn2 : [0.084 0.203 0.589 0.794]
#
# ------ Testing ------
# Accuracy rnn1 : 0.147
# F1-score macro rnn1 : 0.201
# F1-score None rnn1 : [0.178 0.147 0.381 0.097]
#
# ------ Testing ------
# Accuracy rnn2 : 0.295
# F1-score macro rnn2 : 0.288
# F1-score None rnn2 : [0.151 0.15  0.495 0.354]
#
# ------ Testing ------
# Accuracy rnn3 : 0.311
# F1-score macro rnn3 : 0.275
# F1-score None rnn3 : [0.216 0.164 0.358 0.362]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 15  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.696
# F1-score macro cnn1 : 0.413
# F1-score None cnn1 : [0.058 0.18  0.605 0.81 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.638
# F1-score macro cnn2 : 0.417
# F1-score None cnn2 : [0.096 0.255 0.561 0.758]
#
# ------ Testing ------
# Accuracy rnn1 : 0.535
# F1-score macro rnn1 : 0.352
# F1-score None rnn1 : [0.184 0.158 0.397 0.669]
#
# ------ Testing ------
# Accuracy rnn2 : 0.452
# F1-score macro rnn2 : 0.353
# F1-score None rnn2 : [0.14  0.202 0.48  0.588]
#
# ------ Testing ------
# Accuracy rnn3 : 0.277
# F1-score macro rnn3 : 0.305
# F1-score None rnn3 : [0.175 0.188 0.537 0.321]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 16  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.430
# F1-score None cnn1 : [0.093 0.242 0.575 0.808]
#
# ------ Testing ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.401
# F1-score None cnn2 : [0.098 0.161 0.588 0.757]
#
# ------ Testing ------
# Accuracy rnn1 : 0.438
# F1-score macro rnn1 : 0.340
# F1-score None rnn1 : [0.189 0.17  0.457 0.546]
#
# ------ Testing ------
# Accuracy rnn2 : 0.563
# F1-score macro rnn2 : 0.396
# F1-score None rnn2 : [0.181 0.179 0.526 0.696]
#
# ------ Testing ------
# Accuracy rnn3 : 0.203
# F1-score macro rnn3 : 0.257
# F1-score None rnn3 : [0.144 0.183 0.555 0.145]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 17  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.599
# F1-score macro cnn1 : 0.428
# F1-score None cnn1 : [0.186 0.229 0.574 0.724]
#
# ------ Testing ------
# Accuracy cnn2 : 0.635
# F1-score macro cnn2 : 0.406
# F1-score None cnn2 : [0.109 0.209 0.547 0.76 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.306
# F1-score macro rnn1 : 0.261
# F1-score None rnn1 : [0.155 0.151 0.373 0.366]
#
# ------ Testing ------
# Accuracy rnn2 : 0.452
# F1-score macro rnn2 : 0.344
# F1-score None rnn2 : [0.098 0.211 0.485 0.583]
#
# ------ Testing ------
# Accuracy rnn3 : 0.560
# F1-score macro rnn3 : 0.369
# F1-score None rnn3 : [0.151 0.212 0.418 0.695]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 18  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.674
# F1-score macro cnn1 : 0.429
# F1-score None cnn1 : [0.155 0.184 0.583 0.794]
#
# ------ Testing ------
# Accuracy cnn2 : 0.710
# F1-score macro cnn2 : 0.406
# F1-score None cnn2 : [0.055 0.192 0.553 0.824]
#
# ------ Testing ------
# Accuracy rnn1 : 0.113
# F1-score macro rnn1 : 0.075
# F1-score None rnn1 : [0.048 0.043 0.195 0.015]
#
# ------ Testing ------
# Accuracy rnn2 : 0.311
# F1-score macro rnn2 : 0.306
# F1-score None rnn2 : [0.129 0.199 0.497 0.399]
#
# ------ Testing ------
# Accuracy rnn3 : 0.369
# F1-score macro rnn3 : 0.319
# F1-score None rnn3 : [0.186 0.209 0.437 0.446]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 19  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.699
# F1-score macro cnn1 : 0.416
# F1-score None cnn1 : [0.131 0.206 0.511 0.817]
#
# ------ Testing ------
# Accuracy cnn2 : 0.718
# F1-score macro cnn2 : 0.446
# F1-score None cnn2 : [0.098 0.262 0.597 0.826]
#
# ------ Testing ------
# Accuracy rnn1 : 0.290
# F1-score macro rnn1 : 0.265
# F1-score None rnn1 : [0.216 0.172 0.35  0.323]
#
# ------ Testing ------
# Accuracy rnn2 : 0.300
# F1-score macro rnn2 : 0.258
# F1-score None rnn2 : [0.129 0.181 0.364 0.359]
#
# ------ Testing ------
# Accuracy rnn3 : 0.331
# F1-score macro rnn3 : 0.308
# F1-score None rnn3 : [0.171 0.185 0.467 0.407]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 20  --------------------
#
#
#
# ------ Testing ------
# Accuracy cnn1 : 0.565
# F1-score macro cnn1 : 0.392
# F1-score None cnn1 : [0.043 0.215 0.613 0.695]
#
# ------ Testing ------
# Accuracy cnn2 : 0.740
# F1-score macro cnn2 : 0.434
# F1-score None cnn2 : [0.061 0.259 0.573 0.843]
#
# ------ Testing ------
# Accuracy rnn1 : 0.279
# F1-score macro rnn1 : 0.243
# F1-score None rnn1 : [0.177 0.143 0.345 0.307]
#
# ------ Testing ------
# Accuracy rnn2 : 0.641
# F1-score macro rnn2 : 0.401
# F1-score None rnn2 : [0.102 0.196 0.532 0.772]
#
# ------ Testing ------
# Accuracy rnn3 : 0.400
# F1-score macro rnn3 : 0.332
# F1-score None rnn3 : [0.114 0.151 0.536 0.527]

# %%
#(fold, e1, e2, x_val, y_val, xfrom, xto, MAX_LEN, task, balanced=False, x_train=None, y_train=None, n_labels=None, class_weights=None)
### 11 - 20


for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.5 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.5 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.5 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.5 - F1-score promedio para cnn1 : [0.109 0.201 0.574 0.784]
# 0.5 - F1-score promedio para cnn2 : [0.099 0.225 0.579 0.783]
# 0.5 - F1-score promedio para rnn1 : [0.164 0.158 0.401 0.421]
# 0.5 - F1-score promedio para rnn2 : [0.129 0.182 0.471 0.593]
# 0.5 - F1-score promedio para rnn3 : [0.152 0.165 0.456 0.444]
#
# 0.5 - F1-score macro promedio para cnn1 : 0.4172013909486922 desvest:  0.012665108966502263
# 0.5 - F1-score macro promedio para cnn2 : 0.42136108311114173 desvest:  0.014096345902233045
# 0.5 - F1-score macro promedio para rnn1 : 0.28595507793068353 desvest:  0.09732257187513861
# 0.5 - F1-score macro promedio para rnn2 : 0.34374157387412557 desvest:  0.04429250963600034
# 0.5 - F1-score macro promedio para rnn3 : 0.3042592221663802 desvest:  0.03149733362923091
#
# 0.5 - Accuracy promedio para cnn1 : 0.6646425073457395 desvest:  0.04503938786999346
# 0.5 - Accuracy promedio para cnn2 : 0.6630754162585701 desvest:  0.04212696017160933
# 0.5 - Accuracy promedio para rnn1 : 0.3626836434867777 desvest:  0.16261168856408664
# 0.5 - Accuracy promedio para rnn2 : 0.48041136141038204 desvest:  0.1408321285409304
# 0.5 - Accuracy promedio para rnn3 : 0.36895200783545545 desvest:  0.11384525946216509

# %% [markdown]
# ## 85% De 1 - 10

# %%
fs_macro, fs_none, accs, confusions= train_5models_balanced(0.85, 10, 8, 4)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.891
# F1-score macro cnn1 : 0.892
# F1-score None cnn1 : [0.831 0.953 0.966 0.819]
#
# ------ Validation ------
# Accuracy cnn1 : 0.690
# F1-score macro cnn1 : 0.522
# F1-score None cnn1 : [0.565 0.118 0.632 0.773]
#
# ------ Testing ------
# Accuracy cnn1 : 0.702
# F1-score macro cnn1 : 0.405
# F1-score None cnn1 : [0.085 0.179 0.537 0.82 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.860
# F1-score macro cnn2 : 0.856
# F1-score None cnn2 : [0.784 0.894 0.957 0.789]
#
# ------ Validation ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.585
# F1-score None cnn2 : [0.6   0.286 0.687 0.768]
#
# ------ Testing ------
# Accuracy cnn2 : 0.596
# F1-score macro cnn2 : 0.423
# F1-score None cnn2 : [0.14  0.235 0.598 0.721]
#
# ------ Training ------
# Accuracy rnn1 : 0.472
# F1-score macro rnn1 : 0.401
# F1-score None rnn1 : [0.529 0.194 0.781 0.101]
#
# ------ Validation ------
# Accuracy rnn1 : 0.338
# F1-score macro rnn1 : 0.330
# F1-score None rnn1 : [0.432 0.133 0.656 0.097]
#
# ------ Testing ------
# Accuracy rnn1 : 0.195
# F1-score macro rnn1 : 0.220
# F1-score None rnn1 : [0.145 0.024 0.547 0.166]
#
# ------ Training ------
# Accuracy rnn2 : 0.804
# F1-score macro rnn2 : 0.805
# F1-score None rnn2 : [0.794 0.783 0.91  0.734]
#
# ------ Validation ------
# Accuracy rnn2 : 0.644
# F1-score macro rnn2 : 0.455
# F1-score None rnn2 : [0.568 0.    0.516 0.734]
#
# ------ Testing ------
# Accuracy rnn2 : 0.648
# F1-score macro rnn2 : 0.370
# F1-score None rnn2 : [0.118 0.107 0.472 0.781]
#
# ------ Training ------
# Accuracy rnn3 : 0.613
# F1-score macro rnn3 : 0.590
# F1-score None rnn3 : [0.653 0.616 0.691 0.401]
#
# ------ Validation ------
# Accuracy rnn3 : 0.402
# F1-score macro rnn3 : 0.360
# F1-score None rnn3 : [0.561 0.095 0.379 0.404]
#
# ------ Testing ------
# Accuracy rnn3 : 0.297
# F1-score macro rnn3 : 0.254
# F1-score None rnn3 : [0.178 0.157 0.34  0.34 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.885
# F1-score macro cnn1 : 0.886
# F1-score None cnn1 : [0.841 0.927 0.95  0.826]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.532
# F1-score None cnn1 : [0.59  0.143 0.621 0.775]
#
# ------ Testing ------
# Accuracy cnn1 : 0.689
# F1-score macro cnn1 : 0.406
# F1-score None cnn1 : [0.133 0.198 0.487 0.806]
#
# ------ Training ------
# Accuracy cnn2 : 0.880
# F1-score macro cnn2 : 0.881
# F1-score None cnn2 : [0.813 0.932 0.964 0.815]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.573
# F1-score None cnn2 : [0.574 0.333 0.607 0.778]
#
# ------ Testing ------
# Accuracy cnn2 : 0.715
# F1-score macro cnn2 : 0.420
# F1-score None cnn2 : [0.106 0.165 0.581 0.826]
#
# ------ Training ------
# Accuracy rnn1 : 0.534
# F1-score macro rnn1 : 0.533
# F1-score None rnn1 : [0.581 0.55  0.563 0.44 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.416
# F1-score macro rnn1 : 0.381
# F1-score None rnn1 : [0.519 0.114 0.381 0.511]
#
# ------ Testing ------
# Accuracy rnn1 : 0.326
# F1-score macro rnn1 : 0.254
# F1-score None rnn1 : [0.102 0.153 0.292 0.47 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.825
# F1-score macro rnn2 : 0.825
# F1-score None rnn2 : [0.788 0.875 0.882 0.755]
#
# ------ Validation ------
# Accuracy rnn2 : 0.548
# F1-score macro rnn2 : 0.440
# F1-score None rnn2 : [0.515 0.115 0.478 0.651]
#
# ------ Testing ------
# Accuracy rnn2 : 0.532
# F1-score macro rnn2 : 0.361
# F1-score None rnn2 : [0.125 0.19  0.44  0.688]
#
# ------ Training ------
# Accuracy rnn3 : 0.613
# F1-score macro rnn3 : 0.614
# F1-score None rnn3 : [0.656 0.605 0.648 0.547]
#
# ------ Validation ------
# Accuracy rnn3 : 0.505
# F1-score macro rnn3 : 0.495
# F1-score None rnn3 : [0.608 0.145 0.652 0.574]
#
# ------ Testing ------
# Accuracy rnn3 : 0.390
# F1-score macro rnn3 : 0.348
# F1-score None rnn3 : [0.238 0.186 0.458 0.512]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.897
# F1-score macro cnn1 : 0.898
# F1-score None cnn1 : [0.835 0.96  0.966 0.832]
#
# ------ Validation ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.558
# F1-score None cnn1 : [0.508 0.316 0.638 0.77 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.710
# F1-score macro cnn1 : 0.393
# F1-score None cnn1 : [0.067 0.2   0.48  0.825]
#
# ------ Training ------
# Accuracy cnn2 : 0.893
# F1-score macro cnn2 : 0.894
# F1-score None cnn2 : [0.846 0.946 0.963 0.823]
#
# ------ Validation ------
# Accuracy cnn2 : 0.705
# F1-score macro cnn2 : 0.609
# F1-score None cnn2 : [0.583 0.32  0.755 0.776]
#
# ------ Testing ------
# Accuracy cnn2 : 0.642
# F1-score macro cnn2 : 0.390
# F1-score None cnn2 : [0.068 0.21  0.51  0.772]
#
# ------ Training ------
# Accuracy rnn1 : 0.461
# F1-score macro rnn1 : 0.372
# F1-score None rnn1 : [0.592 0.173 0.577 0.145]
#
# ------ Validation ------
# Accuracy rnn1 : 0.324
# F1-score macro rnn1 : 0.243
# F1-score None rnn1 : [0.484 0.    0.369 0.118]
#
# ------ Testing ------
# Accuracy rnn1 : 0.202
# F1-score macro rnn1 : 0.185
# F1-score None rnn1 : [0.149 0.129 0.292 0.17 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.777
# F1-score macro rnn2 : 0.768
# F1-score None rnn2 : [0.621 0.777 0.928 0.747]
#
# ------ Validation ------
# Accuracy rnn2 : 0.559
# F1-score macro rnn2 : 0.481
# F1-score None rnn2 : [0.473 0.1   0.667 0.686]
#
# ------ Testing ------
# Accuracy rnn2 : 0.581
# F1-score macro rnn2 : 0.345
# F1-score None rnn2 : [0.044 0.177 0.433 0.727]
#
# ------ Training ------
# Accuracy rnn3 : 0.518
# F1-score macro rnn3 : 0.500
# F1-score None rnn3 : [0.553 0.468 0.638 0.342]
#
# ------ Validation ------
# Accuracy rnn3 : 0.359
# F1-score macro rnn3 : 0.332
# F1-score None rnn3 : [0.488 0.114 0.371 0.356]
#
# ------ Testing ------
# Accuracy rnn3 : 0.313
# F1-score macro rnn3 : 0.281
# F1-score None rnn3 : [0.234 0.183 0.342 0.366]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.899
# F1-score macro cnn1 : 0.899
# F1-score None cnn1 : [0.837 0.957 0.969 0.833]
#
# ------ Validation ------
# Accuracy cnn1 : 0.655
# F1-score macro cnn1 : 0.492
# F1-score None cnn1 : [0.527 0.08  0.615 0.747]
#
# ------ Testing ------
# Accuracy cnn1 : 0.695
# F1-score macro cnn1 : 0.404
# F1-score None cnn1 : [0.061 0.188 0.554 0.813]
#
# ------ Training ------
# Accuracy cnn2 : 0.885
# F1-score macro cnn2 : 0.885
# F1-score None cnn2 : [0.836 0.931 0.962 0.811]
#
# ------ Validation ------
# Accuracy cnn2 : 0.665
# F1-score macro cnn2 : 0.547
# F1-score None cnn2 : [0.529 0.348 0.556 0.756]
#
# ------ Testing ------
# Accuracy cnn2 : 0.667
# F1-score macro cnn2 : 0.410
# F1-score None cnn2 : [0.11  0.194 0.547 0.788]
#
# ------ Training ------
# Accuracy rnn1 : 0.611
# F1-score macro rnn1 : 0.617
# F1-score None rnn1 : [0.634 0.565 0.774 0.496]
#
# ------ Validation ------
# Accuracy rnn1 : 0.598
# F1-score macro rnn1 : 0.465
# F1-score None rnn1 : [0.533 0.111 0.542 0.673]
#
# ------ Testing ------
# Accuracy rnn1 : 0.523
# F1-score macro rnn1 : 0.369
# F1-score None rnn1 : [0.201 0.161 0.453 0.66 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.825
# F1-score macro rnn2 : 0.824
# F1-score None rnn2 : [0.798 0.857 0.9   0.739]
#
# ------ Validation ------
# Accuracy rnn2 : 0.609
# F1-score macro rnn2 : 0.534
# F1-score None rnn2 : [0.55  0.303 0.611 0.673]
#
# ------ Testing ------
# Accuracy rnn2 : 0.531
# F1-score macro rnn2 : 0.352
# F1-score None rnn2 : [0.127 0.175 0.431 0.675]
#
# ------ Training ------
# Accuracy rnn3 : 0.566
# F1-score macro rnn3 : 0.566
# F1-score None rnn3 : [0.64  0.558 0.564 0.501]
#
# ------ Validation ------
# Accuracy rnn3 : 0.445
# F1-score macro rnn3 : 0.452
# F1-score None rnn3 : [0.573 0.085 0.651 0.498]
#
# ------ Testing ------
# Accuracy rnn3 : 0.338
# F1-score macro rnn3 : 0.315
# F1-score None rnn3 : [0.246 0.156 0.408 0.45 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.859
# F1-score macro cnn1 : 0.862
# F1-score None cnn1 : [0.781 0.938 0.945 0.784]
#
# ------ Validation ------
# Accuracy cnn1 : 0.676
# F1-score macro cnn1 : 0.493
# F1-score None cnn1 : [0.453 0.222 0.524 0.773]
#
# ------ Testing ------
# Accuracy cnn1 : 0.725
# F1-score macro cnn1 : 0.375
# F1-score None cnn1 : [0.034 0.18  0.446 0.838]
# ------ Training ------
# Accuracy cnn2 : 0.882
# F1-score macro cnn2 : 0.880
# F1-score None cnn2 : [0.823 0.928 0.958 0.811]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.573
# F1-score None cnn2 : [0.588 0.242 0.667 0.794]
#
# ------ Testing ------
# Accuracy cnn2 : 0.618
# F1-score macro cnn2 : 0.414
# F1-score None cnn2 : [0.141 0.225 0.548 0.743]
#
# ------ Training ------
# Accuracy rnn1 : 0.608
# F1-score macro rnn1 : 0.608
# F1-score None rnn1 : [0.647 0.556 0.755 0.474]
#
# ------ Validation ------
# Accuracy rnn1 : 0.580
# F1-score macro rnn1 : 0.494
# F1-score None rnn1 : [0.548 0.154 0.645 0.628]
#
# ------ Testing ------
# Accuracy rnn1 : 0.449
# F1-score macro rnn1 : 0.363
# F1-score None rnn1 : [0.171 0.173 0.531 0.576]
#
# ------ Training ------
# Accuracy rnn2 : 0.714
# F1-score macro rnn2 : 0.706
# F1-score None rnn2 : [0.592 0.79  0.776 0.666]
#
# ------ Validation ------
# Accuracy rnn2 : 0.598
# F1-score macro rnn2 : 0.402
# F1-score None rnn2 : [0.408 0.    0.476 0.724]
#
# ------ Testing ------
# Accuracy rnn2 : 0.604
# F1-score macro rnn2 : 0.338
# F1-score None rnn2 : [0.087 0.155 0.369 0.741]
#
# ------ Training ------
# Accuracy rnn3 : 0.634
# F1-score macro rnn3 : 0.616
# F1-score None rnn3 : [0.666 0.465 0.702 0.631]
#
# ------ Validation ------
# Accuracy rnn3 : 0.658
# F1-score macro rnn3 : 0.474
# F1-score None rnn3 : [0.6   0.    0.552 0.744]
#
# ------ Testing ------
# Accuracy rnn3 : 0.599
# F1-score macro rnn3 : 0.351
# F1-score None rnn3 : [0.148 0.157 0.358 0.742]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.898
# F1-score macro cnn1 : 0.897
# F1-score None cnn1 : [0.843 0.954 0.961 0.831]
#
# ------ Validation ------
# Accuracy cnn1 : 0.655
# F1-score macro cnn1 : 0.514
# F1-score None cnn1 : [0.492 0.222 0.6   0.743]
#
# ------ Testing ------
# Accuracy cnn1 : 0.686
# F1-score macro cnn1 : 0.420
# F1-score None cnn1 : [0.12  0.211 0.55  0.8  ]
#
# ------ Training ------
# Accuracy cnn2 : 0.885
# F1-score macro cnn2 : 0.885
# F1-score None cnn2 : [0.809 0.944 0.968 0.818]
#
# ------ Validation ------
# Accuracy cnn2 : 0.687
# F1-score macro cnn2 : 0.534
# F1-score None cnn2 : [0.562 0.19  0.61  0.774]
#
# ------ Testing ------
# Accuracy cnn2 : 0.718
# F1-score macro cnn2 : 0.444
# F1-score None cnn2 : [0.136 0.238 0.576 0.827]
#
# ------ Training ------
# Accuracy rnn1 : 0.629
# F1-score macro rnn1 : 0.579
# F1-score None rnn1 : [0.653 0.677 0.768 0.22 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.338
# F1-score macro rnn1 : 0.321
# F1-score None rnn1 : [0.513 0.111 0.505 0.156]
#
# ------ Testing ------
# Accuracy rnn1 : 0.214
# F1-score macro rnn1 : 0.235
# F1-score None rnn1 : [0.194 0.186 0.405 0.153]
#
# ------ Training ------
# Accuracy rnn2 : 0.807
# F1-score macro rnn2 : 0.804
# F1-score None rnn2 : [0.802 0.826 0.896 0.69 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.530
# F1-score macro rnn2 : 0.468
# F1-score None rnn2 : [0.543 0.161 0.571 0.595]
#
# ------ Testing ------
# Accuracy rnn2 : 0.477
# F1-score macro rnn2 : 0.355
# F1-score None rnn2 : [0.212 0.193 0.4   0.616]
#
# ------ Training ------
# Accuracy rnn3 : 0.583
# F1-score macro rnn3 : 0.577
# F1-score None rnn3 : [0.619 0.542 0.767 0.381]
#
# ------ Validation ------
# Accuracy rnn3 : 0.512
# F1-score macro rnn3 : 0.476
# F1-score None rnn3 : [0.495 0.24  0.645 0.522]
#
# ------ Testing ------
# Accuracy rnn3 : 0.422
# F1-score macro rnn3 : 0.367
# F1-score None rnn3 : [0.165 0.19  0.573 0.54 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.874
# F1-score macro cnn1 : 0.875
# F1-score None cnn1 : [0.794 0.932 0.963 0.81 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.762
# F1-score macro cnn1 : 0.614
# F1-score None cnn1 : [0.622 0.267 0.737 0.83 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.737
# F1-score macro cnn1 : 0.395
# F1-score None cnn1 : [0.039 0.125 0.574 0.841]
#
# ------ Training ------
# Accuracy cnn2 : 0.843
# F1-score macro cnn2 : 0.838
# F1-score None cnn2 : [0.687 0.93  0.961 0.773]
#
# ------ Validation ------
# Accuracy cnn2 : 0.662
# F1-score macro cnn2 : 0.488
# F1-score None cnn2 : [0.347 0.222 0.615 0.766]
#
# ------ Testing ------
# Accuracy cnn2 : 0.736
# F1-score macro cnn2 : 0.412
# F1-score None cnn2 : [0.026 0.225 0.559 0.84 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.676
# F1-score macro rnn1 : 0.671
# F1-score None rnn1 : [0.681 0.631 0.746 0.624]
#
# ------ Validation ------
# Accuracy rnn1 : 0.601
# F1-score macro rnn1 : 0.482
# F1-score None rnn1 : [0.542 0.133 0.568 0.687]
#
# ------ Testing ------
# Accuracy rnn1 : 0.573
# F1-score macro rnn1 : 0.393
# F1-score None rnn1 : [0.207 0.212 0.449 0.704]
#
# ------ Training ------
# Accuracy rnn2 : 0.777
# F1-score macro rnn2 : 0.767
# F1-score None rnn2 : [0.736 0.822 0.85  0.657]
#
# ------ Validation ------
# Accuracy rnn2 : 0.498
# F1-score macro rnn2 : 0.438
# F1-score None rnn2 : [0.452 0.197 0.516 0.587]
#
# ------ Testing ------
# Accuracy rnn2 : 0.473
# F1-score macro rnn2 : 0.348
# F1-score None rnn2 : [0.164 0.214 0.419 0.596]
#
# ------ Training ------
# Accuracy rnn3 : 0.670
# F1-score macro rnn3 : 0.661
# F1-score None rnn3 : [0.653 0.675 0.801 0.517]
#
# ------ Validation ------
# Accuracy rnn3 : 0.473
# F1-score macro rnn3 : 0.457
# F1-score None rnn3 : [0.573 0.108 0.648 0.5  ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.338
# F1-score macro rnn3 : 0.328
# F1-score None rnn3 : [0.281 0.153 0.467 0.41 ]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.898
# F1-score macro cnn1 : 0.897
# F1-score None cnn1 : [0.831 0.957 0.97  0.832]
#
# ------ Validation ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.516
# F1-score None cnn1 : [0.58  0.211 0.5   0.775]
#
# ------ Testing ------
# Accuracy cnn1 : 0.679
# F1-score macro cnn1 : 0.402
# F1-score None cnn1 : [0.108 0.185 0.516 0.798]
#
# ------ Training ------
# Accuracy cnn2 : 0.867
# F1-score macro cnn2 : 0.866
# F1-score None cnn2 : [0.77  0.941 0.96  0.794]
#
# ------ Validation ------
# Accuracy cnn2 : 0.701
# F1-score macro cnn2 : 0.511
# F1-score None cnn2 : [0.491 0.143 0.618 0.794]
#
# ------ Testing ------
# Accuracy cnn2 : 0.725
# F1-score macro cnn2 : 0.409
# F1-score None cnn2 : [0.062 0.174 0.566 0.834]
#
# ------ Training ------
# Accuracy rnn1 : 0.580
# F1-score macro rnn1 : 0.546
# F1-score None rnn1 : [0.468 0.611 0.734 0.373]
#
# ------ Validation ------
# Accuracy rnn1 : 0.338
# F1-score macro rnn1 : 0.339
# F1-score None rnn1 : [0.466 0.103 0.44  0.348]
#
# ------ Testing ------
# Accuracy rnn1 : 0.287
# F1-score macro rnn1 : 0.240
# F1-score None rnn1 : [0.047 0.158 0.413 0.341]
#
# ------ Training ------
# Accuracy rnn2 : 0.818
# F1-score macro rnn2 : 0.820
# F1-score None rnn2 : [0.786 0.856 0.902 0.734]
#
# ------ Validation ------
# Accuracy rnn2 : 0.619
# F1-score macro rnn2 : 0.499
# F1-score None rnn2 : [0.576 0.133 0.588 0.697]
#
# ------ Testing ------
# Accuracy rnn2 : 0.544
# F1-score macro rnn2 : 0.381
# F1-score None rnn2 : [0.182 0.167 0.486 0.69 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.632
# F1-score macro rnn3 : 0.609
# F1-score None rnn3 : [0.634 0.658 0.731 0.414]
#
# ------ Validation ------
# Accuracy rnn3 : 0.399
# F1-score macro rnn3 : 0.379
# F1-score None rnn3 : [0.509 0.148 0.49  0.369]
#
# ------ Testing ------
# Accuracy rnn3 : 0.295
# F1-score macro rnn3 : 0.279
# F1-score None rnn3 : [0.194 0.176 0.421 0.324]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.898
# F1-score macro cnn1 : 0.898
# F1-score None cnn1 : [0.844 0.946 0.968 0.834]
#
# ------ Validation ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.518
# F1-score None cnn1 : [0.593 0.167 0.557 0.754]
#
# ------ Testing ------
# Accuracy cnn1 : 0.663
# F1-score macro cnn1 : 0.410
# F1-score None cnn1 : [0.069 0.226 0.56  0.784]
#
# ------ Training ------
# Accuracy cnn2 : 0.879
# F1-score macro cnn2 : 0.878
# F1-score None cnn2 : [0.791 0.949 0.964 0.808]
#
# ------ Validation ------
# Accuracy cnn2 : 0.680
# F1-score macro cnn2 : 0.535
# F1-score None cnn2 : [0.516 0.19  0.667 0.768]
#
# ------ Testing ------
# Accuracy cnn2 : 0.702
# F1-score macro cnn2 : 0.419
# F1-score None cnn2 : [0.067 0.212 0.582 0.816]
#
# ------ Training ------
# Accuracy rnn1 : 0.486
# F1-score macro rnn1 : 0.475
# F1-score None rnn1 : [0.478 0.521 0.508 0.392]
# ------ Validation ------
# Accuracy rnn1 : 0.402
# F1-score macro rnn1 : 0.413
# F1-score None rnn1 : [0.513 0.116 0.513 0.51 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.274
# F1-score macro rnn1 : 0.232
# F1-score None rnn1 : [0.05  0.154 0.336 0.389]
#
# ------ Training ------
# Accuracy rnn2 : 0.822
# F1-score macro rnn2 : 0.823
# F1-score None rnn2 : [0.778 0.829 0.928 0.757]
#
# ------ Validation ------
# Accuracy rnn2 : 0.705
# F1-score macro rnn2 : 0.516
# F1-score None rnn2 : [0.636 0.    0.646 0.783]
#
# ------ Testing ------
# Accuracy rnn2 : 0.660
# F1-score macro rnn2 : 0.364
# F1-score None rnn2 : [0.109 0.122 0.437 0.791]
#
# ------ Training ------
# Accuracy rnn3 : 0.691
# F1-score macro rnn3 : 0.688
# F1-score None rnn3 : [0.651 0.646 0.812 0.642]
#
# ------ Validation ------
# Accuracy rnn3 : 0.687
# F1-score macro rnn3 : 0.519
# F1-score None rnn3 : [0.56  0.083 0.648 0.784]
#
# ------ Testing ------
# Accuracy rnn3 : 0.657
# F1-score macro rnn3 : 0.391
# F1-score None rnn3 : [0.074 0.174 0.535 0.783]
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.873
# F1-score macro cnn1 : 0.870
# F1-score None cnn1 : [0.803 0.938 0.941 0.8  ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.550
# F1-score None cnn1 : [0.574 0.267 0.605 0.754]
#
# ------ Testing ------
# Accuracy cnn1 : 0.647
# F1-score macro cnn1 : 0.394
# F1-score None cnn1 : [0.041 0.255 0.512 0.769]
#
# ------ Training ------
# Accuracy cnn2 : 0.890
# F1-score macro cnn2 : 0.890
# F1-score None cnn2 : [0.847 0.943 0.952 0.818]
#
# ------ Validation ------
# Accuracy cnn2 : 0.648
# F1-score macro cnn2 : 0.500
# F1-score None cnn2 : [0.547 0.095 0.629 0.729]
#
# ------ Testing ------
# Accuracy cnn2 : 0.666
# F1-score macro cnn2 : 0.418
# F1-score None cnn2 : [0.139 0.213 0.536 0.786]
#
# ------ Training ------
# Accuracy rnn1 : 0.563
# F1-score macro rnn1 : 0.558
# F1-score None rnn1 : [0.608 0.498 0.777 0.348]
#
# ------ Validation ------
# Accuracy rnn1 : 0.470
# F1-score macro rnn1 : 0.423
# F1-score None rnn1 : [0.475 0.1   0.667 0.451]
#
# ------ Testing ------
# Accuracy rnn1 : 0.396
# F1-score macro rnn1 : 0.331
# F1-score None rnn1 : [0.152 0.182 0.458 0.533]
#
# ------ Training ------
# Accuracy rnn2 : 0.784
# F1-score macro rnn2 : 0.788
# F1-score None rnn2 : [0.702 0.846 0.894 0.71 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.669
# F1-score macro rnn2 : 0.481
# F1-score None rnn2 : [0.481 0.129 0.533 0.78 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.720
# F1-score macro rnn2 : 0.365
# F1-score None rnn2 : [0.1   0.152 0.373 0.837]
#
# ------ Training ------
# Accuracy rnn3 : 0.583
# F1-score macro rnn3 : 0.563
# F1-score None rnn3 : [0.326 0.616 0.737 0.571]
#
# ------ Validation ------
# Accuracy rnn3 : 0.644
# F1-score macro rnn3 : 0.449
# F1-score None rnn3 : [0.128 0.24  0.656 0.77 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.687
# F1-score macro rnn3 : 0.386
# F1-score None rnn3 : [0.    0.167 0.57  0.805]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.85 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.85 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.85 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.85 - F1-score promedio para cnn1 : [0.076 0.195 0.522 0.809]
# 0.85 - F1-score promedio para cnn2 : [0.099 0.209 0.56  0.795]
# 0.85 - F1-score promedio para rnn1 : [0.142 0.153 0.418 0.416]
# 0.85 - F1-score promedio para rnn2 : [0.127 0.165 0.426 0.714]
# 0.85 - F1-score promedio para rnn3 : [0.176 0.17  0.447 0.527]
#
# 0.85 - F1-score macro promedio para cnn1 : 0.4003995441184792 desvest:  0.011601102053806212
# 0.85 - F1-score macro promedio para cnn2 : 0.4159982060086902 desvest:  0.012802216429697824
# 0.85 - F1-score macro promedio para rnn1 : 0.2821754812181269 desvest:  0.07014588616143995
# 0.85 - F1-score macro promedio para rnn2 : 0.358010143827124 desvest:  0.012090791677495006
# 0.85 - F1-score macro promedio para rnn3 : 0.32994511860483133 desvest:  0.04473069762537621
#
# 0.85 - Accuracy promedio para cnn1 : 0.6932419196865818 desvest:  0.025573490962378195
# 0.85 - Accuracy promedio para cnn2 : 0.6784524975514202 desvest:  0.04570296378462062
# 0.85 - Accuracy promedio para rnn1 : 0.3437806072477963 desvest:  0.1288427719437222
# 0.85 - Accuracy promedio para rnn2 : 0.5769833496571988 desvest:  0.07699038978109282
# 0.85 - Accuracy promedio para rnn3 : 0.43359451518119496 desvest:  0.14638431817620226

# %%
-------------------------------------------------------------------------------------
-------------------------------------------------------------------------------------

# %% [markdown]
# # Dropout normal - 0.65

# %%
class_weights
# Out:
# [1.0, 1.0, 1.0, 1.0]

# %%
fs_macro, fs_none, accs, confusions= train_5models(10, '0.0', x_train, y_train, n_labels, class_weights, 20, 10)
# Out:
#  -------------------- Entrenando exec 1  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.769
# F1-score macro cnn1 : 0.633
# F1-score None cnn1 : [0.642 0.374 0.672 0.843]
#
# ------ Validation ------
# Accuracy cnn1 : 0.726
# F1-score macro cnn1 : 0.572
# F1-score None cnn1 : [0.513 0.222 0.741 0.812]
#
# ------ Testing ------
# Accuracy cnn1 : 0.754
# F1-score macro cnn1 : 0.403
# F1-score None cnn1 : [0.067 0.092 0.598 0.853]
#
# ------ Training ------
# Accuracy cnn2 : 0.725
# F1-score macro cnn2 : 0.469
# F1-score None cnn2 : [0.393 0.    0.66  0.824]
#
# ------ Validation ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.399
# F1-score None cnn2 : [0.182 0.    0.63  0.786]
#
# ------ Testing ------
# Accuracy cnn2 : 0.795
# F1-score macro cnn2 : 0.380
# F1-score None cnn2 : [0.    0.    0.64  0.879]
#
# ------ Training ------
# Accuracy rnn1 : 0.197
# F1-score macro rnn1 : 0.194
# F1-score None rnn1 : [0.46  0.    0.174 0.141]
#
# ------ Validation ------
# Accuracy rnn1 : 0.238
# F1-score macro rnn1 : 0.204
# F1-score None rnn1 : [0.4   0.    0.236 0.18 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.174
# F1-score macro rnn1 : 0.108
# F1-score None rnn1 : [0.064 0.    0.203 0.167]
#
# ------ Training ------
# Accuracy rnn2 : 0.758
# F1-score macro rnn2 : 0.567
# F1-score None rnn2 : [0.634 0.18  0.61  0.844]
#
# ------ Validation ------
# Accuracy rnn2 : 0.737
# F1-score macro rnn2 : 0.552
# F1-score None rnn2 : [0.637 0.154 0.604 0.814]
#
# ------ Testing ------
# Accuracy rnn2 : 0.741
# F1-score macro rnn2 : 0.391
# F1-score None rnn2 : [0.125 0.072 0.519 0.846]
#
# ------ Training ------
# Accuracy rnn3 : 0.344
# F1-score macro rnn3 : 0.291
# F1-score None rnn3 : [0.547 0.    0.21  0.405]
#
# ------ Validation ------
# Accuracy rnn3 : 0.409
# F1-score macro rnn3 : 0.330
# F1-score None rnn3 : [0.613 0.    0.287 0.418]
#
# ------ Testing ------
# Accuracy rnn3 : 0.313
# F1-score macro rnn3 : 0.189
# F1-score None rnn3 : [0.103 0.    0.242 0.411]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.746
# F1-score macro cnn1 : 0.492
# F1-score None cnn1 : [0.567 0.    0.568 0.834]
#
# ------ Validation ------
# Accuracy cnn1 : 0.740
# F1-score macro cnn1 : 0.486
# F1-score None cnn1 : [0.563 0.    0.558 0.825]
#
# ------ Testing ------
# Accuracy cnn1 : 0.787
# F1-score macro cnn1 : 0.361
# F1-score None cnn1 : [0.025 0.    0.54  0.877]
#
# ------ Training ------
# Accuracy cnn2 : 0.738
# F1-score macro cnn2 : 0.487
# F1-score None cnn2 : [0.531 0.    0.588 0.829]
#
# ------ Validation ------
# Accuracy cnn2 : 0.676
# F1-score macro cnn2 : 0.388
# F1-score None cnn2 : [0.182 0.    0.578 0.793]
#
# ------ Testing ------
# Accuracy cnn2 : 0.783
# F1-score macro cnn2 : 0.355
# F1-score None cnn2 : [0.    0.    0.549 0.872]
#
# ------ Training ------
# Accuracy rnn1 : 0.701
# F1-score macro rnn1 : 0.439
# F1-score None rnn1 : [0.487 0.    0.465 0.805]
#
# ------ Validation ------
# Accuracy rnn1 : 0.705
# F1-score macro rnn1 : 0.478
# F1-score None rnn1 : [0.538 0.    0.583 0.792]
#
# ------ Testing ------
# Accuracy rnn1 : 0.758
# F1-score macro rnn1 : 0.358
# F1-score None rnn1 : [0.08  0.    0.494 0.856]
#
# ------ Training ------
# Accuracy rnn2 : 0.761
# F1-score macro rnn2 : 0.528
# F1-score None rnn2 : [0.647 0.024 0.59  0.851]
#
# ------ Validation ------
# Accuracy rnn2 : 0.751
# F1-score macro rnn2 : 0.529
# F1-score None rnn2 : [0.656 0.    0.633 0.825]
#
# ------ Testing ------
# Accuracy rnn2 : 0.752
# F1-score macro rnn2 : 0.391
# F1-score None rnn2 : [0.139 0.028 0.544 0.852]
#
# ------ Training ------
# Accuracy rnn3 : 0.717
# F1-score macro rnn3 : 0.421
# F1-score None rnn3 : [0.566 0.    0.302 0.816]
#
# ------ Validation ------
# Accuracy rnn3 : 0.712
# F1-score macro rnn3 : 0.460
# F1-score None rnn3 : [0.6   0.    0.444 0.795]
#
# ------ Testing ------
# Accuracy rnn3 : 0.749
# F1-score macro rnn3 : 0.289
# F1-score None rnn3 : [0.082 0.    0.22  0.854]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.755
# F1-score macro cnn1 : 0.538
# F1-score None cnn1 : [0.586 0.035 0.694 0.837]
#
# ------ Validation ------
# Accuracy cnn1 : 0.719
# F1-score macro cnn1 : 0.497
# F1-score None cnn1 : [0.519 0.    0.667 0.802]
#
# ------ Testing ------
# Accuracy cnn1 : 0.766
# F1-score macro cnn1 : 0.359
# F1-score None cnn1 : [0.    0.    0.575 0.86 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.732
# F1-score macro cnn2 : 0.480
# F1-score None cnn2 : [0.487 0.    0.608 0.826]
#
# ------ Validation ------
# Accuracy cnn2 : 0.687
# F1-score macro cnn2 : 0.430
# F1-score None cnn2 : [0.286 0.    0.642 0.792]
#
# ------ Testing ------
# Accuracy cnn2 : 0.792
# F1-score macro cnn2 : 0.377
# F1-score None cnn2 : [0.    0.    0.633 0.877]
#
# ------ Training ------
# Accuracy rnn1 : 0.681
# F1-score macro rnn1 : 0.306
# F1-score None rnn1 : [0.428 0.    0.    0.797]
#
# ------ Validation ------
# Accuracy rnn1 : 0.662
# F1-score macro rnn1 : 0.315
# F1-score None rnn1 : [0.491 0.    0.    0.77 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.750
# F1-score macro rnn1 : 0.232
# F1-score None rnn1 : [0.069 0.    0.    0.857]
#
# ------ Training ------
# Accuracy rnn2 : 0.777
# F1-score macro rnn2 : 0.582
# F1-score None rnn2 : [0.671 0.201 0.6   0.856]
#
# ------ Validation ------
# Accuracy rnn2 : 0.733
# F1-score macro rnn2 : 0.538
# F1-score None rnn2 : [0.647 0.143 0.549 0.813]
#
# ------ Testing ------
# Accuracy rnn2 : 0.751
# F1-score macro rnn2 : 0.405
# F1-score None rnn2 : [0.228 0.095 0.443 0.854]
#
# ------ Training ------
# Accuracy rnn3 : 0.691
# F1-score macro rnn3 : 0.450
# F1-score None rnn3 : [0.527 0.    0.472 0.799]
#
# ------ Validation ------
# Accuracy rnn3 : 0.726
# F1-score macro rnn3 : 0.502
# F1-score None rnn3 : [0.529 0.    0.667 0.813]
#
# ------ Testing ------
# Accuracy rnn3 : 0.759
# F1-score macro rnn3 : 0.378
# F1-score None rnn3 : [0.051 0.    0.607 0.854]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.767
# F1-score macro cnn1 : 0.572
# F1-score None cnn1 : [0.616 0.165 0.663 0.845]
#
# ------ Validation ------
# Accuracy cnn1 : 0.705
# F1-score macro cnn1 : 0.504
# F1-score None cnn1 : [0.442 0.167 0.609 0.8  ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.780
# F1-score macro cnn1 : 0.355
# F1-score None cnn1 : [0.024 0.    0.524 0.872]
#
# ------ Training ------
# Accuracy cnn2 : 0.725
# F1-score macro cnn2 : 0.480
# F1-score None cnn2 : [0.426 0.    0.671 0.823]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.395
# F1-score None cnn2 : [0.16  0.    0.635 0.785]
#
# ------ Testing ------
# Accuracy cnn2 : 0.786
# F1-score macro cnn2 : 0.375
# F1-score None cnn2 : [0.    0.    0.626 0.874]
#
# ------ Training ------
# Accuracy rnn1 : 0.645
# F1-score macro rnn1 : 0.196
# F1-score None rnn1 : [0.    0.    0.    0.784]
#
# ------ Validation ------
# Accuracy rnn1 : 0.616
# F1-score macro rnn1 : 0.191
# F1-score None rnn1 : [0.    0.    0.    0.762]
#
# ------ Testing ------
# Accuracy rnn1 : 0.762
# F1-score macro rnn1 : 0.216
# F1-score None rnn1 : [0.    0.    0.    0.865]
#
# ------ Training ------
# Accuracy rnn2 : 0.772
# F1-score macro rnn2 : 0.539
# F1-score None rnn2 : [0.637 0.018 0.642 0.858]
#
# ------ Validation ------
# Accuracy rnn2 : 0.744
# F1-score macro rnn2 : 0.522
# F1-score None rnn2 : [0.617 0.    0.654 0.818]
#
# ------ Testing ------
# Accuracy rnn2 : 0.750
# F1-score macro rnn2 : 0.343
# F1-score None rnn2 : [0.068 0.    0.45  0.852]
#
# ------ Training ------
# Accuracy rnn3 : 0.577
# F1-score macro rnn3 : 0.402
# F1-score None rnn3 : [0.473 0.    0.451 0.683]
#
# ------ Validation ------
# Accuracy rnn3 : 0.637
# F1-score macro rnn3 : 0.464
# F1-score None rnn3 : [0.539 0.    0.6   0.718]
#
# ------ Testing ------
# Accuracy rnn3 : 0.622
# F1-score macro rnn3 : 0.389
# F1-score None rnn3 : [0.22  0.    0.579 0.757]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.761
# F1-score macro cnn1 : 0.582
# F1-score None cnn1 : [0.567 0.229 0.69  0.843]
#
# ------ Validation ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.443
# F1-score None cnn1 : [0.374 0.    0.604 0.796]
#
# ------ Testing ------
# Accuracy cnn1 : 0.778
# F1-score macro cnn1 : 0.372
# F1-score None cnn1 : [0.    0.025 0.595 0.87 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.735
# F1-score macro cnn2 : 0.480
# F1-score None cnn2 : [0.513 0.    0.581 0.828]
#
# ------ Validation ------
# Accuracy cnn2 : 0.708
# F1-score macro cnn2 : 0.459
# F1-score None cnn2 : [0.391 0.    0.638 0.806]
# ------ Testing ------
# Accuracy cnn2 : 0.791
# F1-score macro cnn2 : 0.362
# F1-score None cnn2 : [0.    0.    0.571 0.878]
#
# ------ Training ------
# Accuracy rnn1 : 0.645
# F1-score macro rnn1 : 0.196
# F1-score None rnn1 : [0.    0.    0.    0.784]
#
# ------ Validation ------
# Accuracy rnn1 : 0.616
# F1-score macro rnn1 : 0.191
# F1-score None rnn1 : [0.    0.    0.    0.762]
#
# ------ Testing ------
# Accuracy rnn1 : 0.762
# F1-score macro rnn1 : 0.216
# F1-score None rnn1 : [0.    0.    0.    0.865]
#
# ------ Training ------
# Accuracy rnn2 : 0.720
# F1-score macro rnn2 : 0.486
# F1-score None rnn2 : [0.634 0.    0.481 0.829]
#
# ------ Validation ------
# Accuracy rnn2 : 0.694
# F1-score macro rnn2 : 0.488
# F1-score None rnn2 : [0.565 0.    0.608 0.782]
#
# ------ Testing ------
# Accuracy rnn2 : 0.702
# F1-score macro rnn2 : 0.387
# F1-score None rnn2 : [0.256 0.    0.473 0.819]
#
# ------ Training ------
# Accuracy rnn3 : 0.357
# F1-score macro rnn3 : 0.302
# F1-score None rnn3 : [0.591 0.    0.215 0.402]
#
# ------ Validation ------
# Accuracy rnn3 : 0.402
# F1-score macro rnn3 : 0.324
# F1-score None rnn3 : [0.628 0.    0.289 0.379]
#
# ------ Testing ------
# Accuracy rnn3 : 0.327
# F1-score macro rnn3 : 0.226
# F1-score None rnn3 : [0.233 0.    0.248 0.425]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.761
# F1-score macro cnn1 : 0.540
# F1-score None cnn1 : [0.594 0.047 0.678 0.842]
#
# ------ Validation ------
# Accuracy cnn1 : 0.719
# F1-score macro cnn1 : 0.483
# F1-score None cnn1 : [0.554 0.    0.571 0.807]
#
# ------ Testing ------
# Accuracy cnn1 : 0.789
# F1-score macro cnn1 : 0.375
# F1-score None cnn1 : [0.027 0.    0.597 0.876]
#
# ------ Training ------
# Accuracy cnn2 : 0.699
# F1-score macro cnn2 : 0.424
# F1-score None cnn2 : [0.252 0.    0.634 0.811]
#
# ------ Validation ------
# Accuracy cnn2 : 0.655
# F1-score macro cnn2 : 0.360
# F1-score None cnn2 : [0.056 0.    0.603 0.782]
#
# ------ Testing ------
# Accuracy cnn2 : 0.795
# F1-score macro cnn2 : 0.386
# F1-score None cnn2 : [0.    0.    0.664 0.879]
#
# ------ Training ------
# Accuracy rnn1 : 0.645
# F1-score macro rnn1 : 0.196
# F1-score None rnn1 : [0.    0.    0.    0.784]
#
# ------ Validation ------
# Accuracy rnn1 : 0.616
# F1-score macro rnn1 : 0.191
# F1-score None rnn1 : [0.    0.    0.    0.762]
#
# ------ Testing ------
# Accuracy rnn1 : 0.762
# F1-score macro rnn1 : 0.216
# F1-score None rnn1 : [0.    0.    0.    0.865]
#
# ------ Training ------
# Accuracy rnn2 : 0.773
# F1-score macro rnn2 : 0.626
# F1-score None rnn2 : [0.696 0.337 0.62  0.853]
#
# ------ Validation ------
# Accuracy rnn2 : 0.712
# F1-score macro rnn2 : 0.542
# F1-score None rnn2 : [0.627 0.133 0.623 0.784]
#
# ------ Testing ------
# Accuracy rnn2 : 0.699
# F1-score macro rnn2 : 0.415
# F1-score None rnn2 : [0.219 0.158 0.465 0.819]
#
# ------ Training ------
# Accuracy rnn3 : 0.718
# F1-score macro rnn3 : 0.472
# F1-score None rnn3 : [0.569 0.    0.506 0.813]
#
# ------ Validation ------
# Accuracy rnn3 : 0.737
# F1-score macro rnn3 : 0.511
# F1-score None rnn3 : [0.641 0.    0.588 0.813]
#
# ------ Testing ------
# Accuracy rnn3 : 0.757
# F1-score macro rnn3 : 0.400
# F1-score None rnn3 : [0.24  0.    0.505 0.855]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.774
# F1-score macro cnn1 : 0.634
# F1-score None cnn1 : [0.621 0.358 0.709 0.847]
#
# ------ Validation ------
# Accuracy cnn1 : 0.737
# F1-score macro cnn1 : 0.548
# F1-score None cnn1 : [0.52  0.167 0.69  0.816]
#
# ------ Testing ------
# Accuracy cnn1 : 0.759
# F1-score macro cnn1 : 0.399
# F1-score None cnn1 : [0.094 0.065 0.581 0.856]
#
# ------ Training ------
# Accuracy cnn2 : 0.724
# F1-score macro cnn2 : 0.466
# F1-score None cnn2 : [0.439 0.    0.603 0.822]
#
# ------ Validation ------
# Accuracy cnn2 : 0.687
# F1-score macro cnn2 : 0.417
# F1-score None cnn2 : [0.205 0.    0.667 0.796]
#
# ------ Testing ------
# Accuracy cnn2 : 0.787
# F1-score macro cnn2 : 0.367
# F1-score None cnn2 : [0.    0.    0.595 0.875]
#
# ------ Training ------
# Accuracy rnn1 : 0.645
# F1-score macro rnn1 : 0.196
# F1-score None rnn1 : [0.    0.    0.    0.784]
#
# ------ Validation ------
# Accuracy rnn1 : 0.616
# F1-score macro rnn1 : 0.191
# F1-score None rnn1 : [0.    0.    0.    0.762]
#
# ------ Testing ------
# Accuracy rnn1 : 0.762
# F1-score macro rnn1 : 0.216
# F1-score None rnn1 : [0.    0.    0.    0.865]
#
# ------ Training ------
# Accuracy rnn2 : 0.748
# F1-score macro rnn2 : 0.532
# F1-score None rnn2 : [0.651 0.012 0.631 0.833]
#
# ------ Validation ------
# Accuracy rnn2 : 0.669
# F1-score macro rnn2 : 0.474
# F1-score None rnn2 : [0.548 0.    0.6   0.749]
#
# ------ Testing ------
# Accuracy rnn2 : 0.699
# F1-score macro rnn2 : 0.388
# F1-score None rnn2 : [0.213 0.    0.526 0.816]
#
# ------ Training ------
# Accuracy rnn3 : 0.703
# F1-score macro rnn3 : 0.385
# F1-score None rnn3 : [0.556 0.    0.178 0.806]
#
# ------ Validation ------
# Accuracy rnn3 : 0.665
# F1-score macro rnn3 : 0.363
# F1-score None rnn3 : [0.552 0.    0.133 0.765]
#
# ------ Testing ------
# Accuracy rnn3 : 0.741
# F1-score macro rnn3 : 0.274
# F1-score None rnn3 : [0.111 0.    0.136 0.851]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.754
# F1-score macro cnn1 : 0.555
# F1-score None cnn1 : [0.52  0.184 0.675 0.839]
#
# ------ Validation ------
# Accuracy cnn1 : 0.719
# F1-score macro cnn1 : 0.482
# F1-score None cnn1 : [0.479 0.    0.643 0.807]
#
# ------ Testing ------
# Accuracy cnn1 : 0.793
# F1-score macro cnn1 : 0.385
# F1-score None cnn1 : [0.    0.027 0.633 0.879]
#
# ------ Training ------
# Accuracy cnn2 : 0.751
# F1-score macro cnn2 : 0.511
# F1-score None cnn2 : [0.599 0.012 0.597 0.836]
#
# ------ Validation ------
# Accuracy cnn2 : 0.687
# F1-score macro cnn2 : 0.446
# F1-score None cnn2 : [0.392 0.    0.605 0.788]
#
# ------ Testing ------
# Accuracy cnn2 : 0.777
# F1-score macro cnn2 : 0.360
# F1-score None cnn2 : [0.047 0.    0.524 0.869]
#
# ------ Training ------
# Accuracy rnn1 : 0.654
# F1-score macro rnn1 : 0.391
# F1-score None rnn1 : [0.48  0.    0.317 0.765]
#
# ------ Validation ------
# Accuracy rnn1 : 0.651
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.553 0.    0.229 0.747]
#
# ------ Testing ------
# Accuracy rnn1 : 0.664
# F1-score macro rnn1 : 0.289
# F1-score None rnn1 : [0.103 0.    0.261 0.792]
#
# ------ Training ------
# Accuracy rnn2 : 0.742
# F1-score macro rnn2 : 0.555
# F1-score None rnn2 : [0.631 0.195 0.565 0.827]
#
# ------ Validation ------
# Accuracy rnn2 : 0.719
# F1-score macro rnn2 : 0.619
# F1-score None rnn2 : [0.595 0.4   0.694 0.789]
#
# ------ Testing ------
# Accuracy rnn2 : 0.712
# F1-score macro rnn2 : 0.392
# F1-score None rnn2 : [0.222 0.025 0.494 0.825]
#
# ------ Training ------
# Accuracy rnn3 : 0.704
# F1-score macro rnn3 : 0.473
# F1-score None rnn3 : [0.576 0.    0.515 0.801]
#
# ------ Validation ------
# Accuracy rnn3 : 0.715
# F1-score macro rnn3 : 0.510
# F1-score None rnn3 : [0.63  0.    0.621 0.79 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.714
# F1-score macro rnn3 : 0.397
# F1-score None rnn3 : [0.169 0.    0.6   0.821]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.740
# F1-score macro cnn1 : 0.500
# F1-score None cnn1 : [0.473 0.091 0.602 0.832]
#
# ------ Validation ------
# Accuracy cnn1 : 0.687
# F1-score macro cnn1 : 0.414
# F1-score None cnn1 : [0.326 0.    0.533 0.795]
#
# ------ Testing ------
# Accuracy cnn1 : 0.783
# F1-score macro cnn1 : 0.332
# F1-score None cnn1 : [0.    0.    0.455 0.874]
#
# ------ Training ------
# Accuracy cnn2 : 0.720
# F1-score macro cnn2 : 0.450
# F1-score None cnn2 : [0.426 0.    0.556 0.821]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.399
# F1-score None cnn2 : [0.22  0.    0.596 0.782]
#
# ------ Testing ------
# Accuracy cnn2 : 0.789
# F1-score macro cnn2 : 0.358
# F1-score None cnn2 : [0.    0.    0.554 0.877]
#
# ------ Training ------
# Accuracy rnn1 : 0.666
# F1-score macro rnn1 : 0.336
# F1-score None rnn1 : [0.479 0.    0.083 0.781]
#
# ------ Validation ------
# Accuracy rnn1 : 0.651
# F1-score macro rnn1 : 0.352
# F1-score None rnn1 : [0.519 0.    0.133 0.754]
#
# ------ Testing ------
# Accuracy rnn1 : 0.688
# F1-score macro rnn1 : 0.233
# F1-score None rnn1 : [0.065 0.    0.054 0.813]
#
# ------ Training ------
# Accuracy rnn2 : 0.747
# F1-score macro rnn2 : 0.496
# F1-score None rnn2 : [0.616 0.012 0.522 0.836]
#
# ------ Validation ------
# Accuracy rnn2 : 0.730
# F1-score macro rnn2 : 0.550
# F1-score None rnn2 : [0.587 0.167 0.638 0.806]
# ------ Testing ------
# Accuracy rnn2 : 0.740
# F1-score macro rnn2 : 0.332
# F1-score None rnn2 : [0.114 0.    0.366 0.847]
#
# ------ Training ------
# Accuracy rnn3 : 0.642
# F1-score macro rnn3 : 0.450
# F1-score None rnn3 : [0.541 0.    0.518 0.741]
#
# ------ Validation ------
# Accuracy rnn3 : 0.690
# F1-score macro rnn3 : 0.516
# F1-score None rnn3 : [0.601 0.    0.704 0.757]
#
# ------ Testing ------
# Accuracy rnn3 : 0.670
# F1-score macro rnn3 : 0.402
# F1-score None rnn3 : [0.218 0.    0.604 0.788]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.724
# F1-score macro cnn1 : 0.478
# F1-score None cnn1 : [0.448 0.012 0.628 0.824]
#
# ------ Validation ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.390
# F1-score None cnn1 : [0.16  0.    0.613 0.787]
#
# ------ Testing ------
# Accuracy cnn1 : 0.771
# F1-score macro cnn1 : 0.362
# F1-score None cnn1 : [0.    0.    0.583 0.865]
#
# ------ Training ------
# Accuracy cnn2 : 0.745
# F1-score macro cnn2 : 0.489
# F1-score None cnn2 : [0.581 0.    0.542 0.833]
#
# ------ Validation ------
# Accuracy cnn2 : 0.690
# F1-score macro cnn2 : 0.431
# F1-score None cnn2 : [0.318 0.    0.609 0.796]
#
# ------ Testing ------
# Accuracy cnn2 : 0.788
# F1-score macro cnn2 : 0.365
# F1-score None cnn2 : [0.027 0.    0.555 0.877]
#
# ------ Training ------
# Accuracy rnn1 : 0.678
# F1-score macro rnn1 : 0.434
# F1-score None rnn1 : [0.45  0.    0.499 0.789]
#
# ------ Validation ------
# Accuracy rnn1 : 0.698
# F1-score macro rnn1 : 0.489
# F1-score None rnn1 : [0.52  0.    0.647 0.789]
#
# ------ Testing ------
# Accuracy rnn1 : 0.742
# F1-score macro rnn1 : 0.378
# F1-score None rnn1 : [0.017 0.    0.655 0.841]
#
# ------ Training ------
# Accuracy rnn2 : 0.767
# F1-score macro rnn2 : 0.539
# F1-score None rnn2 : [0.664 0.    0.639 0.852]
#
# ------ Validation ------
# Accuracy rnn2 : 0.722
# F1-score macro rnn2 : 0.499
# F1-score None rnn2 : [0.642 0.    0.556 0.799]
#
# ------ Testing ------
# Accuracy rnn2 : 0.738
# F1-score macro rnn2 : 0.399
# F1-score None rnn2 : [0.221 0.    0.534 0.842]
#
# ------ Training ------
# Accuracy rnn3 : 0.720
# F1-score macro rnn3 : 0.454
# F1-score None rnn3 : [0.583 0.    0.417 0.815]
#
# ------ Validation ------
# Accuracy rnn3 : 0.719
# F1-score macro rnn3 : 0.488
# F1-score None rnn3 : [0.606 0.    0.55  0.797]
#
# ------ Testing ------
# Accuracy rnn3 : 0.752
# F1-score macro rnn3 : 0.364
# F1-score None rnn3 : [0.231 0.    0.373 0.853]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.0 - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.0 - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.0 - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.0 - F1-score promedio para cnn1 : [0.024 0.021 0.568 0.868]
# 0.0 - F1-score promedio para cnn2 : [0.007 0.    0.591 0.876]
# 0.0 - F1-score promedio para rnn1 : [0.04  0.    0.167 0.779]
# 0.0 - F1-score promedio para rnn2 : [0.18  0.038 0.481 0.837]
# 0.0 - F1-score promedio para rnn3 : [0.166 0.    0.411 0.747]
#
# 0.0 - F1-score macro promedio para cnn1 : 0.37019646481579305 desvest:  0.020190529707242447
# 0.0 - F1-score macro promedio para cnn2 : 0.36853662699175205 desvest:  0.009829008142514091
# 0.0 - F1-score macro promedio para rnn1 : 0.24627580383315256 desvest:  0.07392118322480047
# 0.0 - F1-score macro promedio para rnn2 : 0.3842379539630598 desvest:  0.025002269211470984
# 0.0 - F1-score macro promedio para rnn3 : 0.3310551285002259 desvest:  0.07552406934641462
#
# 0.0 - Accuracy promedio para cnn1 : 0.7760039177277178 desvest:  0.012504933358493911
# 0.0 - Accuracy promedio para cnn2 : 0.7885406464250735 desvest:  0.005443562480544657
# 0.0 - Accuracy promedio para rnn1 : 0.6824681684622919 desvest:  0.17255845097001563
# 0.0 - Accuracy promedio para rnn2 : 0.7286973555337906 desvest:  0.021502936728795444
# 0.0 - Accuracy promedio para rnn3 : 0.6405484818805094 desvest:  0.1655124047660058

# %%
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
#class_weights=np.asarray(class_weights)
## cw de lozano [0.157, 0.396, 0.399, 0.048].
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1.26  3.182 3.211 0.388]

# %%
fs_macro, fs_none, accs, confusions= train_5models(10, '0.0cw', x_train, y_train, n_labels, class_weights, 20, 10)
# Out:
#  -------------------- Entrenando exec 1  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.669
# F1-score macro cnn1 : 0.605
# F1-score None cnn1 : [0.594 0.434 0.646 0.744]
#
# ------ Validation ------
# Accuracy cnn1 : 0.665
# F1-score macro cnn1 : 0.549
# F1-score None cnn1 : [0.559 0.222 0.647 0.767]
#
# ------ Testing ------
# Accuracy cnn1 : 0.618
# F1-score macro cnn1 : 0.413
# F1-score None cnn1 : [0.073 0.215 0.613 0.75 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.520
# F1-score macro cnn2 : 0.488
# F1-score None cnn2 : [0.554 0.262 0.544 0.592]
#
# ------ Validation ------
# Accuracy cnn2 : 0.530
# F1-score macro cnn2 : 0.427
# F1-score None cnn2 : [0.294 0.185 0.575 0.652]
#
# ------ Testing ------
# Accuracy cnn2 : 0.506
# F1-score macro cnn2 : 0.360
# F1-score None cnn2 : [0.042 0.175 0.588 0.634]
#
# ------ Training ------
# Accuracy rnn1 : 0.381
# F1-score macro rnn1 : 0.403
# F1-score None rnn1 : [0.504 0.218 0.531 0.36 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.431
# F1-score macro rnn1 : 0.428
# F1-score None rnn1 : [0.556 0.089 0.667 0.402]
#
# ------ Testing ------
# Accuracy rnn1 : 0.291
# F1-score macro rnn1 : 0.315
# F1-score None rnn1 : [0.201 0.18  0.553 0.325]
#
# ------ Training ------
# Accuracy rnn2 : 0.734
# F1-score macro rnn2 : 0.454
# F1-score None rnn2 : [0.598 0.    0.389 0.827]
#
# ------ Validation ------
# Accuracy rnn2 : 0.730
# F1-score macro rnn2 : 0.463
# F1-score None rnn2 : [0.646 0.    0.39  0.815]
#
# ------ Testing ------
# Accuracy rnn2 : 0.760
# F1-score macro rnn2 : 0.343
# F1-score None rnn2 : [0.12  0.    0.39  0.861]
#
# ------ Training ------
# Accuracy rnn3 : 0.426
# F1-score macro rnn3 : 0.338
# F1-score None rnn3 : [0.571 0.017 0.249 0.513]
#
# ------ Validation ------
# Accuracy rnn3 : 0.456
# F1-score macro rnn3 : 0.352
# F1-score None rnn3 : [0.606 0.    0.329 0.472]
#
# ------ Testing ------
# Accuracy rnn3 : 0.391
# F1-score macro rnn3 : 0.251
# F1-score None rnn3 : [0.215 0.    0.277 0.512]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.665
# F1-score macro cnn1 : 0.601
# F1-score None cnn1 : [0.574 0.439 0.645 0.745]
#
# ------ Validation ------
# Accuracy cnn1 : 0.644
# F1-score macro cnn1 : 0.557
# F1-score None cnn1 : [0.613 0.264 0.627 0.723]
#
# ------ Testing ------
# Accuracy cnn1 : 0.603
# F1-score macro cnn1 : 0.392
# F1-score None cnn1 : [0.068 0.214 0.552 0.734]
#
# ------ Training ------
# Accuracy cnn2 : 0.636
# F1-score macro cnn2 : 0.558
# F1-score None cnn2 : [0.576 0.361 0.583 0.711]
#
# ------ Validation ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.565
# F1-score None cnn2 : [0.601 0.231 0.685 0.742]
#
# ------ Testing ------
# Accuracy cnn2 : 0.614
# F1-score macro cnn2 : 0.442
# F1-score None cnn2 : [0.246 0.23  0.564 0.73 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.276
# F1-score macro rnn1 : 0.342
# F1-score None rnn1 : [0.539 0.18  0.516 0.133]
#
# ------ Validation ------
# Accuracy rnn1 : 0.317
# F1-score macro rnn1 : 0.365
# F1-score None rnn1 : [0.547 0.074 0.676 0.165]
#
# ------ Testing ------
# Accuracy rnn1 : 0.192
# F1-score macro rnn1 : 0.262
# F1-score None rnn1 : [0.179 0.164 0.607 0.097]
#
# ------ Training ------
# Accuracy rnn2 : 0.723
# F1-score macro rnn2 : 0.564
# F1-score None rnn2 : [0.617 0.267 0.561 0.813]
#
# ------ Validation ------
# Accuracy rnn2 : 0.690
# F1-score macro rnn2 : 0.554
# F1-score None rnn2 : [0.598 0.267 0.585 0.766]
#
# ------ Testing ------
# Accuracy rnn2 : 0.651
# F1-score macro rnn2 : 0.376
# F1-score None rnn2 : [0.202 0.132 0.379 0.79 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.476
# F1-score macro rnn3 : 0.413
# F1-score None rnn3 : [0.467 0.157 0.491 0.537]
#
# ------ Validation ------
# Accuracy rnn3 : 0.559
# F1-score macro rnn3 : 0.493
# F1-score None rnn3 : [0.537 0.162 0.676 0.598]
#
# ------ Testing ------
# Accuracy rnn3 : 0.488
# F1-score macro rnn3 : 0.399
# F1-score None rnn3 : [0.207 0.17  0.62  0.601]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.696
# F1-score macro cnn1 : 0.595
# F1-score None cnn1 : [0.592 0.433 0.579 0.778]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.545
# F1-score None cnn1 : [0.593 0.154 0.658 0.774]
#
# ------ Testing ------
# Accuracy cnn1 : 0.675
# F1-score macro cnn1 : 0.398
# F1-score None cnn1 : [0.163 0.115 0.52  0.795]
#
# ------ Training ------
# Accuracy cnn2 : 0.516
# F1-score macro cnn2 : 0.476
# F1-score None cnn2 : [0.567 0.34  0.414 0.584]
#
# ------ Validation ------
# Accuracy cnn2 : 0.505
# F1-score macro cnn2 : 0.416
# F1-score None cnn2 : [0.508 0.078 0.49  0.587]
#
# ------ Testing ------
# Accuracy cnn2 : 0.497
# F1-score macro cnn2 : 0.343
# F1-score None cnn2 : [0.078 0.261 0.418 0.615]
#
# ------ Training ------
# Accuracy rnn1 : 0.268
# F1-score macro rnn1 : 0.308
# F1-score None rnn1 : [0.448 0.183 0.527 0.073]
#
# ------ Validation ------
# Accuracy rnn1 : 0.302
# F1-score macro rnn1 : 0.324
# F1-score None rnn1 : [0.502 0.081 0.667 0.045]
#
# ------ Testing ------
# Accuracy rnn1 : 0.168
# F1-score macro rnn1 : 0.245
# F1-score None rnn1 : [0.143 0.17  0.604 0.062]
#
# ------ Training ------
# Accuracy rnn2 : 0.633
# F1-score macro rnn2 : 0.538
# F1-score None rnn2 : [0.561 0.306 0.566 0.719]
#
# ------ Validation ------
# Accuracy rnn2 : 0.544
# F1-score macro rnn2 : 0.460
# F1-score None rnn2 : [0.51  0.235 0.492 0.601]
#
# ------ Testing ------
# Accuracy rnn2 : 0.530
# F1-score macro rnn2 : 0.389
# F1-score None rnn2 : [0.193 0.222 0.475 0.665]
#
# ------ Training ------
# Accuracy rnn3 : 0.501
# F1-score macro rnn3 : 0.432
# F1-score None rnn3 : [0.541 0.193 0.414 0.581]
#
# ------ Validation ------
# Accuracy rnn3 : 0.544
# F1-score macro rnn3 : 0.447
# F1-score None rnn3 : [0.582 0.05  0.571 0.586]
#
# ------ Testing ------
# Accuracy rnn3 : 0.514
# F1-score macro rnn3 : 0.390
# F1-score None rnn3 : [0.216 0.204 0.507 0.632]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.639
# F1-score macro cnn1 : 0.593
# F1-score None cnn1 : [0.605 0.391 0.669 0.706]
#
# ------ Validation ------
# Accuracy cnn1 : 0.644
# F1-score macro cnn1 : 0.566
# F1-score None cnn1 : [0.571 0.273 0.697 0.721]
#
# ------ Testing ------
# Accuracy cnn1 : 0.580
# F1-score macro cnn1 : 0.428
# F1-score None cnn1 : [0.192 0.184 0.626 0.711]
#
# ------ Training ------
# Accuracy cnn2 : 0.459
# F1-score macro cnn2 : 0.468
# F1-score None cnn2 : [0.556 0.253 0.561 0.502]
#
# ------ Validation ------
# Accuracy cnn2 : 0.495
# F1-score macro cnn2 : 0.458
# F1-score None cnn2 : [0.526 0.124 0.6   0.583]
#
# ------ Testing ------
# Accuracy cnn2 : 0.434
# F1-score macro cnn2 : 0.338
# F1-score None cnn2 : [0.079 0.17  0.549 0.552]
#
# ------ Training ------
# Accuracy rnn1 : 0.343
# F1-score macro rnn1 : 0.359
# F1-score None rnn1 : [0.492 0.177 0.467 0.299]
#
# ------ Validation ------
# Accuracy rnn1 : 0.399
# F1-score macro rnn1 : 0.395
# F1-score None rnn1 : [0.534 0.071 0.667 0.306]
#
# ------ Testing ------
# Accuracy rnn1 : 0.267
# F1-score macro rnn1 : 0.295
# F1-score None rnn1 : [0.169 0.178 0.587 0.246]
#
# ------ Training ------
# Accuracy rnn2 : 0.775
# F1-score macro rnn2 : 0.581
# F1-score None rnn2 : [0.678 0.16  0.63  0.855]
#
# ------ Validation ------
# Accuracy rnn2 : 0.712
# F1-score macro rnn2 : 0.535
# F1-score None rnn2 : [0.583 0.167 0.596 0.792]
#
# ------ Testing ------
# Accuracy rnn2 : 0.744
# F1-score macro rnn2 : 0.407
# F1-score None rnn2 : [0.207 0.045 0.527 0.848]
#
# ------ Training ------
# Accuracy rnn3 : 0.339
# F1-score macro rnn3 : 0.323
# F1-score None rnn3 : [0.566 0.123 0.256 0.348]
#
# ------ Validation ------
# Accuracy rnn3 : 0.374
# F1-score macro rnn3 : 0.311
# F1-score None rnn3 : [0.587 0.    0.323 0.333]
#
# ------ Testing ------
# Accuracy rnn3 : 0.265
# F1-score macro rnn3 : 0.230
# F1-score None rnn3 : [0.224 0.127 0.275 0.296]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.578
# F1-score macro cnn1 : 0.538
# F1-score None cnn1 : [0.567 0.371 0.562 0.651]
#
# ------ Validation ------
# Accuracy cnn1 : 0.544
# F1-score macro cnn1 : 0.454
# F1-score None cnn1 : [0.36  0.189 0.585 0.68 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.520
# F1-score macro cnn1 : 0.367
# F1-score None cnn1 : [0.039 0.234 0.553 0.643]
#
# ------ Training ------
# Accuracy cnn2 : 0.463
# F1-score macro cnn2 : 0.451
# F1-score None cnn2 : [0.585 0.259 0.465 0.497]
#
# ------ Validation ------
# Accuracy cnn2 : 0.495
# F1-score macro cnn2 : 0.457
# F1-score None cnn2 : [0.578 0.187 0.538 0.525]
# ------ Testing ------
# Accuracy cnn2 : 0.422
# F1-score macro cnn2 : 0.307
# F1-score None cnn2 : [0.072 0.156 0.463 0.535]
#
# ------ Training ------
# Accuracy rnn1 : 0.236
# F1-score macro rnn1 : 0.263
# F1-score None rnn1 : [0.422 0.157 0.472 0.   ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.292
# F1-score macro rnn1 : 0.296
# F1-score None rnn1 : [0.495 0.067 0.623 0.   ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.168
# F1-score macro rnn1 : 0.234
# F1-score None rnn1 : [0.163 0.175 0.597 0.   ]
#
# ------ Training ------
# Accuracy rnn2 : 0.765
# F1-score macro rnn2 : 0.536
# F1-score None rnn2 : [0.689 0.    0.607 0.847]
#
# ------ Validation ------
# Accuracy rnn2 : 0.719
# F1-score macro rnn2 : 0.502
# F1-score None rnn2 : [0.627 0.    0.581 0.8  ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.748
# F1-score macro rnn2 : 0.411
# F1-score None rnn2 : [0.224 0.    0.57  0.849]
#
# ------ Training ------
# Accuracy rnn3 : 0.237
# F1-score macro rnn3 : 0.285
# F1-score None rnn3 : [0.456 0.164 0.52  0.   ]
#
# ------ Validation ------
# Accuracy rnn3 : 0.285
# F1-score macro rnn3 : 0.322
# F1-score None rnn3 : [0.531 0.066 0.689 0.   ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.160
# F1-score macro rnn3 : 0.248
# F1-score None rnn3 : [0.199 0.157 0.638 0.   ]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.684
# F1-score macro cnn1 : 0.619
# F1-score None cnn1 : [0.59  0.501 0.633 0.753]
#
# ------ Validation ------
# Accuracy cnn1 : 0.658
# F1-score macro cnn1 : 0.527
# F1-score None cnn1 : [0.573 0.105 0.704 0.727]
#
# ------ Testing ------
# Accuracy cnn1 : 0.659
# F1-score macro cnn1 : 0.463
# F1-score None cnn1 : [0.241 0.21  0.621 0.778]
#
# ------ Training ------
# Accuracy cnn2 : 0.593
# F1-score macro cnn2 : 0.526
# F1-score None cnn2 : [0.586 0.389 0.453 0.674]
#
# ------ Validation ------
# Accuracy cnn2 : 0.577
# F1-score macro cnn2 : 0.472
# F1-score None cnn2 : [0.541 0.15  0.532 0.664]
#
# ------ Testing ------
# Accuracy cnn2 : 0.550
# F1-score macro cnn2 : 0.356
# F1-score None cnn2 : [0.091 0.185 0.47  0.678]
#
# ------ Training ------
# Accuracy rnn1 : 0.346
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.497 0.192 0.533 0.304]
#
# ------ Validation ------
# Accuracy rnn1 : 0.381
# F1-score macro rnn1 : 0.395
# F1-score None rnn1 : [0.521 0.08  0.655 0.324]
#
# ------ Testing ------
# Accuracy rnn1 : 0.265
# F1-score macro rnn1 : 0.290
# F1-score None rnn1 : [0.18  0.159 0.511 0.311]
#
# ------ Training ------
# Accuracy rnn2 : 0.775
# F1-score macro rnn2 : 0.578
# F1-score None rnn2 : [0.664 0.192 0.599 0.855]
#
# ------ Validation ------
# Accuracy rnn2 : 0.737
# F1-score macro rnn2 : 0.560
# F1-score None rnn2 : [0.625 0.167 0.64  0.806]
#
# ------ Testing ------
# Accuracy rnn2 : 0.750
# F1-score macro rnn2 : 0.395
# F1-score None rnn2 : [0.193 0.075 0.46  0.854]
#
# ------ Training ------
# Accuracy rnn3 : 0.491
# F1-score macro rnn3 : 0.391
# F1-score None rnn3 : [0.502 0.119 0.379 0.563]
#
# ------ Validation ------
# Accuracy rnn3 : 0.548
# F1-score macro rnn3 : 0.417
# F1-score None rnn3 : [0.553 0.    0.532 0.581]
#
# ------ Testing ------
# Accuracy rnn3 : 0.484
# F1-score macro rnn3 : 0.334
# F1-score None rnn3 : [0.204 0.077 0.442 0.612]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.635
# F1-score macro cnn1 : 0.581
# F1-score None cnn1 : [0.593 0.373 0.653 0.706]
#
# ------ Validation ------
# Accuracy cnn1 : 0.655
# F1-score macro cnn1 : 0.548
# F1-score None cnn1 : [0.584 0.211 0.658 0.739]
#
# ------ Testing ------
# Accuracy cnn1 : 0.599
# F1-score macro cnn1 : 0.443
# F1-score None cnn1 : [0.193 0.214 0.646 0.72 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.490
# F1-score macro cnn2 : 0.452
# F1-score None cnn2 : [0.586 0.318 0.355 0.549]
#
# ------ Validation ------
# Accuracy cnn2 : 0.555
# F1-score macro cnn2 : 0.463
# F1-score None cnn2 : [0.588 0.194 0.444 0.626]
#
# ------ Testing ------
# Accuracy cnn2 : 0.436
# F1-score macro cnn2 : 0.332
# F1-score None cnn2 : [0.245 0.172 0.359 0.55 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.242
# F1-score macro rnn1 : 0.315
# F1-score None rnn1 : [0.499 0.159 0.464 0.137]
#
# ------ Validation ------
# Accuracy rnn1 : 0.320
# F1-score macro rnn1 : 0.377
# F1-score None rnn1 : [0.551 0.117 0.633 0.208]
#
# ------ Testing ------
# Accuracy rnn1 : 0.207
# F1-score macro rnn1 : 0.239
# F1-score None rnn1 : [0.062 0.155 0.599 0.14 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.680
# F1-score macro rnn2 : 0.552
# F1-score None rnn2 : [0.622 0.276 0.536 0.776]
#
# ------ Validation ------
# Accuracy rnn2 : 0.598
# F1-score macro rnn2 : 0.428
# F1-score None rnn2 : [0.544 0.    0.48  0.688]
#
# ------ Testing ------
# Accuracy rnn2 : 0.566
# F1-score macro rnn2 : 0.392
# F1-score None rnn2 : [0.194 0.182 0.495 0.699]
#
# ------ Training ------
# Accuracy rnn3 : 0.511
# F1-score macro rnn3 : 0.392
# F1-score None rnn3 : [0.537 0.09  0.332 0.609]
#
# ------ Validation ------
# Accuracy rnn3 : 0.580
# F1-score macro rnn3 : 0.421
# F1-score None rnn3 : [0.583 0.    0.441 0.66 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.492
# F1-score macro rnn3 : 0.326
# F1-score None rnn3 : [0.238 0.082 0.368 0.615]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.702
# F1-score macro cnn1 : 0.629
# F1-score None cnn1 : [0.597 0.455 0.693 0.774]
#
# ------ Validation ------
# Accuracy cnn1 : 0.701
# F1-score macro cnn1 : 0.613
# F1-score None cnn1 : [0.601 0.37  0.708 0.771]
#
# ------ Testing ------
# Accuracy cnn1 : 0.659
# F1-score macro cnn1 : 0.421
# F1-score None cnn1 : [0.104 0.192 0.603 0.785]
#
# ------ Training ------
# Accuracy cnn2 : 0.568
# F1-score macro cnn2 : 0.498
# F1-score None cnn2 : [0.576 0.343 0.428 0.646]
#
# ------ Validation ------
# Accuracy cnn2 : 0.626
# F1-score macro cnn2 : 0.505
# F1-score None cnn2 : [0.597 0.182 0.542 0.7  ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.533
# F1-score macro cnn2 : 0.377
# F1-score None cnn2 : [0.242 0.199 0.403 0.661]
#
# ------ Training ------
# Accuracy rnn1 : 0.449
# F1-score macro rnn1 : 0.390
# F1-score None rnn1 : [0.52  0.173 0.344 0.522]
#
# ------ Validation ------
# Accuracy rnn1 : 0.480
# F1-score macro rnn1 : 0.383
# F1-score None rnn1 : [0.541 0.    0.473 0.518]
#
# ------ Testing ------
# Accuracy rnn1 : 0.416
# F1-score macro rnn1 : 0.330
# F1-score None rnn1 : [0.197 0.19  0.422 0.512]
#
# ------ Training ------
# Accuracy rnn2 : 0.766
# F1-score macro rnn2 : 0.537
# F1-score None rnn2 : [0.647 0.111 0.543 0.849]
#
# ------ Validation ------
# Accuracy rnn2 : 0.722
# F1-score macro rnn2 : 0.529
# F1-score None rnn2 : [0.579 0.167 0.571 0.801]
#
# ------ Testing ------
# Accuracy rnn2 : 0.753
# F1-score macro rnn2 : 0.382
# F1-score None rnn2 : [0.24  0.027 0.405 0.855]
#
# ------ Training ------
# Accuracy rnn3 : 0.323
# F1-score macro rnn3 : 0.317
# F1-score None rnn3 : [0.555 0.15  0.243 0.319]
#
# ------ Validation ------
# Accuracy rnn3 : 0.367
# F1-score macro rnn3 : 0.302
# F1-score None rnn3 : [0.585 0.    0.311 0.312]
#
# ------ Testing ------
# Accuracy rnn3 : 0.291
# F1-score macro rnn3 : 0.251
# F1-score None rnn3 : [0.214 0.177 0.272 0.34 ]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.717
# F1-score macro cnn1 : 0.604
# F1-score None cnn1 : [0.593 0.39  0.636 0.796]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.513
# F1-score None cnn1 : [0.596 0.    0.686 0.772]
#
# ------ Testing ------
# Accuracy cnn1 : 0.732
# F1-score macro cnn1 : 0.474
# F1-score None cnn1 : [0.289 0.136 0.638 0.832]
#
# ------ Training ------
# Accuracy cnn2 : 0.633
# F1-score macro cnn2 : 0.536
# F1-score None cnn2 : [0.583 0.369 0.475 0.717]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.544
# F1-score None cnn2 : [0.587 0.267 0.568 0.753]
#
# ------ Testing ------
# Accuracy cnn2 : 0.613
# F1-score macro cnn2 : 0.404
# F1-score None cnn2 : [0.241 0.167 0.469 0.738]
#
# ------ Training ------
# Accuracy rnn1 : 0.298
# F1-score macro rnn1 : 0.364
# F1-score None rnn1 : [0.545 0.172 0.501 0.238]
#
# ------ Validation ------
# Accuracy rnn1 : 0.324
# F1-score macro rnn1 : 0.378
# F1-score None rnn1 : [0.545 0.068 0.649 0.249]
#
# ------ Testing ------
# Accuracy rnn1 : 0.253
# F1-score macro rnn1 : 0.300
# F1-score None rnn1 : [0.201 0.159 0.606 0.235]
#
# ------ Training ------
# Accuracy rnn2 : 0.763
# F1-score macro rnn2 : 0.560
# F1-score None rnn2 : [0.663 0.166 0.56  0.853]
#
# ------ Validation ------
# Accuracy rnn2 : 0.708
# F1-score macro rnn2 : 0.533
# F1-score None rnn2 : [0.576 0.133 0.63  0.792]
# ------ Testing ------
# Accuracy rnn2 : 0.725
# F1-score macro rnn2 : 0.395
# F1-score None rnn2 : [0.239 0.025 0.484 0.833]
#
# ------ Training ------
# Accuracy rnn3 : 0.291
# F1-score macro rnn3 : 0.289
# F1-score None rnn3 : [0.489 0.175 0.325 0.166]
#
# ------ Validation ------
# Accuracy rnn3 : 0.374
# F1-score macro rnn3 : 0.346
# F1-score None rnn3 : [0.559 0.116 0.477 0.232]
#
# ------ Testing ------
# Accuracy rnn3 : 0.220
# F1-score macro rnn3 : 0.216
# F1-score None rnn3 : [0.206 0.125 0.363 0.171]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.642
# F1-score macro cnn1 : 0.586
# F1-score None cnn1 : [0.595 0.41  0.623 0.716]
#
# ------ Validation ------
# Accuracy cnn1 : 0.619
# F1-score macro cnn1 : 0.526
# F1-score None cnn1 : [0.542 0.204 0.658 0.702]
#
# ------ Testing ------
# Accuracy cnn1 : 0.589
# F1-score macro cnn1 : 0.398
# F1-score None cnn1 : [0.059 0.215 0.604 0.714]
#
# ------ Training ------
# Accuracy cnn2 : 0.446
# F1-score macro cnn2 : 0.426
# F1-score None cnn2 : [0.575 0.295 0.347 0.486]
#
# ------ Validation ------
# Accuracy cnn2 : 0.477
# F1-score macro cnn2 : 0.410
# F1-score None cnn2 : [0.563 0.133 0.43  0.513]
#
# ------ Testing ------
# Accuracy cnn2 : 0.393
# F1-score macro cnn2 : 0.316
# F1-score None cnn2 : [0.243 0.181 0.354 0.487]
#
# ------ Training ------
# Accuracy rnn1 : 0.356
# F1-score macro rnn1 : 0.330
# F1-score None rnn1 : [0.547 0.128 0.267 0.377]
#
# ------ Validation ------
# Accuracy rnn1 : 0.409
# F1-score macro rnn1 : 0.343
# F1-score None rnn1 : [0.564 0.062 0.349 0.397]
#
# ------ Testing ------
# Accuracy rnn1 : 0.288
# F1-score macro rnn1 : 0.234
# F1-score None rnn1 : [0.176 0.13  0.294 0.337]
#
# ------ Training ------
# Accuracy rnn2 : 0.751
# F1-score macro rnn2 : 0.544
# F1-score None rnn2 : [0.521 0.17  0.642 0.842]
#
# ------ Validation ------
# Accuracy rnn2 : 0.722
# F1-score macro rnn2 : 0.581
# F1-score None rnn2 : [0.505 0.4   0.612 0.808]
#
# ------ Testing ------
# Accuracy rnn2 : 0.777
# F1-score macro rnn2 : 0.394
# F1-score None rnn2 : [0.051 0.075 0.585 0.866]
#
# ------ Training ------
# Accuracy rnn3 : 0.482
# F1-score macro rnn3 : 0.396
# F1-score None rnn3 : [0.461 0.119 0.458 0.546]
#
# ------ Validation ------
# Accuracy rnn3 : 0.537
# F1-score macro rnn3 : 0.435
# F1-score None rnn3 : [0.52  0.    0.658 0.56 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.456
# F1-score macro rnn3 : 0.352
# F1-score None rnn3 : [0.142 0.155 0.541 0.57 ]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.0cw - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.0cw - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.0cw - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.0cw - F1-score promedio para cnn1 : [0.142 0.193 0.598 0.746]
# 0.0cw - F1-score promedio para cnn2 : [0.158 0.189 0.464 0.618]
# 0.0cw - F1-score promedio para rnn1 : [0.167 0.166 0.538 0.226]
# 0.0cw - F1-score promedio para rnn2 : [0.186 0.078 0.477 0.812]
# 0.0cw - F1-score promedio para rnn3 : [0.207 0.127 0.43  0.435]
#
# 0.0cw - F1-score macro promedio para cnn1 : 0.41977642649153885 desvest:  0.031489677274745095
# 0.0cw - F1-score macro promedio para cnn2 : 0.357311864900698 desvest:  0.03909397472312574
# 0.0cw - F1-score macro promedio para rnn1 : 0.27438304221583487 desvest:  0.03416421361554242
# 0.0cw - F1-score macro promedio para rnn2 : 0.3883612728165267 desvest:  0.018082626767245914
# 0.0cw - F1-score macro promedio para rnn3 : 0.299749259337995 desvest:  0.06461355526311358
#
# 0.0cw - Accuracy promedio para cnn1 : 0.6234084231145935 desvest:  0.05630881850167522
# 0.0cw - Accuracy promedio para cnn2 : 0.49980411361410376 desvest:  0.07452576005963328
# 0.0cw - Accuracy promedio para rnn1 : 0.2516160626836435 desvest:  0.07058225760204638
# 0.0cw - Accuracy promedio para rnn2 : 0.7004897159647404 desvest:  0.08305998548164532
# 0.0cw - Accuracy promedio para rnn3 : 0.376101860920666 desvest:  0.12400938821648134

# %% [markdown]
# # Usando Class weigths de paper

# %%
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights=np.asarray([0.157, 0.396, 0.399, 0.048])
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [0.157 0.396 0.399 0.048]

# %%
fs_macro, fs_none, accs, confusions= train_5models(10, '0.0cwpaper', x_train, y_train, n_labels, class_weights, 20, 10)
# Out:
#  -------------------- Entrenando exec 1  --------------------
#
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# ------ Training ------
# Accuracy cnn1 : 0.675
# F1-score macro cnn1 : 0.682
# F1-score None cnn1 : [0.637 0.6   0.801 0.689]
#
# ------ Validation ------
# Accuracy cnn1 : 0.562
# F1-score macro cnn1 : 0.522
# F1-score None cnn1 : [0.527 0.292 0.656 0.613]
#
# ------ Testing ------
# Accuracy cnn1 : 0.506
# F1-score macro cnn1 : 0.403
# F1-score None cnn1 : [0.181 0.226 0.568 0.636]
#
# ------ Training ------
# Accuracy cnn2 : 0.783
# F1-score macro cnn2 : 0.757
# F1-score None cnn2 : [0.666 0.79  0.744 0.828]
#
# ------ Validation ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.510
# F1-score None cnn2 : [0.584 0.087 0.627 0.742]
#
# ------ Testing ------
# Accuracy cnn2 : 0.668
# F1-score macro cnn2 : 0.435
# F1-score None cnn2 : [0.173 0.2   0.585 0.784]
#
# ------ Training ------
# Accuracy rnn1 : 0.198
# F1-score macro rnn1 : 0.237
# F1-score None rnn1 : [0.528 0.152 0.253 0.015]
#
# ------ Validation ------
# Accuracy rnn1 : 0.249
# F1-score macro rnn1 : 0.248
# F1-score None rnn1 : [0.556 0.066 0.325 0.045]
#
# ------ Testing ------
# Accuracy rnn1 : 0.153
# F1-score macro rnn1 : 0.155
# F1-score None rnn1 : [0.139 0.156 0.288 0.038]
#
# ------ Training ------
# Accuracy rnn2 : 0.709
# F1-score macro rnn2 : 0.581
# F1-score None rnn2 : [0.675 0.382 0.46  0.808]
#
# ------ Validation ------
# Accuracy rnn2 : 0.687
# F1-score macro rnn2 : 0.545
# F1-score None rnn2 : [0.647 0.2   0.562 0.77 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.652
# F1-score macro rnn2 : 0.421
# F1-score None rnn2 : [0.19  0.246 0.478 0.771]
#
# ------ Training ------
# Accuracy rnn3 : 0.361
# F1-score macro rnn3 : 0.367
# F1-score None rnn3 : [0.557 0.172 0.379 0.361]
#
# ------ Validation ------
# Accuracy rnn3 : 0.427
# F1-score macro rnn3 : 0.388
# F1-score None rnn3 : [0.599 0.026 0.51  0.418]
#
# ------ Testing ------
# Accuracy rnn3 : 0.325
# F1-score macro rnn3 : 0.296
# F1-score None rnn3 : [0.19  0.176 0.45  0.368]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.695
# F1-score macro cnn1 : 0.694
# F1-score None cnn1 : [0.61  0.667 0.775 0.726]
#
# ------ Validation ------
# Accuracy cnn1 : 0.612
# F1-score macro cnn1 : 0.551
# F1-score None cnn1 : [0.529 0.308 0.677 0.69 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.564
# F1-score macro cnn1 : 0.430
# F1-score None cnn1 : [0.167 0.241 0.621 0.691]
#
# ------ Training ------
# Accuracy cnn2 : 0.640
# F1-score macro cnn2 : 0.602
# F1-score None cnn2 : [0.644 0.508 0.564 0.691]
#
# ------ Validation ------
# Accuracy cnn2 : 0.544
# F1-score macro cnn2 : 0.453
# F1-score None cnn2 : [0.415 0.197 0.541 0.658]
#
# ------ Testing ------
# Accuracy cnn2 : 0.525
# F1-score macro cnn2 : 0.349
# F1-score None cnn2 : [0.083 0.171 0.47  0.674]
#
# ------ Training ------
# Accuracy rnn1 : 0.405
# F1-score macro rnn1 : 0.368
# F1-score None rnn1 : [0.536 0.172 0.292 0.471]
#
# ------ Validation ------
# Accuracy rnn1 : 0.409
# F1-score macro rnn1 : 0.334
# F1-score None rnn1 : [0.537 0.    0.369 0.431]
#
# ------ Testing ------
# Accuracy rnn1 : 0.388
# F1-score macro rnn1 : 0.281
# F1-score None rnn1 : [0.134 0.17  0.331 0.491]
#
# ------ Training ------
# Accuracy rnn2 : 0.785
# F1-score macro rnn2 : 0.623
# F1-score None rnn2 : [0.695 0.312 0.624 0.863]
#
# ------ Validation ------
# Accuracy rnn2 : 0.701
# F1-score macro rnn2 : 0.588
# F1-score None rnn2 : [0.579 0.444 0.552 0.778]
#
# ------ Testing ------
# Accuracy rnn2 : 0.719
# F1-score macro rnn2 : 0.398
# F1-score None rnn2 : [0.139 0.14  0.482 0.831]
#
# ------ Training ------
# Accuracy rnn3 : 0.339
# F1-score macro rnn3 : 0.352
# F1-score None rnn3 : [0.461 0.193 0.495 0.261]
#
# ------ Validation ------
# Accuracy rnn3 : 0.377
# F1-score macro rnn3 : 0.368
# F1-score None rnn3 : [0.505 0.086 0.629 0.255]
#
# ------ Testing ------
# Accuracy rnn3 : 0.262
# F1-score macro rnn3 : 0.291
# F1-score None rnn3 : [0.182 0.174 0.552 0.258]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.790
# F1-score macro cnn1 : 0.788
# F1-score None cnn1 : [0.661 0.868 0.794 0.829]
#
# ------ Validation ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.544
# F1-score None cnn1 : [0.596 0.211 0.603 0.766]
#
# ------ Testing ------
# Accuracy cnn1 : 0.678
# F1-score macro cnn1 : 0.431
# F1-score None cnn1 : [0.2   0.161 0.565 0.797]
#
# ------ Training ------
# Accuracy cnn2 : 0.681
# F1-score macro cnn2 : 0.667
# F1-score None cnn2 : [0.642 0.472 0.825 0.732]
#
# ------ Validation ------
# Accuracy cnn2 : 0.587
# F1-score macro cnn2 : 0.517
# F1-score None cnn2 : [0.597 0.174 0.627 0.671]
#
# ------ Testing ------
# Accuracy cnn2 : 0.549
# F1-score macro cnn2 : 0.430
# F1-score None cnn2 : [0.211 0.211 0.621 0.68 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.245
# F1-score macro rnn1 : 0.295
# F1-score None rnn1 : [0.566 0.156 0.372 0.087]
#
# ------ Validation ------
# Accuracy rnn1 : 0.299
# F1-score macro rnn1 : 0.325
# F1-score None rnn1 : [0.601 0.089 0.5   0.109]
#
# ------ Testing ------
# Accuracy rnn1 : 0.193
# F1-score macro rnn1 : 0.230
# F1-score None rnn1 : [0.216 0.167 0.465 0.072]
#
# ------ Training ------
# Accuracy rnn2 : 0.780
# F1-score macro rnn2 : 0.628
# F1-score None rnn2 : [0.645 0.367 0.643 0.859]
#
# ------ Validation ------
# Accuracy rnn2 : 0.754
# F1-score macro rnn2 : 0.624
# F1-score None rnn2 : [0.651 0.375 0.643 0.825]
#
# ------ Testing ------
# Accuracy rnn2 : 0.754
# F1-score macro rnn2 : 0.432
# F1-score None rnn2 : [0.154 0.16  0.563 0.853]
#
# ------ Training ------
# Accuracy rnn3 : 0.179
# F1-score macro rnn3 : 0.181
# F1-score None rnn3 : [0.536 0.012 0.171 0.007]
#
# ------ Validation ------
# Accuracy rnn3 : 0.206
# F1-score macro rnn3 : 0.172
# F1-score None rnn3 : [0.47 0.   0.22 0.  ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.120
# F1-score macro rnn3 : 0.104
# F1-score None rnn3 : [0.208 0.    0.203 0.005]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.775
# F1-score macro cnn1 : 0.772
# F1-score None cnn1 : [0.681 0.799 0.8   0.807]
#
# ------ Validation ------
# Accuracy cnn1 : 0.662
# F1-score macro cnn1 : 0.556
# F1-score None cnn1 : [0.558 0.276 0.632 0.759]
#
# ------ Testing ------
# Accuracy cnn1 : 0.623
# F1-score macro cnn1 : 0.429
# F1-score None cnn1 : [0.145 0.217 0.602 0.752]
# ------ Training ------
# Accuracy cnn2 : 0.718
# F1-score macro cnn2 : 0.688
# F1-score None cnn2 : [0.645 0.634 0.707 0.764]
#
# ------ Validation ------
# Accuracy cnn2 : 0.637
# F1-score macro cnn2 : 0.524
# F1-score None cnn2 : [0.573 0.125 0.688 0.712]
#
# ------ Testing ------
# Accuracy cnn2 : 0.583
# F1-score macro cnn2 : 0.415
# F1-score None cnn2 : [0.167 0.193 0.589 0.711]
#
# ------ Training ------
# Accuracy rnn1 : 0.298
# F1-score macro rnn1 : 0.332
# F1-score None rnn1 : [0.5   0.169 0.468 0.19 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.327
# F1-score macro rnn1 : 0.353
# F1-score None rnn1 : [0.536 0.073 0.658 0.144]
#
# ------ Testing ------
# Accuracy rnn1 : 0.232
# F1-score macro rnn1 : 0.282
# F1-score None rnn1 : [0.172 0.172 0.615 0.169]
#
# ------ Training ------
# Accuracy rnn2 : 0.774
# F1-score macro rnn2 : 0.644
# F1-score None rnn2 : [0.673 0.384 0.667 0.854]
#
# ------ Validation ------
# Accuracy rnn2 : 0.726
# F1-score macro rnn2 : 0.564
# F1-score None rnn2 : [0.624 0.174 0.653 0.805]
#
# ------ Testing ------
# Accuracy rnn2 : 0.718
# F1-score macro rnn2 : 0.426
# F1-score None rnn2 : [0.15  0.232 0.489 0.832]
#
# ------ Training ------
# Accuracy rnn3 : 0.460
# F1-score macro rnn3 : 0.378
# F1-score None rnn3 : [0.426 0.086 0.481 0.521]
#
# ------ Validation ------
# Accuracy rnn3 : 0.530
# F1-score macro rnn3 : 0.497
# F1-score None rnn3 : [0.475 0.286 0.676 0.552]
#
# ------ Testing ------
# Accuracy rnn3 : 0.468
# F1-score macro rnn3 : 0.379
# F1-score None rnn3 : [0.188 0.113 0.635 0.579]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.753
# F1-score macro cnn1 : 0.753
# F1-score None cnn1 : [0.664 0.849 0.712 0.787]
#
# ------ Validation ------
# Accuracy cnn1 : 0.648
# F1-score macro cnn1 : 0.534
# F1-score None cnn1 : [0.58  0.24  0.59  0.726]
#
# ------ Testing ------
# Accuracy cnn1 : 0.620
# F1-score macro cnn1 : 0.423
# F1-score None cnn1 : [0.199 0.176 0.571 0.743]
#
# ------ Training ------
# Accuracy cnn2 : 0.727
# F1-score macro cnn2 : 0.703
# F1-score None cnn2 : [0.653 0.579 0.804 0.775]
#
# ------ Validation ------
# Accuracy cnn2 : 0.633
# F1-score macro cnn2 : 0.538
# F1-score None cnn2 : [0.616 0.218 0.593 0.723]
#
# ------ Testing ------
# Accuracy cnn2 : 0.593
# F1-score macro cnn2 : 0.429
# F1-score None cnn2 : [0.122 0.212 0.664 0.719]
#
# ------ Training ------
# Accuracy rnn1 : 0.416
# F1-score macro rnn1 : 0.402
# F1-score None rnn1 : [0.446 0.215 0.525 0.423]
#
# ------ Validation ------
# Accuracy rnn1 : 0.445
# F1-score macro rnn1 : 0.422
# F1-score None rnn1 : [0.483 0.178 0.607 0.419]
#
# ------ Testing ------
# Accuracy rnn1 : 0.358
# F1-score macro rnn1 : 0.335
# F1-score None rnn1 : [0.155 0.121 0.602 0.462]
#
# ------ Training ------
# Accuracy rnn2 : 0.785
# F1-score macro rnn2 : 0.650
# F1-score None rnn2 : [0.679 0.412 0.648 0.86 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.683
# F1-score macro rnn2 : 0.555
# F1-score None rnn2 : [0.559 0.333 0.565 0.762]
#
# ------ Testing ------
# Accuracy rnn2 : 0.692
# F1-score macro rnn2 : 0.405
# F1-score None rnn2 : [0.208 0.172 0.425 0.813]
#
# ------ Training ------
# Accuracy rnn3 : 0.400
# F1-score macro rnn3 : 0.395
# F1-score None rnn3 : [0.572 0.195 0.389 0.422]
#
# ------ Validation ------
# Accuracy rnn3 : 0.488
# F1-score macro rnn3 : 0.444
# F1-score None rnn3 : [0.606 0.108 0.553 0.508]
#
# ------ Testing ------
# Accuracy rnn3 : 0.366
# F1-score macro rnn3 : 0.333
# F1-score None rnn3 : [0.261 0.191 0.456 0.425]
#
#
#  -------------------- Entrenando exec 6  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.775
# F1-score macro cnn1 : 0.774
# F1-score None cnn1 : [0.667 0.838 0.779 0.811]
#
# ------ Validation ------
# Accuracy cnn1 : 0.637
# F1-score macro cnn1 : 0.539
# F1-score None cnn1 : [0.553 0.273 0.618 0.711]
#
# ------ Testing ------
# Accuracy cnn1 : 0.675
# F1-score macro cnn1 : 0.474
# F1-score None cnn1 : [0.251 0.213 0.643 0.788]
#
# ------ Training ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.649
# F1-score None cnn2 : [0.659 0.555 0.657 0.726]
#
# ------ Validation ------
# Accuracy cnn2 : 0.612
# F1-score macro cnn2 : 0.521
# F1-score None cnn2 : [0.581 0.238 0.575 0.689]
#
# ------ Testing ------
# Accuracy cnn2 : 0.545
# F1-score macro cnn2 : 0.381
# F1-score None cnn2 : [0.092 0.203 0.547 0.683]
#
# ------ Training ------
# Accuracy rnn1 : 0.313
# F1-score macro rnn1 : 0.352
# F1-score None rnn1 : [0.468 0.193 0.523 0.226]
#
# ------ Validation ------
# Accuracy rnn1 : 0.377
# F1-score macro rnn1 : 0.392
# F1-score None rnn1 : [0.531 0.079 0.667 0.291]
#
# ------ Testing ------
# Accuracy rnn1 : 0.262
# F1-score macro rnn1 : 0.313
# F1-score None rnn1 : [0.184 0.183 0.633 0.25 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.759
# F1-score macro rnn2 : 0.592
# F1-score None rnn2 : [0.649 0.304 0.572 0.843]
#
# ------ Validation ------
# Accuracy rnn2 : 0.705
# F1-score macro rnn2 : 0.548
# F1-score None rnn2 : [0.607 0.235 0.565 0.785]
#
# ------ Testing ------
# Accuracy rnn2 : 0.702
# F1-score macro rnn2 : 0.404
# F1-score None rnn2 : [0.194 0.143 0.459 0.822]
#
# ------ Training ------
# Accuracy rnn3 : 0.380
# F1-score macro rnn3 : 0.374
# F1-score None rnn3 : [0.53  0.221 0.387 0.358]
#
# ------ Validation ------
# Accuracy rnn3 : 0.427
# F1-score macro rnn3 : 0.401
# F1-score None rnn3 : [0.545 0.139 0.542 0.376]
#
# ------ Testing ------
# Accuracy rnn3 : 0.327
# F1-score macro rnn3 : 0.296
# F1-score None rnn3 : [0.183 0.188 0.445 0.369]
#
#
#  -------------------- Entrenando exec 7  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.764
# F1-score macro cnn1 : 0.749
# F1-score None cnn1 : [0.693 0.858 0.641 0.804]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.583
# F1-score None cnn1 : [0.599 0.353 0.63  0.749]
#
# ------ Testing ------
# Accuracy cnn1 : 0.632
# F1-score macro cnn1 : 0.404
# F1-score None cnn1 : [0.122 0.213 0.524 0.755]
#
# ------ Training ------
# Accuracy cnn2 : 0.679
# F1-score macro cnn2 : 0.663
# F1-score None cnn2 : [0.671 0.74  0.526 0.714]
#
# ------ Validation ------
# Accuracy cnn2 : 0.559
# F1-score macro cnn2 : 0.453
# F1-score None cnn2 : [0.566 0.167 0.453 0.627]
#
# ------ Testing ------
# Accuracy cnn2 : 0.544
# F1-score macro cnn2 : 0.382
# F1-score None cnn2 : [0.141 0.275 0.447 0.666]
#
# ------ Training ------
# Accuracy rnn1 : 0.446
# F1-score macro rnn1 : 0.430
# F1-score None rnn1 : [0.551 0.173 0.48  0.514]
#
# ------ Validation ------
# Accuracy rnn1 : 0.495
# F1-score macro rnn1 : 0.464
# F1-score None rnn1 : [0.585 0.096 0.649 0.525]
#
# ------ Testing ------
# Accuracy rnn1 : 0.430
# F1-score macro rnn1 : 0.383
# F1-score None rnn1 : [0.215 0.176 0.611 0.532]
#
# ------ Training ------
# Accuracy rnn2 : 0.783
# F1-score macro rnn2 : 0.636
# F1-score None rnn2 : [0.666 0.375 0.645 0.86 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.722
# F1-score macro rnn2 : 0.555
# F1-score None rnn2 : [0.637 0.25  0.524 0.809]
#
# ------ Testing ------
# Accuracy rnn2 : 0.738
# F1-score macro rnn2 : 0.422
# F1-score None rnn2 : [0.188 0.252 0.403 0.847]
#
# ------ Training ------
# Accuracy rnn3 : 0.457
# F1-score macro rnn3 : 0.437
# F1-score None rnn3 : [0.515 0.236 0.504 0.493]
#
# ------ Validation ------
# Accuracy rnn3 : 0.495
# F1-score macro rnn3 : 0.452
# F1-score None rnn3 : [0.519 0.136 0.632 0.52 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.416
# F1-score macro rnn3 : 0.368
# F1-score None rnn3 : [0.187 0.184 0.594 0.505]
#
#
#  -------------------- Entrenando exec 8  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.778
# F1-score macro cnn1 : 0.757
# F1-score None cnn1 : [0.66  0.853 0.693 0.824]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.564
# F1-score None cnn1 : [0.549 0.286 0.667 0.754]
#
# ------ Testing ------
# Accuracy cnn1 : 0.697
# F1-score macro cnn1 : 0.389
# F1-score None cnn1 : [0.071 0.094 0.583 0.808]
#
# ------ Training ------
# Accuracy cnn2 : 0.629
# F1-score macro cnn2 : 0.596
# F1-score None cnn2 : [0.626 0.586 0.495 0.678]
#
# ------ Validation ------
# Accuracy cnn2 : 0.573
# F1-score macro cnn2 : 0.492
# F1-score None cnn2 : [0.567 0.235 0.511 0.655]
#
# ------ Testing ------
# Accuracy cnn2 : 0.536
# F1-score macro cnn2 : 0.365
# F1-score None cnn2 : [0.131 0.226 0.441 0.661]
#
# ------ Training ------
# Accuracy rnn1 : 0.288
# F1-score macro rnn1 : 0.251
# F1-score None rnn1 : [0.374 0.023 0.453 0.155]
#
# ------ Validation ------
# Accuracy rnn1 : 0.331
# F1-score macro rnn1 : 0.287
# F1-score None rnn1 : [0.433 0.    0.621 0.096]
#
# ------ Testing ------
# Accuracy rnn1 : 0.197
# F1-score macro rnn1 : 0.224
# F1-score None rnn1 : [0.139 0.    0.594 0.161]
# ------ Training ------
# Accuracy rnn2 : 0.771
# F1-score macro rnn2 : 0.569
# F1-score None rnn2 : [0.638 0.159 0.624 0.855]
#
# ------ Validation ------
# Accuracy rnn2 : 0.733
# F1-score macro rnn2 : 0.536
# F1-score None rnn2 : [0.628 0.154 0.545 0.815]
#
# ------ Testing ------
# Accuracy rnn2 : 0.765
# F1-score macro rnn2 : 0.394
# F1-score None rnn2 : [0.109 0.075 0.533 0.861]
#
# ------ Training ------
# Accuracy rnn3 : 0.503
# F1-score macro rnn3 : 0.454
# F1-score None rnn3 : [0.518 0.189 0.533 0.576]
#
# ------ Validation ------
# Accuracy rnn3 : 0.584
# F1-score macro rnn3 : 0.496
# F1-score None rnn3 : [0.596 0.043 0.708 0.638]
#
# ------ Testing ------
# Accuracy rnn3 : 0.507
# F1-score macro rnn3 : 0.410
# F1-score None rnn3 : [0.225 0.155 0.618 0.64 ]
#
#
#  -------------------- Entrenando exec 9  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.809
# F1-score macro cnn1 : 0.794
# F1-score None cnn1 : [0.701 0.901 0.725 0.847]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.567
# F1-score None cnn1 : [0.618 0.267 0.613 0.769]
#
# ------ Testing ------
# Accuracy cnn1 : 0.705
# F1-score macro cnn1 : 0.427
# F1-score None cnn1 : [0.16  0.136 0.599 0.815]
#
# ------ Training ------
# Accuracy cnn2 : 0.631
# F1-score macro cnn2 : 0.624
# F1-score None cnn2 : [0.61  0.561 0.674 0.65 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.559
# F1-score macro cnn2 : 0.508
# F1-score None cnn2 : [0.565 0.196 0.676 0.594]
#
# ------ Testing ------
# Accuracy cnn2 : 0.497
# F1-score macro cnn2 : 0.395
# F1-score None cnn2 : [0.185 0.206 0.578 0.612]
#
# ------ Training ------
# Accuracy rnn1 : 0.426
# F1-score macro rnn1 : 0.410
# F1-score None rnn1 : [0.54  0.166 0.463 0.47 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.466
# F1-score macro rnn1 : 0.437
# F1-score None rnn1 : [0.573 0.051 0.658 0.465]
#
# ------ Testing ------
# Accuracy rnn1 : 0.382
# F1-score macro rnn1 : 0.349
# F1-score None rnn1 : [0.207 0.181 0.554 0.455]
#
# ------ Training ------
# Accuracy rnn2 : 0.662
# F1-score macro rnn2 : 0.591
# F1-score None rnn2 : [0.629 0.372 0.623 0.741]
#
# ------ Validation ------
# Accuracy rnn2 : 0.626
# F1-score macro rnn2 : 0.554
# F1-score None rnn2 : [0.605 0.211 0.73  0.671]
#
# ------ Testing ------
# Accuracy rnn2 : 0.531
# F1-score macro rnn2 : 0.399
# F1-score None rnn2 : [0.208 0.183 0.541 0.665]
#
# ------ Training ------
# Accuracy rnn3 : 0.307
# F1-score macro rnn3 : 0.279
# F1-score None rnn3 : [0.377 0.051 0.478 0.209]
#
# ------ Validation ------
# Accuracy rnn3 : 0.335
# F1-score macro rnn3 : 0.312
# F1-score None rnn3 : [0.414 0.    0.73  0.105]
#
# ------ Testing ------
# Accuracy rnn3 : 0.221
# F1-score macro rnn3 : 0.250
# F1-score None rnn3 : [0.142 0.048 0.602 0.21 ]
#
#
#  -------------------- Entrenando exec 10  --------------------
#
#
#
# ------ Training ------
# Accuracy cnn1 : 0.678
# F1-score macro cnn1 : 0.688
# F1-score None cnn1 : [0.55  0.69  0.796 0.715]
#
# ------ Validation ------
# Accuracy cnn1 : 0.594
# F1-score macro cnn1 : 0.545
# F1-score None cnn1 : [0.531 0.294 0.712 0.644]
#
# ------ Testing ------
# Accuracy cnn1 : 0.535
# F1-score macro cnn1 : 0.405
# F1-score None cnn1 : [0.081 0.25  0.622 0.667]
#
# ------ Training ------
# Accuracy cnn2 : 0.677
# F1-score macro cnn2 : 0.652
# F1-score None cnn2 : [0.639 0.702 0.546 0.721]
#
# ------ Validation ------
# Accuracy cnn2 : 0.619
# F1-score macro cnn2 : 0.538
# F1-score None cnn2 : [0.6   0.303 0.568 0.68 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.550
# F1-score macro cnn2 : 0.379
# F1-score None cnn2 : [0.208 0.168 0.468 0.674]
#
# ------ Training ------
# Accuracy rnn1 : 0.515
# F1-score macro rnn1 : 0.470
# F1-score None rnn1 : [0.52  0.228 0.542 0.59 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.559
# F1-score macro rnn1 : 0.482
# F1-score None rnn1 : [0.561 0.122 0.627 0.618]
#
# ------ Testing ------
# Accuracy rnn1 : 0.486
# F1-score macro rnn1 : 0.400
# F1-score None rnn1 : [0.169 0.179 0.643 0.608]
#
# ------ Training ------
# Accuracy rnn2 : 0.747
# F1-score macro rnn2 : 0.565
# F1-score None rnn2 : [0.646 0.189 0.585 0.84 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.705
# F1-score macro rnn2 : 0.534
# F1-score None rnn2 : [0.628 0.125 0.6   0.785]
#
# ------ Testing ------
# Accuracy rnn2 : 0.719
# F1-score macro rnn2 : 0.428
# F1-score None rnn2 : [0.263 0.088 0.534 0.827]
#
# ------ Training ------
# Accuracy rnn3 : 0.381
# F1-score macro rnn3 : 0.340
# F1-score None rnn3 : [0.493 0.164 0.334 0.367]
#
# ------ Validation ------
# Accuracy rnn3 : 0.427
# F1-score macro rnn3 : 0.335
# F1-score None rnn3 : [0.51  0.    0.444 0.386]
#
# ------ Testing ------
# Accuracy rnn3 : 0.338
# F1-score macro rnn3 : 0.280
# F1-score None rnn3 : [0.177 0.146 0.39  0.406]

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.0cw paper - F1-score promedio para",key,":" , temp/10)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.0cw paper - F1-score macro promedio para",key,":" , temp/10, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.0cw paper - Accuracy promedio para",key,":", temp/10 , "desvest: ",np.std(accs[key]))
# Out:
# 0.0cw paper - F1-score promedio para cnn1 : [0.158 0.193 0.59  0.745]
# 0.0cw paper - F1-score promedio para cnn2 : [0.151 0.206 0.541 0.686]
# 0.0cw paper - F1-score promedio para rnn1 : [0.173 0.15  0.533 0.324]
# 0.0cw paper - F1-score promedio para rnn2 : [0.18  0.169 0.491 0.812]
# 0.0cw paper - F1-score promedio para rnn3 : [0.194 0.137 0.494 0.377]
#
# 0.0cw paper - F1-score macro promedio para cnn1 : 0.4213905930315788 desvest:  0.022375332662383174
# 0.0cw paper - F1-score macro promedio para cnn2 : 0.3962056281465805 desvest:  0.028357770026148466
# 0.0cw paper - F1-score macro promedio para rnn1 : 0.2951693276756101 desvest:  0.07275642148010028
# 0.0cw paper - F1-score macro promedio para rnn2 : 0.413048116191697 desvest:  0.01347618991841413
# 0.0cw paper - F1-score macro promedio para rnn3 : 0.3007144329715875 desvest:  0.08084335570799364
#
# 0.0cw paper - Accuracy promedio para cnn1 : 0.6235063663075416 desvest:  0.0655007871945247
# 0.0cw paper - Accuracy promedio para cnn2 : 0.5588638589618022 desvest:  0.04446491517616141
# 0.0cw paper - Accuracy promedio para rnn1 : 0.3080313418217434 desvest:  0.10884943969382763
# 0.0cw paper - Accuracy promedio para rnn2 : 0.6991185112634672 desvest:  0.06372452394955053
# 0.0cw paper - Accuracy promedio para rnn3 : 0.33516160626836433 desvest:  0.10932829669590514

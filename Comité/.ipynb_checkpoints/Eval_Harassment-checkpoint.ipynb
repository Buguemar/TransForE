# %%
from tools_harassment import * 
from models import *
import torch 
import pandas as pd
import gc

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")


dict_cl=dict()
dict_cl[0]="NonH"
dict_cl[1]="IndirectH"
dict_cl[2]="PhysicalH"
dict_cl[3]="SexualH"

#sdqc
d_lab=dict()
d_lab["NonH"]=0
d_lab["IndirectH"]=1
d_lab["PhysicalH"]=2
d_lab["SexualH"]=3

path="../../Datasets/CSV_Harassment/"
train =pd.read_csv(path + "train_format.csv")
val=pd.read_csv(path + "val_format.csv")
test=pd.read_csv(path + "test_format.csv")

stoplist = stopwords.words("english")
puntos='!?."()[´]“<>¡¿-/;:=_”@#.'
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
def cm_norma(matrix):
    return matrix/matrix.sum(axis=-1, keepdims=True)
    
    
def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=cm_norma(confusion_matrix(etiq, trainPredict))
    """print ("")
    print ("------ Training ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)"""
    
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=cm_norma(confusion_matrix(etiq_v, trainPredict))
    """print ("")
    print ("------ Validation ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)"""
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=cm_norma(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("------ Testing ------")
    print ("Accuracy", name_model, ": %.3f" % acc_t)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma_t)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

def cleaner(post): 
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=token_2_idx[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in token_2_idx.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in token_2_idx.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
import os 
embeddings_index = {}
token_2_idx={}
idx_2_token={}
f = open(os.path.join("../../Datasets/glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
i=0
for line in f:
    values = line.split()
    if len(values)>200:
        word = values[0]
    else:
        #print ("Problema con line ", line)
        continue
    token_2_idx[word]=i
    idx_2_token[i]=word
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
    i+=1
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# Se encontraron 1193513 terminos con sus vectores de embedding.

# %%
MAX_LEN = 34
emb=200
EMB_matrix=np.zeros((len(token_2_idx.keys()), emb))
for i in range(len(token_2_idx.keys())):
    EMB_matrix[i]=embeddings_index[idx_2_token[i]]
    
transformer = Normalizer().fit(EMB_matrix) 
EMB_matrix=transformer.transform(EMB_matrix)
print(EMB_matrix.shape)

ids_train=train['tweet_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
#class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)

ids_val=val['tweet_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

ids_test=test['tweet_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]

sentences = tws_train
n_labels = np.asarray(labels_train)
y_train=to_categorical(n_labels,num_classes=4)

sentences_val = tws_val
n_labels_val = np.array(labels_val)
y_val=to_categorical(n_labels_val,num_classes=4)

sentences_test = tws_test
n_labels_test = np.array(labels_test)
y_test=to_categorical(n_labels_test,num_classes=4)

input_ids=[]
for sent in sentences:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids.append(encoded_sent) 
    
input_ids_val=[]
for sent in sentences_val:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_val.append(encoded_sent) 

input_ids_test=[]
for sent in sentences_test:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_test.append(encoded_sent)
# Out:
# (1193513, 200)
# Pesos de clases: [ 0.43526359 28.97272727 20.96710526  0.61715724]

# %%
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
shape_val=np.asarray(input_ids_val).shape
shape_test=np.asarray(input_ids_test).shape

x_train=np.zeros((shape[0], shape[1], emb))
j=0
for in_id in input_ids:
    x_train[j]=EMB_matrix[in_id]
    j+=1
    
x_val=np.zeros((shape_val[0], shape_val[1], emb))
i=0
for in_id in input_ids_val:
    x_val[i]=EMB_matrix[in_id]
    i+=1
    
x_test=np.zeros((shape_test[0], shape_test[1], emb))
i=0
for in_id in input_ids_test:
    x_test[i]=EMB_matrix[in_id]
    i+=1

# %%
def load_data(mask, k, task):
    if task=='Stance':
        path='../Datasets/CSV_Stance'
    elif task=='Harassment':
        path='../Datasets/CSV_Harassment'
        
    macro_augmented = np.load(path+'/Aumento_ofi/balance_GloVe_'+mask+'_'+str(k)+'_run.npy', allow_pickle=True)
    np.random.shuffle(macro_augmented)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    print (np.unique(labels_train), type(labels_train))
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)

    n_labels = labels_train.copy()

    input_ids = []
    for sent in tws_train:
        encoded_sent = [] 
        for wd in sent:
            try:
                encoded_sent.append(token_2_idx[wd])
            except:
                continue
        input_ids.append(encoded_sent)

    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], emb))
    j=0
    for in_id in input_ids:
        x_train[j]=EMB_matrix[in_id]
        j+=1

    return x_train, y_train, n_labels, class_weights


def train_5models(fold, e1, e2, x_val, y_val, xfrom, xto, task, balanced=False, x_train=None, y_train=None, n_labels=None, class_weights=None):
    fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    if balanced:
        mask=str(int(fold*100))
    
    if task== 'Stance':
        path='../Datasets/Models_Stance/'
    elif task== 'Harassment':
        path= '../Datasets/Models_Harassment/'
        
    for i in range(xfrom,xto + 1):    
        if balanced:
            x_train, y_train, n_labels, class_weights = load_data(mask, i, task)
        
        print ("\n\n -------------------- Entrenando exec", i," -------------------- \n\n")
        cnn1=create_cnn1(x_train.shape[1:])
        trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=e1, BS=32, verb=0, focal=True)
        trained.save(path+str(fold)+'/cnn1_'+str(i)+'-exec.h5')   
        f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
        keras.backend.clear_session()
        gc.collect()
        
        fs_macro['cnn1'].append(f1_ma_t)
        fs_none['cnn1'].append(f1_t)
        accs['cnn1'].append(acc_t)
        confusions['cnn1'].append(matriz_t)

        cnn2=create_cnn2(x_train.shape[1:])
        trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=e1, BS=32, verb=0, focal=True)
        trained.save(path+str(fold)+'/cnn2_'+str(i)+'-exec.h5')
        f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
        keras.backend.clear_session()
        gc.collect()
        
        fs_macro['cnn2'].append(f1_ma_t)
        fs_none['cnn2'].append(f1_t)
        accs['cnn2'].append(acc_t)
        confusions['cnn2'].append(matriz_t)

        rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
        trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=e2, BS=32, verb=0, focal=True)
        trained.save(path+str(fold)+'/rnn1_'+str(i)+'-exec.h5')
        f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
        keras.backend.clear_session()
        gc.collect()
        
        fs_macro['rnn1'].append(f1_ma_t)
        fs_none['rnn1'].append(f1_t)
        accs['rnn1'].append(acc_t)
        confusions['rnn1'].append(matriz_t)

        rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
        trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=e1, BS=32, verb=0, focal=False)
        trained.save(path+str(fold)+'/rnn2_'+str(i)+'-exec.h5')
        f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
        keras.backend.clear_session()
        gc.collect()
        
        fs_macro['rnn2'].append(f1_ma_t)
        fs_none['rnn2'].append(f1_t)
        accs['rnn2'].append(acc_t)
        confusions['rnn2'].append(matriz_t)

        rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
        trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=e2, BS=32, verb=0, focal=True)
        trained.save(path+str(fold)+'/rnn3_'+str(i)+'-exec.h5')
        f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
        keras.backend.clear_session()
        gc.collect()
        
        fs_macro['rnn3'].append(f1_ma_t)
        fs_none['rnn3'].append(f1_t)
        accs['rnn3'].append(acc_t)
        confusions['rnn3'].append(matriz_t)

    return fs_macro, fs_none, accs, confusions

# %%
def predecir_modelos(bs,predichos_all):  #best fit
    temp=predichos_all.copy()
    final=[np.argmax(pred) for pred in temp]  
    confianzas=[temp[i][final[i]] for i in range(len(final))]
    predichos_new=[]
    for i in range(len(temp)):
        indice=final[i]%4
        predichos_new.append(int(indice))
    return predichos_new,final,confianzas    

def predecir_modelos_norm(bs,predichos_all):  #normalizado
    temp=predichos_all.copy()
    final=[]
    confianzas=[]
    for pred in temp:   
        aux=np.ones(4)
        for i in range(1,6): #for machine pred
            sub=pred[(4*(i-1)):(4*i)]
            aux=aux*np.asarray(sub)
            
        aux=aux/np.sum(aux)
        final.append(np.argmax(aux))
        confianzas.append(aux[np.argmax(aux)])  
           
    predichos_new=[]
    for i in range(len(temp)):
        predichos_new.append(final[i])
    return predichos_new,final,confianzas
    
def predecir_modelos_average(bs,predichos_all): #average
    temp=predichos_all.copy()
    final=[]
    confianzas=[]
    for pred in temp:
        aux=np.zeros(4)
        for i in range(1,6):
            sub=pred[(4*(i-1)):(4*i)]
            aux=aux+np.asarray(sub)
            
        aux=aux/5.0 #dividido en el total de machines
        final.append(np.argmax(aux))
        confianzas.append(aux[np.argmax(aux)])  
           
    predichos_new=[]
    for i in range(len(temp)):
        predichos_new.append(final[i])
    return predichos_new,final,confianzas

# %% [markdown]
# # 0.0 No class weights

# %%
import matplotlib.pyplot as plt 

def eval_committe(mask, path, xfrom, xto, x_test, labels_test, bs=32):
    fs_macro_test={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    fs_none_test={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    accs_test={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
    confusions_test={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

    best_test={'acc':[], 'none':[], 'macro':[], 'cm':[]}
    norm_test={'acc':[], 'none':[], 'macro':[], 'cm':[]}
    voting_test={'acc':[], 'none':[], 'macro':[], 'cm':[]}

    for j in range(xfrom, xto + 1):
        print ("")
        print ("---------------- EJECUCIÓN #"+str(j)+'----------------')
        cnn1= load_model(path+str(mask)+'/cnn1_'+str(j)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})  
        cnn2= load_model(path+str(mask)+'/cnn2_'+str(j)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()}) 
        rnn1= load_model(path+str(mask)+'/rnn1_'+str(j)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()}) 
        rnn2= load_model(path+str(mask)+'/rnn2_'+str(j)+'-exec.h5') 
        rnn3= load_model(path+str(mask)+'/rnn3_'+str(j)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()}) 

        list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
        index_models=np.arange(5)
        dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
        modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
        ind=np.arange(5)
        dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

        print ("Trabajando en predicciones Test")    
        for i in dict_trainedModel.keys(): 
            a_evaluar=dict_models[i]
            predicho=dict_trainedModel[i].predict(x_test, batch_size=bs)
            predicho=[np.argmax(pred) for pred in predicho]
            acc= accuracy_score(labels_test, predicho)  
            f1_ma=f1_score(labels_test, predicho, average='macro')
            f1_no=f1_score(labels_test, predicho, average=None)
            matriz=cm_norma(confusion_matrix(labels_test, predicho))
            fs_macro_test[dict_models[i]].append(f1_ma)
            fs_none_test[dict_models[i]].append(f1_no)
            accs_test[dict_models[i]].append(acc)
            confusions_test[dict_models[i]].append(matriz)

        predicciones_all_test=[]
        for i in dict_trainedModel.keys(): 
            a_evaluar=dict_models[i]
            predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))
        predichos_all_test=np.concatenate(np.asarray(predicciones_all_test),axis=-1)


        #print ("--------TESTING SET--------")

        print ("\nEvaluating Committee Best Fit...")
        trainPredicho, maxPredicho, confianzas = predecir_modelos(bs,predichos_all_test)
        acc_comite= accuracy_score(labels_test, trainPredicho)  
        print("Accuracy: %.3f" % acc_comite)
        f1=f1_score(labels_test, trainPredicho, average='macro') 
        print("F1-macro: %.3f" % f1)
        f1_no=f1_score(labels_test, trainPredicho, average=None)
        np.set_printoptions(precision=3)
        print("F1-score NIPS:",f1_no)
        cm=cm_norma(confusion_matrix(labels_test, trainPredicho))      
        best_test['acc'].append(acc_comite)
        best_test['macro'].append(f1)
        best_test['none'].append(f1_no)
        best_test['cm'].append(cm)

        print ("\nEvaluating Committee Norm...")
        trainPredicho, maxPredicho, confianzas = predecir_modelos_norm(bs,predichos_all_test)
        acc_comite= accuracy_score(labels_test, trainPredicho)  
        print("Accuracy: %.3f" % acc_comite)
        f1=f1_score(labels_test, trainPredicho, average='macro') 
        print("F1-macro: %.3f" % f1)
        f1_no=f1_score(labels_test, trainPredicho, average=None)
        np.set_printoptions(precision=3)
        print("F1-score NIPS:",f1_no)
        cm=cm_norma(confusion_matrix(labels_test, trainPredicho))
        norm_test['acc'].append(acc_comite)
        norm_test['macro'].append(f1)
        norm_test['none'].append(f1_no)
        norm_test['cm'].append(cm)
        
        print ("\nEvaluating Committee Voting...")
        trainPredicho, maxPredicho, confianzas = predecir_modelos_average(bs,predichos_all_test)
        acc_comite= accuracy_score(labels_test, trainPredicho)  
        print("Accuracy: %.3f" % acc_comite)
        f1=f1_score(labels_test, trainPredicho, average='macro') 
        print("F1-macro: %.3f" % f1)
        f1_no=f1_score(labels_test, trainPredicho, average=None)
        np.set_printoptions(precision=3)
        print("F1-score NIPS:",f1_no)
        cm=cm_norma(confusion_matrix(labels_test, trainPredicho))
        voting_test['acc'].append(acc_comite)
        voting_test['macro'].append(f1)
        voting_test['none'].append(f1_no)
        voting_test['cm'].append(cm)
        
        keras.backend.clear_session()
        gc.collect()

    return best_test, norm_test, voting_test

def plot_cm(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):
    
    import itertools
    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
        
    thresh = cm.max() / 2.# if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{:0.3f}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.show()

# %%
ruta= '../../Datasets/Models_Harassment/'
best_test, norm_test, voting_test  = eval_committe('0.0', ruta, 1, 20, x_test, labels_test)
# Out:
# ---------------- EJECUCIÓN #1----------------
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.861
# F1-macro: 0.428
# F1-score NIPS: [0.921 0.    0.    0.791]
#
# Evaluating Committee Norm...
# Accuracy: 0.874
# F1-macro: 0.440
# F1-score NIPS: [0.929 0.    0.    0.829]
#
# Evaluating Committee Voting...
# Accuracy: 0.872
# F1-macro: 0.438
# F1-score NIPS: [0.928 0.    0.    0.823]
#
# ---------------- EJECUCIÓN #2----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.865
# F1-macro: 0.429
# F1-score NIPS: [0.926 0.    0.    0.791]
#
# Evaluating Committee Norm...
# Accuracy: 0.869
# F1-macro: 0.433
# F1-score NIPS: [0.925 0.    0.    0.808]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.430
# F1-score NIPS: [0.923 0.    0.    0.797]
#
# ---------------- EJECUCIÓN #3----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.852
# F1-macro: 0.415
# F1-score NIPS: [0.915 0.    0.    0.743]
#
# Evaluating Committee Norm...
# Accuracy: 0.858
# F1-macro: 0.422
# F1-score NIPS: [0.918 0.    0.    0.768]
#
# Evaluating Committee Voting...
# Accuracy: 0.858
# F1-macro: 0.421
# F1-score NIPS: [0.918 0.    0.    0.765]
#
# ---------------- EJECUCIÓN #4----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.861
# F1-macro: 0.424
# F1-score NIPS: [0.921 0.    0.    0.775]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.431
# F1-score NIPS: [0.923 0.    0.    0.801]
#
# Evaluating Committee Voting...
# Accuracy: 0.868
# F1-macro: 0.432
# F1-score NIPS: [0.925 0.    0.    0.803]
#
# ---------------- EJECUCIÓN #5----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.866
# F1-macro: 0.430
# F1-score NIPS: [0.927 0.    0.    0.794]
#
# Evaluating Committee Norm...
# Accuracy: 0.870
# F1-macro: 0.434
# F1-score NIPS: [0.928 0.    0.    0.809]
#
# Evaluating Committee Voting...
# Accuracy: 0.870
# F1-macro: 0.435
# F1-score NIPS: [0.929 0.    0.    0.811]
#
# ---------------- EJECUCIÓN #6----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.862
# F1-macro: 0.429
# F1-score NIPS: [0.923 0.    0.    0.792]
#
# Evaluating Committee Norm...
# Accuracy: 0.871
# F1-macro: 0.438
# F1-score NIPS: [0.927 0.    0.    0.825]
#
# Evaluating Committee Voting...
# Accuracy: 0.873
# F1-macro: 0.439
# F1-score NIPS: [0.928 0.    0.    0.828]
#
# ---------------- EJECUCIÓN #7----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.832
# F1-macro: 0.386
# F1-score NIPS: [0.902 0.    0.    0.642]
#
# Evaluating Committee Norm...
# Accuracy: 0.837
# F1-macro: 0.393
# F1-score NIPS: [0.906 0.    0.    0.667]
#
# Evaluating Committee Voting...
# Accuracy: 0.839
# F1-macro: 0.396
# F1-score NIPS: [0.907 0.    0.    0.678]
#
# ---------------- EJECUCIÓN #8----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.860
# F1-macro: 0.425
# F1-score NIPS: [0.922 0.    0.    0.779]
#
# Evaluating Committee Norm...
# Accuracy: 0.865
# F1-macro: 0.430
# F1-score NIPS: [0.924 0.    0.    0.797]
#
# Evaluating Committee Voting...
# Accuracy: 0.869
# F1-macro: 0.434
# F1-score NIPS: [0.927 0.    0.    0.809]
#
# ---------------- EJECUCIÓN #9----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.850
# F1-macro: 0.412
# F1-score NIPS: [0.914 0.    0.    0.735]
#
# Evaluating Committee Norm...
# Accuracy: 0.860
# F1-macro: 0.424
# F1-score NIPS: [0.92  0.    0.    0.776]
#
# Evaluating Committee Voting...
# Accuracy: 0.862
# F1-macro: 0.426
# F1-score NIPS: [0.92  0.    0.    0.782]
#
# ---------------- EJECUCIÓN #10----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.850
# F1-macro: 0.418
# F1-score NIPS: [0.918 0.    0.    0.754]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.433
# F1-score NIPS: [0.927 0.    0.    0.804]
#
# Evaluating Committee Voting...
# Accuracy: 0.869
# F1-macro: 0.435
# F1-score NIPS: [0.928 0.    0.    0.813]
#
# ---------------- EJECUCIÓN #11----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.871
# F1-macro: 0.442
# F1-score NIPS: [0.93  0.    0.025 0.815]
#
# Evaluating Committee Norm...
# Accuracy: 0.872
# F1-macro: 0.437
# F1-score NIPS: [0.93  0.    0.    0.817]
#
# Evaluating Committee Voting...
# Accuracy: 0.874
# F1-macro: 0.439
# F1-score NIPS: [0.931 0.    0.    0.825]
#
# ---------------- EJECUCIÓN #12----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.861
# F1-macro: 0.427
# F1-score NIPS: [0.921 0.    0.    0.786]
#
# Evaluating Committee Norm...
# Accuracy: 0.872
# F1-macro: 0.437
# F1-score NIPS: [0.927 0.    0.    0.822]
#
# Evaluating Committee Voting...
# Accuracy: 0.870
# F1-macro: 0.437
# F1-score NIPS: [0.925 0.    0.    0.821]
#
# ---------------- EJECUCIÓN #13----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.855
# F1-macro: 0.419
# F1-score NIPS: [0.918 0.    0.    0.758]
#
# Evaluating Committee Norm...
# Accuracy: 0.864
# F1-macro: 0.428
# F1-score NIPS: [0.923 0.    0.    0.79 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.429
# F1-score NIPS: [0.924 0.    0.    0.794]
#
# ---------------- EJECUCIÓN #14----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.858
# F1-macro: 0.421
# F1-score NIPS: [0.92  0.    0.    0.765]
#
# Evaluating Committee Norm...
# Accuracy: 0.865
# F1-macro: 0.429
# F1-score NIPS: [0.924 0.    0.    0.792]
#
# Evaluating Committee Voting...
# Accuracy: 0.868
# F1-macro: 0.432
# F1-score NIPS: [0.926 0.    0.    0.802]
#
# ---------------- EJECUCIÓN #15----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.864
# F1-macro: 0.429
# F1-score NIPS: [0.921 0.    0.    0.797]
#
# Evaluating Committee Norm...
# Accuracy: 0.862
# F1-macro: 0.427
# F1-score NIPS: [0.92  0.    0.    0.789]
#
# Evaluating Committee Voting...
# Accuracy: 0.863
# F1-macro: 0.428
# F1-score NIPS: [0.921 0.    0.    0.792]
# ---------------- EJECUCIÓN #16----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.850
# F1-macro: 0.411
# F1-score NIPS: [0.914 0.    0.    0.728]
#
# Evaluating Committee Norm...
# Accuracy: 0.861
# F1-macro: 0.426
# F1-score NIPS: [0.919 0.    0.    0.786]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.431
# F1-score NIPS: [0.922 0.    0.    0.801]
#
# ---------------- EJECUCIÓN #17----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.861
# F1-macro: 0.427
# F1-score NIPS: [0.923 0.    0.    0.787]
#
# Evaluating Committee Norm...
# Accuracy: 0.871
# F1-macro: 0.436
# F1-score NIPS: [0.927 0.    0.    0.818]
#
# Evaluating Committee Voting...
# Accuracy: 0.870
# F1-macro: 0.436
# F1-score NIPS: [0.927 0.    0.    0.816]
#
# ---------------- EJECUCIÓN #18----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.841
# F1-macro: 0.400
# F1-score NIPS: [0.908 0.    0.    0.692]
#
# Evaluating Committee Norm...
# Accuracy: 0.849
# F1-macro: 0.411
# F1-score NIPS: [0.912 0.    0.    0.732]
#
# Evaluating Committee Voting...
# Accuracy: 0.852
# F1-macro: 0.415
# F1-score NIPS: [0.915 0.    0.    0.744]
#
# ---------------- EJECUCIÓN #19----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.863
# F1-macro: 0.429
# F1-score NIPS: [0.923 0.    0.    0.791]
#
# Evaluating Committee Norm...
# Accuracy: 0.873
# F1-macro: 0.439
# F1-score NIPS: [0.928 0.    0.    0.827]
#
# Evaluating Committee Voting...
# Accuracy: 0.875
# F1-macro: 0.441
# F1-score NIPS: [0.93  0.    0.    0.835]
#
# ---------------- EJECUCIÓN #20----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.837
# F1-macro: 0.393
# F1-score NIPS: [0.906 0.    0.    0.667]
#
# Evaluating Committee Norm...
# Accuracy: 0.849
# F1-macro: 0.411
# F1-score NIPS: [0.912 0.    0.    0.73 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.855
# F1-macro: 0.419
# F1-score NIPS: [0.916 0.    0.    0.758]

# %%
x=20.0

print ("[TEST] Acc Best comité: %.3f" % np.mean(np.asarray(best_test['acc'])), " -- std: %.3f" % np.std(np.asarray(best_test['acc'])))
print ("[TEST] F1 macro Best comité: %.3f" % np.mean(np.asarray(best_test['macro'])), " -- std: %.3f" % np.std(np.asarray(best_test['macro'])))
temp=np.zeros(4)
for result in best_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Best comité:" ,temp/x)
cm=np.zeros((4,4))
for result in best_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Blues')

print ("-----------")
print ("[TEST] Acc Norm comité: %.3f" % np.mean(np.asarray(norm_test['acc'])), " -- std: %.3f" % np.std(np.asarray(norm_test['acc'])))
print ("[TEST] F1 macro Norm comité: %.3f" % np.mean(np.asarray(norm_test['macro'])), " -- std: %.3f" % np.std(np.asarray(norm_test['macro'])))
temp=np.zeros(4)
for result in norm_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Norm comité:" ,temp/x)

cm=np.zeros((4,4))
for result in norm_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Blues')

print ("-----------")
print ("[TEST] Acc Voting comité: %.3f" % np.mean(np.asarray(voting_test['acc'])), " -- std: %.3f" % np.std(np.asarray(voting_test['acc'])))
print ("[TEST] F1 macro Voting comité: %.3f" % np.mean(np.asarray(voting_test['macro'])), " -- std: %.3f" % np.std(np.asarray(voting_test['macro'])))
temp=np.zeros(4)
for result in voting_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Voting comité:" ,temp/x)

cm=np.zeros((4,4))
for result in voting_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Blues')
# Out:
# [TEST] Acc Best comité: 0.856  -- std: 0.010
# [TEST] F1 macro Best comité: 0.420  -- std: 0.013
# [TEST] F1-score NIPS Best comité: [0.919 0.    0.001 0.759]
# -----------
# [TEST] Acc Norm comité: 0.864  -- std: 0.009
# [TEST] F1 macro Norm comité: 0.428  -- std: 0.011
# [TEST] F1-score NIPS Norm comité: [0.923 0.    0.    0.789]
# -----------
# [TEST] Acc Voting comité: 0.865  -- std: 0.008
# [TEST] F1 macro Voting comité: 0.430  -- std: 0.010
# [TEST] F1-score NIPS Voting comité: [0.923 0.    0.    0.795]

# %% [markdown]
# ## 0.0 Class Weights

# %%
ruta= '../../Datasets/Models_Harassment/'
best_test, norm_test, voting_test  = eval_committe('0.0cw', ruta, 1, 20, x_test, labels_test)
# Out:
# ---------------- EJECUCIÓN #1----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.862
# F1-macro: 0.441
# F1-score NIPS: [0.927 0.037 0.026 0.775]
#
# Evaluating Committee Norm...
# Accuracy: 0.869
# F1-macro: 0.431
# F1-score NIPS: [0.931 0.    0.    0.794]
#
# Evaluating Committee Voting...
# Accuracy: 0.869
# F1-macro: 0.438
# F1-score NIPS: [0.93  0.    0.026 0.798]
#
# ---------------- EJECUCIÓN #2----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.838
# F1-macro: 0.443
# F1-score NIPS: [0.913 0.151 0.049 0.659]
#
# Evaluating Committee Norm...
# Accuracy: 0.830
# F1-macro: 0.408
# F1-score NIPS: [0.903 0.089 0.025 0.613]
#
# Evaluating Committee Voting...
# Accuracy: 0.832
# F1-macro: 0.414
# F1-score NIPS: [0.905 0.103 0.026 0.624]
#
# ---------------- EJECUCIÓN #3----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.860
# F1-macro: 0.462
# F1-score NIPS: [0.923 0.054 0.084 0.786]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.437
# F1-score NIPS: [0.925 0.    0.026 0.797]
#
# Evaluating Committee Voting...
# Accuracy: 0.869
# F1-macro: 0.456
# F1-score NIPS: [0.926 0.037 0.051 0.81 ]
#
# ---------------- EJECUCIÓN #4----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.858
# F1-macro: 0.427
# F1-score NIPS: [0.922 0.019 0.    0.766]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.436
# F1-score NIPS: [0.928 0.    0.025 0.791]
#
# Evaluating Committee Voting...
# Accuracy: 0.866
# F1-macro: 0.441
# F1-score NIPS: [0.927 0.    0.049 0.787]
#
# ---------------- EJECUCIÓN #5----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.839
# F1-macro: 0.427
# F1-score NIPS: [0.911 0.119 0.    0.677]
#
# Evaluating Committee Norm...
# Accuracy: 0.865
# F1-macro: 0.480
# F1-score NIPS: [0.926 0.115 0.09  0.789]
#
# Evaluating Committee Voting...
# Accuracy: 0.856
# F1-macro: 0.479
# F1-score NIPS: [0.92  0.163 0.068 0.766]
#
# ---------------- EJECUCIÓN #6----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.855
# F1-macro: 0.469
# F1-score NIPS: [0.918 0.136 0.073 0.749]
#
# Evaluating Committee Norm...
# Accuracy: 0.862
# F1-macro: 0.467
# F1-score NIPS: [0.921 0.067 0.094 0.786]
#
# Evaluating Committee Voting...
# Accuracy: 0.851
# F1-macro: 0.502
# F1-score NIPS: [0.915 0.157 0.154 0.783]
#
# ---------------- EJECUCIÓN #7----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.841
# F1-macro: 0.457
# F1-score NIPS: [0.913 0.07  0.112 0.732]
#
# Evaluating Committee Norm...
# Accuracy: 0.861
# F1-macro: 0.434
# F1-score NIPS: [0.924 0.019 0.025 0.767]
#
# Evaluating Committee Voting...
# Accuracy: 0.862
# F1-macro: 0.464
# F1-score NIPS: [0.924 0.036 0.118 0.777]
#
# ---------------- EJECUCIÓN #8----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.853
# F1-macro: 0.445
# F1-score NIPS: [0.918 0.036 0.071 0.754]
#
# Evaluating Committee Norm...
# Accuracy: 0.865
# F1-macro: 0.456
# F1-score NIPS: [0.925 0.037 0.075 0.788]
#
# Evaluating Committee Voting...
# Accuracy: 0.866
# F1-macro: 0.464
# F1-score NIPS: [0.925 0.071 0.074 0.787]
#
# ---------------- EJECUCIÓN #9----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.854
# F1-macro: 0.455
# F1-score NIPS: [0.92  0.019 0.108 0.772]
#
# Evaluating Committee Norm...
# Accuracy: 0.871
# F1-macro: 0.444
# F1-score NIPS: [0.929 0.    0.025 0.82 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.870
# F1-macro: 0.452
# F1-score NIPS: [0.928 0.019 0.049 0.815]
#
# ---------------- EJECUCIÓN #10----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.849
# F1-macro: 0.435
# F1-score NIPS: [0.915 0.054 0.026 0.745]
#
# Evaluating Committee Norm...
# Accuracy: 0.854
# F1-macro: 0.416
# F1-score NIPS: [0.92  0.    0.    0.743]
#
# Evaluating Committee Voting...
# Accuracy: 0.859
# F1-macro: 0.436
# F1-score NIPS: [0.922 0.037 0.026 0.759]
#
# ---------------- EJECUCIÓN #11----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.855
# F1-macro: 0.436
# F1-score NIPS: [0.917 0.055 0.026 0.745]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.455
# F1-score NIPS: [0.926 0.037 0.075 0.782]
#
# Evaluating Committee Voting...
# Accuracy: 0.866
# F1-macro: 0.491
# F1-score NIPS: [0.923 0.136 0.12  0.787]
#
# ---------------- EJECUCIÓN #12----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.857
# F1-macro: 0.461
# F1-score NIPS: [0.92  0.068 0.094 0.761]
#
# Evaluating Committee Norm...
# Accuracy: 0.862
# F1-macro: 0.451
# F1-score NIPS: [0.922 0.037 0.073 0.771]
#
# Evaluating Committee Voting...
# Accuracy: 0.860
# F1-macro: 0.477
# F1-score NIPS: [0.92  0.101 0.118 0.769]
#
# ---------------- EJECUCIÓN #13----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.849
# F1-macro: 0.515
# F1-score NIPS: [0.921 0.072 0.318 0.747]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.484
# F1-score NIPS: [0.929 0.036 0.189 0.781]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.492
# F1-score NIPS: [0.927 0.053 0.2   0.788]
#
# ---------------- EJECUCIÓN #14----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.846
# F1-macro: 0.436
# F1-score NIPS: [0.917 0.05  0.023 0.752]
#
# Evaluating Committee Norm...
# Accuracy: 0.859
# F1-macro: 0.436
# F1-score NIPS: [0.925 0.019 0.025 0.776]
#
# Evaluating Committee Voting...
# Accuracy: 0.860
# F1-macro: 0.457
# F1-score NIPS: [0.925 0.054 0.074 0.775]
#
# ---------------- EJECUCIÓN #15----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.861
# F1-macro: 0.531
# F1-score NIPS: [0.925 0.12  0.308 0.773]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.491
# F1-score NIPS: [0.926 0.    0.243 0.793]
#
# Evaluating Committee Voting...
# Accuracy: 0.866
# F1-macro: 0.507
# F1-score NIPS: [0.924 0.055 0.262 0.786]
#
# ---------------- EJECUCIÓN #16----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.859
# F1-macro: 0.518
# F1-score NIPS: [0.924 0.163 0.209 0.777]
#
# Evaluating Committee Norm...
# Accuracy: 0.875
# F1-macro: 0.541
# F1-score NIPS: [0.936 0.073 0.341 0.813]
#
# Evaluating Committee Voting...
# Accuracy: 0.876
# F1-macro: 0.531
# F1-score NIPS: [0.937 0.073 0.299 0.815]
#
# ---------------- EJECUCIÓN #17----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.837
# F1-macro: 0.444
# F1-score NIPS: [0.912 0.034 0.115 0.713]
#
# Evaluating Committee Norm...
# Accuracy: 0.844
# F1-macro: 0.453
# F1-score NIPS: [0.911 0.019 0.191 0.69 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.848
# F1-macro: 0.467
# F1-score NIPS: [0.915 0.054 0.189 0.709]
#
# ---------------- EJECUCIÓN #18----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.857
# F1-macro: 0.505
# F1-score NIPS: [0.919 0.199 0.112 0.789]
#
# Evaluating Committee Norm...
# Accuracy: 0.870
# F1-macro: 0.477
# F1-score NIPS: [0.93  0.133 0.048 0.799]
#
# Evaluating Committee Voting...
# Accuracy: 0.872
# F1-macro: 0.513
# F1-score NIPS: [0.928 0.176 0.133 0.815]
#
# ---------------- EJECUCIÓN #19----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.838
# F1-macro: 0.529
# F1-score NIPS: [0.913 0.222 0.23  0.749]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.508
# F1-score NIPS: [0.929 0.115 0.178 0.809]
#
# Evaluating Committee Voting...
# Accuracy: 0.867
# F1-macro: 0.527
# F1-score NIPS: [0.927 0.172 0.204 0.805]
#
# ---------------- EJECUCIÓN #20----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.847
# F1-macro: 0.533
# F1-score NIPS: [0.92  0.171 0.27  0.771]
#
# Evaluating Committee Norm...
# Accuracy: 0.868
# F1-macro: 0.467
# F1-score NIPS: [0.925 0.12  0.026 0.799]
#
# Evaluating Committee Voting...
# Accuracy: 0.867
# F1-macro: 0.486
# F1-score NIPS: [0.924 0.146 0.074 0.801]

# %%
x=20.0

print ("[TEST] Acc Best comité: %.3f" % np.mean(np.asarray(best_test['acc'])), " -- std: %.3f" % np.std(np.asarray(best_test['acc'])))
print ("[TEST] F1 macro Best comité: %.3f" % np.mean(np.asarray(best_test['macro'])), " -- std: %.3f" % np.std(np.asarray(best_test['macro'])))
temp=np.zeros(4)
for result in best_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Best comité:" ,temp/x)
cm=np.zeros((4,4))
for result in best_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Greens')

print ("-----------")
print ("[TEST] Acc Norm comité: %.3f" % np.mean(np.asarray(norm_test['acc'])), " -- std: %.3f" % np.std(np.asarray(norm_test['acc'])))
print ("[TEST] F1 macro Norm comité: %.3f" % np.mean(np.asarray(norm_test['macro'])), " -- std: %.3f" % np.std(np.asarray(norm_test['macro'])))
temp=np.zeros(4)
for result in norm_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Norm comité:" ,temp/x)

cm=np.zeros((4,4))
for result in norm_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Greens')

print ("-----------")
print ("[TEST] Acc Voting comité: %.3f" % np.mean(np.asarray(voting_test['acc'])), " -- std: %.3f" % np.std(np.asarray(voting_test['acc'])))
print ("[TEST] F1 macro Voting comité: %.3f" % np.mean(np.asarray(voting_test['macro'])), " -- std: %.3f" % np.std(np.asarray(voting_test['macro'])))
temp=np.zeros(4)
for result in voting_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Voting comité:" ,temp/x)

cm=np.zeros((4,4))
for result in voting_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='Greens')
# Out:
# [TEST] Acc Best comité: 0.851  -- std: 0.008
# [TEST] F1 macro Best comité: 0.468  -- std: 0.037
# [TEST] F1-score NIPS Best comité: [0.918 0.092 0.113 0.75 ]
# -----------
# [TEST] Acc Norm comité: 0.863  -- std: 0.010
# [TEST] F1 macro Norm comité: 0.459  -- std: 0.031
# [TEST] F1-score NIPS Norm comité: [0.925 0.046 0.089 0.775]
# -----------
# [TEST] Acc Voting comité: 0.862  -- std: 0.010
# [TEST] F1 macro Voting comité: 0.475  -- std: 0.031
# [TEST] F1-score NIPS Voting comité: [0.924 0.082 0.116 0.778]

# %% [markdown]
# ## 0.15 Balanced

# %%
best_test, norm_test, voting_test  = eval_committe('0.15', ruta, 1, 20, x_test, labels_test)
# Out:
# ---------------- EJECUCIÓN #1----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.835
# F1-macro: 0.559
# F1-score NIPS: [0.916 0.252 0.291 0.775]
#
# Evaluating Committee Norm...
# Accuracy: 0.862
# F1-macro: 0.498
# F1-score NIPS: [0.921 0.135 0.13  0.805]
#
# Evaluating Committee Voting...
# Accuracy: 0.862
# F1-macro: 0.533
# F1-score NIPS: [0.922 0.222 0.178 0.808]
#
# ---------------- EJECUCIÓN #2----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.826
# F1-macro: 0.560
# F1-score NIPS: [0.901 0.278 0.255 0.805]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.486
# F1-score NIPS: [0.929 0.035 0.172 0.807]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.504
# F1-score NIPS: [0.928 0.101 0.18  0.808]
#
# ---------------- EJECUCIÓN #3----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.848
# F1-macro: 0.524
# F1-score NIPS: [0.914 0.171 0.217 0.796]
#
# Evaluating Committee Norm...
# Accuracy: 0.869
# F1-macro: 0.487
# F1-score NIPS: [0.927 0.081 0.111 0.83 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.873
# F1-macro: 0.516
# F1-score NIPS: [0.929 0.109 0.189 0.835]
#
# ---------------- EJECUCIÓN #4----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.851
# F1-macro: 0.561
# F1-score NIPS: [0.922 0.282 0.259 0.781]
#
# Evaluating Committee Norm...
# Accuracy: 0.862
# F1-macro: 0.490
# F1-score NIPS: [0.922 0.068 0.176 0.795]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.522
# F1-score NIPS: [0.924 0.144 0.212 0.806]
#
# ---------------- EJECUCIÓN #5----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.839
# F1-macro: 0.552
# F1-score NIPS: [0.912 0.222 0.286 0.789]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.493
# F1-score NIPS: [0.925 0.081 0.143 0.824]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.523
# F1-score NIPS: [0.923 0.153 0.195 0.824]
#
# ---------------- EJECUCIÓN #6----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.844
# F1-macro: 0.538
# F1-score NIPS: [0.914 0.221 0.211 0.807]
#
# Evaluating Committee Norm...
# Accuracy: 0.871
# F1-macro: 0.505
# F1-score NIPS: [0.929 0.113 0.157 0.822]
#
# Evaluating Committee Voting...
# Accuracy: 0.874
# F1-macro: 0.538
# F1-score NIPS: [0.93  0.13  0.268 0.824]
#
# ---------------- EJECUCIÓN #7----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.846
# F1-macro: 0.522
# F1-score NIPS: [0.915 0.143 0.234 0.797]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.485
# F1-score NIPS: [0.923 0.018 0.194 0.806]
#
# Evaluating Committee Voting...
# Accuracy: 0.868
# F1-macro: 0.494
# F1-score NIPS: [0.924 0.018 0.222 0.811]
#
# ---------------- EJECUCIÓN #8----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.834
# F1-macro: 0.542
# F1-score NIPS: [0.913 0.224 0.243 0.787]
#
# Evaluating Committee Norm...
# Accuracy: 0.869
# F1-macro: 0.512
# F1-score NIPS: [0.925 0.083 0.224 0.817]
#
# Evaluating Committee Voting...
# Accuracy: 0.861
# F1-macro: 0.512
# F1-score NIPS: [0.922 0.127 0.194 0.805]
#
# ---------------- EJECUCIÓN #9----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.854
# F1-macro: 0.534
# F1-score NIPS: [0.922 0.186 0.23  0.797]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.471
# F1-score NIPS: [0.924 0.035 0.122 0.805]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.491
# F1-score NIPS: [0.924 0.083 0.151 0.806]
#
# ---------------- EJECUCIÓN #10----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.837
# F1-macro: 0.567
# F1-score NIPS: [0.911 0.317 0.247 0.792]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.525
# F1-score NIPS: [0.924 0.25  0.119 0.807]
#
# Evaluating Committee Voting...
# Accuracy: 0.865
# F1-macro: 0.538
# F1-score NIPS: [0.924 0.239 0.186 0.802]
#
# ---------------- EJECUCIÓN #11----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.784
# F1-macro: 0.531
# F1-score NIPS: [0.883 0.263 0.23  0.749]
#
# Evaluating Committee Norm...
# Accuracy: 0.858
# F1-macro: 0.520
# F1-score NIPS: [0.923 0.218 0.13  0.807]
#
# Evaluating Committee Voting...
# Accuracy: 0.849
# F1-macro: 0.543
# F1-score NIPS: [0.919 0.257 0.2   0.797]
#
# ---------------- EJECUCIÓN #12----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.763
# F1-macro: 0.524
# F1-score NIPS: [0.853 0.257 0.233 0.755]
#
# Evaluating Committee Norm...
# Accuracy: 0.840
# F1-macro: 0.505
# F1-score NIPS: [0.913 0.199 0.146 0.762]
#
# Evaluating Committee Voting...
# Accuracy: 0.823
# F1-macro: 0.538
# F1-score NIPS: [0.898 0.262 0.222 0.772]
#
# ---------------- EJECUCIÓN #13----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.837
# F1-macro: 0.549
# F1-score NIPS: [0.916 0.229 0.268 0.784]
#
# Evaluating Committee Norm...
# Accuracy: 0.864
# F1-macro: 0.477
# F1-score NIPS: [0.923 0.066 0.109 0.812]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.524
# F1-score NIPS: [0.923 0.199 0.157 0.816]
#
# ---------------- EJECUCIÓN #14----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.782
# F1-macro: 0.521
# F1-score NIPS: [0.879 0.223 0.239 0.745]
#
# Evaluating Committee Norm...
# Accuracy: 0.848
# F1-macro: 0.529
# F1-score NIPS: [0.914 0.284 0.143 0.776]
#
# Evaluating Committee Voting...
# Accuracy: 0.839
# F1-macro: 0.528
# F1-score NIPS: [0.911 0.277 0.152 0.772]
#
# ---------------- EJECUCIÓN #15----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.806
# F1-macro: 0.518
# F1-score NIPS: [0.899 0.188 0.197 0.79 ]
#
# Evaluating Committee Norm...
# Accuracy: 0.870
# F1-macro: 0.483
# F1-score NIPS: [0.928 0.035 0.146 0.822]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.511
# F1-score NIPS: [0.926 0.082 0.218 0.817]
#
# ---------------- EJECUCIÓN #16----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.774
# F1-macro: 0.525
# F1-score NIPS: [0.878 0.24  0.289 0.691]
#
# Evaluating Committee Norm...
# Accuracy: 0.847
# F1-macro: 0.492
# F1-score NIPS: [0.913 0.147 0.149 0.761]
#
# Evaluating Committee Voting...
# Accuracy: 0.840
# F1-macro: 0.528
# F1-score NIPS: [0.91  0.227 0.216 0.757]
#
# ---------------- EJECUCIÓN #17----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.831
# F1-macro: 0.533
# F1-score NIPS: [0.905 0.258 0.185 0.784]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.500
# F1-score NIPS: [0.924 0.124 0.141 0.81 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.493
# F1-score NIPS: [0.923 0.108 0.138 0.804]
#
# ---------------- EJECUCIÓN #18----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.811
# F1-macro: 0.560
# F1-score NIPS: [0.893 0.249 0.296 0.801]
#
# Evaluating Committee Norm...
# Accuracy: 0.864
# F1-macro: 0.524
# F1-score NIPS: [0.926 0.183 0.165 0.824]
#
# Evaluating Committee Voting...
# Accuracy: 0.854
# F1-macro: 0.541
# F1-score NIPS: [0.921 0.212 0.218 0.812]
#
# ---------------- EJECUCIÓN #19----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.833
# F1-macro: 0.541
# F1-score NIPS: [0.908 0.206 0.266 0.784]
#
# Evaluating Committee Norm...
# Accuracy: 0.865
# F1-macro: 0.520
# F1-score NIPS: [0.926 0.116 0.236 0.804]
#
# Evaluating Committee Voting...
# Accuracy: 0.854
# F1-macro: 0.516
# F1-score NIPS: [0.92  0.126 0.227 0.791]
#
# ---------------- EJECUCIÓN #20----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.806
# F1-macro: 0.556
# F1-score NIPS: [0.894 0.232 0.328 0.772]
#
# Evaluating Committee Norm...
# Accuracy: 0.866
# F1-macro: 0.477
# F1-score NIPS: [0.927 0.084 0.094 0.802]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.493
# F1-score NIPS: [0.925 0.111 0.132 0.805]

# %%
x=20.0

print ("[TEST] Acc Best comité: %.3f" % np.mean(np.asarray(best_test['acc'])), " -- std: %.3f" % np.std(np.asarray(best_test['acc'])))
print ("[TEST] F1 macro Best comité: %.3f" % np.mean(np.asarray(best_test['macro'])), " -- std: %.3f" % np.std(np.asarray(best_test['macro'])))
temp=np.zeros(4)
for result in best_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Best comité:" ,temp/x)
cm=np.zeros((4,4))
for result in best_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Norm comité: %.3f" % np.mean(np.asarray(norm_test['acc'])), " -- std: %.3f" % np.std(np.asarray(norm_test['acc'])))
print ("[TEST] F1 macro Norm comité: %.3f" % np.mean(np.asarray(norm_test['macro'])), " -- std: %.3f" % np.std(np.asarray(norm_test['macro'])))
temp=np.zeros(4)
for result in norm_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Norm comité:" ,temp/x)

cm=np.zeros((4,4))
for result in norm_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Voting comité: %.3f" % np.mean(np.asarray(voting_test['acc'])), " -- std: %.3f" % np.std(np.asarray(voting_test['acc'])))
print ("[TEST] F1 macro Voting comité: %.3f" % np.mean(np.asarray(voting_test['macro'])), " -- std: %.3f" % np.std(np.asarray(voting_test['macro'])))
temp=np.zeros(4)
for result in voting_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Voting comité:" ,temp/x)

cm=np.zeros((4,4))
for result in voting_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')
# Out:
# [TEST] Acc Best comité: 0.822  -- std: 0.027
# [TEST] F1 macro Best comité: 0.541  -- std: 0.015
# [TEST] F1-score NIPS Best comité: [0.902 0.232 0.25  0.779]
# -----------
# [TEST] Acc Norm comité: 0.863  -- std: 0.008
# [TEST] F1 macro Norm comité: 0.499  -- std: 0.017
# [TEST] F1-score NIPS Norm comité: [0.923 0.118 0.15  0.805]
# -----------
# [TEST] Acc Voting comité: 0.859  -- std: 0.012
# [TEST] F1 macro Voting comité: 0.519  -- std: 0.017
# [TEST] F1-score NIPS Voting comité: [0.921 0.159 0.193 0.804]

# %% [markdown]
# ## 50% De 1 - 20

# %%
best_test, norm_test, voting_test  = eval_committe('0.5', ruta, 1, 20, x_test, labels_test)
# Out:
# ---------------- EJECUCIÓN #1----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.797
# F1-macro: 0.550
# F1-score NIPS: [0.887 0.254 0.286 0.772]
#
# Evaluating Committee Norm...
# Accuracy: 0.844
# F1-macro: 0.531
# F1-score NIPS: [0.91  0.195 0.216 0.802]
#
# Evaluating Committee Voting...
# Accuracy: 0.843
# F1-macro: 0.557
# F1-score NIPS: [0.911 0.272 0.26  0.786]
#
# ---------------- EJECUCIÓN #2----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.769
# F1-macro: 0.519
# F1-score NIPS: [0.889 0.276 0.253 0.66 ]
#
# Evaluating Committee Norm...
# Accuracy: 0.833
# F1-macro: 0.513
# F1-score NIPS: [0.912 0.111 0.269 0.761]
#
# Evaluating Committee Voting...
# Accuracy: 0.815
# F1-macro: 0.522
# F1-score NIPS: [0.909 0.217 0.238 0.723]
#
# ---------------- EJECUCIÓN #3----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.830
# F1-macro: 0.504
# F1-score NIPS: [0.905 0.076 0.278 0.757]
#
# Evaluating Committee Norm...
# Accuracy: 0.854
# F1-macro: 0.484
# F1-score NIPS: [0.919 0.034 0.202 0.782]
#
# Evaluating Committee Voting...
# Accuracy: 0.850
# F1-macro: 0.494
# F1-score NIPS: [0.919 0.067 0.216 0.772]
#
# ---------------- EJECUCIÓN #4----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.763
# F1-macro: 0.482
# F1-score NIPS: [0.858 0.232 0.112 0.726]
#
# Evaluating Committee Norm...
# Accuracy: 0.829
# F1-macro: 0.491
# F1-score NIPS: [0.903 0.176 0.119 0.765]
#
# Evaluating Committee Voting...
# Accuracy: 0.818
# F1-macro: 0.498
# F1-score NIPS: [0.897 0.227 0.115 0.753]
#
# ---------------- EJECUCIÓN #5----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.819
# F1-macro: 0.525
# F1-score NIPS: [0.902 0.226 0.209 0.764]
#
# Evaluating Committee Norm...
# Accuracy: 0.849
# F1-macro: 0.505
# F1-score NIPS: [0.916 0.11  0.22  0.774]
#
# Evaluating Committee Voting...
# Accuracy: 0.840
# F1-macro: 0.517
# F1-score NIPS: [0.913 0.148 0.244 0.763]
#
# ---------------- EJECUCIÓN #6----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.821
# F1-macro: 0.528
# F1-score NIPS: [0.903 0.192 0.266 0.749]
#
# Evaluating Committee Norm...
# Accuracy: 0.848
# F1-macro: 0.510
# F1-score NIPS: [0.914 0.075 0.256 0.794]
#
# Evaluating Committee Voting...
# Accuracy: 0.847
# F1-macro: 0.519
# F1-score NIPS: [0.916 0.113 0.262 0.786]
#
# ---------------- EJECUCIÓN #7----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.844
# F1-macro: 0.542
# F1-score NIPS: [0.918 0.188 0.272 0.789]
#
# Evaluating Committee Norm...
# Accuracy: 0.861
# F1-macro: 0.496
# F1-score NIPS: [0.925 0.05  0.208 0.801]
#
# Evaluating Committee Voting...
# Accuracy: 0.856
# F1-macro: 0.512
# F1-score NIPS: [0.924 0.093 0.231 0.799]
#
# ---------------- EJECUCIÓN #8----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.830
# F1-macro: 0.536
# F1-score NIPS: [0.906 0.212 0.273 0.752]
#
# Evaluating Committee Norm...
# Accuracy: 0.854
# F1-macro: 0.520
# F1-score NIPS: [0.918 0.167 0.212 0.785]
#
# Evaluating Committee Voting...
# Accuracy: 0.850
# F1-macro: 0.532
# F1-score NIPS: [0.916 0.22  0.212 0.782]
#
# ---------------- EJECUCIÓN #9----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.802
# F1-macro: 0.501
# F1-score NIPS: [0.886 0.193 0.216 0.711]
#
# Evaluating Committee Norm...
# Accuracy: 0.852
# F1-macro: 0.469
# F1-score NIPS: [0.917 0.086 0.093 0.779]
#
# Evaluating Committee Voting...
# Accuracy: 0.855
# F1-macro: 0.489
# F1-score NIPS: [0.919 0.103 0.152 0.783]
#
# ---------------- EJECUCIÓN #10----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.833
# F1-macro: 0.524
# F1-score NIPS: [0.907 0.21  0.211 0.769]
#
# Evaluating Committee Norm...
# Accuracy: 0.855
# F1-macro: 0.495
# F1-score NIPS: [0.917 0.11  0.16  0.792]
#
# Evaluating Committee Voting...
# Accuracy: 0.855
# F1-macro: 0.503
# F1-score NIPS: [0.918 0.11  0.198 0.787]
#
# ---------------- EJECUCIÓN #11----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.821
# F1-macro: 0.514
# F1-score NIPS: [0.902 0.274 0.133 0.747]
#
# Evaluating Committee Norm...
# Accuracy: 0.858
# F1-macro: 0.487
# F1-score NIPS: [0.919 0.19  0.05  0.787]
#
# Evaluating Committee Voting...
# Accuracy: 0.858
# F1-macro: 0.497
# F1-score NIPS: [0.919 0.226 0.05  0.793]
#
# ---------------- EJECUCIÓN #12----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.791
# F1-macro: 0.534
# F1-score NIPS: [0.885 0.244 0.263 0.744]
#
# Evaluating Committee Norm...
# Accuracy: 0.845
# F1-macro: 0.543
# F1-score NIPS: [0.911 0.235 0.233 0.793]
#
# Evaluating Committee Voting...
# Accuracy: 0.840
# F1-macro: 0.556
# F1-score NIPS: [0.908 0.262 0.265 0.79 ]
#
# ---------------- EJECUCIÓN #13----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.780
# F1-macro: 0.499
# F1-score NIPS: [0.882 0.183 0.231 0.701]
#
# Evaluating Committee Norm...
# Accuracy: 0.849
# F1-macro: 0.490
# F1-score NIPS: [0.915 0.112 0.159 0.773]
#
# Evaluating Committee Voting...
# Accuracy: 0.849
# F1-macro: 0.523
# F1-score NIPS: [0.918 0.152 0.265 0.759]
#
# ---------------- EJECUCIÓN #14----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.794
# F1-macro: 0.525
# F1-score NIPS: [0.885 0.243 0.226 0.747]
#
# Evaluating Committee Norm...
# Accuracy: 0.846
# F1-macro: 0.529
# F1-score NIPS: [0.913 0.202 0.202 0.797]
#
# Evaluating Committee Voting...
# Accuracy: 0.843
# F1-macro: 0.531
# F1-score NIPS: [0.911 0.204 0.22  0.79 ]
#
# ---------------- EJECUCIÓN #15----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.842
# F1-macro: 0.518
# F1-score NIPS: [0.917 0.175 0.225 0.756]
#
# Evaluating Committee Norm...
# Accuracy: 0.856
# F1-macro: 0.490
# F1-score NIPS: [0.919 0.067 0.187 0.786]
#
# Evaluating Committee Voting...
# Accuracy: 0.848
# F1-macro: 0.498
# F1-score NIPS: [0.917 0.155 0.154 0.767]
#
# ---------------- EJECUCIÓN #16----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.748
# F1-macro: 0.492
# F1-score NIPS: [0.864 0.207 0.231 0.666]
#
# Evaluating Committee Norm...
# Accuracy: 0.839
# F1-macro: 0.531
# F1-score NIPS: [0.91  0.246 0.198 0.77 ]
#
# Evaluating Committee Voting...
# Accuracy: 0.824
# F1-macro: 0.541
# F1-score NIPS: [0.903 0.259 0.256 0.749]
#
# ---------------- EJECUCIÓN #17----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.814
# F1-macro: 0.527
# F1-score NIPS: [0.893 0.214 0.226 0.777]
#
# Evaluating Committee Norm...
# Accuracy: 0.855
# F1-macro: 0.509
# F1-score NIPS: [0.919 0.158 0.17  0.789]
#
# Evaluating Committee Voting...
# Accuracy: 0.855
# F1-macro: 0.506
# F1-score NIPS: [0.919 0.182 0.13  0.79 ]
#
# ---------------- EJECUCIÓN #18----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.828
# F1-macro: 0.525
# F1-score NIPS: [0.913 0.178 0.272 0.738]
#
# Evaluating Committee Norm...
# Accuracy: 0.867
# F1-macro: 0.494
# F1-score NIPS: [0.924 0.082 0.154 0.818]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.501
# F1-score NIPS: [0.923 0.124 0.146 0.811]
#
# ---------------- EJECUCIÓN #19----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.854
# F1-macro: 0.523
# F1-score NIPS: [0.924 0.143 0.236 0.787]
#
# Evaluating Committee Norm...
# Accuracy: 0.864
# F1-macro: 0.491
# F1-score NIPS: [0.923 0.083 0.157 0.801]
#
# Evaluating Committee Voting...
# Accuracy: 0.864
# F1-macro: 0.500
# F1-score NIPS: [0.923 0.083 0.194 0.801]
#
# ---------------- EJECUCIÓN #20----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.818
# F1-macro: 0.544
# F1-score NIPS: [0.901 0.213 0.295 0.768]
#
# Evaluating Committee Norm...
# Accuracy: 0.848
# F1-macro: 0.524
# F1-score NIPS: [0.916 0.145 0.258 0.777]
#
# Evaluating Committee Voting...
# Accuracy: 0.845
# F1-macro: 0.538
# F1-score NIPS: [0.914 0.171 0.29  0.776]

# %%
x=20.0

print ("[TEST] Acc Best comité: %.3f" % np.mean(np.asarray(best_test['acc'])), " -- std: %.3f" % np.std(np.asarray(best_test['acc'])))
print ("[TEST] F1 macro Best comité: %.3f" % np.mean(np.asarray(best_test['macro'])), " -- std: %.3f" % np.std(np.asarray(best_test['macro'])))
temp=np.zeros(4)
for result in best_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Best comité:" ,temp/x)
cm=np.zeros((4,4))
for result in best_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Norm comité: %.3f" % np.mean(np.asarray(norm_test['acc'])), " -- std: %.3f" % np.std(np.asarray(norm_test['acc'])))
print ("[TEST] F1 macro Norm comité: %.3f" % np.mean(np.asarray(norm_test['macro'])), " -- std: %.3f" % np.std(np.asarray(norm_test['macro'])))
temp=np.zeros(4)
for result in norm_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Norm comité:" ,temp/x)

cm=np.zeros((4,4))
for result in norm_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Voting comité: %.3f" % np.mean(np.asarray(voting_test['acc'])), " -- std: %.3f" % np.std(np.asarray(voting_test['acc'])))
print ("[TEST] F1 macro Voting comité: %.3f" % np.mean(np.asarray(voting_test['macro'])), " -- std: %.3f" % np.std(np.asarray(voting_test['macro'])))
temp=np.zeros(4)
for result in voting_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Voting comité:" ,temp/x)

cm=np.zeros((4,4))
for result in voting_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')
# Out:
# [TEST] Acc Best comité: 0.810  -- std: 0.028
# [TEST] F1 macro Best comité: 0.521  -- std: 0.017
# [TEST] F1-score NIPS Best comité: [0.896 0.207 0.236 0.744]
# -----------
# [TEST] Acc Norm comité: 0.850  -- std: 0.009
# [TEST] F1 macro Norm comité: 0.505  -- std: 0.019
# [TEST] F1-score NIPS Norm comité: [0.916 0.132 0.186 0.786]
# -----------
# [TEST] Acc Voting comité: 0.846  -- std: 0.013
# [TEST] F1 macro Voting comité: 0.517  -- std: 0.020
# [TEST] F1-score NIPS Voting comité: [0.915 0.169 0.205 0.778]

# %% [markdown]
# ## 85% De 1 - 10

# %%
best_test, norm_test, voting_test  = eval_committe('0.85', ruta, 1, 10, x_test, labels_test)
# Out:
# ---------------- EJECUCIÓN #1----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.811
# F1-macro: 0.522
# F1-score NIPS: [0.895 0.217 0.2   0.774]
#
# Evaluating Committee Norm...
# Accuracy: 0.851
# F1-macro: 0.483
# F1-score NIPS: [0.916 0.129 0.095 0.794]
#
# Evaluating Committee Voting...
# Accuracy: 0.844
# F1-macro: 0.496
# F1-score NIPS: [0.911 0.174 0.114 0.785]
#
# ---------------- EJECUCIÓN #2----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.672
# F1-macro: 0.446
# F1-score NIPS: [0.783 0.21  0.148 0.644]
#
# Evaluating Committee Norm...
# Accuracy: 0.771
# F1-macro: 0.499
# F1-score NIPS: [0.86  0.26  0.182 0.692]
#
# Evaluating Committee Voting...
# Accuracy: 0.758
# F1-macro: 0.485
# F1-score NIPS: [0.852 0.261 0.139 0.688]
#
# ---------------- EJECUCIÓN #3----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.827
# F1-macro: 0.532
# F1-score NIPS: [0.904 0.205 0.262 0.756]
#
# Evaluating Committee Norm...
# Accuracy: 0.851
# F1-macro: 0.491
# F1-score NIPS: [0.92  0.104 0.158 0.781]
#
# Evaluating Committee Voting...
# Accuracy: 0.852
# F1-macro: 0.495
# F1-score NIPS: [0.919 0.119 0.158 0.783]
#
# ---------------- EJECUCIÓN #4----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.746
# F1-macro: 0.484
# F1-score NIPS: [0.848 0.222 0.133 0.733]
#
# Evaluating Committee Norm...
# Accuracy: 0.811
# F1-macro: 0.496
# F1-score NIPS: [0.889 0.226 0.105 0.766]
#
# Evaluating Committee Voting...
# Accuracy: 0.797
# F1-macro: 0.490
# F1-score NIPS: [0.88  0.216 0.105 0.757]
#
# ---------------- EJECUCIÓN #5----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.851
# F1-macro: 0.511
# F1-score NIPS: [0.916 0.142 0.205 0.782]
#
# Evaluating Committee Norm...
# Accuracy: 0.859
# F1-macro: 0.481
# F1-score NIPS: [0.919 0.068 0.147 0.788]
#
# Evaluating Committee Voting...
# Accuracy: 0.859
# F1-macro: 0.477
# F1-score NIPS: [0.919 0.052 0.147 0.791]
#
# ---------------- EJECUCIÓN #6----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.829
# F1-macro: 0.512
# F1-score NIPS: [0.903 0.146 0.232 0.766]
#
# Evaluating Committee Norm...
# Accuracy: 0.854
# F1-macro: 0.471
# F1-score NIPS: [0.918 0.066 0.114 0.785]
#
# Evaluating Committee Voting...
# Accuracy: 0.854
# F1-macro: 0.492
# F1-score NIPS: [0.917 0.109 0.152 0.788]
#
# ---------------- EJECUCIÓN #7----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.806
# F1-macro: 0.505
# F1-score NIPS: [0.894 0.137 0.227 0.761]
#
# Evaluating Committee Norm...
# Accuracy: 0.833
# F1-macro: 0.484
# F1-score NIPS: [0.909 0.05  0.23  0.748]
#
# Evaluating Committee Voting...
# Accuracy: 0.839
# F1-macro: 0.505
# F1-score NIPS: [0.911 0.05  0.295 0.767]
#
# ---------------- EJECUCIÓN #8----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.776
# F1-macro: 0.443
# F1-score NIPS: [0.895 0.062 0.204 0.612]
#
# Evaluating Committee Norm...
# Accuracy: 0.844
# F1-macro: 0.511
# F1-score NIPS: [0.914 0.089 0.277 0.763]
#
# Evaluating Committee Voting...
# Accuracy: 0.837
# F1-macro: 0.517
# F1-score NIPS: [0.911 0.074 0.322 0.76 ]
#
# ---------------- EJECUCIÓN #9----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.849
# F1-macro: 0.478
# F1-score NIPS: [0.915 0.016 0.207 0.772]
#
# Evaluating Committee Norm...
# Accuracy: 0.858
# F1-macro: 0.485
# F1-score NIPS: [0.919 0.035 0.211 0.774]
#
# Evaluating Committee Voting...
# Accuracy: 0.854
# F1-macro: 0.496
# F1-score NIPS: [0.917 0.077 0.213 0.777]
#
# ---------------- EJECUCIÓN #10----------------
# Trabajando en predicciones Test
#
# Evaluating Committee Best Fit...
# Accuracy: 0.733
# F1-macro: 0.504
# F1-score NIPS: [0.844 0.223 0.25  0.701]
#
# Evaluating Committee Norm...
# Accuracy: 0.816
# F1-macro: 0.501
# F1-score NIPS: [0.893 0.197 0.165 0.747]
#
# Evaluating Committee Voting...
# Accuracy: 0.815
# F1-macro: 0.519
# F1-score NIPS: [0.893 0.2   0.239 0.742]

# %%
x=10.0

print ("[TEST] Acc Best comité: %.3f" % np.mean(np.asarray(best_test['acc'])), " -- std: %.3f" % np.std(np.asarray(best_test['acc'])))
print ("[TEST] F1 macro Best comité: %.3f" % np.mean(np.asarray(best_test['macro'])), " -- std: %.3f" % np.std(np.asarray(best_test['macro'])))
temp=np.zeros(4)
for result in best_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Best comité:" ,temp/x)
cm=np.zeros((4,4))
for result in best_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Norm comité: %.3f" % np.mean(np.asarray(norm_test['acc'])), " -- std: %.3f" % np.std(np.asarray(norm_test['acc'])))
print ("[TEST] F1 macro Norm comité: %.3f" % np.mean(np.asarray(norm_test['macro'])), " -- std: %.3f" % np.std(np.asarray(norm_test['macro'])))
temp=np.zeros(4)
for result in norm_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Norm comité:" ,temp/x)

cm=np.zeros((4,4))
for result in norm_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')

print ("-----------")
print ("[TEST] Acc Voting comité: %.3f" % np.mean(np.asarray(voting_test['acc'])), " -- std: %.3f" % np.std(np.asarray(voting_test['acc'])))
print ("[TEST] F1 macro Voting comité: %.3f" % np.mean(np.asarray(voting_test['macro'])), " -- std: %.3f" % np.std(np.asarray(voting_test['macro'])))
temp=np.zeros(4)
for result in voting_test['none']:
    temp+=result
np.set_printoptions(precision=3)
print ("[TEST] F1-score NIPS Voting comité:" ,temp/x)

cm=np.zeros((4,4))
for result in voting_test['cm']:
    cm+=result
plot_cm(cm_norma(cm), ["NonH", "IndirectH", "PhysicalH", "SexualH"], title='', cmap='RdPu')
# Out:
# [TEST] Acc Best comité: 0.790  -- std: 0.055
# [TEST] F1 macro Best comité: 0.494  -- std: 0.029
# [TEST] F1-score NIPS Best comité: [0.88  0.158 0.207 0.73 ]
# -----------
# [TEST] Acc Norm comité: 0.835  -- std: 0.027
# [TEST] F1 macro Norm comité: 0.490  -- std: 0.011
# [TEST] F1-score NIPS Norm comité: [0.906 0.122 0.168 0.764]
# -----------
# [TEST] Acc Voting comité: 0.831  -- std: 0.030
# [TEST] F1 macro Voting comité: 0.497  -- std: 0.012
# [TEST] F1-score NIPS Voting comité: [0.903 0.133 0.188 0.764]

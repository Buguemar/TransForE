# %%
from tools_stance import * 
from models import *
import torch 
import pandas as pd

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")


dict_cl=dict()
dict_cl[0]="NonH"
dict_cl[1]="IndirectH"
dict_cl[2]="PhysicalH"
dict_cl[3]="SexualH"

#sdqc
d_lab=dict()
d_lab["NonH"]=0
d_lab["IndirectH"]=1
d_lab["PhysicalH"]=2
d_lab["SexualH"]=3

path="../Datasets/CSV_Harassment/"
train =pd.read_csv(path + "train_format.csv")
val=pd.read_csv(path + "val_format.csv")
test=pd.read_csv(path + "test_format.csv")

stoplist = stopwords.words("english")
puntos='!?."()[´]“<>¡¿-/;:=_”@#.'
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
import seaborn as sns
sns.set(font_scale=1)
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,7))
j=220
labs=["NonH", "IndirectH", "PhysicalH", "SexualH"]
data=[train['Label'], val['Label'], test["Label"]]
name=["Training", "Validation", "Testing"]
for i in range(3):
    j+=1
    h=fig.add_subplot(j)
    ax= sns.countplot(data[i], order=labs)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=12)
    h.title.set_text(str(name[i]))

fig.suptitle("SIMAH - Distribución de etiquetas", fontsize=14)
plt.show()

# %%
def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("------ Training ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)
    
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("------ Validation ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("------ Testing ------")
    print ("Accuracy", name_model, ": %.3f" % acc_t)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma_t)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

def cleaner(post): 
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=token_2_idx[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in token_2_idx.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in token_2_idx.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
import os 
embeddings_index = {}
token_2_idx={}
idx_2_token={}
f = open(os.path.join("../Datasets/glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
i=0
for line in f:
    values = line.split()
    if len(values)>200:
        word = values[0]
    else:
        #print ("Problema con line ", line)
        continue
    token_2_idx[word]=i
    idx_2_token[i]=word
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
    i+=1
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# Se encontraron 1193513 terminos con sus vectores de embedding.

# %%
MAX_LEN = 34
emb=200
EMB_matrix=np.zeros((len(token_2_idx.keys()), emb))
for i in range(len(token_2_idx.keys())):
    EMB_matrix[i]=embeddings_index[idx_2_token[i]]
    
transformer = Normalizer().fit(EMB_matrix) 
EMB_matrix=transformer.transform(EMB_matrix)
EMB_matrix.shape
# Out:
# (1193513, 200)

# %%
ids_train=train['tweet_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
#class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)

ids_val=val['tweet_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

ids_test=test['tweet_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]
# Out:
# Pesos de clases: [ 0.43526359 28.97272727 20.96710526  0.61715724]

# %%
sentences = tws_train
n_labels = np.asarray(labels_train)
y_train=to_categorical(n_labels,num_classes=4)

sentences_val = tws_val
n_labels_val = np.array(labels_val)
y_val=to_categorical(n_labels_val,num_classes=4)

sentences_test = tws_test
n_labels_test = np.array(labels_test)
y_test=to_categorical(n_labels_test,num_classes=4)

# %%
input_ids=[]
for sent in sentences:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids.append(encoded_sent) 
    
input_ids_val=[]
for sent in sentences_val:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_val.append(encoded_sent) 

input_ids_test=[]
for sent in sentences_test:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_test.append(encoded_sent)

# %%
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
shape_val=np.asarray(input_ids_val).shape
shape_test=np.asarray(input_ids_test).shape

# %%
x_train=np.zeros((shape[0], shape[1], emb))
j=0
for in_id in input_ids:
    x_train[j]=EMB_matrix[in_id]
    j+=1
    
x_val=np.zeros((shape_val[0], shape_val[1], emb))
i=0
for in_id in input_ids_val:
    x_val[i]=EMB_matrix[in_id]
    i+=1
    
x_test=np.zeros((shape_test[0], shape_test[1], emb))
i=0
for in_id in input_ids_test:
    x_test[i]=EMB_matrix[in_id]
    i+=1

# %%
x_train.shape
# Out:
# (6374, 34, 200)

# %%
x_test.shape
# Out:
# (2123, 34, 200)

# %% [markdown]
# ## 0.15

# %%
def load_data(path_to_data):
    macro_augmented = np.load(path_to_data, allow_pickle=True)
    np.random.shuffle(macro_augmented)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    print (np.unique(labels_train), type(labels_train))
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)

    sentences = tws_train
    n_labels = labels_train.copy()

    input_ids = []
    for sent in sentences:
        encoded_sent = [] 
        for wd in sent:
            try:
                encoded_sent.append(token_2_idx[wd])
            except:
                continue
        input_ids.append(encoded_sent)

    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], emb))
    j=0
    for in_id in input_ids:
        x_train[j]=EMB_matrix[in_id]
        j+=1

    return x_train, y_train, n_labels, class_weights

# %%
k=2

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_15_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# ------ Training ------
# Accuracy cnn1 : 0.945
# F1-score macro cnn1 : 0.945
# F1-score None cnn1 : [0.895 0.997 0.997 0.892]
#
# ------ Validation ------
# Accuracy cnn1 : 0.887
# F1-score macro cnn1 : 0.457
# F1-score None cnn1 : [0.934 0.    0.05  0.845]
#
# ------ Testing ------
# Accuracy cnn1 : 0.860
# F1-score macro cnn1 : 0.460
# F1-score None cnn1 : [0.921 0.07  0.071 0.778]
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# ------ Training ------
# Accuracy cnn2 : 0.947
# F1-score macro cnn2 : 0.947
# F1-score None cnn2 : [0.893 0.997 0.995 0.902]
#
# ------ Validation ------
# Accuracy cnn2 : 0.862
# F1-score macro cnn2 : 0.442
# F1-score None cnn2 : [0.919 0.    0.048 0.803]
#
# ------ Testing ------
# Accuracy cnn2 : 0.835
# F1-score macro cnn2 : 0.444
# F1-score None cnn2 : [0.908 0.035 0.096 0.734]
#
# ------ Training ------
# Accuracy rnn1 : 0.885
# F1-score macro rnn1 : 0.887
# F1-score None rnn1 : [0.824 0.948 0.932 0.845]
#
# ------ Validation ------
# Accuracy rnn1 : 0.870
# F1-score macro rnn1 : 0.473
# F1-score None rnn1 : [0.924 0.112 0.037 0.819]
#
# ------ Testing ------
# Accuracy rnn1 : 0.848
# F1-score macro rnn1 : 0.498
# F1-score None rnn1 : [0.912 0.133 0.211 0.735]
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# ------ Training ------
# Accuracy rnn2 : 0.948
# F1-score macro rnn2 : 0.947
# F1-score None rnn2 : [0.902 0.994 0.992 0.902]
#
# ------ Validation ------
# Accuracy rnn2 : 0.872
# F1-score macro rnn2 : 0.479
# F1-score None rnn2 : [0.926 0.111 0.034 0.845]
#
# ------ Testing ------
# Accuracy rnn2 : 0.841
# F1-score macro rnn2 : 0.503
# F1-score None rnn2 : [0.911 0.17  0.152 0.779]
#
# ------ Training ------
# Accuracy rnn3 : 0.883
# F1-score macro rnn3 : 0.882
# F1-score None rnn3 : [0.822 0.942 0.923 0.842]
#
# ------ Validation ------
# Accuracy rnn3 : 0.791
# F1-score macro rnn3 : 0.468
# F1-score None rnn3 : [0.87  0.177 0.035 0.79 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.748
# F1-score macro rnn3 : 0.505
# F1-score None rnn3 : [0.847 0.26  0.188 0.726]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.943
# F1-score macro cnn1 : 0.943
# F1-score None cnn1 : [0.891 0.997 0.996 0.886]
#
# ------ Validation ------
# Accuracy cnn1 : 0.882
# F1-score macro cnn1 : 0.453
# F1-score None cnn1 : [0.93  0.    0.05  0.833]
#
# ------ Testing ------
# Accuracy cnn1 : 0.847
# F1-score macro cnn1 : 0.430
# F1-score None cnn1 : [0.912 0.    0.075 0.732]
#
# ------ Training ------
# Accuracy cnn2 : 0.932
# F1-score macro cnn2 : 0.931
# F1-score None cnn2 : [0.876 0.996 0.994 0.858]
#
# ------ Validation ------
# Accuracy cnn2 : 0.873
# F1-score macro cnn2 : 0.458
# F1-score None cnn2 : [0.922 0.    0.093 0.817]
#
# ------ Testing ------
# Accuracy cnn2 : 0.837
# F1-score macro cnn2 : 0.420
# F1-score None cnn2 : [0.906 0.054 0.051 0.67 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.878
# F1-score macro rnn1 : 0.876
# F1-score None rnn1 : [0.816 0.897 0.959 0.83 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.722
# F1-score macro rnn1 : 0.450
# F1-score None rnn1 : [0.832 0.15  0.06  0.759]
#
# ------ Testing ------
# Accuracy rnn1 : 0.680
# F1-score macro rnn1 : 0.474
# F1-score None rnn1 : [0.809 0.217 0.23  0.641]
#
# ------ Training ------
# Accuracy rnn2 : 0.946
# F1-score macro rnn2 : 0.946
# F1-score None rnn2 : [0.9   0.988 0.991 0.905]
#
# ------ Validation ------
# Accuracy rnn2 : 0.861
# F1-score macro rnn2 : 0.497
# F1-score None rnn2 : [0.918 0.199 0.036 0.835]
#
# ------ Testing ------
# Accuracy rnn2 : 0.822
# F1-score macro rnn2 : 0.507
# F1-score None rnn2 : [0.897 0.229 0.119 0.785]
#
# ------ Training ------
# Accuracy rnn3 : 0.906
# F1-score macro rnn3 : 0.904
# F1-score None rnn3 : [0.839 0.962 0.955 0.859]
#
# ------ Validation ------
# Accuracy rnn3 : 0.793
# F1-score macro rnn3 : 0.458
# F1-score None rnn3 : [0.879 0.141 0.034 0.777]
#
# ------ Testing ------
# Accuracy rnn3 : 0.770
# F1-score macro rnn3 : 0.551
# F1-score None rnn3 : [0.862 0.302 0.33  0.711]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.951
# F1-score macro cnn1 : 0.951
# F1-score None cnn1 : [0.904 0.997 0.996 0.909]
#
# ------ Validation ------
# Accuracy cnn1 : 0.876
# F1-score macro cnn1 : 0.457
# F1-score None cnn1 : [0.927 0.027 0.049 0.826]
#
# ------ Testing ------
# Accuracy cnn1 : 0.849
# F1-score macro cnn1 : 0.449
# F1-score None cnn1 : [0.917 0.095 0.025 0.759]
#
# ------ Training ------
# Accuracy cnn2 : 0.950
# F1-score macro cnn2 : 0.950
# F1-score None cnn2 : [0.901 0.998 0.996 0.906]
#
# ------ Validation ------
# Accuracy cnn2 : 0.878
# F1-score macro cnn2 : 0.452
# F1-score None cnn2 : [0.929 0.    0.049 0.831]
#
# ------ Testing ------
# Accuracy cnn2 : 0.860
# F1-score macro cnn2 : 0.455
# F1-score None cnn2 : [0.925 0.088 0.026 0.78 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.893
# F1-score macro rnn1 : 0.893
# F1-score None rnn1 : [0.843 0.945 0.946 0.836]
#
# ------ Validation ------
# Accuracy rnn1 : 0.804
# F1-score macro rnn1 : 0.473
# F1-score None rnn1 : [0.882 0.139 0.071 0.8  ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.778
# F1-score macro rnn1 : 0.511
# F1-score None rnn1 : [0.872 0.243 0.245 0.682]
#
# ------ Training ------
# Accuracy rnn2 : 0.841
# F1-score macro rnn2 : 0.838
# F1-score None rnn2 : [0.857 0.981 0.801 0.714]
# ------ Validation ------
# Accuracy rnn2 : 0.731
# F1-score macro rnn2 : 0.426
# F1-score None rnn2 : [0.889 0.103 0.078 0.635]
#
# ------ Testing ------
# Accuracy rnn2 : 0.749
# F1-score macro rnn2 : 0.465
# F1-score None rnn2 : [0.885 0.132 0.249 0.594]
#
# ------ Training ------
# Accuracy rnn3 : 0.900
# F1-score macro rnn3 : 0.899
# F1-score None rnn3 : [0.823 0.972 0.956 0.845]
#
# ------ Validation ------
# Accuracy rnn3 : 0.784
# F1-score macro rnn3 : 0.452
# F1-score None rnn3 : [0.869 0.175 0.042 0.722]
#
# ------ Testing ------
# Accuracy rnn3 : 0.729
# F1-score macro rnn3 : 0.469
# F1-score None rnn3 : [0.838 0.208 0.227 0.604]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.944
# F1-score macro cnn1 : 0.944
# F1-score None cnn1 : [0.895 0.994 0.996 0.89 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.872
# F1-score macro cnn1 : 0.495
# F1-score None cnn1 : [0.924 0.097 0.128 0.831]
#
# ------ Testing ------
# Accuracy cnn1 : 0.843
# F1-score macro cnn1 : 0.482
# F1-score None cnn1 : [0.908 0.083 0.18  0.757]
#
# ------ Training ------
# Accuracy cnn2 : 0.947
# F1-score macro cnn2 : 0.947
# F1-score None cnn2 : [0.899 0.997 0.994 0.897]
#
# ------ Validation ------
# Accuracy cnn2 : 0.883
# F1-score macro cnn2 : 0.455
# F1-score None cnn2 : [0.932 0.    0.048 0.839]
#
# ------ Testing ------
# Accuracy cnn2 : 0.865
# F1-score macro cnn2 : 0.476
# F1-score None cnn2 : [0.923 0.051 0.12  0.808]
#
# ------ Training ------
# Accuracy rnn1 : 0.855
# F1-score macro rnn1 : 0.854
# F1-score None rnn1 : [0.791 0.925 0.91  0.791]
#
# ------ Validation ------
# Accuracy rnn1 : 0.744
# F1-score macro rnn1 : 0.417
# F1-score None rnn1 : [0.852 0.089 0.067 0.661]
#
# ------ Testing ------
# Accuracy rnn1 : 0.700
# F1-score macro rnn1 : 0.463
# F1-score None rnn1 : [0.816 0.176 0.3   0.562]
#
# ------ Training ------
# Accuracy rnn2 : 0.898
# F1-score macro rnn2 : 0.900
# F1-score None rnn2 : [0.838 0.916 0.961 0.885]
#
# ------ Validation ------
# Accuracy rnn2 : 0.880
# F1-score macro rnn2 : 0.466
# F1-score None rnn2 : [0.932 0.053 0.038 0.839]
#
# ------ Testing ------
# Accuracy rnn2 : 0.859
# F1-score macro rnn2 : 0.474
# F1-score None rnn2 : [0.924 0.017 0.162 0.794]
#
# ------ Training ------
# Accuracy rnn3 : 0.900
# F1-score macro rnn3 : 0.900
# F1-score None rnn3 : [0.848 0.952 0.957 0.844]
#
# ------ Validation ------
# Accuracy rnn3 : 0.857
# F1-score macro rnn3 : 0.447
# F1-score None rnn3 : [0.922 0.    0.059 0.807]
#
# ------ Testing ------
# Accuracy rnn3 : 0.838
# F1-score macro rnn3 : 0.508
# F1-score None rnn3 : [0.91  0.104 0.284 0.733]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.949
# F1-score macro cnn1 : 0.948
# F1-score None cnn1 : [0.9   0.997 0.996 0.9  ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.872
# F1-score macro cnn1 : 0.477
# F1-score None cnn1 : [0.924 0.07  0.093 0.823]
#
# ------ Testing ------
# Accuracy cnn1 : 0.847
# F1-score macro cnn1 : 0.456
# F1-score None cnn1 : [0.915 0.134 0.025 0.749]
#
# ------ Training ------
# Accuracy cnn2 : 0.948
# F1-score macro cnn2 : 0.947
# F1-score None cnn2 : [0.898 0.995 0.995 0.901]
#
# ------ Validation ------
# Accuracy cnn2 : 0.877
# F1-score macro cnn2 : 0.476
# F1-score None cnn2 : [0.927 0.051 0.095 0.829]
#
# ------ Testing ------
# Accuracy cnn2 : 0.852
# F1-score macro cnn2 : 0.466
# F1-score None cnn2 : [0.915 0.085 0.098 0.766]
#
# ------ Training ------
# Accuracy rnn1 : 0.838
# F1-score macro rnn1 : 0.832
# F1-score None rnn1 : [0.735 0.915 0.849 0.827]
#
# ------ Validation ------
# Accuracy rnn1 : 0.647
# F1-score macro rnn1 : 0.419
# F1-score None rnn1 : [0.761 0.114 0.039 0.761]
#
# ------ Testing ------
# Accuracy rnn1 : 0.622
# F1-score macro rnn1 : 0.464
# F1-score None rnn1 : [0.749 0.227 0.197 0.682]
#
# ------ Training ------
# Accuracy rnn2 : 0.924
# F1-score macro rnn2 : 0.923
# F1-score None rnn2 : [0.889 0.984 0.948 0.873]
#
# ------ Validation ------
# Accuracy rnn2 : 0.833
# F1-score macro rnn2 : 0.465
# F1-score None rnn2 : [0.916 0.091 0.057 0.797]
#
# ------ Testing ------
# Accuracy rnn2 : 0.813
# F1-score macro rnn2 : 0.509
# F1-score None rnn2 : [0.901 0.141 0.26  0.735]
#
# ------ Training ------
# Accuracy rnn3 : 0.921
# F1-score macro rnn3 : 0.921
# F1-score None rnn3 : [0.878 0.984 0.954 0.87 ]
#
# ------ Validation ------
# Accuracy rnn3 : 0.864
# F1-score macro rnn3 : 0.511
# F1-score None rnn3 : [0.924 0.167 0.133 0.82 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.836
# F1-score macro rnn3 : 0.507
# F1-score None rnn3 : [0.913 0.167 0.183 0.763]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.15 Clase Ponderado - F1-score promedio para cnn1 : [0.915 0.076 0.075 0.755]
# 0.15 Clase Ponderado - F1-score promedio para cnn2 : [0.915 0.063 0.078 0.752]
# 0.15 Clase Ponderado - F1-score promedio para rnn1 : [0.832 0.199 0.236 0.66 ]
# 0.15 Clase Ponderado - F1-score promedio para rnn2 : [0.904 0.138 0.188 0.737]
# 0.15 Clase Ponderado - F1-score promedio para rnn3 : [0.874 0.208 0.242 0.707]
#
# 0.15 Clase Ponderado - F1-score macro promedio para cnn1 : 0.45537694208294643 desvest:  0.016931741203383463
# 0.15 Clase Ponderado - F1-score macro promedio para cnn2 : 0.4520182019986777 desvest:  0.019159401685091774
# 0.15 Clase Ponderado - F1-score macro promedio para rnn1 : 0.4819227384884444 desvest:  0.01899086730860548
# 0.15 Clase Ponderado - F1-score macro promedio para rnn2 : 0.49193468988231315 desvest:  0.018407351725036034
# 0.15 Clase Ponderado - F1-score macro promedio para rnn3 : 0.5079826061289778 desvest:  0.02596806131480467
#
# 0.15 Clase Ponderado - Accuracy promedio para cnn1 : 0.8491756947715497 desvest:  0.005552581075192222
# 0.15 Clase Ponderado - Accuracy promedio para cnn2 : 0.8500235515779557 desvest:  0.011977916707067153
# 0.15 Clase Ponderado - Accuracy promedio para rnn1 : 0.7254828073480923 desvest:  0.0788768470748548
# 0.15 Clase Ponderado - Accuracy promedio para rnn2 : 0.8167687235044749 desvest:  0.03718226581037296
# 0.15 Clase Ponderado - Accuracy promedio para rnn3 : 0.7841733396137542 desvest:  0.04524787116018303

# %% [markdown]
# ## 0.5

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_50_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.943
# F1-score macro cnn1 : 0.943
# F1-score None cnn1 : [0.893 0.993 0.994 0.892]
#
# ------ Validation ------
# Accuracy cnn1 : 0.868
# F1-score macro cnn1 : 0.487
# F1-score None cnn1 : [0.922 0.145 0.043 0.838]
#
# ------ Testing ------
# Accuracy cnn1 : 0.820
# F1-score macro cnn1 : 0.480
# F1-score None cnn1 : [0.898 0.154 0.121 0.748]
#
# ------ Training ------
# Accuracy cnn2 : 0.942
# F1-score macro cnn2 : 0.942
# F1-score None cnn2 : [0.89  0.994 0.991 0.892]
#
# ------ Validation ------
# Accuracy cnn2 : 0.864
# F1-score macro cnn2 : 0.497
# F1-score None cnn2 : [0.92  0.163 0.093 0.81 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.819
# F1-score macro cnn2 : 0.455
# F1-score None cnn2 : [0.901 0.188 0.024 0.708]
#
# ------ Training ------
# Accuracy rnn1 : 0.877
# F1-score macro rnn1 : 0.878
# F1-score None rnn1 : [0.825 0.921 0.945 0.819]
#
# ------ Validation ------
# Accuracy rnn1 : 0.852
# F1-score macro rnn1 : 0.472
# F1-score None rnn1 : [0.919 0.103 0.058 0.807]
#
# ------ Testing ------
# Accuracy rnn1 : 0.832
# F1-score macro rnn1 : 0.529
# F1-score None rnn1 : [0.907 0.181 0.289 0.74 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.818
# F1-score macro rnn2 : 0.815
# F1-score None rnn2 : [0.825 0.888 0.775 0.774]
#
# ------ Validation ------
# Accuracy rnn2 : 0.750
# F1-score macro rnn2 : 0.462
# F1-score None rnn2 : [0.833 0.156 0.053 0.807]
#
# ------ Testing ------
# Accuracy rnn2 : 0.700
# F1-score macro rnn2 : 0.446
# F1-score None rnn2 : [0.814 0.206 0.05  0.712]
#
# ------ Training ------
# Accuracy rnn3 : 0.876
# F1-score macro rnn3 : 0.874
# F1-score None rnn3 : [0.823 0.92  0.928 0.825]
#
# ------ Validation ------
# Accuracy rnn3 : 0.733
# F1-score macro rnn3 : 0.460
# F1-score None rnn3 : [0.826 0.147 0.09  0.777]
#
# ------ Testing ------
# Accuracy rnn3 : 0.694
# F1-score macro rnn3 : 0.490
# F1-score None rnn3 : [0.81  0.216 0.225 0.709]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.942
# F1-score macro cnn1 : 0.941
# F1-score None cnn1 : [0.89  0.994 0.996 0.886]
#
# ------ Validation ------
# Accuracy cnn1 : 0.870
# F1-score macro cnn1 : 0.477
# F1-score None cnn1 : [0.923 0.117 0.044 0.825]
#
# ------ Testing ------
# Accuracy cnn1 : 0.842
# F1-score macro cnn1 : 0.491
# F1-score None cnn1 : [0.911 0.194 0.109 0.749]
#
# ------ Training ------
# Accuracy cnn2 : 0.932
# F1-score macro cnn2 : 0.931
# F1-score None cnn2 : [0.885 0.986 0.982 0.872]
#
# ------ Validation ------
# Accuracy cnn2 : 0.841
# F1-score macro cnn2 : 0.493
# F1-score None cnn2 : [0.91  0.144 0.124 0.796]
#
# ------ Testing ------
# Accuracy cnn2 : 0.808
# F1-score macro cnn2 : 0.512
# F1-score None cnn2 : [0.893 0.152 0.282 0.718]
#
# ------ Training ------
# Accuracy rnn1 : 0.840
# F1-score macro rnn1 : 0.842
# F1-score None rnn1 : [0.833 0.957 0.808 0.769]
#
# ------ Validation ------
# Accuracy rnn1 : 0.834
# F1-score macro rnn1 : 0.460
# F1-score None rnn1 : [0.897 0.103 0.038 0.801]
#
# ------ Testing ------
# Accuracy rnn1 : 0.812
# F1-score macro rnn1 : 0.496
# F1-score None rnn1 : [0.888 0.189 0.167 0.738]
#
# ------ Training ------
# Accuracy rnn2 : 0.924
# F1-score macro rnn2 : 0.924
# F1-score None rnn2 : [0.873 0.981 0.966 0.876]
#
# ------ Validation ------
# Accuracy rnn2 : 0.836
# F1-score macro rnn2 : 0.475
# F1-score None rnn2 : [0.9   0.136 0.047 0.816]
#
# ------ Testing ------
# Accuracy rnn2 : 0.794
# F1-score macro rnn2 : 0.476
# F1-score None rnn2 : [0.881 0.156 0.132 0.737]
#
# ------ Training ------
# Accuracy rnn3 : 0.677
# F1-score macro rnn3 : 0.647
# F1-score None rnn3 : [0.686 0.924 0.651 0.326]
#
# ------ Validation ------
# Accuracy rnn3 : 0.464
# F1-score macro rnn3 : 0.302
# F1-score None rnn3 : [0.707 0.136 0.06  0.306]
#
# ------ Testing ------
# Accuracy rnn3 : 0.482
# F1-score macro rnn3 : 0.340
# F1-score None rnn3 : [0.67  0.196 0.154 0.342]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.943
# F1-score macro cnn1 : 0.943
# F1-score None cnn1 : [0.891 0.995 0.995 0.892]
#
# ------ Validation ------
# Accuracy cnn1 : 0.870
# F1-score macro cnn1 : 0.470
# F1-score None cnn1 : [0.924 0.092 0.049 0.817]
#
# ------ Testing ------
# Accuracy cnn1 : 0.829
# F1-score macro cnn1 : 0.435
# F1-score None cnn1 : [0.902 0.09  0.025 0.724]
#
# ------ Training ------
# Accuracy cnn2 : 0.941
# F1-score macro cnn2 : 0.941
# F1-score None cnn2 : [0.887 0.996 0.993 0.887]
#
# ------ Validation ------
# Accuracy cnn2 : 0.850
# F1-score macro cnn2 : 0.457
# F1-score None cnn2 : [0.912 0.086 0.037 0.791]
#
# ------ Testing ------
# Accuracy cnn2 : 0.820
# F1-score macro cnn2 : 0.475
# F1-score None cnn2 : [0.898 0.093 0.192 0.717]
#
# ------ Training ------
# Accuracy rnn1 : 0.875
# F1-score macro rnn1 : 0.873
# F1-score None rnn1 : [0.813 0.941 0.944 0.792]
#
# ------ Validation ------
# Accuracy rnn1 : 0.783
# F1-score macro rnn1 : 0.464
# F1-score None rnn1 : [0.867 0.163 0.044 0.782]
#
# ------ Testing ------
# Accuracy rnn1 : 0.751
# F1-score macro rnn1 : 0.478
# F1-score None rnn1 : [0.854 0.189 0.216 0.653]
#
# ------ Training ------
# Accuracy rnn2 : 0.938
# F1-score macro rnn2 : 0.938
# F1-score None rnn2 : [0.889 0.991 0.988 0.883]
#
# ------ Validation ------
# Accuracy rnn2 : 0.862
# F1-score macro rnn2 : 0.463
# F1-score None rnn2 : [0.923 0.091 0.026 0.811]
#
# ------ Testing ------
# Accuracy rnn2 : 0.832
# F1-score macro rnn2 : 0.484
# F1-score None rnn2 : [0.906 0.084 0.206 0.741]
#
# ------ Training ------
# Accuracy rnn3 : 0.862
# F1-score macro rnn3 : 0.858
# F1-score None rnn3 : [0.78  0.889 0.936 0.826]
#
# ------ Validation ------
# Accuracy rnn3 : 0.670
# F1-score macro rnn3 : 0.423
# F1-score None rnn3 : [0.775 0.13  0.055 0.732]
#
# ------ Testing ------
# Accuracy rnn3 : 0.634
# F1-score macro rnn3 : 0.447
# F1-score None rnn3 : [0.753 0.202 0.151 0.682]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.942
# F1-score macro cnn1 : 0.942
# F1-score None cnn1 : [0.891 0.991 0.995 0.891]
#
# ------ Validation ------
# Accuracy cnn1 : 0.861
# F1-score macro cnn1 : 0.509
# F1-score None cnn1 : [0.917 0.203 0.093 0.823]
#
# ------ Testing ------
# Accuracy cnn1 : 0.823
# F1-score macro cnn1 : 0.463
# F1-score None cnn1 : [0.898 0.155 0.048 0.75 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.937
# F1-score macro cnn2 : 0.936
# F1-score None cnn2 : [0.886 0.989 0.993 0.878]
#
# ------ Validation ------
# Accuracy cnn2 : 0.864
# F1-score macro cnn2 : 0.469
# F1-score None cnn2 : [0.921 0.088 0.037 0.829]
#
# ------ Testing ------
# Accuracy cnn2 : 0.822
# F1-score macro cnn2 : 0.489
# F1-score None cnn2 : [0.898 0.176 0.182 0.702]
#
# ------ Training ------
# Accuracy rnn1 : 0.881
# F1-score macro rnn1 : 0.883
# F1-score None rnn1 : [0.829 0.929 0.951 0.822]
#
# ------ Validation ------
# Accuracy rnn1 : 0.863
# F1-score macro rnn1 : 0.479
# F1-score None rnn1 : [0.92  0.146 0.026 0.825]
#
# ------ Testing ------
# Accuracy rnn1 : 0.834
# F1-score macro rnn1 : 0.505
# F1-score None rnn1 : [0.907 0.114 0.261 0.736]
#
# ------ Training ------
# Accuracy rnn2 : 0.934
# F1-score macro rnn2 : 0.933
# F1-score None rnn2 : [0.885 0.99  0.985 0.873]
#
# ------ Validation ------
# Accuracy rnn2 : 0.854
# F1-score macro rnn2 : 0.478
# F1-score None rnn2 : [0.918 0.112 0.062 0.818]
#
# ------ Testing ------
# Accuracy rnn2 : 0.815
# F1-score macro rnn2 : 0.470
# F1-score None rnn2 : [0.897 0.078 0.172 0.732]
#
# ------ Training ------
# Accuracy rnn3 : 0.879
# F1-score macro rnn3 : 0.876
# F1-score None rnn3 : [0.84  0.959 0.919 0.785]
#
# ------ Validation ------
# Accuracy rnn3 : 0.780
# F1-score macro rnn3 : 0.461
# F1-score None rnn3 : [0.88  0.123 0.083 0.757]
#
# ------ Testing ------
# Accuracy rnn3 : 0.752
# F1-score macro rnn3 : 0.492
# F1-score None rnn3 : [0.857 0.195 0.263 0.652]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.938
# F1-score macro cnn1 : 0.938
# F1-score None cnn1 : [0.885 0.994 0.994 0.879]
#
# ------ Validation ------
# Accuracy cnn1 : 0.864
# F1-score macro cnn1 : 0.494
# F1-score None cnn1 : [0.919 0.155 0.077 0.824]
#
# ------ Testing ------
# Accuracy cnn1 : 0.832
# F1-score macro cnn1 : 0.484
# F1-score None cnn1 : [0.907 0.152 0.115 0.759]
#
# ------ Training ------
# Accuracy cnn2 : 0.938
# F1-score macro cnn2 : 0.938
# F1-score None cnn2 : [0.886 0.996 0.992 0.879]
#
# ------ Validation ------
# Accuracy cnn2 : 0.874
# F1-score macro cnn2 : 0.500
# F1-score None cnn2 : [0.924 0.16  0.08  0.835]
# ------ Testing ------
# Accuracy cnn2 : 0.843
# F1-score macro cnn2 : 0.493
# F1-score None cnn2 : [0.91  0.155 0.149 0.757]
#
# ------ Training ------
# Accuracy rnn1 : 0.641
# F1-score macro rnn1 : 0.621
# F1-score None rnn1 : [0.62  0.923 0.412 0.53 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.805
# F1-score macro rnn1 : 0.398
# F1-score None rnn1 : [0.881 0.097 0.    0.613]
#
# ------ Testing ------
# Accuracy rnn1 : 0.772
# F1-score macro rnn1 : 0.333
# F1-score None rnn1 : [0.87  0.132 0.026 0.303]
#
# ------ Training ------
# Accuracy rnn2 : 0.875
# F1-score macro rnn2 : 0.872
# F1-score None rnn2 : [0.878 0.982 0.869 0.761]
#
# ------ Validation ------
# Accuracy rnn2 : 0.804
# F1-score macro rnn2 : 0.452
# F1-score None rnn2 : [0.923 0.129 0.056 0.701]
#
# ------ Testing ------
# Accuracy rnn2 : 0.790
# F1-score macro rnn2 : 0.473
# F1-score None rnn2 : [0.904 0.134 0.233 0.622]
#
# ------ Training ------
# Accuracy rnn3 : 0.860
# F1-score macro rnn3 : 0.859
# F1-score None rnn3 : [0.82  0.922 0.892 0.802]
#
# ------ Validation ------
# Accuracy rnn3 : 0.780
# F1-score macro rnn3 : 0.461
# F1-score None rnn3 : [0.865 0.157 0.025 0.796]
#
# ------ Testing ------
# Accuracy rnn3 : 0.732
# F1-score macro rnn3 : 0.500
# F1-score None rnn3 : [0.838 0.234 0.218 0.711]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.5 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.5 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.5 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.5 Clase Ponderado - F1-score promedio para cnn1 : [0.903 0.149 0.084 0.746]
# 0.5 Clase Ponderado - F1-score promedio para cnn2 : [0.9   0.153 0.166 0.72 ]
# 0.5 Clase Ponderado - F1-score promedio para rnn1 : [0.885 0.161 0.192 0.634]
# 0.5 Clase Ponderado - F1-score promedio para rnn2 : [0.88  0.132 0.159 0.709]
# 0.5 Clase Ponderado - F1-score promedio para rnn3 : [0.786 0.209 0.202 0.619]
#
# 0.5 Clase Ponderado - F1-score macro promedio para cnn1 : 0.4705927759289231 desvest:  0.019866161536675895
# 0.5 Clase Ponderado - F1-score macro promedio para cnn2 : 0.48476664396323493 desvest:  0.018777757328339622
# 0.5 Clase Ponderado - F1-score macro promedio para rnn1 : 0.4680222204122881 desvest:  0.06966496984344453
# 0.5 Clase Ponderado - F1-score macro promedio para rnn2 : 0.46991385684807935 desvest:  0.013061358251755296
# 0.5 Clase Ponderado - F1-score macro promedio para rnn3 : 0.4539128150346915 desvest:  0.059745013658032746
#
# 0.5 Clase Ponderado - Accuracy promedio para cnn1 : 0.8292039566650965 desvest:  0.007504642964353981
# 0.5 Clase Ponderado - Accuracy promedio para cnn2 : 0.8223268959020255 desvest:  0.011341594871988686
# 0.5 Clase Ponderado - Accuracy promedio para rnn1 : 0.8001884126236456 desvest:  0.033312822469632276
# 0.5 Clase Ponderado - Accuracy promedio para rnn2 : 0.7863400847856805 desvest:  0.04548477416476965
# 0.5 Clase Ponderado - Accuracy promedio para rnn3 : 0.6588789448893075 desvest:  0.09726563325732622

# %% [markdown]
# ## 0.85

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_85_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.940
# F1-score macro cnn1 : 0.939
# F1-score None cnn1 : [0.89  0.991 0.991 0.886]
#
# ------ Validation ------
# Accuracy cnn1 : 0.839
# F1-score macro cnn1 : 0.471
# F1-score None cnn1 : [0.904 0.124 0.065 0.791]
#
# ------ Testing ------
# Accuracy cnn1 : 0.813
# F1-score macro cnn1 : 0.487
# F1-score None cnn1 : [0.894 0.175 0.147 0.734]
#
# ------ Training ------
# Accuracy cnn2 : 0.939
# F1-score macro cnn2 : 0.939
# F1-score None cnn2 : [0.886 0.992 0.992 0.886]
#
# ------ Validation ------
# Accuracy cnn2 : 0.840
# F1-score macro cnn2 : 0.485
# F1-score None cnn2 : [0.904 0.177 0.066 0.793]
#
# ------ Testing ------
# Accuracy cnn2 : 0.804
# F1-score macro cnn2 : 0.483
# F1-score None cnn2 : [0.888 0.142 0.196 0.708]
#
# ------ Training ------
# Accuracy rnn1 : 0.839
# F1-score macro rnn1 : 0.833
# F1-score None rnn1 : [0.748 0.871 0.94  0.774]
#
# ------ Validation ------
# Accuracy rnn1 : 0.654
# F1-score macro rnn1 : 0.430
# F1-score None rnn1 : [0.77  0.138 0.074 0.738]
#
# ------ Testing ------
# Accuracy rnn1 : 0.592
# F1-score macro rnn1 : 0.435
# F1-score None rnn1 : [0.734 0.175 0.224 0.607]
#
# ------ Training ------
# Accuracy rnn2 : 0.928
# F1-score macro rnn2 : 0.927
# F1-score None rnn2 : [0.869 0.986 0.973 0.881]
#
# ------ Validation ------
# Accuracy rnn2 : 0.821
# F1-score macro rnn2 : 0.461
# F1-score None rnn2 : [0.893 0.114 0.058 0.777]
#
# ------ Testing ------
# Accuracy rnn2 : 0.773
# F1-score macro rnn2 : 0.481
# F1-score None rnn2 : [0.871 0.182 0.214 0.657]
#
# ------ Training ------
# Accuracy rnn3 : 0.903
# F1-score macro rnn3 : 0.904
# F1-score None rnn3 : [0.853 0.971 0.948 0.843]
#
# ------ Validation ------
# Accuracy rnn3 : 0.858
# F1-score macro rnn3 : 0.458
# F1-score None rnn3 : [0.916 0.103 0.    0.811]
#
# ------ Testing ------
# Accuracy rnn3 : 0.826
# F1-score macro rnn3 : 0.497
# F1-score None rnn3 : [0.903 0.192 0.179 0.716]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.941
# F1-score macro cnn1 : 0.941
# F1-score None cnn1 : [0.889 0.991 0.992 0.89 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.832
# F1-score macro cnn1 : 0.471
# F1-score None cnn1 : [0.901 0.137 0.066 0.781]
#
# ------ Testing ------
# Accuracy cnn1 : 0.794
# F1-score macro cnn1 : 0.468
# F1-score None cnn1 : [0.883 0.137 0.144 0.709]
#
# ------ Training ------
# Accuracy cnn2 : 0.928
# F1-score macro cnn2 : 0.928
# F1-score None cnn2 : [0.869 0.992 0.994 0.855]
#
# ------ Validation ------
# Accuracy cnn2 : 0.868
# F1-score macro cnn2 : 0.443
# F1-score None cnn2 : [0.92  0.    0.045 0.807]
#
# ------ Testing ------
# Accuracy cnn2 : 0.834
# F1-score macro cnn2 : 0.438
# F1-score None cnn2 : [0.906 0.051 0.103 0.69 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.742
# F1-score macro rnn1 : 0.744
# F1-score None rnn1 : [0.739 0.777 0.736 0.721]
#
# ------ Validation ------
# Accuracy rnn1 : 0.638
# F1-score macro rnn1 : 0.383
# F1-score None rnn1 : [0.792 0.055 0.059 0.626]
#
# ------ Testing ------
# Accuracy rnn1 : 0.575
# F1-score macro rnn1 : 0.352
# F1-score None rnn1 : [0.747 0.054 0.14  0.466]
#
# ------ Training ------
# Accuracy rnn2 : 0.935
# F1-score macro rnn2 : 0.935
# F1-score None rnn2 : [0.886 0.984 0.985 0.884]
#
# ------ Validation ------
# Accuracy rnn2 : 0.860
# F1-score macro rnn2 : 0.515
# F1-score None rnn2 : [0.915 0.225 0.08  0.84 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.818
# F1-score macro rnn2 : 0.508
# F1-score None rnn2 : [0.893 0.197 0.17  0.771]
#
# ------ Training ------
# Accuracy rnn3 : 0.865
# F1-score macro rnn3 : 0.865
# F1-score None rnn3 : [0.825 0.873 0.92  0.841]
#
# ------ Validation ------
# Accuracy rnn3 : 0.834
# F1-score macro rnn3 : 0.445
# F1-score None rnn3 : [0.908 0.054 0.031 0.789]
#
# ------ Testing ------
# Accuracy rnn3 : 0.800
# F1-score macro rnn3 : 0.465
# F1-score None rnn3 : [0.887 0.018 0.246 0.707]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.938
# F1-score macro cnn1 : 0.937
# F1-score None cnn1 : [0.884 0.996 0.994 0.875]
#
# ------ Validation ------
# Accuracy cnn1 : 0.862
# F1-score macro cnn1 : 0.463
# F1-score None cnn1 : [0.918 0.082 0.037 0.814]
#
# ------ Testing ------
# Accuracy cnn1 : 0.834
# F1-score macro cnn1 : 0.454
# F1-score None cnn1 : [0.907 0.072 0.097 0.741]
#
# ------ Training ------
# Accuracy cnn2 : 0.938
# F1-score macro cnn2 : 0.938
# F1-score None cnn2 : [0.886 0.991 0.992 0.884]
#
# ------ Validation ------
# Accuracy cnn2 : 0.858
# F1-score macro cnn2 : 0.495
# F1-score None cnn2 : [0.913 0.205 0.045 0.817]
#
# ------ Testing ------
# Accuracy cnn2 : 0.818
# F1-score macro cnn2 : 0.457
# F1-score None cnn2 : [0.895 0.097 0.086 0.75 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.840
# F1-score macro rnn1 : 0.832
# F1-score None rnn1 : [0.786 0.916 0.898 0.729]
#
# ------ Validation ------
# Accuracy rnn1 : 0.687
# F1-score macro rnn1 : 0.424
# F1-score None rnn1 : [0.813 0.126 0.068 0.689]
#
# ------ Testing ------
# Accuracy rnn1 : 0.659
# F1-score macro rnn1 : 0.448
# F1-score None rnn1 : [0.794 0.19  0.217 0.592]
#
# ------ Training ------
# Accuracy rnn2 : 0.925
# F1-score macro rnn2 : 0.925
# F1-score None rnn2 : [0.87  0.979 0.971 0.881]
#
# ------ Validation ------
# Accuracy rnn2 : 0.831
# F1-score macro rnn2 : 0.488
# F1-score None rnn2 : [0.898 0.167 0.079 0.807]
#
# ------ Testing ------
# Accuracy rnn2 : 0.792
# F1-score macro rnn2 : 0.447
# F1-score None rnn2 : [0.888 0.033 0.161 0.708]
#
# ------ Training ------
# Accuracy rnn3 : 0.782
# F1-score macro rnn3 : 0.775
# F1-score None rnn3 : [0.784 0.849 0.704 0.765]
#
# ------ Validation ------
# Accuracy rnn3 : 0.728
# F1-score macro rnn3 : 0.448
# F1-score None rnn3 : [0.809 0.168 0.    0.813]
#
# ------ Testing ------
# Accuracy rnn3 : 0.672
# F1-score macro rnn3 : 0.437
# F1-score None rnn3 : [0.789 0.187 0.051 0.722]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.938
# F1-score macro cnn1 : 0.938
# F1-score None cnn1 : [0.886 0.996 0.994 0.877]
#
# ------ Validation ------
# Accuracy cnn1 : 0.862
# F1-score macro cnn1 : 0.468
# F1-score None cnn1 : [0.919 0.112 0.034 0.809]
#
# ------ Testing ------
# Accuracy cnn1 : 0.830
# F1-score macro cnn1 : 0.471
# F1-score None cnn1 : [0.903 0.055 0.171 0.753]
#
# ------ Training ------
# Accuracy cnn2 : 0.930
# F1-score macro cnn2 : 0.930
# F1-score None cnn2 : [0.876 0.984 0.985 0.873]
#
# ------ Validation ------
# Accuracy cnn2 : 0.821
# F1-score macro cnn2 : 0.459
# F1-score None cnn2 : [0.894 0.106 0.042 0.794]
#
# ------ Testing ------
# Accuracy cnn2 : 0.783
# F1-score macro cnn2 : 0.510
# F1-score None cnn2 : [0.872 0.207 0.242 0.719]
#
# ------ Training ------
# Accuracy rnn1 : 0.839
# F1-score macro rnn1 : 0.842
# F1-score None rnn1 : [0.816 0.966 0.823 0.763]
#
# ------ Validation ------
# Accuracy rnn1 : 0.794
# F1-score macro rnn1 : 0.438
# F1-score None rnn1 : [0.867 0.089 0.047 0.747]
#
# ------ Testing ------
# Accuracy rnn1 : 0.772
# F1-score macro rnn1 : 0.463
# F1-score None rnn1 : [0.864 0.235 0.067 0.685]
#
# ------ Training ------
# Accuracy rnn2 : 0.939
# F1-score macro rnn2 : 0.939
# F1-score None rnn2 : [0.886 0.988 0.986 0.894]
#
# ------ Validation ------
# Accuracy rnn2 : 0.862
# F1-score macro rnn2 : 0.483
# F1-score None rnn2 : [0.921 0.143 0.047 0.822]
#
# ------ Testing ------
# Accuracy rnn2 : 0.835
# F1-score macro rnn2 : 0.495
# F1-score None rnn2 : [0.91  0.095 0.222 0.752]
#
# ------ Training ------
# Accuracy rnn3 : 0.838
# F1-score macro rnn3 : 0.829
# F1-score None rnn3 : [0.698 0.881 0.919 0.818]
#
# ------ Validation ------
# Accuracy rnn3 : 0.555
# F1-score macro rnn3 : 0.374
# F1-score None rnn3 : [0.622 0.144 0.033 0.696]
#
# ------ Testing ------
# Accuracy rnn3 : 0.465
# F1-score macro rnn3 : 0.366
# F1-score None rnn3 : [0.567 0.174 0.181 0.541]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.941
# F1-score macro cnn1 : 0.940
# F1-score None cnn1 : [0.888 0.995 0.993 0.886]
#
# ------ Validation ------
# Accuracy cnn1 : 0.860
# F1-score macro cnn1 : 0.501
# F1-score None cnn1 : [0.916 0.2   0.074 0.814]
#
# ------ Testing ------
# Accuracy cnn1 : 0.822
# F1-score macro cnn1 : 0.474
# F1-score None cnn1 : [0.899 0.151 0.131 0.715]
#
# ------ Training ------
# Accuracy cnn2 : 0.937
# F1-score macro cnn2 : 0.937
# F1-score None cnn2 : [0.884 0.996 0.993 0.875]
#
# ------ Validation ------
# Accuracy cnn2 : 0.872
# F1-score macro cnn2 : 0.460
# F1-score None cnn2 : [0.924 0.049 0.047 0.82 ]
# ------ Testing ------
# Accuracy cnn2 : 0.843
# F1-score macro cnn2 : 0.445
# F1-score None cnn2 : [0.914 0.033 0.109 0.722]
#
# ------ Training ------
# Accuracy rnn1 : 0.840
# F1-score macro rnn1 : 0.841
# F1-score None rnn1 : [0.792 0.957 0.899 0.716]
#
# ------ Validation ------
# Accuracy rnn1 : 0.812
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.88  0.15  0.051 0.716]
#
# ------ Testing ------
# Accuracy rnn1 : 0.768
# F1-score macro rnn1 : 0.403
# F1-score None rnn1 : [0.864 0.152 0.091 0.506]
#
# ------ Training ------
# Accuracy rnn2 : 0.829
# F1-score macro rnn2 : 0.818
# F1-score None rnn2 : [0.701 0.9   0.873 0.797]
#
# ------ Validation ------
# Accuracy rnn2 : 0.543
# F1-score macro rnn2 : 0.371
# F1-score None rnn2 : [0.665 0.118 0.049 0.651]
#
# ------ Testing ------
# Accuracy rnn2 : 0.509
# F1-score macro rnn2 : 0.397
# F1-score None rnn2 : [0.634 0.183 0.192 0.577]
#
# ------ Training ------
# Accuracy rnn3 : 0.896
# F1-score macro rnn3 : 0.896
# F1-score None rnn3 : [0.838 0.967 0.955 0.823]
#
# ------ Validation ------
# Accuracy rnn3 : 0.852
# F1-score macro rnn3 : 0.461
# F1-score None rnn3 : [0.915 0.13  0.    0.801]
#
# ------ Testing ------
# Accuracy rnn3 : 0.821
# F1-score macro rnn3 : 0.496
# F1-score None rnn3 : [0.898 0.182 0.175 0.73 ]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.85 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.85 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.85 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.85 Clase Ponderado - F1-score promedio para cnn1 : [0.897 0.118 0.138 0.73 ]
# 0.85 Clase Ponderado - F1-score promedio para cnn2 : [0.895 0.106 0.147 0.718]
# 0.85 Clase Ponderado - F1-score promedio para rnn1 : [0.801 0.161 0.148 0.571]
# 0.85 Clase Ponderado - F1-score promedio para rnn2 : [0.839 0.138 0.192 0.693]
# 0.85 Clase Ponderado - F1-score promedio para rnn3 : [0.809 0.151 0.166 0.683]
#
# 0.85 Clase Ponderado - F1-score macro promedio para cnn1 : 0.4708157967039023 desvest:  0.010605493441398276
# 0.85 Clase Ponderado - F1-score macro promedio para cnn2 : 0.4666141831853062 desvest:  0.02683556281625459
# 0.85 Clase Ponderado - F1-score macro promedio para rnn1 : 0.42019769662810286 desvest:  0.03949362804462176
# 0.85 Clase Ponderado - F1-score macro promedio para rnn2 : 0.46552295260907206 desvest:  0.03983921426619546
# 0.85 Clase Ponderado - F1-score macro promedio para rnn3 : 0.45232154932721097 desvest:  0.048597343994404844
#
# 0.85 Clase Ponderado - Accuracy promedio para cnn1 : 0.8188412623645785 desvest:  0.014326175336943633
# 0.85 Clase Ponderado - Accuracy promedio para cnn2 : 0.8162976919453604 desvest:  0.02144720020833272
# 0.85 Clase Ponderado - Accuracy promedio para rnn1 : 0.6730098916627414 desvest:  0.08392476504114513
# 0.85 Clase Ponderado - Accuracy promedio para rnn2 : 0.7453603391427226 desvest:  0.12016737939762814
# 0.85 Clase Ponderado - Accuracy promedio para rnn3 : 0.7165332077249176 desvest:  0.13784009235876085

# %%
k=3

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_15_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.15/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.15/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.941
# F1-score macro cnn1 : 0.941
# F1-score None cnn1 : [0.891 0.997 0.995 0.879]
#
# ------ Validation ------
# Accuracy cnn1 : 0.876
# F1-score macro cnn1 : 0.462
# F1-score None cnn1 : [0.926 0.049 0.049 0.824]
#
# ------ Testing ------
# Accuracy cnn1 : 0.843
# F1-score macro cnn1 : 0.428
# F1-score None cnn1 : [0.91  0.066 0.026 0.712]
#
# ------ Training ------
# Accuracy cnn2 : 0.942
# F1-score macro cnn2 : 0.942
# F1-score None cnn2 : [0.892 0.997 0.995 0.883]
#
# ------ Validation ------
# Accuracy cnn2 : 0.874
# F1-score macro cnn2 : 0.478
# F1-score None cnn2 : [0.924 0.071 0.095 0.823]
#
# ------ Testing ------
# Accuracy cnn2 : 0.842
# F1-score macro cnn2 : 0.453
# F1-score None cnn2 : [0.908 0.114 0.049 0.74 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.688
# F1-score macro rnn1 : 0.683
# F1-score None rnn1 : [0.766 0.699 0.601 0.665]
#
# ------ Validation ------
# Accuracy rnn1 : 0.872
# F1-score macro rnn1 : 0.455
# F1-score None rnn1 : [0.926 0.027 0.047 0.821]
#
# ------ Testing ------
# Accuracy rnn1 : 0.843
# F1-score macro rnn1 : 0.446
# F1-score None rnn1 : [0.915 0.036 0.098 0.734]
#
# ------ Training ------
# Accuracy rnn2 : 0.928
# F1-score macro rnn2 : 0.927
# F1-score None rnn2 : [0.874 0.981 0.964 0.887]
#
# ------ Validation ------
# Accuracy rnn2 : 0.787
# F1-score macro rnn2 : 0.467
# F1-score None rnn2 : [0.878 0.18  0.05  0.761]
#
# ------ Testing ------
# Accuracy rnn2 : 0.762
# F1-score macro rnn2 : 0.491
# F1-score None rnn2 : [0.867 0.215 0.184 0.699]
#
# ------ Training ------
# Accuracy rnn3 : 0.786
# F1-score macro rnn3 : 0.780
# F1-score None rnn3 : [0.716 0.957 0.762 0.684]
#
# ------ Validation ------
# Accuracy rnn3 : 0.560
# F1-score macro rnn3 : 0.375
# F1-score None rnn3 : [0.736 0.131 0.057 0.578]
#
# ------ Testing ------
# Accuracy rnn3 : 0.605
# F1-score macro rnn3 : 0.458
# F1-score None rnn3 : [0.748 0.29  0.212 0.581]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.949
# F1-score macro cnn1 : 0.949
# F1-score None cnn1 : [0.902 0.996 0.997 0.903]
#
# ------ Validation ------
# Accuracy cnn1 : 0.879
# F1-score macro cnn1 : 0.451
# F1-score None cnn1 : [0.93  0.    0.043 0.829]
#
# ------ Testing ------
# Accuracy cnn1 : 0.855
# F1-score macro cnn1 : 0.447
# F1-score None cnn1 : [0.919 0.019 0.096 0.755]
#
# ------ Training ------
# Accuracy cnn2 : 0.948
# F1-score macro cnn2 : 0.948
# F1-score None cnn2 : [0.897 0.997 0.997 0.901]
#
# ------ Validation ------
# Accuracy cnn2 : 0.862
# F1-score macro cnn2 : 0.453
# F1-score None cnn2 : [0.918 0.    0.093 0.801]
#
# ------ Testing ------
# Accuracy cnn2 : 0.844
# F1-score macro cnn2 : 0.443
# F1-score None cnn2 : [0.914 0.018 0.098 0.743]
#
# ------ Training ------
# Accuracy rnn1 : 0.891
# F1-score macro rnn1 : 0.889
# F1-score None rnn1 : [0.858 0.973 0.911 0.816]
#
# ------ Validation ------
# Accuracy rnn1 : 0.807
# F1-score macro rnn1 : 0.442
# F1-score None rnn1 : [0.91  0.045 0.072 0.739]
#
# ------ Testing ------
# Accuracy rnn1 : 0.814
# F1-score macro rnn1 : 0.521
# F1-score None rnn1 : [0.904 0.154 0.327 0.7  ]
#
# ------ Training ------
# Accuracy rnn2 : 0.924
# F1-score macro rnn2 : 0.923
# F1-score None rnn2 : [0.892 0.984 0.95  0.865]
#
# ------ Validation ------
# Accuracy rnn2 : 0.836
# F1-score macro rnn2 : 0.478
# F1-score None rnn2 : [0.921 0.16  0.048 0.783]
#
# ------ Testing ------
# Accuracy rnn2 : 0.835
# F1-score macro rnn2 : 0.525
# F1-score None rnn2 : [0.912 0.177 0.25  0.76 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.879
# F1-score macro rnn3 : 0.880
# F1-score None rnn3 : [0.824 0.913 0.944 0.84 ]
#
# ------ Validation ------
# Accuracy rnn3 : 0.859
# F1-score macro rnn3 : 0.463
# F1-score None rnn3 : [0.923 0.049 0.055 0.824]
#
# ------ Testing ------
# Accuracy rnn3 : 0.836
# F1-score macro rnn3 : 0.510
# F1-score None rnn3 : [0.911 0.104 0.294 0.732]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.949
# F1-score macro cnn1 : 0.949
# F1-score None cnn1 : [0.904 0.997 0.996 0.9  ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.877
# F1-score macro cnn1 : 0.462
# F1-score None cnn1 : [0.926 0.    0.089 0.832]
#
# ------ Testing ------
# Accuracy cnn1 : 0.849
# F1-score macro cnn1 : 0.441
# F1-score None cnn1 : [0.914 0.035 0.067 0.746]
#
# ------ Training ------
# Accuracy cnn2 : 0.939
# F1-score macro cnn2 : 0.939
# F1-score None cnn2 : [0.887 0.997 0.994 0.877]
#
# ------ Validation ------
# Accuracy cnn2 : 0.877
# F1-score macro cnn2 : 0.449
# F1-score None cnn2 : [0.927 0.    0.049 0.82 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.845
# F1-score macro cnn2 : 0.432
# F1-score None cnn2 : [0.911 0.037 0.075 0.707]
#
# ------ Training ------
# Accuracy rnn1 : 0.659
# F1-score macro rnn1 : 0.606
# F1-score None rnn1 : [0.735 0.233 0.795 0.661]
#
# ------ Validation ------
# Accuracy rnn1 : 0.707
# F1-score macro rnn1 : 0.394
# F1-score None rnn1 : [0.819 0.    0.049 0.709]
#
# ------ Testing ------
# Accuracy rnn1 : 0.663
# F1-score macro rnn1 : 0.396
# F1-score None rnn1 : [0.792 0.    0.212 0.582]
#
# ------ Training ------
# Accuracy rnn2 : 0.936
# F1-score macro rnn2 : 0.935
# F1-score None rnn2 : [0.897 0.994 0.96  0.888]
#
# ------ Validation ------
# Accuracy rnn2 : 0.829
# F1-score macro rnn2 : 0.450
# F1-score None rnn2 : [0.911 0.021 0.073 0.794]
#
# ------ Testing ------
# Accuracy rnn2 : 0.830
# F1-score macro rnn2 : 0.520
# F1-score None rnn2 : [0.908 0.189 0.2   0.784]
#
# ------ Training ------
# Accuracy rnn3 : 0.840
# F1-score macro rnn3 : 0.834
# F1-score None rnn3 : [0.717 0.859 0.937 0.824]
#
# ------ Validation ------
# Accuracy rnn3 : 0.641
# F1-score macro rnn3 : 0.421
# F1-score None rnn3 : [0.734 0.125 0.051 0.773]
#
# ------ Testing ------
# Accuracy rnn3 : 0.573
# F1-score macro rnn3 : 0.463
# F1-score None rnn3 : [0.687 0.191 0.293 0.681]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.942
# F1-score macro cnn1 : 0.942
# F1-score None cnn1 : [0.891 0.996 0.996 0.884]
#
# ------ Validation ------
# Accuracy cnn1 : 0.881
# F1-score macro cnn1 : 0.465
# F1-score None cnn1 : [0.93  0.052 0.044 0.834]
#
# ------ Testing ------
# Accuracy cnn1 : 0.844
# F1-score macro cnn1 : 0.449
# F1-score None cnn1 : [0.911 0.133 0.025 0.725]
#
# ------ Training ------
# Accuracy cnn2 : 0.948
# F1-score macro cnn2 : 0.948
# F1-score None cnn2 : [0.902 0.997 0.994 0.901]
#
# ------ Validation ------
# Accuracy cnn2 : 0.882
# F1-score macro cnn2 : 0.472
# F1-score None cnn2 : [0.931 0.027 0.1   0.832]
#
# ------ Testing ------
# Accuracy cnn2 : 0.853
# F1-score macro cnn2 : 0.441
# F1-score None cnn2 : [0.918 0.05  0.026 0.77 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.877
# F1-score macro rnn1 : 0.875
# F1-score None rnn1 : [0.827 0.953 0.937 0.783]
#
# ------ Validation ------
# Accuracy rnn1 : 0.841
# F1-score macro rnn1 : 0.465
# F1-score None rnn1 : [0.922 0.132 0.066 0.739]
#
# ------ Testing ------
# Accuracy rnn1 : 0.819
# F1-score macro rnn1 : 0.459
# F1-score None rnn1 : [0.903 0.115 0.214 0.605]
#
# ------ Training ------
# Accuracy rnn2 : 0.892
# F1-score macro rnn2 : 0.894
# F1-score None rnn2 : [0.861 0.99  0.898 0.827]
#
# ------ Validation ------
# Accuracy rnn2 : 0.839
# F1-score macro rnn2 : 0.460
# F1-score None rnn2 : [0.902 0.112 0.053 0.774]
#
# ------ Testing ------
# Accuracy rnn2 : 0.791
# F1-score macro rnn2 : 0.446
# F1-score None rnn2 : [0.884 0.186 0.049 0.666]
#
# ------ Training ------
# Accuracy rnn3 : 0.893
# F1-score macro rnn3 : 0.892
# F1-score None rnn3 : [0.83  0.963 0.935 0.842]
#
# ------ Validation ------
# Accuracy rnn3 : 0.792
# F1-score macro rnn3 : 0.472
# F1-score None rnn3 : [0.87  0.199 0.046 0.773]
#
# ------ Testing ------
# Accuracy rnn3 : 0.744
# F1-score macro rnn3 : 0.513
# F1-score None rnn3 : [0.844 0.265 0.273 0.67 ]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.948
# F1-score macro cnn1 : 0.948
# F1-score None cnn1 : [0.895 0.997 0.996 0.903]
#
# ------ Validation ------
# Accuracy cnn1 : 0.850
# F1-score macro cnn1 : 0.448
# F1-score None cnn1 : [0.911 0.046 0.043 0.792]
#
# ------ Testing ------
# Accuracy cnn1 : 0.839
# F1-score macro cnn1 : 0.461
# F1-score None cnn1 : [0.914 0.138 0.049 0.741]
#
# ------ Training ------
# Accuracy cnn2 : 0.949
# F1-score macro cnn2 : 0.949
# F1-score None cnn2 : [0.901 0.995 0.996 0.903]
#
# ------ Validation ------
# Accuracy cnn2 : 0.879
# F1-score macro cnn2 : 0.462
# F1-score None cnn2 : [0.928 0.    0.091 0.831]
# ------ Testing ------
# Accuracy cnn2 : 0.852
# F1-score macro cnn2 : 0.466
# F1-score None cnn2 : [0.915 0.055 0.125 0.771]
#
# ------ Training ------
# Accuracy rnn1 : 0.863
# F1-score macro rnn1 : 0.865
# F1-score None rnn1 : [0.835 0.975 0.848 0.8  ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.839
# F1-score macro rnn1 : 0.465
# F1-score None rnn1 : [0.901 0.123 0.047 0.789]
#
# ------ Testing ------
# Accuracy rnn1 : 0.818
# F1-score macro rnn1 : 0.510
# F1-score None rnn1 : [0.899 0.243 0.186 0.713]
#
# ------ Training ------
# Accuracy rnn2 : 0.937
# F1-score macro rnn2 : 0.936
# F1-score None rnn2 : [0.879 0.995 0.973 0.897]
#
# ------ Validation ------
# Accuracy rnn2 : 0.837
# F1-score macro rnn2 : 0.467
# F1-score None rnn2 : [0.906 0.09  0.065 0.806]
#
# ------ Testing ------
# Accuracy rnn2 : 0.814
# F1-score macro rnn2 : 0.495
# F1-score None rnn2 : [0.896 0.122 0.198 0.765]
#
# ------ Training ------
# Accuracy rnn3 : 0.884
# F1-score macro rnn3 : 0.883
# F1-score None rnn3 : [0.812 0.949 0.927 0.842]
#
# ------ Validation ------
# Accuracy rnn3 : 0.781
# F1-score macro rnn3 : 0.472
# F1-score None rnn3 : [0.86  0.174 0.066 0.787]
#
# ------ Testing ------
# Accuracy rnn3 : 0.746
# F1-score macro rnn3 : 0.518
# F1-score None rnn3 : [0.844 0.287 0.232 0.708]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.15 Clase Ponderado - F1-score promedio para cnn1 : [0.914 0.078 0.053 0.736]
# 0.15 Clase Ponderado - F1-score promedio para cnn2 : [0.913 0.055 0.075 0.746]
# 0.15 Clase Ponderado - F1-score promedio para rnn1 : [0.882 0.11  0.207 0.667]
# 0.15 Clase Ponderado - F1-score promedio para rnn2 : [0.894 0.178 0.176 0.735]
# 0.15 Clase Ponderado - F1-score promedio para rnn3 : [0.806 0.228 0.261 0.675]
#
# 0.15 Clase Ponderado - F1-score macro promedio para cnn1 : 0.4450878256813072 desvest:  0.010595793591700695
# 0.15 Clase Ponderado - F1-score macro promedio para cnn2 : 0.44721263932036487 desvest:  0.01158562229698148
# 0.15 Clase Ponderado - F1-score macro promedio para rnn1 : 0.46653673301220666 desvest:  0.04536943333225193
# 0.15 Clase Ponderado - F1-score macro promedio para rnn2 : 0.49554531720338046 desvest:  0.028008967598446812
# 0.15 Clase Ponderado - F1-score macro promedio para rnn3 : 0.49239311885002673 desvest:  0.0263613504907655
#
# 0.15 Clase Ponderado - Accuracy promedio para cnn1 : 0.8460668864813943 desvest:  0.005455838807562999
# 0.15 Clase Ponderado - Accuracy promedio para cnn2 : 0.847197362223269 desvest:  0.0044844579313846195
# 0.15 Clase Ponderado - Accuracy promedio para rnn1 : 0.7914272256241168 desvest:  0.06492885999195339
# 0.15 Clase Ponderado - Accuracy promedio para rnn2 : 0.8064060292039568 desvest:  0.026961774027861152
# 0.15 Clase Ponderado - Accuracy promedio para rnn3 : 0.7007065473386718 desvest:  0.09752724071838595

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_50_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.5/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.5/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.946
# F1-score macro cnn1 : 0.946
# F1-score None cnn1 : [0.896 0.996 0.994 0.898]
#
# ------ Validation ------
# Accuracy cnn1 : 0.866
# F1-score macro cnn1 : 0.461
# F1-score None cnn1 : [0.922 0.065 0.042 0.817]
#
# ------ Testing ------
# Accuracy cnn1 : 0.840
# F1-score macro cnn1 : 0.492
# F1-score None cnn1 : [0.908 0.181 0.126 0.754]
#
# ------ Training ------
# Accuracy cnn2 : 0.923
# F1-score macro cnn2 : 0.922
# F1-score None cnn2 : [0.866 0.985 0.994 0.845]
#
# ------ Validation ------
# Accuracy cnn2 : 0.853
# F1-score macro cnn2 : 0.508
# F1-score None cnn2 : [0.914 0.2   0.118 0.801]
#
# ------ Testing ------
# Accuracy cnn2 : 0.809
# F1-score macro cnn2 : 0.457
# F1-score None cnn2 : [0.889 0.222 0.043 0.673]
#
# ------ Training ------
# Accuracy rnn1 : 0.884
# F1-score macro rnn1 : 0.887
# F1-score None rnn1 : [0.841 0.946 0.938 0.823]
#
# ------ Validation ------
# Accuracy rnn1 : 0.853
# F1-score macro rnn1 : 0.483
# F1-score None rnn1 : [0.915 0.18  0.032 0.804]
#
# ------ Testing ------
# Accuracy rnn1 : 0.824
# F1-score macro rnn1 : 0.528
# F1-score None rnn1 : [0.9   0.221 0.252 0.738]
#
# ------ Training ------
# Accuracy rnn2 : 0.914
# F1-score macro rnn2 : 0.912
# F1-score None rnn2 : [0.882 0.984 0.937 0.847]
#
# ------ Validation ------
# Accuracy rnn2 : 0.823
# F1-score macro rnn2 : 0.471
# F1-score None rnn2 : [0.917 0.124 0.073 0.769]
#
# ------ Testing ------
# Accuracy rnn2 : 0.794
# F1-score macro rnn2 : 0.515
# F1-score None rnn2 : [0.892 0.193 0.261 0.713]
#
# ------ Training ------
# Accuracy rnn3 : 0.842
# F1-score macro rnn3 : 0.842
# F1-score None rnn3 : [0.723 0.942 0.933 0.77 ]
#
# ------ Validation ------
# Accuracy rnn3 : 0.647
# F1-score macro rnn3 : 0.367
# F1-score None rnn3 : [0.728 0.118 0.019 0.602]
#
# ------ Testing ------
# Accuracy rnn3 : 0.558
# F1-score macro rnn3 : 0.373
# F1-score None rnn3 : [0.674 0.194 0.182 0.443]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.924
# F1-score macro cnn1 : 0.923
# F1-score None cnn1 : [0.866 0.996 0.994 0.837]
#
# ------ Validation ------
# Accuracy cnn1 : 0.857
# F1-score macro cnn1 : 0.485
# F1-score None cnn1 : [0.915 0.152 0.083 0.788]
#
# ------ Testing ------
# Accuracy cnn1 : 0.806
# F1-score macro cnn1 : 0.443
# F1-score None cnn1 : [0.888 0.129 0.144 0.612]
#
# ------ Training ------
# Accuracy cnn2 : 0.935
# F1-score macro cnn2 : 0.935
# F1-score None cnn2 : [0.884 0.991 0.993 0.872]
#
# ------ Validation ------
# Accuracy cnn2 : 0.850
# F1-score macro cnn2 : 0.502
# F1-score None cnn2 : [0.91  0.222 0.062 0.814]
#
# ------ Testing ------
# Accuracy cnn2 : 0.806
# F1-score macro cnn2 : 0.481
# F1-score None cnn2 : [0.888 0.203 0.136 0.699]
#
# ------ Training ------
# Accuracy rnn1 : 0.834
# F1-score macro rnn1 : 0.832
# F1-score None rnn1 : [0.808 0.87  0.9   0.748]
#
# ------ Validation ------
# Accuracy rnn1 : 0.789
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.887 0.192 0.    0.718]
#
# ------ Testing ------
# Accuracy rnn1 : 0.750
# F1-score macro rnn1 : 0.467
# F1-score None rnn1 : [0.869 0.241 0.206 0.552]
#
# ------ Training ------
# Accuracy rnn2 : 0.929
# F1-score macro rnn2 : 0.930
# F1-score None rnn2 : [0.884 0.992 0.97  0.874]
#
# ------ Validation ------
# Accuracy rnn2 : 0.878
# F1-score macro rnn2 : 0.479
# F1-score None rnn2 : [0.928 0.098 0.044 0.846]
#
# ------ Testing ------
# Accuracy rnn2 : 0.856
# F1-score macro rnn2 : 0.509
# F1-score None rnn2 : [0.92  0.23  0.07  0.816]
#
# ------ Training ------
# Accuracy rnn3 : 0.862
# F1-score macro rnn3 : 0.865
# F1-score None rnn3 : [0.842 0.932 0.89  0.798]
#
# ------ Validation ------
# Accuracy rnn3 : 0.828
# F1-score macro rnn3 : 0.454
# F1-score None rnn3 : [0.895 0.091 0.027 0.802]
#
# ------ Testing ------
# Accuracy rnn3 : 0.797
# F1-score macro rnn3 : 0.515
# F1-score None rnn3 : [0.884 0.176 0.268 0.733]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.922
# F1-score macro cnn1 : 0.921
# F1-score None cnn1 : [0.866 0.977 0.994 0.848]
#
# ------ Validation ------
# Accuracy cnn1 : 0.822
# F1-score macro cnn1 : 0.474
# F1-score None cnn1 : [0.894 0.173 0.041 0.788]
#
# ------ Testing ------
# Accuracy cnn1 : 0.774
# F1-score macro cnn1 : 0.454
# F1-score None cnn1 : [0.869 0.174 0.094 0.679]
#
# ------ Training ------
# Accuracy cnn2 : 0.933
# F1-score macro cnn2 : 0.933
# F1-score None cnn2 : [0.876 0.994 0.994 0.868]
#
# ------ Validation ------
# Accuracy cnn2 : 0.871
# F1-score macro cnn2 : 0.459
# F1-score None cnn2 : [0.924 0.044 0.043 0.824]
#
# ------ Testing ------
# Accuracy cnn2 : 0.846
# F1-score macro cnn2 : 0.477
# F1-score None cnn2 : [0.911 0.106 0.116 0.774]
#
# ------ Training ------
# Accuracy rnn1 : 0.897
# F1-score macro rnn1 : 0.897
# F1-score None rnn1 : [0.856 0.967 0.924 0.842]
#
# ------ Validation ------
# Accuracy rnn1 : 0.835
# F1-score macro rnn1 : 0.472
# F1-score None rnn1 : [0.9   0.172 0.    0.815]
#
# ------ Testing ------
# Accuracy rnn1 : 0.814
# F1-score macro rnn1 : 0.520
# F1-score None rnn1 : [0.892 0.226 0.186 0.777]
#
# ------ Training ------
# Accuracy rnn2 : 0.936
# F1-score macro rnn2 : 0.936
# F1-score None rnn2 : [0.891 0.99  0.976 0.888]
#
# ------ Validation ------
# Accuracy rnn2 : 0.865
# F1-score macro rnn2 : 0.462
# F1-score None rnn2 : [0.921 0.065 0.036 0.827]
#
# ------ Testing ------
# Accuracy rnn2 : 0.837
# F1-score macro rnn2 : 0.491
# F1-score None rnn2 : [0.909 0.095 0.183 0.775]
#
# ------ Training ------
# Accuracy rnn3 : 0.808
# F1-score macro rnn3 : 0.797
# F1-score None rnn3 : [0.785 0.877 0.853 0.674]
#
# ------ Validation ------
# Accuracy rnn3 : 0.624
# F1-score macro rnn3 : 0.407
# F1-score None rnn3 : [0.788 0.13  0.094 0.615]
#
# ------ Testing ------
# Accuracy rnn3 : 0.598
# F1-score macro rnn3 : 0.429
# F1-score None rnn3 : [0.758 0.191 0.245 0.523]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.941
# F1-score macro cnn1 : 0.941
# F1-score None cnn1 : [0.889 0.995 0.991 0.889]
#
# ------ Validation ------
# Accuracy cnn1 : 0.851
# F1-score macro cnn1 : 0.466
# F1-score None cnn1 : [0.911 0.109 0.04  0.804]
#
# ------ Testing ------
# Accuracy cnn1 : 0.832
# F1-score macro cnn1 : 0.509
# F1-score None cnn1 : [0.907 0.215 0.168 0.744]
#
# ------ Training ------
# Accuracy cnn2 : 0.931
# F1-score macro cnn2 : 0.931
# F1-score None cnn2 : [0.881 0.996 0.982 0.866]
#
# ------ Validation ------
# Accuracy cnn2 : 0.884
# F1-score macro cnn2 : 0.468
# F1-score None cnn2 : [0.931 0.049 0.051 0.842]
#
# ------ Testing ------
# Accuracy cnn2 : 0.854
# F1-score macro cnn2 : 0.460
# F1-score None cnn2 : [0.917 0.079 0.074 0.77 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.858
# F1-score macro rnn1 : 0.850
# F1-score None rnn1 : [0.841 0.969 0.882 0.706]
#
# ------ Validation ------
# Accuracy rnn1 : 0.784
# F1-score macro rnn1 : 0.447
# F1-score None rnn1 : [0.902 0.155 0.038 0.691]
#
# ------ Testing ------
# Accuracy rnn1 : 0.758
# F1-score macro rnn1 : 0.465
# F1-score None rnn1 : [0.876 0.215 0.224 0.544]
#
# ------ Training ------
# Accuracy rnn2 : 0.922
# F1-score macro rnn2 : 0.922
# F1-score None rnn2 : [0.855 0.988 0.976 0.869]
#
# ------ Validation ------
# Accuracy rnn2 : 0.788
# F1-score macro rnn2 : 0.426
# F1-score None rnn2 : [0.862 0.088 0.034 0.721]
#
# ------ Testing ------
# Accuracy rnn2 : 0.744
# F1-score macro rnn2 : 0.417
# F1-score None rnn2 : [0.852 0.06  0.155 0.601]
#
# ------ Training ------
# Accuracy rnn3 : 0.885
# F1-score macro rnn3 : 0.887
# F1-score None rnn3 : [0.844 0.947 0.933 0.822]
#
# ------ Validation ------
# Accuracy rnn3 : 0.848
# F1-score macro rnn3 : 0.460
# F1-score None rnn3 : [0.912 0.088 0.029 0.81 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.826
# F1-score macro rnn3 : 0.532
# F1-score None rnn3 : [0.899 0.209 0.252 0.766]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.942
# F1-score macro cnn1 : 0.942
# F1-score None cnn1 : [0.888 0.995 0.995 0.888]
#
# ------ Validation ------
# Accuracy cnn1 : 0.882
# F1-score macro cnn1 : 0.472
# F1-score None cnn1 : [0.931 0.027 0.095 0.833]
#
# ------ Testing ------
# Accuracy cnn1 : 0.854
# F1-score macro cnn1 : 0.449
# F1-score None cnn1 : [0.917 0.035 0.068 0.775]
#
# ------ Training ------
# Accuracy cnn2 : 0.931
# F1-score macro cnn2 : 0.931
# F1-score None cnn2 : [0.875 0.988 0.989 0.873]
#
# ------ Validation ------
# Accuracy cnn2 : 0.872
# F1-score macro cnn2 : 0.499
# F1-score None cnn2 : [0.923 0.188 0.051 0.831]
# ------ Testing ------
# Accuracy cnn2 : 0.833
# F1-score macro cnn2 : 0.483
# F1-score None cnn2 : [0.902 0.199 0.095 0.737]
#
# ------ Training ------
# Accuracy rnn1 : 0.670
# F1-score macro rnn1 : 0.621
# F1-score None rnn1 : [0.675 0.29  0.825 0.696]
#
# ------ Validation ------
# Accuracy rnn1 : 0.680
# F1-score macro rnn1 : 0.364
# F1-score None rnn1 : [0.786 0.    0.032 0.64 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.640
# F1-score macro rnn1 : 0.364
# F1-score None rnn1 : [0.778 0.    0.178 0.5  ]
#
# ------ Training ------
# Accuracy rnn2 : 0.928
# F1-score macro rnn2 : 0.929
# F1-score None rnn2 : [0.873 0.991 0.971 0.879]
#
# ------ Validation ------
# Accuracy rnn2 : 0.834
# F1-score macro rnn2 : 0.441
# F1-score None rnn2 : [0.898 0.044 0.05  0.772]
#
# ------ Testing ------
# Accuracy rnn2 : 0.801
# F1-score macro rnn2 : 0.430
# F1-score None rnn2 : [0.89  0.074 0.072 0.683]
#
# ------ Training ------
# Accuracy rnn3 : 0.850
# F1-score macro rnn3 : 0.853
# F1-score None rnn3 : [0.831 0.926 0.876 0.781]
#
# ------ Validation ------
# Accuracy rnn3 : 0.864
# F1-score macro rnn3 : 0.473
# F1-score None rnn3 : [0.919 0.103 0.038 0.835]
#
# ------ Testing ------
# Accuracy rnn3 : 0.837
# F1-score macro rnn3 : 0.492
# F1-score None rnn3 : [0.906 0.152 0.141 0.767]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.5 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.5 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.5 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.5 Clase Ponderado - F1-score promedio para cnn1 : [0.898 0.147 0.12  0.713]
# 0.5 Clase Ponderado - F1-score promedio para cnn2 : [0.901 0.162 0.093 0.731]
# 0.5 Clase Ponderado - F1-score promedio para rnn1 : [0.863 0.181 0.209 0.622]
# 0.5 Clase Ponderado - F1-score promedio para rnn2 : [0.892 0.13  0.148 0.718]
# 0.5 Clase Ponderado - F1-score promedio para rnn3 : [0.824 0.184 0.218 0.646]
#
# 0.5 Clase Ponderado - F1-score macro promedio para cnn1 : 0.4693688622045501 desvest:  0.026078471729301812
# 0.5 Clase Ponderado - F1-score macro promedio para cnn2 : 0.4716704334416493 desvest:  0.011132390465470201
# 0.5 Clase Ponderado - F1-score macro promedio para rnn1 : 0.46875998305341193 desvest:  0.058444236837127794
# 0.5 Clase Ponderado - F1-score macro promedio para rnn2 : 0.4721482344859117 desvest:  0.04078476025963576
# 0.5 Clase Ponderado - F1-score macro promedio para rnn3 : 0.46811707055890633 desvest:  0.058740890514117
#
# 0.5 Clase Ponderado - Accuracy promedio para cnn1 : 0.8211022138483278 desvest:  0.028257810978481877
# 0.5 Clase Ponderado - Accuracy promedio para cnn2 : 0.8294865756005653 desvest:  0.019128753419687967
# 0.5 Clase Ponderado - Accuracy promedio para rnn1 : 0.7574187470560527 desvest:  0.06578744522898673
# 0.5 Clase Ponderado - Accuracy promedio para rnn2 : 0.8062176165803109 desvest:  0.03864709889372197
# 0.5 Clase Ponderado - Accuracy promedio para rnn3 : 0.7231276495525201 desvest:  0.11987263629791652

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Harassment/Aumento_ofi/balance_GloVe_85_'+str(k)+'_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_cnn1(x_train.shape[1:])
    #cnn1=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    #cnn2=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    #rnn1=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn2=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=7, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    #rnn3=load_model('../Datasets/Models_Stance/0.85/'+str(k)+'/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Harassment/0.85/'+str(k)+'/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.941
# F1-score macro cnn1 : 0.941
# F1-score None cnn1 : [0.889 0.991 0.994 0.889]
#
# ------ Validation ------
# Accuracy cnn1 : 0.859
# F1-score macro cnn1 : 0.489
# F1-score None cnn1 : [0.915 0.177 0.048 0.816]
#
# ------ Testing ------
# Accuracy cnn1 : 0.822
# F1-score macro cnn1 : 0.452
# F1-score None cnn1 : [0.898 0.122 0.049 0.74 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.931
# F1-score macro cnn2 : 0.931
# F1-score None cnn2 : [0.883 0.993 0.979 0.87 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.869
# F1-score macro cnn2 : 0.489
# F1-score None cnn2 : [0.922 0.172 0.054 0.809]
#
# ------ Testing ------
# Accuracy cnn2 : 0.832
# F1-score macro cnn2 : 0.441
# F1-score None cnn2 : [0.904 0.096 0.024 0.741]
#
# ------ Training ------
# Accuracy rnn1 : 0.844
# F1-score macro rnn1 : 0.844
# F1-score None rnn1 : [0.791 0.849 0.921 0.814]
#
# ------ Validation ------
# Accuracy rnn1 : 0.691
# F1-score macro rnn1 : 0.420
# F1-score None rnn1 : [0.797 0.137 0.    0.746]
#
# ------ Testing ------
# Accuracy rnn1 : 0.634
# F1-score macro rnn1 : 0.433
# F1-score None rnn1 : [0.768 0.191 0.144 0.629]
#
# ------ Training ------
# Accuracy rnn2 : 0.925
# F1-score macro rnn2 : 0.924
# F1-score None rnn2 : [0.874 0.989 0.954 0.88 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.800
# F1-score macro rnn2 : 0.451
# F1-score None rnn2 : [0.884 0.101 0.064 0.756]
#
# ------ Testing ------
# Accuracy rnn2 : 0.750
# F1-score macro rnn2 : 0.467
# F1-score None rnn2 : [0.856 0.12  0.251 0.64 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.905
# F1-score macro rnn3 : 0.904
# F1-score None rnn3 : [0.852 0.95  0.964 0.848]
#
# ------ Validation ------
# Accuracy rnn3 : 0.823
# F1-score macro rnn3 : 0.470
# F1-score None rnn3 : [0.896 0.135 0.031 0.817]
#
# ------ Testing ------
# Accuracy rnn3 : 0.781
# F1-score macro rnn3 : 0.507
# F1-score None rnn3 : [0.871 0.208 0.182 0.766]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.942
# F1-score macro cnn1 : 0.942
# F1-score None cnn1 : [0.885 0.996 0.995 0.89 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.836
# F1-score macro cnn1 : 0.443
# F1-score None cnn1 : [0.901 0.068 0.038 0.766]
#
# ------ Testing ------
# Accuracy cnn1 : 0.811
# F1-score macro cnn1 : 0.439
# F1-score None cnn1 : [0.893 0.016 0.152 0.694]
#
# ------ Training ------
# Accuracy cnn2 : 0.934
# F1-score macro cnn2 : 0.934
# F1-score None cnn2 : [0.88  0.994 0.991 0.872]
#
# ------ Validation ------
# Accuracy cnn2 : 0.865
# F1-score macro cnn2 : 0.455
# F1-score None cnn2 : [0.918 0.048 0.05  0.806]
#
# ------ Testing ------
# Accuracy cnn2 : 0.835
# F1-score macro cnn2 : 0.447
# F1-score None cnn2 : [0.906 0.088 0.069 0.724]
#
# ------ Training ------
# Accuracy rnn1 : 0.873
# F1-score macro rnn1 : 0.872
# F1-score None rnn1 : [0.831 0.961 0.9   0.794]
#
# ------ Validation ------
# Accuracy rnn1 : 0.785
# F1-score macro rnn1 : 0.458
# F1-score None rnn1 : [0.89  0.145 0.077 0.718]
#
# ------ Testing ------
# Accuracy rnn1 : 0.772
# F1-score macro rnn1 : 0.494
# F1-score None rnn1 : [0.878 0.216 0.215 0.668]
#
# ------ Training ------
# Accuracy rnn2 : 0.922
# F1-score macro rnn2 : 0.921
# F1-score None rnn2 : [0.868 0.985 0.963 0.87 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.800
# F1-score macro rnn2 : 0.423
# F1-score None rnn2 : [0.885 0.025 0.047 0.737]
#
# ------ Testing ------
# Accuracy rnn2 : 0.759
# F1-score macro rnn2 : 0.434
# F1-score None rnn2 : [0.864 0.016 0.209 0.645]
#
# ------ Training ------
# Accuracy rnn3 : 0.851
# F1-score macro rnn3 : 0.855
# F1-score None rnn3 : [0.806 0.898 0.925 0.792]
#
# ------ Validation ------
# Accuracy rnn3 : 0.799
# F1-score macro rnn3 : 0.422
# F1-score None rnn3 : [0.87  0.047 0.036 0.735]
#
# ------ Testing ------
# Accuracy rnn3 : 0.743
# F1-score macro rnn3 : 0.424
# F1-score None rnn3 : [0.846 0.032 0.218 0.601]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.914
# F1-score macro cnn1 : 0.912
# F1-score None cnn1 : [0.859 0.986 0.987 0.817]
#
# ------ Validation ------
# Accuracy cnn1 : 0.837
# F1-score macro cnn1 : 0.481
# F1-score None cnn1 : [0.903 0.211 0.036 0.774]
#
# ------ Testing ------
# Accuracy cnn1 : 0.808
# F1-score macro cnn1 : 0.468
# F1-score None cnn1 : [0.889 0.168 0.115 0.7  ]
#
# ------ Training ------
# Accuracy cnn2 : 0.914
# F1-score macro cnn2 : 0.912
# F1-score None cnn2 : [0.856 0.984 0.989 0.82 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.830
# F1-score macro cnn2 : 0.481
# F1-score None cnn2 : [0.897 0.194 0.063 0.771]
#
# ------ Testing ------
# Accuracy cnn2 : 0.777
# F1-score macro cnn2 : 0.449
# F1-score None cnn2 : [0.869 0.166 0.157 0.603]
#
# ------ Training ------
# Accuracy rnn1 : 0.841
# F1-score macro rnn1 : 0.832
# F1-score None rnn1 : [0.699 0.954 0.888 0.789]
#
# ------ Validation ------
# Accuracy rnn1 : 0.560
# F1-score macro rnn1 : 0.353
# F1-score None rnn1 : [0.659 0.109 0.039 0.604]
#
# ------ Testing ------
# Accuracy rnn1 : 0.499
# F1-score macro rnn1 : 0.368
# F1-score None rnn1 : [0.622 0.204 0.169 0.476]
#
# ------ Training ------
# Accuracy rnn2 : 0.942
# F1-score macro rnn2 : 0.942
# F1-score None rnn2 : [0.891 0.993 0.988 0.896]
#
# ------ Validation ------
# Accuracy rnn2 : 0.856
# F1-score macro rnn2 : 0.463
# F1-score None rnn2 : [0.914 0.093 0.036 0.809]
#
# ------ Testing ------
# Accuracy rnn2 : 0.835
# F1-score macro rnn2 : 0.464
# F1-score None rnn2 : [0.906 0.05  0.138 0.761]
#
# ------ Training ------
# Accuracy rnn3 : 0.859
# F1-score macro rnn3 : 0.855
# F1-score None rnn3 : [0.828 0.962 0.873 0.755]
#
# ------ Validation ------
# Accuracy rnn3 : 0.698
# F1-score macro rnn3 : 0.422
# F1-score None rnn3 : [0.833 0.147 0.046 0.663]
#
# ------ Testing ------
# Accuracy rnn3 : 0.661
# F1-score macro rnn3 : 0.454
# F1-score None rnn3 : [0.79  0.201 0.206 0.619]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.935
# F1-score macro cnn1 : 0.935
# F1-score None cnn1 : [0.884 0.994 0.991 0.871]
#
# ------ Validation ------
# Accuracy cnn1 : 0.870
# F1-score macro cnn1 : 0.452
# F1-score None cnn1 : [0.923 0.025 0.05  0.81 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.839
# F1-score macro cnn1 : 0.432
# F1-score None cnn1 : [0.909 0.062 0.023 0.731]
#
# ------ Training ------
# Accuracy cnn2 : 0.939
# F1-score macro cnn2 : 0.939
# F1-score None cnn2 : [0.885 0.994 0.992 0.885]
#
# ------ Validation ------
# Accuracy cnn2 : 0.846
# F1-score macro cnn2 : 0.487
# F1-score None cnn2 : [0.906 0.171 0.07  0.799]
#
# ------ Testing ------
# Accuracy cnn2 : 0.809
# F1-score macro cnn2 : 0.483
# F1-score None cnn2 : [0.888 0.158 0.17  0.715]
#
# ------ Training ------
# Accuracy rnn1 : 0.838
# F1-score macro rnn1 : 0.825
# F1-score None rnn1 : [0.817 0.968 0.88  0.633]
#
# ------ Validation ------
# Accuracy rnn1 : 0.780
# F1-score macro rnn1 : 0.438
# F1-score None rnn1 : [0.902 0.185 0.052 0.614]
#
# ------ Testing ------
# Accuracy rnn1 : 0.756
# F1-score macro rnn1 : 0.420
# F1-score None rnn1 : [0.878 0.213 0.223 0.365]
#
# ------ Training ------
# Accuracy rnn2 : 0.863
# F1-score macro rnn2 : 0.862
# F1-score None rnn2 : [0.814 0.982 0.842 0.809]
#
# ------ Validation ------
# Accuracy rnn2 : 0.670
# F1-score macro rnn2 : 0.423
# F1-score None rnn2 : [0.802 0.143 0.061 0.686]
#
# ------ Testing ------
# Accuracy rnn2 : 0.641
# F1-score macro rnn2 : 0.427
# F1-score None rnn2 : [0.787 0.166 0.172 0.581]
#
# ------ Training ------
# Accuracy rnn3 : 0.886
# F1-score macro rnn3 : 0.884
# F1-score None rnn3 : [0.843 0.973 0.914 0.807]
#
# ------ Validation ------
# Accuracy rnn3 : 0.767
# F1-score macro rnn3 : 0.458
# F1-score None rnn3 : [0.863 0.176 0.052 0.74 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.741
# F1-score macro rnn3 : 0.462
# F1-score None rnn3 : [0.855 0.149 0.199 0.645]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.939
# F1-score macro cnn1 : 0.939
# F1-score None cnn1 : [0.887 0.996 0.991 0.881]
#
# ------ Validation ------
# Accuracy cnn1 : 0.873
# F1-score macro cnn1 : 0.461
# F1-score None cnn1 : [0.924 0.052 0.053 0.815]
#
# ------ Testing ------
# Accuracy cnn1 : 0.844
# F1-score macro cnn1 : 0.423
# F1-score None cnn1 : [0.913 0.017 0.025 0.737]
#
# ------ Training ------
# Accuracy cnn2 : 0.919
# F1-score macro cnn2 : 0.918
# F1-score None cnn2 : [0.862 0.946 0.989 0.874]
#
# ------ Validation ------
# Accuracy cnn2 : 0.782
# F1-score macro cnn2 : 0.471
# F1-score None cnn2 : [0.859 0.175 0.049 0.803]
# ------ Testing ------
# Accuracy cnn2 : 0.717
# F1-score macro cnn2 : 0.440
# F1-score None cnn2 : [0.826 0.172 0.047 0.716]
#
# ------ Training ------
# Accuracy rnn1 : 0.832
# F1-score macro rnn1 : 0.827
# F1-score None rnn1 : [0.769 0.869 0.93  0.738]
#
# ------ Validation ------
# Accuracy rnn1 : 0.672
# F1-score macro rnn1 : 0.430
# F1-score None rnn1 : [0.793 0.132 0.088 0.706]
#
# ------ Testing ------
# Accuracy rnn1 : 0.618
# F1-score macro rnn1 : 0.431
# F1-score None rnn1 : [0.764 0.188 0.244 0.527]
#
# ------ Training ------
# Accuracy rnn2 : 0.899
# F1-score macro rnn2 : 0.897
# F1-score None rnn2 : [0.831 0.981 0.912 0.864]
#
# ------ Validation ------
# Accuracy rnn2 : 0.715
# F1-score macro rnn2 : 0.422
# F1-score None rnn2 : [0.824 0.124 0.033 0.705]
#
# ------ Testing ------
# Accuracy rnn2 : 0.672
# F1-score macro rnn2 : 0.439
# F1-score None rnn2 : [0.802 0.172 0.181 0.601]
#
# ------ Training ------
# Accuracy rnn3 : 0.812
# F1-score macro rnn3 : 0.807
# F1-score None rnn3 : [0.835 0.951 0.788 0.652]
#
# ------ Validation ------
# Accuracy rnn3 : 0.711
# F1-score macro rnn3 : 0.430
# F1-score None rnn3 : [0.87  0.161 0.069 0.619]
#
# ------ Testing ------
# Accuracy rnn3 : 0.696
# F1-score macro rnn3 : 0.431
# F1-score None rnn3 : [0.851 0.2   0.163 0.512]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.85 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.85 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.85 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.85 Clase Ponderado - F1-score promedio para cnn1 : [0.901 0.077 0.073 0.72 ]
# 0.85 Clase Ponderado - F1-score promedio para cnn2 : [0.879 0.136 0.093 0.7  ]
# 0.85 Clase Ponderado - F1-score promedio para rnn1 : [0.782 0.202 0.199 0.533]
# 0.85 Clase Ponderado - F1-score promedio para rnn2 : [0.843 0.105 0.19  0.645]
# 0.85 Clase Ponderado - F1-score promedio para rnn3 : [0.842 0.158 0.194 0.629]
#
# 0.85 Clase Ponderado - F1-score macro promedio para cnn1 : 0.4427067682639917 desvest:  0.015982307033809855
# 0.85 Clase Ponderado - F1-score macro promedio para cnn2 : 0.4519713422785198 desvest:  0.015810236693785396
# 0.85 Clase Ponderado - F1-score macro promedio para rnn1 : 0.4290963829795218 desvest:  0.040417755303313
# 0.85 Clase Ponderado - F1-score macro promedio para rnn2 : 0.44592928979385127 desvest:  0.0163093724482105
# 0.85 Clase Ponderado - F1-score macro promedio para rnn3 : 0.45560897897231334 desvest:  0.029062968332942165
#
# 0.85 Clase Ponderado - Accuracy promedio para cnn1 : 0.8246820536975978 desvest:  0.014381203683286957
# 0.85 Clase Ponderado - Accuracy promedio para cnn2 : 0.7941592086669806 desvest:  0.04372837404580261
# 0.85 Clase Ponderado - Accuracy promedio para rnn1 : 0.6558643429109751 desvest:  0.10018902161887414
# 0.85 Clase Ponderado - Accuracy promedio para rnn2 : 0.7314178049929345 desvest:  0.06859125270815057
# 0.85 Clase Ponderado - Accuracy promedio para rnn3 : 0.7246349505416863 desvest:  0.041607420374788866

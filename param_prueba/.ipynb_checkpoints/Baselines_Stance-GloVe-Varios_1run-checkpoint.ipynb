# %%
from tools_stance import * 
from models import *
import torch 
import pandas as pd

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")


dict_cl=dict()
dict_cl[0]="support"
dict_cl[1]="denying"
dict_cl[2]="questioning"
dict_cl[3]="commenting"

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

path="../Datasets/CSV_Stance/"
train =pd.read_csv(path + "train_semeval_raw.csv")
val=pd.read_csv(path + "dev_semeval_raw.csv")
test=pd.read_csv(path + "test_semeval_raw.csv")

stoplist = stopwords.words("english")
puntos='!?."()[´]“<>¡¿-/;:=_”@#.'
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
import seaborn as sns
sns.set(font_scale=1)
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,7))
j=220
labs=['support', 'denying', 'questioning', 'commenting']
data=[train['Label'], val['Label'], test["Label"]]
name=["Training", "Validation", "Testing"]
for i in range(3):
    j+=1
    h=fig.add_subplot(j)
    ax= sns.countplot(data[i], order=labs)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=12)
    h.title.set_text(str(name[i]))

fig.suptitle("RumourEval task A - Distribución de etiquetas", fontsize=14)
plt.show()

# %%
def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("------ Training ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)
    
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("------ Validation ------")
    print ("Accuracy", name_model, ": %.3f" % acc)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("------ Testing ------")
    print ("Accuracy", name_model, ": %.3f" % acc_t)     
    print ("F1-score macro", name_model, ": %.3f" % f1_ma_t)
    np.set_printoptions(precision=3)
    print ("F1-score None", name_model, ":", f1_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

def cleaner(post): 
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=token_2_idx[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in token_2_idx.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in token_2_idx.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
import os 
embeddings_index = {}
token_2_idx={}
idx_2_token={}
f = open(os.path.join("../Datasets/glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
i=0
for line in f:
    values = line.split()
    if len(values)>200:
        word = values[0]
    else:
        #print ("Problema con line ", line)
        continue
    token_2_idx[word]=i
    idx_2_token[i]=word
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
    i+=1
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# Se encontraron 1193513 terminos con sus vectores de embedding.

# %%
MAX_LEN = 37
emb=200
EMB_matrix=np.zeros((len(token_2_idx.keys()), emb))
for i in range(len(token_2_idx.keys())):
    EMB_matrix[i]=embeddings_index[idx_2_token[i]]
    
transformer = Normalizer().fit(EMB_matrix) 
EMB_matrix=transformer.transform(EMB_matrix)
EMB_matrix.shape
# Out:
# (1193513, 200)

# %%
ids_train=train['Tw_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
#class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)

ids_val=val['Tw_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

ids_test=test['Tw_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]
# Out:
# Pesos de clases: [1.25980975 3.18168168 3.21060606 0.38752743]

# %%
sentences = tws_train
n_labels = np.asarray(labels_train)
y_train=to_categorical(n_labels,num_classes=4)

sentences_val = tws_val
n_labels_val = np.array(labels_val)
y_val=to_categorical(n_labels_val,num_classes=4)

sentences_test = tws_test
n_labels_test = np.array(labels_test)
y_test=to_categorical(n_labels_test,num_classes=4)

# %%
input_ids=[]
for sent in sentences:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids.append(encoded_sent) 
    
input_ids_val=[]
for sent in sentences_val:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_val.append(encoded_sent) 

input_ids_test=[]
for sent in sentences_test:
    encoded_sent=[]
    for wd in cleaner(sent)[1]:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids_test.append(encoded_sent)

# %%
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
shape_val=np.asarray(input_ids_val).shape
shape_test=np.asarray(input_ids_test).shape

# %%
x_train=np.zeros((shape[0], shape[1], emb))
j=0
for in_id in input_ids:
    x_train[j]=EMB_matrix[in_id]
    j+=1
    
x_val=np.zeros((shape_val[0], shape_val[1], emb))
i=0
for in_id in input_ids_val:
    x_val[i]=EMB_matrix[in_id]
    i+=1
    
x_test=np.zeros((shape_test[0], shape_test[1], emb))
i=0
for in_id in input_ids_test:
    x_test[i]=EMB_matrix[in_id]
    i+=1

# %%
x_train.shape
# Out:
# (4238, 37, 200)

# %%
x_test.shape
# Out:
# (1021, 37, 200)

# %% [markdown]
# ## Original - No aumento

# %%
fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\nEntrenando exec ", i,"\n")
    cnn1=create_ccn1(x_train.shape[1:])
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=20, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/cnn1_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch CNN1")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch CNN1")
    plt.show()
    
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=20, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/cnn2_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch CNN2")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch CNN2")
    plt.show()
    
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=10, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn1_'+str(i)+'-exec_8.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN1")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN1")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=20, BS=32, verb=0, focal=False)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn2_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN2")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN2")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=10, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn3_'+str(i)+'-exec_8.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN3")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN3")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# Entrenando exec  1
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ------ Training ------
# Accuracy cnn1 : 0.653610193487494
# F1-score None cnn1 : [0.58218319 0.4628821  0.57860465 0.72909425]
# F1-score macro cnn1 : 0.5881910472343388
#
# ------ Validation ------
# Accuracy cnn1 : 0.6512455516014235
# F1-score None cnn1 : [0.58992806 0.30769231 0.6        0.73684211]
# F1-score macro cnn1 : 0.5586156176273556
#
# ------ Testing ------
# Accuracy cnn1 : 0.6023506366307542
# F1-score None cnn1 : [0.125      0.23275862 0.53797468 0.72474378]
# F1-score macro cnn1 : 0.4051192704215937
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# ------ Training ------
# Accuracy cnn2 : 0.5422369042000944
# F1-score None cnn2 : [0.58231293 0.33504274 0.44460127 0.61507128]
# F1-score macro cnn2 : 0.4942570533994674
#
# ------ Validation ------
# Accuracy cnn2 : 0.5800711743772242
# F1-score None cnn2 : [0.57575758 0.13333333 0.52631579 0.66896552]
# F1-score macro cnn2 : 0.47609305395149315
#
# ------ Testing ------
# Accuracy cnn2 : 0.49951028403525954
# F1-score None cnn2 : [0.11570248 0.2        0.45255474 0.62113821]
# F1-score macro cnn2 : 0.347348858811626
# ------ Training ------
# Accuracy rnn1 : 0.32468145351580935
# F1-score None rnn1 : [0.55267703 0.17094017 0.25777041 0.2979351 ]
# F1-score macro rnn1 : 0.3198306784559096
#
# ------ Validation ------
# Accuracy rnn1 : 0.3665480427046263
# F1-score None rnn1 : [0.56756757 0.         0.32298137 0.3196347 ]
# F1-score macro rnn1 : 0.3025459093058855
#
# ------ Testing ------
# Accuracy rnn1 : 0.25857002938295787
# F1-score None rnn1 : [0.2        0.15447154 0.29640719 0.27155172]
# F1-score macro rnn1 : 0.23060761362053017
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# ------ Training ------
# Accuracy rnn2 : 0.6939594148183105
# F1-score None rnn2 : [0.55364455 0.08602151 0.46511628 0.81246698]
# F1-score macro rnn2 : 0.4793123304286357
#
# ------ Validation ------
# Accuracy rnn2 : 0.701067615658363
# F1-score None rnn2 : [0.52252252 0.16666667 0.62337662 0.79005525]
# F1-score macro rnn2 : 0.5256552652961493
#
# ------ Testing ------
# Accuracy rnn2 : 0.702252693437806
# F1-score None rnn2 : [0.05128205 0.12345679 0.46242775 0.81977879]
# F1-score macro rnn2 : 0.3642363442301515
# ------ Training ------
# Accuracy rnn3 : 0.2888154789995281
# F1-score None rnn3 : [0.37842997 0.01173021 0.4874477  0.13119143]
# F1-score macro rnn3 : 0.252199826350191
#
# ------ Validation ------
# Accuracy rnn3 : 0.3274021352313167
# F1-score None rnn3 : [0.41471572 0.         0.70422535 0.05524862]
# F1-score macro rnn3 : 0.29354742249018795
#
# ------ Testing ------
# Accuracy rnn3 : 0.1939275220372184
# F1-score None rnn3 : [0.14165666 0.         0.5862069  0.12735849]
# F1-score macro rnn3 : 0.213805512445707
#
# Entrenando exec  2
# ------ Training ------
# Accuracy cnn1 : 0.6304860783388391
# F1-score None cnn1 : [0.58237548 0.40510638 0.63851699 0.70025189]
# F1-score macro cnn1 : 0.5815626859664074
#
# ------ Validation ------
# Accuracy cnn1 : 0.6298932384341637
# F1-score None cnn1 : [0.53731343 0.28571429 0.64705882 0.72025723]
# F1-score macro cnn1 : 0.5475859442015516
#
# ------ Testing ------
# Accuracy cnn1 : 0.5905974534769833
# F1-score None cnn1 : [0.11666667 0.22291022 0.6119403  0.71825695]
# F1-score macro cnn1 : 0.41744353288857605
# ------ Training ------
# Accuracy cnn2 : 0.5792826805096744
# F1-score None cnn2 : [0.59030303 0.38383838 0.46372688 0.64959152]
# F1-score macro cnn2 : 0.5218649550570156
#
# ------ Validation ------
# Accuracy cnn2 : 0.5800711743772242
# F1-score None cnn2 : [0.58992806 0.15384615 0.52631579 0.65051903]
# F1-score macro cnn2 : 0.4801522580039158
#
# ------ Testing ------
# Accuracy cnn2 : 0.5416258570029383
# F1-score None cnn2 : [0.21192053 0.23931624 0.46268657 0.66294821]
# F1-score macro cnn2 : 0.3942178858632644
# ------ Training ------
# Accuracy rnn1 : 0.24775837659273242
# F1-score None rnn1 : [0.55210918 0.16659927 0.35967302 0.09237085]
# F1-score macro rnn1 : 0.29268808241705624
#
# ------ Validation ------
# Accuracy rnn1 : 0.28113879003558717
# F1-score None rnn1 : [0.57746479 0.032      0.48598131 0.10638298]
# F1-score macro rnn1 : 0.3004572689667534
#
# ------ Testing ------
# Accuracy rnn1 : 0.1929480901077375
# F1-score None rnn1 : [0.18079096 0.17418351 0.46943765 0.07134071]
# F1-score macro rnn1 : 0.22393821036133552
# ------ Training ------
# Accuracy rnn2 : 0.7180273714016046
# F1-score None rnn2 : [0.65629053 0.25401929 0.54739336 0.81455743]
# F1-score macro rnn2 : 0.5680651535821533
#
# ------ Validation ------
# Accuracy rnn2 : 0.6654804270462633
# F1-score None rnn2 : [0.62068966 0.15384615 0.52307692 0.75460123]
# F1-score macro rnn2 : 0.5130534897723389
#
# ------ Testing ------
# Accuracy rnn2 : 0.6356513222331048
# F1-score None rnn2 : [0.2208589  0.13095238 0.47389558 0.76744186]
# F1-score macro rnn2 : 0.398287179863084
# ------ Training ------
# Accuracy rnn3 : 0.3473336479471449
# F1-score None rnn3 : [0.55916616 0.12947977 0.25844102 0.36302709]
# F1-score macro rnn3 : 0.3275285072537534
#
# ------ Validation ------
# Accuracy rnn3 : 0.39501779359430605
# F1-score None rnn3 : [0.57534247 0.         0.32911392 0.37554585]
# F1-score macro rnn3 : 0.3200005603331105
#
# ------ Testing ------
# Accuracy rnn3 : 0.31047992164544563
# F1-score None rnn3 : [0.24390244 0.14814815 0.28328612 0.3723296 ]
# F1-score macro rnn3 : 0.26191657735201224
#
# Entrenando exec  3
# ------ Training ------
# Accuracy cnn1 : 0.39570552147239263
# F1-score None cnn1 : [0.58293515 0.2748538  0.44413602 0.36839113]
# F1-score macro cnn1 : 0.41757902568323135
#
# ------ Validation ------
# Accuracy cnn1 : 0.3914590747330961
# F1-score None cnn1 : [0.528      0.09009009 0.4950495  0.41777778]
# F1-score macro cnn1 : 0.38272934320459073
#
# ------ Testing ------
# Accuracy cnn1 : 0.3006856023506366
# F1-score None cnn1 : [0.11428571 0.17770035 0.46568627 0.32460733]
# F1-score macro cnn1 : 0.2705699167676265
# ------ Training ------
# Accuracy cnn2 : 0.5792826805096744
# F1-score None cnn2 : [0.55664336 0.34429066 0.49310624 0.66738244]
# F1-score macro cnn2 : 0.5153556735144713
#
# ------ Validation ------
# Accuracy cnn2 : 0.6120996441281139
# F1-score None cnn2 : [0.57142857 0.17021277 0.56818182 0.71096346]
# F1-score macro cnn2 : 0.5051966526793346
#
# ------ Testing ------
# Accuracy cnn2 : 0.5475024485798237
# F1-score None cnn2 : [0.09708738 0.2027027  0.51540616 0.6718507 ]
# F1-score macro cnn2 : 0.37176173591323614
# ------ Training ------
# Accuracy rnn1 : 0.2104766399244927
# F1-score None rnn1 : [0.55807744 0.05168986 0.18366197 0.09230769]
# F1-score macro rnn1 : 0.22143424038894444
#
# ------ Validation ------
# Accuracy rnn1 : 0.24555160142348753
# F1-score None rnn1 : [0.54814815 0.         0.23893805 0.05464481]
# F1-score macro rnn1 : 0.21043275249716564
#
# ------ Testing ------
# Accuracy rnn1 : 0.14397649363369247
# F1-score None rnn1 : [0.14634146 0.02040816 0.20682731 0.08242424]
# F1-score macro rnn1 : 0.11400029458528262
# ------ Training ------
# Accuracy rnn2 : 0.7491741387446909
# F1-score None rnn2 : [0.6595144  0.13881748 0.62883436 0.83298023]
# F1-score macro rnn2 : 0.5650366152953873
#
# ------ Validation ------
# Accuracy rnn2 : 0.6761565836298933
# F1-score None rnn2 : [0.58598726 0.         0.57142857 0.76190476]
# F1-score macro rnn2 : 0.4798301486199575
#
# ------ Testing ------
# Accuracy rnn2 : 0.7140058765915769
# F1-score None rnn2 : [0.24731183 0.04494382 0.5177665  0.83184713]
# F1-score macro rnn2 : 0.41046731985039975
# ------ Training ------
# Accuracy rnn3 : 0.41599811231713074
# F1-score None rnn3 : [0.55899198 0.09964413 0.26751592 0.48010076]
# F1-score macro rnn3 : 0.3515631972551646
#
# ------ Validation ------
# Accuracy rnn3 : 0.47686832740213525
# F1-score None rnn3 : [0.6        0.         0.36363636 0.5060241 ]
# F1-score macro rnn3 : 0.3674151150054764
#
# ------ Testing ------
# Accuracy rnn3 : 0.38491674828599415
# F1-score None rnn3 : [0.23404255 0.11382114 0.30769231 0.48843663]
# F1-score macro rnn3 : 0.2859981579606588
#
# Entrenando exec  4
# ------ Training ------
# Accuracy cnn1 : 0.6323737612081171
# F1-score None cnn1 : [0.60223464 0.44214162 0.66243386 0.68601353]
# F1-score macro cnn1 : 0.5982059127626862
#
# ------ Validation ------
# Accuracy cnn1 : 0.604982206405694
# F1-score None cnn1 : [0.56774194 0.17777778 0.64788732 0.68041237]
# F1-score macro cnn1 : 0.5184548520848328
#
# ------ Testing ------
# Accuracy cnn1 : 0.555337904015671
# F1-score None cnn1 : [0.29189189 0.22492401 0.58426966 0.6740682 ]
# F1-score macro cnn1 : 0.44378844170317255
# ------ Training ------
# Accuracy cnn2 : 0.6396885323265691
# F1-score None cnn2 : [0.58018253 0.3577431  0.56117755 0.72162485]
# F1-score macro cnn2 : 0.55518200753224
#
# ------ Validation ------
# Accuracy cnn2 : 0.6512455516014235
# F1-score None cnn2 : [0.5942029  0.17142857 0.64788732 0.72955975]
# F1-score macro cnn2 : 0.5357696355876578
#
# ------ Testing ------
# Accuracy cnn2 : 0.6150832517140059
# F1-score None cnn2 : [0.1147541  0.20627803 0.53374233 0.74544128]
# F1-score macro cnn2 : 0.40005393507233233
# ------ Training ------
# Accuracy rnn1 : 0.4601226993865031
# F1-score None rnn1 : [0.46451133 0.17868676 0.51327434 0.51119311]
# F1-score macro rnn1 : 0.4169163855619499
#
# ------ Validation ------
# Accuracy rnn1 : 0.4875444839857651
# F1-score None rnn1 : [0.5046729  0.15384615 0.65714286 0.47698745]
# F1-score macro rnn1 : 0.4481623389710044
#
# ------ Testing ------
# Accuracy rnn1 : 0.40744368266405484
# F1-score None rnn1 : [0.16708861 0.13571429 0.65271967 0.5070922 ]
# F1-score macro rnn1 : 0.3656536892906873
# ------ Training ------
# Accuracy rnn2 : 0.7730061349693251
# F1-score None rnn2 : [0.65416667 0.28701595 0.65047233 0.85416667]
# F1-score macro rnn2 : 0.6114554033366226
#
# ------ Validation ------
# Accuracy rnn2 : 0.708185053380783
# F1-score None rnn2 : [0.56692913 0.26666667 0.6440678  0.7867036 ]
# F1-score macro rnn2 : 0.5660917995607843
#
# ------ Testing ------
# Accuracy rnn2 : 0.7091087169441724
# F1-score None rnn2 : [0.11111111 0.10752688 0.55357143 0.82099937]
# F1-score macro rnn2 : 0.3983021972229752
# ------ Training ------
# Accuracy rnn3 : 0.4738084001887683
# F1-score None rnn3 : [0.53912111 0.16347124 0.37864769 0.54959658]
# F1-score macro rnn3 : 0.4077091563765662
#
# ------ Validation ------
# Accuracy rnn3 : 0.5160142348754448
# F1-score None rnn3 : [0.53571429 0.         0.53608247 0.56273764]
# F1-score macro rnn3 : 0.40863360063166027
#
# ------ Testing ------
# Accuracy rnn3 : 0.43290891283055827
# F1-score None rnn3 : [0.16740088 0.19762846 0.43925234 0.5361552 ]
# F1-score macro rnn3 : 0.33510921970644003
#
# Entrenando exec  5
# ------ Training ------
# Accuracy cnn1 : 0.6387446908919302
# F1-score None cnn1 : [0.58815959 0.388      0.60079051 0.71364562]
# F1-score macro cnn1 : 0.5726489307937108
#
# ------ Validation ------
# Accuracy cnn1 : 0.6583629893238434
# F1-score None cnn1 : [0.56934307 0.23529412 0.66666667 0.73981191]
# F1-score macro cnn1 : 0.5527789405582153
#
# ------ Testing ------
# Accuracy cnn1 : 0.6023506366307542
# F1-score None cnn1 : [0.10169492 0.20477816 0.58394161 0.73544584]
# F1-score macro cnn1 : 0.40646512862351813
# ------ Training ------
# Accuracy cnn2 : 0.4110429447852761
# F1-score None cnn2 : [0.57823129 0.23727273 0.54864154 0.40545703]
# F1-score macro cnn2 : 0.44240064705429516
#
# ------ Validation ------
# Accuracy cnn2 : 0.398576512455516
# F1-score None cnn2 : [0.546875   0.09677419 0.65789474 0.39316239]
# F1-score macro cnn2 : 0.42367658088822135
#
# ------ Testing ------
# Accuracy cnn2 : 0.3379040156709109
# F1-score None cnn2 : [0.12068966 0.1858864  0.50609756 0.39528024]
# F1-score macro cnn2 : 0.3019884637225242
# ------ Training ------
# Accuracy rnn1 : 0.30863614912694665
# F1-score None rnn1 : [0.50403587 0.17647059 0.39166046 0.20826759]
# F1-score macro rnn1 : 0.3201086291570455
#
# ------ Validation ------
# Accuracy rnn1 : 0.35587188612099646
# F1-score None rnn1 : [0.54255319 0.07228916 0.55319149 0.20304569]
# F1-score macro rnn1 : 0.3427698806891894
#
# ------ Testing ------
# Accuracy rnn1 : 0.23996082272282077
# F1-score None rnn1 : [0.1704918  0.17429194 0.45273632 0.20091324]
# F1-score macro rnn1 : 0.24960832567340063
# ------ Training ------
# Accuracy rnn2 : 0.766635205285512
# F1-score None rnn2 : [0.66043165 0.30111524 0.63989637 0.85249307]
# F1-score macro rnn2 : 0.6134840860402964
#
# ------ Validation ------
# Accuracy rnn2 : 0.7153024911032029
# F1-score None rnn2 : [0.57142857 0.2        0.5862069  0.8109589 ]
# F1-score macro rnn2 : 0.5421485930224712
#
# ------ Testing ------
# Accuracy rnn2 : 0.702252693437806
# F1-score None rnn2 : [0.20967742 0.144      0.47161572 0.81969309]
# F1-score macro rnn2 : 0.411246558627003
# ------ Training ------
# Accuracy rnn3 : 0.3154789995280793
# F1-score None rnn3 : [0.43768023 0.03252033 0.32696629 0.22270742]
# F1-score macro rnn3 : 0.2549685679035399
#
# ------ Validation ------
# Accuracy rnn3 : 0.3665480427046263
# F1-score None rnn3 : [0.48101266 0.         0.44067797 0.20408163]
# F1-score macro rnn3 : 0.281443064245651
#
# ------ Testing ------
# Accuracy rnn3 : 0.24877571008814886
# F1-score None rnn3 : [0.16764133 0.07228916 0.3575419  0.24642464]
# F1-score macro rnn3 : 0.2109742560170389

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("Original - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("Original - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("Original - Accuracy promedio para",key,":" ,temp/5)
# Out:
# Original - F1-score promedio para cnn1 : [0.14990784 0.21261427 0.55676251 0.63542442]
# Original - F1-score promedio para cnn2 : [0.13203083 0.20683667 0.49409747 0.61933173]
# Original - F1-score promedio para rnn1 : [0.17294257 0.13181389 0.41562563 0.22666442]
# Original - F1-score promedio para rnn2 : [0.16804826 0.11017597 0.49585539 0.81195205]
# Original - F1-score promedio para rnn3 : [0.19092877 0.10637738 0.39479591 0.35414091]
#
# Original - F1-score macro promedio para cnn1 : 0.38867725808089737 desvest:  0.060664377202607346
# Original - F1-score macro promedio para cnn2 : 0.3630741758765966 desvest:  0.035753760046916834
# Original - F1-score macro promedio para rnn1 : 0.23676162670624726 desvest:  0.08006354728533052
# Original - F1-score macro promedio para rnn2 : 0.3965079199587227 desvest:  0.017087610200628215
# Original - F1-score macro promedio para rnn3 : 0.26156074469637136 desvest:  0.04657520156575645
#
# Original - Accuracy promedio para cnn1 : 0.5302644466209598
# Original - Accuracy promedio para cnn2 : 0.5083251714005876
# Original - Accuracy promedio para rnn1 : 0.24857982370225268
# Original - Accuracy promedio para rnn2 : 0.6926542605288932
# Original - Accuracy promedio para rnn3 : 0.31420176297747304

# %%
macro_augmented = np.load('../Datasets/CSV_Stance/balance_clase_Pon_GloVe.npy', allow_pickle=True)
np.random.shuffle(macro_augmented)

ids_train=macro_augmented[:,0]
tws_train=macro_augmented[:,1]
labels_train=macro_augmented[:,2]
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)

sentences = tws_train
n_labels = labels_train.copy()

input_ids = []
for sent in sentences:
    encoded_sent = [] 
    for wd in sent:
        try:
            encoded_sent.append(token_2_idx[wd])
        except:
            continue
    input_ids.append(encoded_sent)

input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                          value=0, truncating="post", padding="post")
y_train=to_categorical(n_labels,num_classes=4)
shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], emb))
j=0
for in_id in input_ids:
    x_train[j]=EMB_matrix[in_id]
    j+=1
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\nEntrenando exec ", i,"\n")
    cnn1=create_ccn1(x_train.shape[1:])
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/cnn1_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch CNN1")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch CNN1")
    plt.show()
    
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/cnn2_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch CNN2")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch CNN2")
    plt.show()
    
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn1_'+str(i)+'-exec_8.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN1")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN1")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=False)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn2_'+str(i)+'-exec_15.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN2")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN2")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../new_glove_augmented/harassment_baselines/0.0/rnn3_'+str(i)+'-exec_8.h5')
    plt.plot(hist.history['loss'], label='loss train')
    plt.plot(hist.history['val_loss'],label='loss val')
    plt.legend(loc='upper left')
    plt.title("Loss vs epoch RNN3")
    plt.show()

    plt.plot(hist.history['acc'], label='acc train')
    plt.plot(hist.history['val_acc'],label='acc val')
    plt.legend(loc='upper left')
    plt.title("Accuracy vs epoch RNN3")
    plt.show()
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# Entrenando exec  1
# ------ Training ------
# Accuracy cnn1 : 0.8202267739575714
# F1-score None cnn1 : [0.71666667 0.89264678 0.94480691 0.72360726]
# F1-score macro cnn1 : 0.8194319055511633
#
# ------ Validation ------
# Accuracy cnn1 : 0.7117437722419929
# F1-score None cnn1 : [0.57575758 0.4        0.62686567 0.79883382]
# F1-score macro cnn1 : 0.6003642666603373
#
# ------ Testing ------
# Accuracy cnn1 : 0.7316356513222331
# F1-score None cnn1 : [0.04545455 0.23287671 0.61111111 0.83676093]
# F1-score macro cnn1 : 0.4315508235860738
# ------ Training ------
# Accuracy cnn2 : 0.8179407461594733
# F1-score None cnn2 : [0.73686432 0.88380015 0.94386921 0.71437579]
# F1-score macro cnn2 : 0.8197273666806328
#
# ------ Validation ------
# Accuracy cnn2 : 0.708185053380783
# F1-score None cnn2 : [0.62318841 0.41666667 0.59649123 0.78134111]
# F1-score macro cnn2 : 0.604421852101416
#
# ------ Testing ------
# Accuracy cnn2 : 0.6856023506366308
# F1-score None cnn2 : [0.13333333 0.22966507 0.61538462 0.80428954]
# F1-score macro cnn2 : 0.44566814118105214
# ------ Training ------
# Accuracy rnn1 : 0.6518836869056328
# F1-score None rnn1 : [0.68300654 0.66964593 0.73787625 0.51495146]
# F1-score macro rnn1 : 0.6513700432185487
#
# ------ Validation ------
# Accuracy rnn1 : 0.5516014234875445
# F1-score None rnn1 : [0.54054054 0.17391304 0.6440678  0.60294118]
# F1-score macro rnn1 : 0.4903656392748898
#
# ------ Testing ------
# Accuracy rnn1 : 0.4338883447600392
# F1-score None rnn1 : [0.17475728 0.2311828  0.54634146 0.54844291]
# F1-score macro rnn1 : 0.37518111181033786
# ------ Training ------
# Accuracy rnn2 : 0.797457937088515
# F1-score None rnn2 : [0.77042654 0.8510978  0.89774462 0.67135325]
# F1-score macro rnn2 : 0.7976555529750182
#
# ------ Validation ------
# Accuracy rnn2 : 0.6227758007117438
# F1-score None rnn2 : [0.5751634  0.25       0.54761905 0.69767442]
# F1-score macro rnn2 : 0.5176142162291273
#
# ------ Testing ------
# Accuracy rnn2 : 0.574926542605289
# F1-score None rnn2 : [0.18556701 0.18994413 0.48929664 0.70342772]
# F1-score macro rnn2 : 0.39205887507357007
# ------ Training ------
# Accuracy rnn3 : 0.6456656912948061
# F1-score None rnn3 : [0.69753458 0.61454408 0.73565574 0.49631035]
# F1-score macro rnn3 : 0.6360111875677498
#
# ------ Validation ------
# Accuracy rnn3 : 0.5373665480427047
# F1-score None rnn3 : [0.57746479 0.2173913  0.47169811 0.59701493]
# F1-score macro rnn3 : 0.46589228291522544
#
# ------ Testing ------
# Accuracy rnn3 : 0.40744368266405484
# F1-score None rnn3 : [0.17391304 0.19512195 0.42081448 0.50551471]
# F1-score macro rnn3 : 0.3238410450545337
#
# Entrenando exec  2
# ------ Training ------
# Accuracy cnn1 : 0.8296452084857352
# F1-score None cnn1 : [0.72518747 0.91080166 0.95326423 0.73195402]
# F1-score macro cnn1 : 0.830301845320504
#
# ------ Validation ------
# Accuracy cnn1 : 0.708185053380783
# F1-score None cnn1 : [0.55737705 0.41666667 0.61818182 0.79224377]
# F1-score macro cnn1 : 0.596117325335458
#
# ------ Testing ------
# Accuracy cnn1 : 0.7257590597453477
# F1-score None cnn1 : [0.1        0.2        0.60487805 0.83449588]
# F1-score macro cnn1 : 0.4348434817575823
# ------ Training ------
# Accuracy cnn2 : 0.8261704462326261
# F1-score None cnn2 : [0.73939394 0.89533603 0.9468963  0.72207959]
# F1-score macro cnn2 : 0.8259264648305333
#
# ------ Validation ------
# Accuracy cnn2 : 0.6832740213523132
# F1-score None cnn2 : [0.56692913 0.3125     0.61290323 0.77419355]
# F1-score macro cnn2 : 0.5666314770129539
#
# ------ Testing ------
# Accuracy cnn2 : 0.6885406464250735
# F1-score None cnn2 : [0.10714286 0.25688073 0.62882096 0.80512475]
# F1-score macro cnn2 : 0.4494923247301722
# ------ Training ------
# Accuracy rnn1 : 0.6058888076079005
# F1-score None rnn1 : [0.66859833 0.54096876 0.69968618 0.44362372]
# F1-score macro rnn1 : 0.5882192499845856
#
# ------ Validation ------
# Accuracy rnn1 : 0.49110320284697506
# F1-score None rnn1 : [0.60689655 0.21052632 0.40625    0.50996016]
# F1-score macro rnn1 : 0.4334082567190404
#
# ------ Testing ------
# Accuracy rnn1 : 0.40646425073457393
# F1-score None rnn1 : [0.26976744 0.22026432 0.35606061 0.49813433]
# F1-score macro rnn1 : 0.3360566733649742
# ------ Training ------
# Accuracy rnn2 : 0.8013899049012436
# F1-score None rnn2 : [0.75795017 0.85037264 0.91730666 0.68818614]
# F1-score macro rnn2 : 0.8034539018094686
#
# ------ Validation ------
# Accuracy rnn2 : 0.6370106761565836
# F1-score None rnn2 : [0.59722222 0.17647059 0.57575758 0.71698113]
# F1-score macro rnn2 : 0.516607879572641
#
# ------ Testing ------
# Accuracy rnn2 : 0.6307541625857003
# F1-score None rnn2 : [0.2259887  0.19       0.53174603 0.76150035]
# F1-score macro rnn2 : 0.4273087715420113
# ------ Training ------
# Accuracy rnn3 : 0.6245427944403804
# F1-score None rnn3 : [0.68210117 0.51738693 0.72349526 0.54576857]
# F1-score macro rnn3 : 0.6171879831915073
#
# ------ Validation ------
# Accuracy rnn3 : 0.5871886120996441
# F1-score None rnn3 : [0.61111111 0.20408163 0.58139535 0.64310954]
# F1-score macro rnn3 : 0.509924408309356
#
# ------ Testing ------
# Accuracy rnn3 : 0.4838393731635651
# F1-score None rnn3 : [0.2371134  0.20849421 0.39705882 0.61473328]
# F1-score macro rnn3 : 0.36434992774236813
#
# Entrenando exec  3
# ------ Training ------
# Accuracy cnn1 : 0.8069678127286027
# F1-score None cnn1 : [0.66777409 0.91473163 0.92470464 0.71082727]
# F1-score macro cnn1 : 0.8045094064317362
#
# ------ Validation ------
# Accuracy cnn1 : 0.7046263345195729
# F1-score None cnn1 : [0.51785714 0.45454545 0.63888889 0.79213483]
# F1-score macro cnn1 : 0.60085657943804
#
# ------ Testing ------
# Accuracy cnn1 : 0.7267384916748286
# F1-score None cnn1 : [0.025      0.2189781  0.5509434  0.83717949]
# F1-score macro cnn1 : 0.4080252463989208
# ------ Training ------
# Accuracy cnn2 : 0.813643013899049
# F1-score None cnn2 : [0.74635818 0.87512063 0.92698302 0.7103929 ]
# F1-score macro cnn2 : 0.8147136835251163
#
# ------ Validation ------
# Accuracy cnn2 : 0.7224199288256228
# F1-score None cnn2 : [0.5984252  0.52631579 0.66666667 0.78962536]
# F1-score macro cnn2 : 0.645258253305323
#
# ------ Testing ------
# Accuracy cnn2 : 0.7140058765915769
# F1-score None cnn2 : [0.10619469 0.25       0.62948207 0.82213439]
# F1-score macro cnn2 : 0.4519527873326032
# ------ Training ------
# Accuracy rnn1 : 0.5921726408193123
# F1-score None rnn1 : [0.63729648 0.63172043 0.71325202 0.3439575 ]
# F1-score macro rnn1 : 0.5815566082317276
#
# ------ Validation ------
# Accuracy rnn1 : 0.4804270462633452
# F1-score None rnn1 : [0.49122807 0.21052632 0.68852459 0.45957447]
# F1-score macro rnn1 : 0.4624633610534883
#
# ------ Testing ------
# Accuracy rnn1 : 0.385896180215475
# F1-score None rnn1 : [0.1814059  0.20598007 0.61261261 0.47309833]
# F1-score macro rnn1 : 0.36827422624764816
# ------ Training ------
# Accuracy rnn2 : 0.7944403803950256
# F1-score None rnn2 : [0.77910389 0.84169742 0.89884615 0.67708842]
# F1-score macro rnn2 : 0.7991839716160805
#
# ------ Validation ------
# Accuracy rnn2 : 0.6227758007117438
# F1-score None rnn2 : [0.58503401 0.2173913  0.62068966 0.70096463]
# F1-score macro rnn2 : 0.5310199008376907
#
# ------ Testing ------
# Accuracy rnn2 : 0.6219392752203722
# F1-score None rnn2 : [0.1025641  0.2295082  0.54545455 0.75484765]
# F1-score macro rnn2 : 0.4080936225423306
# ------ Training ------
# Accuracy rnn3 : 0.5397768836869057
# F1-score None rnn3 : [0.6532721  0.26601743 0.64400597 0.51690749]
# F1-score macro rnn3 : 0.5200507475193371
#
# ------ Validation ------
# Accuracy rnn3 : 0.6441281138790036
# F1-score None rnn3 : [0.60689655 0.12121212 0.61333333 0.72491909]
# F1-score macro rnn3 : 0.5165902750301813
#
# ------ Testing ------
# Accuracy rnn3 : 0.6013712047012733
# F1-score None rnn3 : [0.22727273 0.16666667 0.48850575 0.73841555]
# F1-score macro rnn3 : 0.40521517166406607
#
# Entrenando exec  4
# ------ Training ------
# Accuracy cnn1 : 0.8008412582297001
# F1-score None cnn1 : [0.73737153 0.8619281  0.91557996 0.69779468]
# F1-score macro cnn1 : 0.8031685671844512
#
# ------ Validation ------
# Accuracy cnn1 : 0.6654804270462633
# F1-score None cnn1 : [0.48275862 0.15384615 0.58974359 0.76056338]
# F1-score macro cnn1 : 0.4967279361402722
#
# ------ Testing ------
# Accuracy cnn1 : 0.7238001958863859
# F1-score None cnn1 : [0.09803922 0.18947368 0.55813953 0.83031088]
# F1-score macro cnn1 : 0.41899082890238437
# ------ Training ------
# Accuracy cnn2 : 0.7884967081199707
# F1-score None cnn2 : [0.68527919 0.84767086 0.92224735 0.6751312 ]
# F1-score macro cnn2 : 0.7825821489261245
#
# ------ Validation ------
# Accuracy cnn2 : 0.6761565836298933
# F1-score None cnn2 : [0.55737705 0.35       0.66666667 0.76219512]
# F1-score macro cnn2 : 0.5840597094495534
#
# ------ Testing ------
# Accuracy cnn2 : 0.6101860920666013
# F1-score None cnn2 : [0.0625     0.2244898  0.5795053  0.73776479]
# F1-score macro cnn2 : 0.4010649720226426
# ------ Training ------
# Accuracy rnn1 : 0.5200256035113388
# F1-score None rnn1 : [0.63109373 0.56133729 0.54196762 0.15731707]
# F1-score macro rnn1 : 0.47292892761083827
#
# ------ Validation ------
# Accuracy rnn1 : 0.3238434163701068
# F1-score None rnn1 : [0.47257384 0.12048193 0.65454545 0.12834225]
# F1-score macro rnn1 : 0.3439858669770125
#
# ------ Testing ------
# Accuracy rnn1 : 0.21057786483839372
# F1-score None rnn1 : [0.14977974 0.19366853 0.50847458 0.19221968]
# F1-score macro rnn1 : 0.2610356301129832
# ------ Training ------
# Accuracy rnn2 : 0.6896488661302121
# F1-score None rnn2 : [0.75850622 0.65318479 0.87560193 0.43832021]
# F1-score macro rnn2 : 0.6814032876775108
#
# ------ Validation ------
# Accuracy rnn2 : 0.3416370106761566
# F1-score None rnn2 : [0.52554745 0.11464968 0.53061224 0.34703196]
# F1-score macro rnn2 : 0.3794603337881039
#
# ------ Testing ------
# Accuracy rnn2 : 0.31341821743388837
# F1-score None rnn2 : [0.14285714 0.16833096 0.50847458 0.40234375]
# F1-score macro rnn2 : 0.3055016062264475
# ------ Training ------
# Accuracy rnn3 : 0.6571872713972202
# F1-score None rnn3 : [0.66946085 0.63768116 0.77765145 0.52390852]
# F1-score macro rnn3 : 0.6521754966611206
#
# ------ Validation ------
# Accuracy rnn3 : 0.5551601423487544
# F1-score None rnn3 : [0.55263158 0.23255814 0.51612903 0.62043796]
# F1-score macro rnn3 : 0.48043917673617403
#
# ------ Testing ------
# Accuracy rnn3 : 0.46131243878550443
# F1-score None rnn3 : [0.19298246 0.20846906 0.47536232 0.57659208]
# F1-score macro rnn3 : 0.36335147824292563
#
# Entrenando exec  5
# ------ Training ------
# Accuracy cnn1 : 0.8213240673006583
# F1-score None cnn1 : [0.74484536 0.88682965 0.92430833 0.73253087]
# F1-score macro cnn1 : 0.8221285556130172
#
# ------ Validation ------
# Accuracy cnn1 : 0.697508896797153
# F1-score None cnn1 : [0.56692913 0.375      0.62337662 0.77777778]
# F1-score macro cnn1 : 0.5857708837531672
#
# ------ Testing ------
# Accuracy cnn1 : 0.7375122428991185
# F1-score None cnn1 : [0.04123711 0.27118644 0.61029412 0.83858521]
# F1-score macro cnn1 : 0.44032572018257554
# ------ Training ------
# Accuracy cnn2 : 0.748811265544989
# F1-score None cnn2 : [0.74990654 0.6455915  0.94041132 0.64887972]
# F1-score macro cnn2 : 0.7461972708009229
#
# ------ Validation ------
# Accuracy cnn2 : 0.7259786476868327
# F1-score None cnn2 : [0.63013699 0.30769231 0.66666667 0.79525223]
# F1-score macro cnn2 : 0.599937046544908
#
# ------ Testing ------
# Accuracy cnn2 : 0.7149853085210578
# F1-score None cnn2 : [0.26041667 0.11904762 0.58870968 0.82608696]
# F1-score macro cnn2 : 0.44856522991384495
# ------ Training ------
# Accuracy rnn1 : 0.6274689100219458
# F1-score None rnn1 : [0.67826087 0.58023107 0.75907363 0.45390071]
# F1-score macro rnn1 : 0.6178665675618507
#
# ------ Validation ------
# Accuracy rnn1 : 0.5266903914590747
# F1-score None rnn1 : [0.57142857 0.16       0.57831325 0.55172414]
# F1-score macro rnn1 : 0.4653664905929136
#
# ------ Testing ------
# Accuracy rnn1 : 0.39764936336924583
# F1-score None rnn1 : [0.17266187 0.20652174 0.51234568 0.4869403 ]
# F1-score macro rnn1 : 0.34461739678846004
# ------ Training ------
# Accuracy rnn2 : 0.7957205559619605
# F1-score None rnn2 : [0.68822171 0.85458537 0.92728247 0.69289509]
# F1-score macro rnn2 : 0.790746160543446
#
# ------ Validation ------
# Accuracy rnn2 : 0.6405693950177936
# F1-score None rnn2 : [0.53781513 0.23076923 0.58064516 0.75379939]
# F1-score macro rnn2 : 0.5257572275518094
#
# ------ Testing ------
# Accuracy rnn2 : 0.6199804113614104
# F1-score None rnn2 : [0.06       0.21481481 0.51181102 0.75599436]
# F1-score macro rnn2 : 0.38565504917198
# ------ Training ------
# Accuracy rnn3 : 0.5204828090709583
# F1-score None rnn3 : [0.64537265 0.02380094 0.65013462 0.46993431]
# F1-score macro rnn3 : 0.4473106278381809
#
# ------ Validation ------
# Accuracy rnn3 : 0.6192170818505338
# F1-score None rnn3 : [0.57647059 0.         0.56521739 0.68512111]
# F1-score macro rnn3 : 0.45670227170151945
#
# ------ Testing ------
# Accuracy rnn3 : 0.5014691478942214
# F1-score None rnn3 : [0.21011673 0.         0.38271605 0.63843648]
# F1-score macro rnn3 : 0.30781731574622906

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5)
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.15 Clase Ponderado - F1-score promedio para cnn1 : [0.06194617 0.22250299 0.58707324 0.83546648]
# 0.15 Clase Ponderado - F1-score promedio para cnn2 : [0.13391751 0.21601664 0.60838053 0.79908009]
# 0.15 Clase Ponderado - F1-score promedio para rnn1 : [0.18967445 0.21152349 0.50716699 0.43976711]
# 0.15 Clase Ponderado - F1-score promedio para rnn2 : [0.14339539 0.19851962 0.51735656 0.67562277]
# 0.15 Clase Ponderado - F1-score promedio para rnn3 : [0.20827967 0.15575038 0.43289148 0.61473842]
#
# 0.15 Clase Ponderado - F1-score macro promedio para cnn1 : 0.42674722016550737 desvest:  0.011693362454369676
# 0.15 Clase Ponderado - F1-score macro promedio para cnn2 : 0.43934869103606305 desvest:  0.019247232156816334
# 0.15 Clase Ponderado - F1-score macro promedio para rnn1 : 0.3370330076648807 desvest:  0.0406580106995844
# 0.15 Clase Ponderado - F1-score macro promedio para rnn2 : 0.38372358491126785 desvest:  0.04167841838031962
# 0.15 Clase Ponderado - F1-score macro promedio para rnn3 : 0.3529149876900245 desvest:  0.034217193303665586
#
# 0.15 Clase Ponderado - Accuracy promedio para cnn1 : 0.7290891283055828
# 0.15 Clase Ponderado - Accuracy promedio para cnn2 : 0.6826640548481882
# 0.15 Clase Ponderado - Accuracy promedio para rnn1 : 0.3668952007835456
# 0.15 Clase Ponderado - Accuracy promedio para rnn2 : 0.5522037218413319
# 0.15 Clase Ponderado - Accuracy promedio para rnn3 : 0.49108716944172376

# %% [markdown]
# ## 0.15

# %%
def load_data(path_to_data):
    macro_augmented = np.load(path_to_data, allow_pickle=True)
    np.random.shuffle(macro_augmented)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    print (np.unique(labels_train), type(labels_train))
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)

    sentences = tws_train
    n_labels = labels_train.copy()

    input_ids = []
    for sent in sentences:
        encoded_sent = [] 
        for wd in sent:
            try:
                encoded_sent.append(token_2_idx[wd])
            except:
                continue
        input_ids.append(encoded_sent)

    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], emb))
    j=0
    for in_id in input_ids:
        x_train[j]=EMB_matrix[in_id]
        j+=1

    return x_train, y_train, n_labels, class_weights

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Stance/Aumento_ofi/balance_GloVe_15_1_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    #cnn1=create_ccn1(x_train.shape[1:])
    cnn1=load_model('../Datasets/Models_Stance/0.15/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    #cnn2=create_cnn2(x_train.shape[1:])
    cnn2=load_model('../Datasets/Models_Stance/0.15/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    #rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    rnn1=load_model('../Datasets/Models_Stance/0.15/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    #rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    rnn2=load_model('../Datasets/Models_Stance/0.15/rnn2_'+str(i)+'-exec.h5')
    #trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=False)
    #trained.save('../Datasets/Models_Stance/0.15/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    #rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    rnn3=load_model('../Datasets/Models_Stance/0.15/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.825
# F1-score macro cnn1 : 0.825
# F1-score None cnn1 : [0.767 0.903 0.919 0.713]
#
# ------ Validation ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.593
# F1-score None cnn1 : [0.607 0.4   0.592 0.773]
#
# ------ Testing ------
# Accuracy cnn1 : 0.661
# F1-score macro cnn1 : 0.418
# F1-score None cnn1 : [0.12  0.22  0.55  0.784]
#
# ------ Training ------
# Accuracy cnn2 : 0.776
# F1-score macro cnn2 : 0.775
# F1-score None cnn2 : [0.688 0.827 0.923 0.661]
#
# ------ Validation ------
# Accuracy cnn2 : 0.598
# F1-score macro cnn2 : 0.486
# F1-score None cnn2 : [0.416 0.185 0.615 0.727]
#
# ------ Testing ------
# Accuracy cnn2 : 0.601
# F1-score macro cnn2 : 0.399
# F1-score None cnn2 : [0.048 0.206 0.598 0.743]
#
# ------ Training ------
# Accuracy rnn1 : 0.612
# F1-score macro rnn1 : 0.607
# F1-score None rnn1 : [0.57  0.537 0.763 0.559]
#
# ------ Validation ------
# Accuracy rnn1 : 0.630
# F1-score macro rnn1 : 0.524
# F1-score None rnn1 : [0.422 0.375 0.561 0.737]
#
# ------ Testing ------
# Accuracy rnn1 : 0.646
# F1-score macro rnn1 : 0.393
# F1-score None rnn1 : [0.097 0.206 0.497 0.773]
#
# ------ Training ------
# Accuracy rnn2 : 0.719
# F1-score macro rnn2 : 0.724
# F1-score None rnn2 : [0.704 0.778 0.778 0.637]
#
# ------ Validation ------
# Accuracy rnn2 : 0.566
# F1-score macro rnn2 : 0.441
# F1-score None rnn2 : [0.543 0.08  0.511 0.632]
#
# ------ Testing ------
# Accuracy rnn2 : 0.527
# F1-score macro rnn2 : 0.381
# F1-score None rnn2 : [0.187 0.244 0.416 0.677]
#
# ------ Training ------
# Accuracy rnn3 : 0.570
# F1-score macro rnn3 : 0.548
# F1-score None rnn3 : [0.63  0.354 0.682 0.523]
#
# ------ Validation ------
# Accuracy rnn3 : 0.587
# F1-score macro rnn3 : 0.507
# F1-score None rnn3 : [0.559 0.348 0.45  0.671]
#
# ------ Testing ------
# Accuracy rnn3 : 0.494
# F1-score macro rnn3 : 0.345
# F1-score None rnn3 : [0.18  0.201 0.375 0.624]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.837
# F1-score macro cnn1 : 0.839
# F1-score None cnn1 : [0.766 0.908 0.944 0.736]
#
# ------ Validation ------
# Accuracy cnn1 : 0.701
# F1-score macro cnn1 : 0.614
# F1-score None cnn1 : [0.588 0.5   0.587 0.782]
#
# ------ Testing ------
# Accuracy cnn1 : 0.712
# F1-score macro cnn1 : 0.455
# F1-score None cnn1 : [0.14  0.259 0.598 0.821]
#
# ------ Training ------
# Accuracy cnn2 : 0.839
# F1-score macro cnn2 : 0.839
# F1-score None cnn2 : [0.771 0.905 0.948 0.733]
#
# ------ Validation ------
# Accuracy cnn2 : 0.722
# F1-score macro cnn2 : 0.624
# F1-score None cnn2 : [0.628 0.455 0.615 0.799]
#
# ------ Testing ------
# Accuracy cnn2 : 0.673
# F1-score macro cnn2 : 0.457
# F1-score None cnn2 : [0.197 0.211 0.63  0.789]
#
# ------ Training ------
# Accuracy rnn1 : 0.520
# F1-score macro rnn1 : 0.493
# F1-score None rnn1 : [0.555 0.301 0.721 0.394]
#
# ------ Validation ------
# Accuracy rnn1 : 0.480
# F1-score macro rnn1 : 0.449
# F1-score None rnn1 : [0.498 0.235 0.629 0.436]
#
# ------ Testing ------
# Accuracy rnn1 : 0.384
# F1-score macro rnn1 : 0.334
# F1-score None rnn1 : [0.168 0.132 0.553 0.484]
#
# ------ Training ------
# Accuracy rnn2 : 0.798
# F1-score macro rnn2 : 0.800
# F1-score None rnn2 : [0.759 0.855 0.88  0.704]
#
# ------ Validation ------
# Accuracy rnn2 : 0.616
# F1-score macro rnn2 : 0.528
# F1-score None rnn2 : [0.594 0.157 0.667 0.695]
#
# ------ Testing ------
# Accuracy rnn2 : 0.581
# F1-score macro rnn2 : 0.406
# F1-score None rnn2 : [0.195 0.174 0.53  0.726]
#
# ------ Training ------
# Accuracy rnn3 : 0.523
# F1-score macro rnn3 : 0.480
# F1-score None rnn3 : [0.685 0.205 0.583 0.447]
#
# ------ Validation ------
# Accuracy rnn3 : 0.466
# F1-score macro rnn3 : 0.405
# F1-score None rnn3 : [0.567 0.211 0.34  0.502]
#
# ------ Testing ------
# Accuracy rnn3 : 0.354
# F1-score macro rnn3 : 0.274
# F1-score None rnn3 : [0.237 0.133 0.273 0.454]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.826
# F1-score macro cnn1 : 0.825
# F1-score None cnn1 : [0.784 0.908 0.902 0.706]
#
# ------ Validation ------
# Accuracy cnn1 : 0.673
# F1-score macro cnn1 : 0.564
# F1-score None cnn1 : [0.621 0.316 0.575 0.746]
#
# ------ Testing ------
# Accuracy cnn1 : 0.634
# F1-score macro cnn1 : 0.426
# F1-score None cnn1 : [0.22  0.236 0.49  0.759]
#
# ------ Training ------
# Accuracy cnn2 : 0.793
# F1-score macro cnn2 : 0.789
# F1-score None cnn2 : [0.647 0.905 0.913 0.692]
#
# ------ Validation ------
# Accuracy cnn2 : 0.694
# F1-score macro cnn2 : 0.583
# F1-score None cnn2 : [0.5   0.435 0.608 0.79 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.703
# F1-score macro cnn2 : 0.405
# F1-score None cnn2 : [0.    0.247 0.56  0.814]
#
# ------ Training ------
# Accuracy rnn1 : 0.624
# F1-score macro rnn1 : 0.621
# F1-score None rnn1 : [0.672 0.523 0.797 0.492]
#
# ------ Validation ------
# Accuracy rnn1 : 0.548
# F1-score macro rnn1 : 0.478
# F1-score None rnn1 : [0.51  0.182 0.635 0.587]
#
# ------ Testing ------
# Accuracy rnn1 : 0.519
# F1-score macro rnn1 : 0.381
# F1-score None rnn1 : [0.188 0.174 0.504 0.658]
#
# ------ Training ------
# Accuracy rnn2 : 0.811
# F1-score macro rnn2 : 0.809
# F1-score None rnn2 : [0.778 0.838 0.923 0.698]
#
# ------ Validation ------
# Accuracy rnn2 : 0.548
# F1-score macro rnn2 : 0.466
# F1-score None rnn2 : [0.531 0.156 0.536 0.642]
#
# ------ Testing ------
# Accuracy rnn2 : 0.548
# F1-score macro rnn2 : 0.410
# F1-score None rnn2 : [0.218 0.223 0.515 0.685]
#
# ------ Training ------
# Accuracy rnn3 : 0.620
# F1-score macro rnn3 : 0.607
# F1-score None rnn3 : [0.696 0.59  0.764 0.378]
#
# ------ Validation ------
# Accuracy rnn3 : 0.406
# F1-score macro rnn3 : 0.412
# F1-score None rnn3 : [0.55  0.091 0.613 0.395]
#
# ------ Testing ------
# Accuracy rnn3 : 0.322
# F1-score macro rnn3 : 0.329
# F1-score None rnn3 : [0.227 0.19  0.535 0.362]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.795
# F1-score macro cnn1 : 0.800
# F1-score None cnn1 : [0.712 0.841 0.941 0.706]
#
# ------ Validation ------
# Accuracy cnn1 : 0.740
# F1-score macro cnn1 : 0.586
# F1-score None cnn1 : [0.614 0.286 0.627 0.816]
#
# ------ Testing ------
# Accuracy cnn1 : 0.772
# F1-score macro cnn1 : 0.427
# F1-score None cnn1 : [0.044 0.198 0.601 0.866]
#
# ------ Training ------
# Accuracy cnn2 : 0.798
# F1-score macro cnn2 : 0.795
# F1-score None cnn2 : [0.701 0.866 0.926 0.688]
#
# ------ Validation ------
# Accuracy cnn2 : 0.669
# F1-score macro cnn2 : 0.553
# F1-score None cnn2 : [0.505 0.323 0.622 0.763]
#
# ------ Testing ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.385
# F1-score None cnn2 : [0.021 0.177 0.584 0.757]
#
# ------ Training ------
# Accuracy rnn1 : 0.604
# F1-score macro rnn1 : 0.593
# F1-score None rnn1 : [0.691 0.362 0.779 0.54 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.701
# F1-score macro rnn1 : 0.545
# F1-score None rnn1 : [0.575 0.125 0.697 0.784]
#
# ------ Testing ------
# Accuracy rnn1 : 0.714
# F1-score macro rnn1 : 0.456
# F1-score None rnn1 : [0.241 0.155 0.608 0.822]
#
# ------ Training ------
# Accuracy rnn2 : 0.755
# F1-score macro rnn2 : 0.753
# F1-score None rnn2 : [0.768 0.815 0.795 0.636]
#
# ------ Validation ------
# Accuracy rnn2 : 0.584
# F1-score macro rnn2 : 0.499
# F1-score None rnn2 : [0.606 0.276 0.463 0.65 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.517
# F1-score macro rnn2 : 0.356
# F1-score None rnn2 : [0.209 0.184 0.376 0.655]
#
# ------ Training ------
# Accuracy rnn3 : 0.635
# F1-score macro rnn3 : 0.634
# F1-score None rnn3 : [0.68  0.565 0.751 0.541]
#
# ------ Validation ------
# Accuracy rnn3 : 0.626
# F1-score macro rnn3 : 0.536
# F1-score None rnn3 : [0.597 0.278 0.571 0.698]
#
# ------ Testing ------
# Accuracy rnn3 : 0.528
# F1-score macro rnn3 : 0.383
# F1-score None rnn3 : [0.201 0.199 0.475 0.659]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.841
# F1-score macro cnn1 : 0.842
# F1-score None cnn1 : [0.785 0.906 0.941 0.737]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.588
# F1-score None cnn1 : [0.603 0.385 0.613 0.75 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.677
# F1-score macro cnn1 : 0.463
# F1-score None cnn1 : [0.169 0.271 0.618 0.793]
#
# ------ Training ------
# Accuracy cnn2 : 0.803
# F1-score macro cnn2 : 0.802
# F1-score None cnn2 : [0.736 0.872 0.913 0.685]
#
# ------ Validation ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.592
# F1-score None cnn2 : [0.586 0.4   0.623 0.758]
# ------ Testing ------
# Accuracy cnn2 : 0.635
# F1-score macro cnn2 : 0.400
# F1-score None cnn2 : [0.125 0.176 0.535 0.764]
#
# ------ Training ------
# Accuracy rnn1 : 0.573
# F1-score macro rnn1 : 0.549
# F1-score None rnn1 : [0.591 0.446 0.772 0.388]
#
# ------ Validation ------
# Accuracy rnn1 : 0.463
# F1-score macro rnn1 : 0.452
# F1-score None rnn1 : [0.488 0.286 0.639 0.396]
#
# ------ Testing ------
# Accuracy rnn1 : 0.361
# F1-score macro rnn1 : 0.338
# F1-score None rnn1 : [0.181 0.227 0.503 0.44 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.835
# F1-score macro rnn2 : 0.829
# F1-score None rnn2 : [0.798 0.908 0.945 0.664]
#
# ------ Validation ------
# Accuracy rnn2 : 0.477
# F1-score macro rnn2 : 0.419
# F1-score None rnn2 : [0.524 0.08  0.576 0.494]
#
# ------ Testing ------
# Accuracy rnn2 : 0.500
# F1-score macro rnn2 : 0.393
# F1-score None rnn2 : [0.214 0.212 0.517 0.628]
#
# ------ Training ------
# Accuracy rnn3 : 0.621
# F1-score macro rnn3 : 0.596
# F1-score None rnn3 : [0.677 0.596 0.752 0.357]
#
# ------ Validation ------
# Accuracy rnn3 : 0.448
# F1-score macro rnn3 : 0.426
# F1-score None rnn3 : [0.536 0.167 0.578 0.421]
#
# ------ Testing ------
# Accuracy rnn3 : 0.331
# F1-score macro rnn3 : 0.284
# F1-score None rnn3 : [0.156 0.157 0.412 0.41 ]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.15 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.15 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.15 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.15 Clase Ponderado - F1-score promedio para cnn1 : [0.138 0.237 0.571 0.805]
# 0.15 Clase Ponderado - F1-score promedio para cnn2 : [0.078 0.203 0.581 0.773]
# 0.15 Clase Ponderado - F1-score promedio para rnn1 : [0.175 0.179 0.533 0.635]
# 0.15 Clase Ponderado - F1-score promedio para rnn2 : [0.204 0.207 0.471 0.674]
# 0.15 Clase Ponderado - F1-score promedio para rnn3 : [0.2   0.176 0.414 0.502]
#
# 0.15 Clase Ponderado - F1-score macro promedio para cnn1 : 0.43780307529224627 desvest:  0.01743329363675586
# 0.15 Clase Ponderado - F1-score macro promedio para cnn2 : 0.40909487017912427 desvest:  0.02481521038370867
# 0.15 Clase Ponderado - F1-score macro promedio para rnn1 : 0.3804914901230047 desvest:  0.044396175073480426
# 0.15 Clase Ponderado - F1-score macro promedio para rnn2 : 0.3892767754515859 desvest:  0.01956833394043034
# 0.15 Clase Ponderado - F1-score macro promedio para rnn3 : 0.3230122590127412 desvest:  0.04020128932397405
#
# 0.15 Clase Ponderado - Accuracy promedio para cnn1 : 0.6910871694417238 desvest:  0.04764349950279221
# 0.15 Clase Ponderado - Accuracy promedio para cnn2 : 0.6483839373163566 desvest:  0.03564378734509227
# 0.15 Clase Ponderado - Accuracy promedio para rnn1 : 0.524975514201763 desvest:  0.1394003826449827
# 0.15 Clase Ponderado - Accuracy promedio para rnn2 : 0.5343780607247796 desvest:  0.02791363815951374
# 0.15 Clase Ponderado - Accuracy promedio para rnn3 : 0.40568070519098925 desvest:  0.08709215339110639

# %% [markdown]
# ## 0.5

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Stance/Aumento_ofi/balance_GloVe_50_1_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    #cnn1=create_ccn1(x_train.shape[1:])
    cnn1=load_model('../Datasets/Models_Stance/0.5/cnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn1, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    #cnn2=create_cnn2(x_train.shape[1:])
    cnn2=load_model('../Datasets/Models_Stance/0.5/cnn2_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(cnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    #rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    rnn1=load_model('../Datasets/Models_Stance/0.5/rnn1_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn1, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    #rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    rnn2=load_model('../Datasets/Models_Stance/0.5/rnn2_'+str(i)+'-exec.h5')
    #trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=False)
    #trained.save('../Datasets/Models_Stance/0.15/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn2, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    #rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    rnn3=load_model('../Datasets/Models_Stance/0.5/rnn3_'+str(i)+'-exec.h5', custom_objects={'FocalLoss': focal_loss, 'focal_loss_fixed': focal_loss()})
    #trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    #trained.save('../Datasets/Models_Stance/0.15/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(rnn3, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.785
# F1-score macro cnn1 : 0.786
# F1-score None cnn1 : [0.698 0.82  0.928 0.698]
#
# ------ Validation ------
# Accuracy cnn1 : 0.705
# F1-score macro cnn1 : 0.589
# F1-score None cnn1 : [0.526 0.444 0.588 0.796]
#
# ------ Testing ------
# Accuracy cnn1 : 0.718
# F1-score macro cnn1 : 0.434
# F1-score None cnn1 : [0.114 0.213 0.581 0.827]
#
# ------ Training ------
# Accuracy cnn2 : 0.779
# F1-score macro cnn2 : 0.779
# F1-score None cnn2 : [0.734 0.8   0.9   0.681]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.609
# F1-score None cnn2 : [0.589 0.4   0.676 0.769]
#
# ------ Testing ------
# Accuracy cnn2 : 0.643
# F1-score macro cnn2 : 0.408
# F1-score None cnn2 : [0.139 0.193 0.536 0.766]
#
# ------ Training ------
# Accuracy rnn1 : 0.603
# F1-score macro rnn1 : 0.583
# F1-score None rnn1 : [0.598 0.608 0.751 0.374]
#
# ------ Validation ------
# Accuracy rnn1 : 0.413
# F1-score macro rnn1 : 0.396
# F1-score None rnn1 : [0.565 0.103 0.505 0.412]
#
# ------ Testing ------
# Accuracy rnn1 : 0.319
# F1-score macro rnn1 : 0.286
# F1-score None rnn1 : [0.129 0.192 0.462 0.36 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.802
# F1-score macro rnn2 : 0.801
# F1-score None rnn2 : [0.759 0.851 0.912 0.682]
#
# ------ Validation ------
# Accuracy rnn2 : 0.562
# F1-score macro rnn2 : 0.458
# F1-score None rnn2 : [0.556 0.071 0.597 0.606]
#
# ------ Testing ------
# Accuracy rnn2 : 0.515
# F1-score macro rnn2 : 0.381
# F1-score None rnn2 : [0.126 0.189 0.555 0.652]
#
# ------ Training ------
# Accuracy rnn3 : 0.542
# F1-score macro rnn3 : 0.490
# F1-score None rnn3 : [0.528 0.556 0.727 0.148]
#
# ------ Validation ------
# Accuracy rnn3 : 0.274
# F1-score macro rnn3 : 0.296
# F1-score None rnn3 : [0.464 0.09  0.414 0.214]
#
# ------ Testing ------
# Accuracy rnn3 : 0.200
# F1-score macro rnn3 : 0.208
# F1-score None rnn3 : [0.082 0.151 0.443 0.157]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.789
# F1-score macro cnn1 : 0.792
# F1-score None cnn1 : [0.762 0.793 0.918 0.696]
#
# ------ Validation ------
# Accuracy cnn1 : 0.698
# F1-score macro cnn1 : 0.581
# F1-score None cnn1 : [0.589 0.3   0.657 0.778]
#
# ------ Testing ------
# Accuracy cnn1 : 0.700
# F1-score macro cnn1 : 0.439
# F1-score None cnn1 : [0.14  0.19  0.607 0.816]
#
# ------ Training ------
# Accuracy cnn2 : 0.735
# F1-score macro cnn2 : 0.726
# F1-score None cnn2 : [0.538 0.808 0.916 0.644]
#
# ------ Validation ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.493
# F1-score None cnn2 : [0.316 0.27  0.643 0.743]
#
# ------ Testing ------
# Accuracy cnn2 : 0.683
# F1-score macro cnn2 : 0.424
# F1-score None cnn2 : [0.025 0.25  0.619 0.8  ]
#
# ------ Training ------
# Accuracy rnn1 : 0.596
# F1-score macro rnn1 : 0.584
# F1-score None rnn1 : [0.609 0.476 0.705 0.545]
#
# ------ Validation ------
# Accuracy rnn1 : 0.573
# F1-score macro rnn1 : 0.423
# F1-score None rnn1 : [0.424 0.08  0.5   0.69 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.533
# F1-score macro rnn1 : 0.382
# F1-score None rnn1 : [0.247 0.207 0.418 0.659]
#
# ------ Training ------
# Accuracy rnn2 : 0.781
# F1-score macro rnn2 : 0.777
# F1-score None rnn2 : [0.747 0.825 0.878 0.658]
#
# ------ Validation ------
# Accuracy rnn2 : 0.552
# F1-score macro rnn2 : 0.461
# F1-score None rnn2 : [0.507 0.19  0.512 0.633]
#
# ------ Testing ------
# Accuracy rnn2 : 0.519
# F1-score macro rnn2 : 0.361
# F1-score None rnn2 : [0.132 0.206 0.451 0.654]
#
# ------ Training ------
# Accuracy rnn3 : 0.578
# F1-score macro rnn3 : 0.547
# F1-score None rnn3 : [0.66  0.446 0.711 0.373]
#
# ------ Validation ------
# Accuracy rnn3 : 0.456
# F1-score macro rnn3 : 0.397
# F1-score None rnn3 : [0.487 0.182 0.473 0.446]
#
# ------ Testing ------
# Accuracy rnn3 : 0.346
# F1-score macro rnn3 : 0.293
# F1-score None rnn3 : [0.187 0.191 0.383 0.412]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.780
# F1-score macro cnn1 : 0.773
# F1-score None cnn1 : [0.683 0.837 0.904 0.668]
#
# ------ Validation ------
# Accuracy cnn1 : 0.609
# F1-score macro cnn1 : 0.506
# F1-score None cnn1 : [0.564 0.196 0.563 0.7  ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.565
# F1-score macro cnn1 : 0.378
# F1-score None cnn1 : [0.059 0.218 0.54  0.694]
#
# ------ Training ------
# Accuracy cnn2 : 0.760
# F1-score macro cnn2 : 0.761
# F1-score None cnn2 : [0.697 0.763 0.91  0.676]
#
# ------ Validation ------
# Accuracy cnn2 : 0.698
# F1-score macro cnn2 : 0.545
# F1-score None cnn2 : [0.562 0.211 0.618 0.79 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.722
# F1-score macro cnn2 : 0.459
# F1-score None cnn2 : [0.134 0.259 0.615 0.829]
#
# ------ Training ------
# Accuracy rnn1 : 0.596
# F1-score macro rnn1 : 0.593
# F1-score None rnn1 : [0.647 0.579 0.701 0.447]
#
# ------ Validation ------
# Accuracy rnn1 : 0.473
# F1-score macro rnn1 : 0.439
# F1-score None rnn1 : [0.495 0.154 0.618 0.49 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.397
# F1-score macro rnn1 : 0.355
# F1-score None rnn1 : [0.199 0.198 0.513 0.51 ]
#
# ------ Training ------
# Accuracy rnn2 : 0.783
# F1-score macro rnn2 : 0.780
# F1-score None rnn2 : [0.736 0.836 0.927 0.62 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.480
# F1-score macro rnn2 : 0.432
# F1-score None rnn2 : [0.521 0.174 0.545 0.488]
#
# ------ Testing ------
# Accuracy rnn2 : 0.411
# F1-score macro rnn2 : 0.357
# F1-score None rnn2 : [0.16  0.238 0.504 0.528]
#
# ------ Training ------
# Accuracy rnn3 : 0.538
# F1-score macro rnn3 : 0.478
# F1-score None rnn3 : [0.605 0.072 0.707 0.528]
#
# ------ Validation ------
# Accuracy rnn3 : 0.665
# F1-score macro rnn3 : 0.474
# F1-score None rnn3 : [0.567 0.    0.568 0.761]
#
# ------ Testing ------
# Accuracy rnn3 : 0.639
# F1-score macro rnn3 : 0.352
# F1-score None rnn3 : [0.148 0.068 0.42  0.77 ]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.804
# F1-score macro cnn1 : 0.806
# F1-score None cnn1 : [0.773 0.828 0.914 0.71 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.690
# F1-score macro cnn1 : 0.578
# F1-score None cnn1 : [0.589 0.333 0.62  0.771]
#
# ------ Testing ------
# Accuracy cnn1 : 0.692
# F1-score macro cnn1 : 0.453
# F1-score None cnn1 : [0.19  0.202 0.616 0.806]
#
# ------ Training ------
# Accuracy cnn2 : 0.772
# F1-score macro cnn2 : 0.766
# F1-score None cnn2 : [0.691 0.808 0.905 0.659]
#
# ------ Validation ------
# Accuracy cnn2 : 0.623
# F1-score macro cnn2 : 0.513
# F1-score None cnn2 : [0.583 0.196 0.545 0.726]
#
# ------ Testing ------
# Accuracy cnn2 : 0.550
# F1-score macro cnn2 : 0.391
# F1-score None cnn2 : [0.145 0.209 0.527 0.681]
#
# ------ Training ------
# Accuracy rnn1 : 0.586
# F1-score macro rnn1 : 0.569
# F1-score None rnn1 : [0.662 0.559 0.752 0.303]
#
# ------ Validation ------
# Accuracy rnn1 : 0.399
# F1-score macro rnn1 : 0.403
# F1-score None rnn1 : [0.59  0.125 0.545 0.35 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.236
# F1-score macro rnn1 : 0.259
# F1-score None rnn1 : [0.145 0.175 0.495 0.222]
#
# ------ Training ------
# Accuracy rnn2 : 0.661
# F1-score macro rnn2 : 0.647
# F1-score None rnn2 : [0.648 0.5   0.87  0.571]
#
# ------ Validation ------
# Accuracy rnn2 : 0.534
# F1-score macro rnn2 : 0.424
# F1-score None rnn2 : [0.507 0.    0.639 0.552]
#
# ------ Testing ------
# Accuracy rnn2 : 0.495
# F1-score macro rnn2 : 0.375
# F1-score None rnn2 : [0.165 0.17  0.536 0.629]
#
# ------ Training ------
# Accuracy rnn3 : 0.593
# F1-score macro rnn3 : 0.586
# F1-score None rnn3 : [0.66  0.43  0.731 0.523]
#
# ------ Validation ------
# Accuracy rnn3 : 0.651
# F1-score macro rnn3 : 0.545
# F1-score None rnn3 : [0.537 0.25  0.667 0.728]
#
# ------ Testing ------
# Accuracy rnn3 : 0.587
# F1-score macro rnn3 : 0.396
# F1-score None rnn3 : [0.151 0.224 0.487 0.722]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.816
# F1-score macro cnn1 : 0.817
# F1-score None cnn1 : [0.741 0.869 0.935 0.722]
#
# ------ Validation ------
# Accuracy cnn1 : 0.683
# F1-score macro cnn1 : 0.580
# F1-score None cnn1 : [0.588 0.333 0.636 0.764]
#
# ------ Testing ------
# Accuracy cnn1 : 0.690
# F1-score macro cnn1 : 0.437
# F1-score None cnn1 : [0.101 0.224 0.613 0.808]
#
# ------ Training ------
# Accuracy cnn2 : 0.742
# F1-score macro cnn2 : 0.738
# F1-score None cnn2 : [0.675 0.777 0.834 0.665]
#
# ------ Validation ------
# Accuracy cnn2 : 0.648
# F1-score macro cnn2 : 0.549
# F1-score None cnn2 : [0.571 0.345 0.545 0.734]
# ------ Testing ------
# Accuracy cnn2 : 0.609
# F1-score macro cnn2 : 0.373
# F1-score None cnn2 : [0.057 0.235 0.461 0.739]
#
# ------ Training ------
# Accuracy rnn1 : 0.556
# F1-score macro rnn1 : 0.545
# F1-score None rnn1 : [0.65  0.562 0.64  0.329]
#
# ------ Validation ------
# Accuracy rnn1 : 0.381
# F1-score macro rnn1 : 0.405
# F1-score None rnn1 : [0.523 0.122 0.596 0.38 ]
#
# ------ Testing ------
# Accuracy rnn1 : 0.267
# F1-score macro rnn1 : 0.288
# F1-score None rnn1 : [0.173 0.175 0.489 0.314]
#
# ------ Training ------
# Accuracy rnn2 : 0.754
# F1-score macro rnn2 : 0.753
# F1-score None rnn2 : [0.779 0.762 0.829 0.64 ]
#
# ------ Validation ------
# Accuracy rnn2 : 0.509
# F1-score macro rnn2 : 0.447
# F1-score None rnn2 : [0.582 0.074 0.542 0.591]
#
# ------ Testing ------
# Accuracy rnn2 : 0.418
# F1-score macro rnn2 : 0.340
# F1-score None rnn2 : [0.178 0.158 0.469 0.556]
#
# ------ Training ------
# Accuracy rnn3 : 0.576
# F1-score macro rnn3 : 0.554
# F1-score None rnn3 : [0.645 0.51  0.686 0.373]
#
# ------ Validation ------
# Accuracy rnn3 : 0.413
# F1-score macro rnn3 : 0.354
# F1-score None rnn3 : [0.5   0.095 0.409 0.41 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.352
# F1-score macro rnn3 : 0.293
# F1-score None rnn3 : [0.188 0.186 0.373 0.426]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.5 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.5 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.5 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.5 Clase Ponderado - F1-score promedio para cnn1 : [0.121 0.209 0.591 0.79 ]
# 0.5 Clase Ponderado - F1-score promedio para cnn2 : [0.1   0.229 0.552 0.763]
# 0.5 Clase Ponderado - F1-score promedio para rnn1 : [0.179 0.19  0.475 0.413]
# 0.5 Clase Ponderado - F1-score promedio para rnn2 : [0.152 0.192 0.503 0.604]
# 0.5 Clase Ponderado - F1-score promedio para rnn3 : [0.151 0.164 0.421 0.497]
#
# 0.5 Clase Ponderado - F1-score macro promedio para cnn1 : 0.42802979917300304 desvest:  0.025996512219882896
# 0.5 Clase Ponderado - F1-score macro promedio para cnn2 : 0.4110295905047098 desvest:  0.029531235638134343
# 0.5 Clase Ponderado - F1-score macro promedio para rnn1 : 0.3141408964621907 desvest:  0.04652730574513736
# 0.5 Clase Ponderado - F1-score macro promedio para rnn2 : 0.36274453874468676 desvest:  0.014263680339383593
# 0.5 Clase Ponderado - F1-score macro promedio para rnn3 : 0.30830249935728454 desvest:  0.06333376622501938
#
# 0.5 Clase Ponderado - Accuracy promedio para cnn1 : 0.6730656219392752 desvest:  0.05486357696525196
# 0.5 Clase Ponderado - Accuracy promedio para cnn2 : 0.6415279138099901 desvest:  0.05914017292634878
# 0.5 Clase Ponderado - Accuracy promedio para rnn1 : 0.3504407443682664 desvest:  0.10616138542132934
# 0.5 Clase Ponderado - Accuracy promedio para rnn2 : 0.47169441723800204 desvest:  0.04725127207788676
# 0.5 Clase Ponderado - Accuracy promedio para rnn3 : 0.4244857982370225 desvest:  0.16379264792564222

# %% [markdown]
# ## 0.85

# %%
x_train, y_train, n_labels, class_weights = load_data('../Datasets/CSV_Stance/Aumento_ofi/balance_GloVe_85_1_run.npy')

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):    
    print ("\n\n -------------------- Entrenando exec", i," -------------------- \n")
    cnn1=create_ccn1(x_train.shape[1:])
    trained, hist =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Stance/0.85/cnn1_'+str(i)+'-exec.h5')   
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, n_labels, n_labels_val, n_labels_test, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained, hist =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Stance/0.85/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Stance/0.85/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=8, BS=32, verb=0, focal=False)
    trained.save('../Datasets/Models_Stance/0.85/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained, hist =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=4, BS=32, verb=0, focal=True)
    trained.save('../Datasets/Models_Stance/0.85/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test,  n_labels, n_labels_val, n_labels_test, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# [0 1 2 3] <class 'numpy.ndarray'>
# Pesos de clases: [1. 1. 1. 1.]
#
#
#  -------------------- Entrenando exec 1  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.826
# F1-score macro cnn1 : 0.825
# F1-score None cnn1 : [0.765 0.869 0.927 0.737]
#
# ------ Validation ------
# Accuracy cnn1 : 0.658
# F1-score macro cnn1 : 0.544
# F1-score None cnn1 : [0.569 0.231 0.639 0.738]
#
# ------ Testing ------
# Accuracy cnn1 : 0.658
# F1-score macro cnn1 : 0.544
# F1-score None cnn1 : [0.569 0.231 0.639 0.738]
#
# ------ Training ------
# Accuracy cnn2 : 0.775
# F1-score macro cnn2 : 0.769
# F1-score None cnn2 : [0.682 0.797 0.914 0.684]
#
# ------ Validation ------
# Accuracy cnn2 : 0.598
# F1-score macro cnn2 : 0.530
# F1-score None cnn2 : [0.551 0.182 0.7   0.686]
#
# ------ Testing ------
# Accuracy cnn2 : 0.598
# F1-score macro cnn2 : 0.530
# F1-score None cnn2 : [0.551 0.182 0.7   0.686]
#
# ------ Training ------
# Accuracy rnn1 : 0.626
# F1-score macro rnn1 : 0.634
# F1-score None rnn1 : [0.606 0.645 0.758 0.529]
#
# ------ Validation ------
# Accuracy rnn1 : 0.641
# F1-score macro rnn1 : 0.536
# F1-score None rnn1 : [0.539 0.176 0.702 0.727]
#
# ------ Testing ------
# Accuracy rnn1 : 0.641
# F1-score macro rnn1 : 0.536
# F1-score None rnn1 : [0.539 0.176 0.702 0.727]
#
# ------ Training ------
# Accuracy rnn2 : 0.794
# F1-score macro rnn2 : 0.792
# F1-score None rnn2 : [0.72  0.835 0.873 0.739]
#
# ------ Validation ------
# Accuracy rnn2 : 0.612
# F1-score macro rnn2 : 0.459
# F1-score None rnn2 : [0.581 0.059 0.482 0.713]
#
# ------ Testing ------
# Accuracy rnn2 : 0.612
# F1-score macro rnn2 : 0.459
# F1-score None rnn2 : [0.581 0.059 0.482 0.713]
#
# ------ Training ------
# Accuracy rnn3 : 0.654
# F1-score macro rnn3 : 0.657
# F1-score None rnn3 : [0.657 0.65  0.693 0.628]
#
# ------ Validation ------
# Accuracy rnn3 : 0.619
# F1-score macro rnn3 : 0.542
# F1-score None rnn3 : [0.586 0.19  0.679 0.712]
#
# ------ Testing ------
# Accuracy rnn3 : 0.619
# F1-score macro rnn3 : 0.542
# F1-score None rnn3 : [0.586 0.19  0.679 0.712]
#
#
#  -------------------- Entrenando exec 2  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.793
# F1-score macro cnn1 : 0.797
# F1-score None cnn1 : [0.718 0.835 0.912 0.721]
#
# ------ Validation ------
# Accuracy cnn1 : 0.719
# F1-score macro cnn1 : 0.534
# F1-score None cnn1 : [0.595 0.125 0.612 0.803]
#
# ------ Testing ------
# Accuracy cnn1 : 0.719
# F1-score macro cnn1 : 0.534
# F1-score None cnn1 : [0.595 0.125 0.612 0.803]
#
# ------ Training ------
# Accuracy cnn2 : 0.760
# F1-score macro cnn2 : 0.763
# F1-score None cnn2 : [0.683 0.773 0.904 0.691]
#
# ------ Validation ------
# Accuracy cnn2 : 0.680
# F1-score macro cnn2 : 0.526
# F1-score None cnn2 : [0.456 0.235 0.642 0.772]
#
# ------ Testing ------
# Accuracy cnn2 : 0.680
# F1-score macro cnn2 : 0.526
# F1-score None cnn2 : [0.456 0.235 0.642 0.772]
#
# ------ Training ------
# Accuracy rnn1 : 0.579
# F1-score macro rnn1 : 0.572
# F1-score None rnn1 : [0.628 0.473 0.778 0.41 ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.523
# F1-score macro rnn1 : 0.461
# F1-score None rnn1 : [0.491 0.174 0.627 0.554]
#
# ------ Testing ------
# Accuracy rnn1 : 0.523
# F1-score macro rnn1 : 0.461
# F1-score None rnn1 : [0.491 0.174 0.627 0.554]
#
# ------ Training ------
# Accuracy rnn2 : 0.736
# F1-score macro rnn2 : 0.726
# F1-score None rnn2 : [0.728 0.718 0.906 0.551]
#
# ------ Validation ------
# Accuracy rnn2 : 0.377
# F1-score macro rnn2 : 0.400
# F1-score None rnn2 : [0.508 0.126 0.556 0.41 ]
#
# ------ Testing ------
# Accuracy rnn2 : 0.377
# F1-score macro rnn2 : 0.400
# F1-score None rnn2 : [0.508 0.126 0.556 0.41 ]
#
# ------ Training ------
# Accuracy rnn3 : 0.645
# F1-score macro rnn3 : 0.647
# F1-score None rnn3 : [0.657 0.559 0.79  0.582]
#
# ------ Validation ------
# Accuracy rnn3 : 0.662
# F1-score macro rnn3 : 0.512
# F1-score None rnn3 : [0.548 0.091 0.656 0.752]
#
# ------ Testing ------
# Accuracy rnn3 : 0.662
# F1-score macro rnn3 : 0.512
# F1-score None rnn3 : [0.548 0.091 0.656 0.752]
#
#
#  -------------------- Entrenando exec 3  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.793
# F1-score macro cnn1 : 0.793
# F1-score None cnn1 : [0.747 0.805 0.892 0.729]
#
# ------ Validation ------
# Accuracy cnn1 : 0.676
# F1-score macro cnn1 : 0.509
# F1-score None cnn1 : [0.524 0.133 0.611 0.768]
#
# ------ Testing ------
# Accuracy cnn1 : 0.676
# F1-score macro cnn1 : 0.509
# F1-score None cnn1 : [0.524 0.133 0.611 0.768]
#
# ------ Training ------
# Accuracy cnn2 : 0.747
# F1-score macro cnn2 : 0.739
# F1-score None cnn2 : [0.595 0.792 0.875 0.694]
#
# ------ Validation ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.512
# F1-score None cnn2 : [0.438 0.182 0.679 0.751]
#
# ------ Testing ------
# Accuracy cnn2 : 0.630
# F1-score macro cnn2 : 0.512
# F1-score None cnn2 : [0.438 0.182 0.679 0.751]
#
# ------ Training ------
# Accuracy rnn1 : 0.386
# F1-score macro rnn1 : 0.327
# F1-score None rnn1 : [0.429 0.457 0.373 0.047]
#
# ------ Validation ------
# Accuracy rnn1 : 0.164
# F1-score macro rnn1 : 0.246
# F1-score None rnn1 : [0.389 0.095 0.444 0.055]
#
# ------ Testing ------
# Accuracy rnn1 : 0.164
# F1-score macro rnn1 : 0.246
# F1-score None rnn1 : [0.389 0.095 0.444 0.055]
#
# ------ Training ------
# Accuracy rnn2 : 0.801
# F1-score macro rnn2 : 0.803
# F1-score None rnn2 : [0.729 0.851 0.9   0.731]
#
# ------ Validation ------
# Accuracy rnn2 : 0.626
# F1-score macro rnn2 : 0.450
# F1-score None rnn2 : [0.404 0.067 0.586 0.745]
#
# ------ Testing ------
# Accuracy rnn2 : 0.626
# F1-score macro rnn2 : 0.450
# F1-score None rnn2 : [0.404 0.067 0.586 0.745]
#
# ------ Training ------
# Accuracy rnn3 : 0.603
# F1-score macro rnn3 : 0.585
# F1-score None rnn3 : [0.643 0.479 0.717 0.501]
#
# ------ Validation ------
# Accuracy rnn3 : 0.537
# F1-score macro rnn3 : 0.403
# F1-score None rnn3 : [0.541 0.    0.485 0.586]
#
# ------ Testing ------
# Accuracy rnn3 : 0.537
# F1-score macro rnn3 : 0.403
# F1-score None rnn3 : [0.541 0.    0.485 0.586]
#
#
#  -------------------- Entrenando exec 4  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.755
# F1-score macro cnn1 : 0.750
# F1-score None cnn1 : [0.577 0.812 0.924 0.687]
#
# ------ Validation ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.438
# F1-score None cnn1 : [0.308 0.    0.655 0.79 ]
#
# ------ Testing ------
# Accuracy cnn1 : 0.680
# F1-score macro cnn1 : 0.438
# F1-score None cnn1 : [0.308 0.    0.655 0.79 ]
#
# ------ Training ------
# Accuracy cnn2 : 0.739
# F1-score macro cnn2 : 0.728
# F1-score None cnn2 : [0.499 0.843 0.9   0.67 ]
#
# ------ Validation ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.462
# F1-score None cnn2 : [0.056 0.32  0.692 0.78 ]
#
# ------ Testing ------
# Accuracy cnn2 : 0.658
# F1-score macro cnn2 : 0.462
# F1-score None cnn2 : [0.056 0.32  0.692 0.78 ]
#
# ------ Training ------
# Accuracy rnn1 : 0.641
# F1-score macro rnn1 : 0.627
# F1-score None rnn1 : [0.641 0.671 0.783 0.414]
#
# ------ Validation ------
# Accuracy rnn1 : 0.459
# F1-score macro rnn1 : 0.422
# F1-score None rnn1 : [0.52  0.192 0.532 0.444]
#
# ------ Testing ------
# Accuracy rnn1 : 0.459
# F1-score macro rnn1 : 0.422
# F1-score None rnn1 : [0.52  0.192 0.532 0.444]
#
# ------ Training ------
# Accuracy rnn2 : 0.733
# F1-score macro rnn2 : 0.731
# F1-score None rnn2 : [0.689 0.759 0.861 0.615]
#
# ------ Validation ------
# Accuracy rnn2 : 0.552
# F1-score macro rnn2 : 0.482
# F1-score None rnn2 : [0.571 0.19  0.58  0.587]
#
# ------ Testing ------
# Accuracy rnn2 : 0.552
# F1-score macro rnn2 : 0.482
# F1-score None rnn2 : [0.571 0.19  0.58  0.587]
#
# ------ Training ------
# Accuracy rnn3 : 0.650
# F1-score macro rnn3 : 0.651
# F1-score None rnn3 : [0.661 0.612 0.712 0.618]
#
# ------ Validation ------
# Accuracy rnn3 : 0.609
# F1-score macro rnn3 : 0.501
# F1-score None rnn3 : [0.561 0.121 0.643 0.68 ]
#
# ------ Testing ------
# Accuracy rnn3 : 0.609
# F1-score macro rnn3 : 0.501
# F1-score None rnn3 : [0.561 0.121 0.643 0.68 ]
#
#
#  -------------------- Entrenando exec 5  --------------------
#
#
# ------ Training ------
# Accuracy cnn1 : 0.823
# F1-score macro cnn1 : 0.824
# F1-score None cnn1 : [0.782 0.86  0.903 0.75 ]
#
# ------ Validation ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.565
# F1-score None cnn1 : [0.583 0.25  0.657 0.771]
#
# ------ Testing ------
# Accuracy cnn1 : 0.694
# F1-score macro cnn1 : 0.565
# F1-score None cnn1 : [0.583 0.25  0.657 0.771]
#
# ------ Training ------
# Accuracy cnn2 : 0.798
# F1-score macro cnn2 : 0.796
# F1-score None cnn2 : [0.705 0.835 0.914 0.729]
#
# ------ Validation ------
# Accuracy cnn2 : 0.662
# F1-score macro cnn2 : 0.523
# F1-score None cnn2 : [0.491 0.171 0.667 0.763]
# ------ Testing ------
# Accuracy cnn2 : 0.662
# F1-score macro cnn2 : 0.523
# F1-score None cnn2 : [0.491 0.171 0.667 0.763]
#
# ------ Training ------
# Accuracy rnn1 : 0.545
# F1-score macro rnn1 : 0.550
# F1-score None rnn1 : [0.643 0.484 0.671 0.4  ]
#
# ------ Validation ------
# Accuracy rnn1 : 0.448
# F1-score macro rnn1 : 0.432
# F1-score None rnn1 : [0.497 0.137 0.625 0.468]
#
# ------ Testing ------
# Accuracy rnn1 : 0.448
# F1-score macro rnn1 : 0.432
# F1-score None rnn1 : [0.497 0.137 0.625 0.468]
#
# ------ Training ------
# Accuracy rnn2 : 0.766
# F1-score macro rnn2 : 0.775
# F1-score None rnn2 : [0.766 0.796 0.86  0.676]
#
# ------ Validation ------
# Accuracy rnn2 : 0.633
# F1-score macro rnn2 : 0.462
# F1-score None rnn2 : [0.55  0.    0.582 0.717]
#
# ------ Testing ------
# Accuracy rnn2 : 0.633
# F1-score macro rnn2 : 0.462
# F1-score None rnn2 : [0.55  0.    0.582 0.717]
#
# ------ Training ------
# Accuracy rnn3 : 0.491
# F1-score macro rnn3 : 0.469
# F1-score None rnn3 : [0.532 0.287 0.622 0.433]
#
# ------ Validation ------
# Accuracy rnn3 : 0.448
# F1-score macro rnn3 : 0.387
# F1-score None rnn3 : [0.505 0.053 0.452 0.536]
#
# ------ Testing ------
# Accuracy rnn3 : 0.448
# F1-score macro rnn3 : 0.387
# F1-score None rnn3 : [0.505 0.053 0.452 0.536]

# %%
print ("--------- Usando contexto positivo y negativo obligadamente ---------\n")

for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("0.85 Clase Ponderado - F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("0.85 Clase Ponderado - F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("0.85 Clase Ponderado - Accuracy promedio para",key,":" ,temp/5 , "desvest: ",np.std(accs[key]))
# Out:
# --------- Usando contexto positivo y negativo obligadamente ---------
#
# 0.85 Clase Ponderado - F1-score promedio para cnn1 : [0.102 0.177 0.558 0.801]
# 0.85 Clase Ponderado - F1-score promedio para cnn2 : [0.074 0.19  0.547 0.774]
# 0.85 Clase Ponderado - F1-score promedio para rnn1 : [0.131 0.162 0.451 0.432]
# 0.85 Clase Ponderado - F1-score promedio para rnn2 : [0.078 0.171 0.434 0.675]
# 0.85 Clase Ponderado - F1-score promedio para rnn3 : [0.125 0.177 0.418 0.63 ]
#
# 0.85 Clase Ponderado - F1-score macro promedio para cnn1 : 0.40959171454047044 desvest:  0.010548607241628474
# 0.85 Clase Ponderado - F1-score macro promedio para cnn2 : 0.3964762709664503 desvest:  0.01964354197693595
# 0.85 Clase Ponderado - F1-score macro promedio para rnn1 : 0.2940818529473455 desvest:  0.08356388206630395
# 0.85 Clase Ponderado - F1-score macro promedio para rnn2 : 0.3395371040064944 desvest:  0.016278965297184603
# 0.85 Clase Ponderado - F1-score macro promedio para rnn3 : 0.33737064692794466 desvest:  0.04555663781285685
#
# 0.85 Clase Ponderado - Accuracy promedio para cnn1 : 0.6863858961802155 desvest:  0.04678938129472673
# 0.85 Clase Ponderado - Accuracy promedio para cnn2 : 0.6491674828599413 desvest:  0.06721329761671713
# 0.85 Clase Ponderado - Accuracy promedio para rnn1 : 0.3563173359451518 desvest:  0.14531205425808189
# 0.85 Clase Ponderado - Accuracy promedio para rnn2 : 0.5455435847208618 desvest:  0.11291282777164771
# 0.85 Clase Ponderado - Accuracy promedio para rnn3 : 0.49833496571988245 desvest:  0.08375924113670509
